# %% [markdown]
# # 👶 Baby Crib Monitoring Demo using VideoDB RTStream + TwelveLabs
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/integrations/twelvelabs/Baby_Crib_Monitoring_TwelveLabs.ipynb)
# ## 📖 Storytime: Why This Matters
#
# Meet **Vidit** and **Meghna** — a young couple juggling demanding jobs and household responsibilities. After a long, exhausting day, all they hope for is a peaceful night's sleep. But their energetic little one has other plans.
#
# Their child, once safely tucked into his crib, has recently discovered how to climb out. While the parents sleep, unaware, the baby risks injury by wandering unsupervised at night. How can they keep him safe without losing their much-needed rest?
#
# ---
#
# ## 🎥 Enter VideoDB RTStream
#
# **VideoDB** offers the perfect solution for this problem. Using **RTStream**, we can let AI continuously monitor a live video feed, index scenes, detect specific events like **baby attempting to climb out of the crib**, and instantly send alerts to the parents when something risky happens.
#
# In this demo, **Vidit and Meghna install an IP camera near the crib** and use **VideoDB RTStream** to power an AI monitoring system powered by **TwelveLabs Pegasus 1.2**.
# As soon as the baby makes a move to climb out, AI detects it, triggers an event, and fires a real-time alert so the parents can step in.
#
# ---
#
# ## 🚀 What You'll Build in This Notebook
#
# By the end of this notebook, you'll learn how to:
# - Connect a live RTSP video stream to VideoDB
# - Continuously analyze video scenes using AI-generated natural language descriptions
# - Detect specific events like *"baby escaping crib"*
# - Trigger real-time alerts on such events
#
# So — **do you want to build an intelligent AI-powered baby monitor too?**
# Let's get started!

# %% [markdown]
# ---
# ## 📦 Step 1: Install Dependencies
# Before setting up the AI-powered baby monitor, let's install the necessary VideoDB SDK.

# %%
# !pip install -q videodb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 3.3 MB/s eta 0:00:00

# %% [markdown]
# ---
# ## 📦 Step 2: Connect to VideoDB
#
# Let's connect to VideoDB's API using your credentials to prepare for stream monitoring.
#
# Your API key will be loaded from the `.env` file.

# %%
import videodb
import os
from getpass import getpass

api_key = getpass("Please enter your VideoDB API Key: ")

os.environ["VIDEO_DB_API_KEY"] = api_key

conn = videodb.connect()
coll = conn.get_collection()

print("Connected to VideoDB securely!")
# Out:
# Please enter your VideoDB API Key: ··········
# Connected to VideoDB securely!

# %% [markdown]
# ---
#
# ## 📦 Step 3: Connect to the Baby Crib RTSP Stream
# We'll now connect to the live video stream of the crib using its RTSP URL.
#
# In this demo, the stream is running at `rtsp://samples.rts.videodb.io:8554/crib`.

# %%
rtsp_url = "rtsp://samples.rts.videodb.io:8554/crib"
crib_stream = coll.connect_rtstream(
    name="Baby Crib Monitor",
    url=rtsp_url,
    store=True,
)
print(crib_stream)
# Out:
# RTStream(id=rts-019ec07e-9348-7e33-8659-0d922be0f4e1, name=Baby Crib Monitor, collection_id=c-5256e90f-4619-4451-9d23-071c1930bd34, created_at=2026-06-13T10:19:41.257030+00:00, sample_rate=30, status=connected, stream_url=None, player_url=None)

# %% [markdown]
# #### If you have already connected the stream, run the below cell with the **rtstream id** to reconnect.

# %%
# crib_stream = coll.get_rtstream("")

# %%
# To stop the stream
# crib_stream.stop()

# %%
# To start the stream
# crib_stream.start()

# %% [markdown]
# ---
# ### 👀 Let us have a look at the crib stream

# %% [markdown]
# #### 📺 Helper Functions: Search and Display
#
# This cell contains all the utility functions to search, fetch, and visualize video streams. You don't need to modify this code.

# %%
# To display the stream with relevant information

from IPython.display import HTML
import re
import time
from datetime import datetime, UTC
from videodb import play_stream


def display_stream(video_url, video_name="🎥 Camera Feed"):
    match = re.search(r"/(\d{16})-(\d{16})\.m3u8", video_url)
    if match:
        start_ts = int(match.group(1)) / 1e6
        end_ts = int(match.group(2)) / 1e6
        start_time = datetime.fromtimestamp(start_ts, UTC).strftime("%Y-%m-%d %H:%M:%S")
        end_time = datetime.fromtimestamp(end_ts, UTC).strftime("%Y-%m-%d %H:%M:%S")
        time_range = f"{start_time} → {end_time} UTC"
    else:
        time_range = "Time Unknown"

    video_player_html = play_stream(video_url)

    return HTML(f"""
    <div style="position:relative;width:640px;">
      {video_player_html._repr_html_() if hasattr(video_player_html, "_repr_html_") else video_player_html}
      <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
        <strong>{video_name}</strong><br>{time_range}
      </div>
    </div>
    """)


# To dynamically set the display duration


def prompt_to_time(prompt):
    now = int(time.time())
    prompt = (
        f"It's {now} in epoch seconds. "
        f"Convert the phrase '{prompt}' into JSON "
        f'with keys "from" and "to" (both epoch seconds)'
    )

    result = coll.generate_text(
        prompt=prompt,
        model_name="pro",
        response_type="json",
    )
    output = result.get("output", {})
    return output.get("from"), output.get("to")


# To fetch stream


def fetch_stream(rtstream):
    _from, to = prompt_to_time("Show me last 5 mins")
    rtstream.generate_stream(_from, to)
    return rtstream.stream_url

# %% [markdown]
# #### 🔗 Get & Display Recent Stream
#
# This cell uses the helper functions above to fetch and display the last few minutes of the stream.

# %%
# To get last few minutes stream link
video_url = fetch_stream(crib_stream)

video_name = "👶 Baby Monitor · Crib Activity Feed"
display_stream(video_url, video_name)
# Out:
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019ec07e-9348-7e33-8659-0d922be0f4e1/1781346415000000-1781346715000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>👶 Baby Monitor · Crib Activity Feed</strong><br>2026-06-13 10:26:55 → 2026-06-13 10:31:55 UTC
#       </div>
#     </div>

# %% [markdown]
# ---
#
# ## 📦 Step 4: Index Scenes with TwelveLabs Pegasus 1.2
# Now, we'll create a real-time scene index that periodically analyzes the video and generates natural language descriptions using the **TwelveLabs Pegasus 1.2** vision-language model.

# %% [markdown]
# The AI model will watch for activity such as the baby moving, sitting, or attempting to climb out.

# %%
crib_scene_index = crib_stream.index_visuals(
    batch_config={
        "type": "time",
        "value": 10,
        "frame_count": 6,
    },
    prompt="Describe the activity of the baby kept inside a baby crib. Notice if baby climbs out, is standing up in the crib or attempts to escape.",
    name="Baby_Crib_Index",
    model_name="twelvelabs-pegasus-1.2",
)
crib_index_id = crib_scene_index.rtstream_index_id
print("Scene Index ID:", crib_index_id)
# Out:
# Scene Index ID: 2b1a1d64a424f2c6

# %% [markdown]
# #### If you have already created a scene index, run the below cell with your **scene index id** to reconnect.

# %%
# crib_index_id = ""
# crib_scene_index = crib_stream.get_scene_index(crib_index_id)

# %%
# To stop the index
# crib_scene_index.stop()

# %%
# To start the index
# crib_scene_index.start()

# %% [markdown]
# ---
# ### Let us see the result of the scene indexing

# %%
import time
from datetime import datetime
from zoneinfo import ZoneInfo

def _convert_to_ist(timestamp: float) -> str:
    """Convert UTC timestamp to IST (Asia/Kolkata) datetime string."""
    return (
        datetime.fromtimestamp(timestamp)
        .astimezone(ZoneInfo("Asia/Kolkata"))
        .strftime("%Y-%m-%d %H:%M:%S")
    )

def get_scenes(index):
    scenes = index.get_scenes(page_size=5)
    if scenes and scenes.get("scenes"):
        for scene in scenes.get("scenes"):
            start = _convert_to_ist(scene["start"])
            end = _convert_to_ist(scene["end"])
            description = scene["description"]
            print(f"{start}-{end}: {description}")
            print("-" * 80)
    else:
        print("Scenes not found for given index. The index may still be processing.")

get_scenes(crib_scene_index)
# Out:
# 2026-06-13 17:18:39-2026-06-13 17:18:50: The baby in the white crib is actively attempting to escape.
#
# 1.  **Standing up in the crib:** Initially, the baby is standing upright in the crib, holding onto the top rail.
# 2.  **Attempts to escape/climbs out:** The baby then proceeds to climb out of the crib. They first get one leg over the top rail, then the other, straddling the rail.
# 3.  **Successful escape:** With a firm grip on the rail, the baby carefully lowers themselves down the outside of the crib until both feet are on the floor.
# 4.  **Out of the crib:** In the final image, the baby is standing completely outside the crib, having successfully climbed out.
# --------------------------------------------------------------------------------
# 2026-06-13 17:18:26-2026-06-13 17:18:37: The baby in the crib is highly active and is in the process of **attempting to climb out** of the crib.
#
# Here's a detailed description:
#
# *   **Standing Up:** The baby is clearly standing up in the crib, using the height of the mattress and possibly some toys inside to gain leverage.
# *   **Climbing Out/Attempting to Escape:** The baby is actively hoisting itself over the side rail of the wooden crib.
#     *   One leg (the baby's left leg, from the viewer's perspective) is already draped over the top rail and is outside the crib.
#     *   The other leg (the baby's right leg) is still inside the crib, bent at the knee, with the foot likely on the mattress or a pile of toys.
#     *   Both hands are gripping the top rail of the crib, providing support and leverage for the climb.
#     *   The baby's body is leaning forward and outward, indicating a strong intent to get out.
# *   **Appearance:** The baby has curly, light brown hair and is wearing green pajamas with a light pattern (possibly leaves or small animals). The baby's face is visible, looking downwards, seemingly concentrating on the task.
# *   **Crib Contents:** Inside the crib, there are several soft toys or stuffed animals, some appearing blue or green, which might be contributing to the baby's ability to reach the top rail.
# *   **Overall:** The baby is demonstrating advanced motor skills and a determined effort to escape the confines of the crib.
# --------------------------------------------------------------------------------
# 2026-06-13 17:18:13-2026-06-13 17:18:25: The images clearly show a highly active toddler engaged in various attempts to exit or observe from a wooden crib.
#
# Here's a breakdown of the activity:
#
# *   **Climbing out / Attempting to escape:** Yes, in the first four images, a toddler wearing blue shorts/jeans is depicted in the process of climbing out of a dark brown crib. Their bare feet and lower legs are dangling over the top rail, indicating they are mid-climb or have just successfully exited. In some of these frames, the child is already standing outside the crib, looking back at it, confirming a successful escape. A dog's face is visible through the crib slats in the background, seemingly observing the toddler's antics.
# *   **Standing up in the crib:** Yes, in the last two images, a different toddler (or the same child in different attire) is shown inside a lighter-colored wooden crib, wearing green patterned pajamas. This child is standing upright in the crib, holding onto the top rail and looking over it, clearly demonstrating they are standing up in the crib and likely contemplating or preparing for an escape attempt.
# --------------------------------------------------------------------------------
# 2026-06-13 17:18:01-2026-06-13 17:18:12: The images depict a baby actively engaged in escaping its crib.
#
# Here's a breakdown of the activity:
# *   **Standing up in the crib:** In multiple frames (e.g., image 1), the baby is clearly standing upright inside the crib, often with its hands gripping the top rail.
# *   **Attempts to escape/Climbs out:** The primary activity shown is the baby's determined effort to climb out.
#     *   In image 1, the baby is standing, facing away, with one leg already lifted high and bent, appearing to be in the process of getting it over the top rail.
#     *   Images 4, 5, and 6 show the baby in various stages of climbing over the side of the crib. Its hands are on the top rail, and its legs are actively maneuvering to get over and down to the floor.
# *   **Climbs out:** Image 2 explicitly shows the baby successfully out of the crib, standing on the floor next to it, looking back towards the crib.
#
# In summary, the baby is standing up in the crib, actively attempting to climb out, and is successful in escaping the crib.
# --------------------------------------------------------------------------------
# 2026-06-13 17:17:48-2026-06-13 17:17:59: The baby in the crib is highly active and is clearly attempting to escape.
#
# The sequence of images shows the baby in various stages of **climbing out** of the crib:
#
# *   In the initial frames, the baby has one leg (the right one) already swung over the side rail, dangling down, while the other leg is bent, pushing off the mattress or the top rail. The baby's arms are reaching up and over the crib side, gripping the top rail or an adjacent piece of furniture for leverage.
# *   As the sequence progresses, the baby successfully pulls itself further up.
# *   By the later frames, the baby is **standing upright on the narrow top rail of the crib**, using its arms to maintain balance by holding onto the crib post or an adjacent object. The baby's gaze is directed away from the crib, indicating its focus on getting out.
#
# Therefore, the baby is not merely standing up *in* the crib, but is actively and successfully **climbing out of it**, demonstrating a clear and determined **attempt to escape**.
# --------------------------------------------------------------------------------

# %% [markdown]
# ---
# ### 🔌 Step 5.5: Connect WebSocket for Real-Time Alerts
#
# Before creating an alert, connect to VideoDB's WebSocket server.

# %%
import asyncio

ws_wrapper = conn.connect_websocket()
ws = await ws_wrapper.connect()

print(f"WebSocket connected!")
print(f"Connection ID: {ws.connection_id}")
# Out:
# INFO:videodb.websocket_client:WebSocket connected with ID: gQ1tmY8RaeO4KAIQsA==
# WebSocket connected!
# Connection ID: gQ1tmY8RaeO4KAIQsA==

# %% [markdown]
# ---
# ## 📦 Step 5: Define an Event for Baby Escape
# We'll now create an event in VideoDB to detect when the AI spots the baby attempting to climb out.

# %%
event_id = conn.create_event(
    event_prompt="Detect if the baby is trying to escape or climbing out of the crib.",
    label="baby_escape",
)
print("Event ID:", event_id)
# Out:
# Event ID: d5b7e85ed4de38cd

# %% [markdown]
# ---
# ## 📦 Step 6: Attach an Alert for the Escape Event
# We'll link a real-time alert via WebSocket.

# %%
alert_id = crib_scene_index.create_alert(
    event_id,
    callback_url="",
    ws_connection_id=ws.connection_id
)
print("Alert ID:", alert_id)
# Out:
# Alert ID: 886f96a13a591e9c

# %% [markdown]
# ---
# ## 📦 Step 7: Listen for Real-Time Alerts
#
# Listen for incoming WebSocket alerts.

# %%
received_alerts = []

async def listen_for_alerts():
    timeout = 30
    print(f"Listening for alerts ({timeout} seconds)...")
    print("The baby monitor will trigger alerts when an escape attempt is detected\n")
    try:
        async with asyncio.timeout(timeout):
            async for msg in ws.receive():
                if msg.get("channel") == "alert":
                    received_alerts.append(msg)
                    data = msg.get("data", {})
                    print(f"\nALERT #{len(received_alerts)} RECEIVED!")
                    print(f"  Event     : {data.get('label', 'N/A')}")
                    print(f"  Time      : {msg.get('timestamp', 'N/A')}")
                    print(f"  Confidence: {data.get('confidence', 'N/A')}")
                    print(f"  Clip URL  : {data.get('stream_url', 'N/A')}")
                    print(f"  Details   : {data.get('explanation', 'N/A')}")
    except asyncio.TimeoutError:
        print(f"\nListening complete! {len(received_alerts)} alert(s) received")

await listen_for_alerts()
# Out:
# Listening for alerts (30 seconds)...
# The baby monitor will trigger alerts when an escape attempt is detected
#
#
# ALERT #1 RECEIVED!
#   Event     : baby_escape
#   Time      : 2026-06-13T11:50:09.143326+00:00
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec07e-9348-7e33-8659-0d922be0f4e1/1781351382000000-1781351394000000.m3u8
#   Details   : Both babies are explicitly described as actively attempting to escape or climbing out of their respective enclosures (crib and playpen), directly matching the alert context.
#
# ALERT #2 RECEIVED!
#   Event     : baby_escape
#   Time      : 2026-06-13T11:50:18.515164+00:00
#   Confidence: 0.95
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec07e-9348-7e33-8659-0d922be0f4e1/1781351395000000-1781351407000000.m3u8
#   Details   : The scene analysis explicitly states that babies are 'climbing out,' 'escaping,' and 'attempting to escape' from their cribs in multiple instances, directly matching the alert context.
#
# Listening complete! 2 alert(s) received

# %%
if received_alerts:
    first = received_alerts[0]
    clip_url = first.get("data", {}).get("stream_url")
    video_name = f"Baby Monitor · {first['data']['label']}"
    display(display_stream(clip_url, video_name))
else:
    print("No alerts received yet.")
# Out:
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019ec07e-9348-7e33-8659-0d922be0f4e1/1781351382000000-1781351394000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>Baby Monitor · baby_escape</strong><br>2026-06-13 11:49:42 → 2026-06-13 11:49:54 UTC
#       </div>
#     </div>

# %% [markdown]
# ---
# ## Cleanup
#
# Close the WebSocket, disable the alert, and stop the stream.

# %%
await ws_wrapper.close()
print("WebSocket closed")

crib_scene_index.disable_alert(alert_id)
print("Alert disabled")
# Out:
# WebSocket closed
# Alert disabled

# %% [markdown]
# - Stop the stream when fully done:

# %%
crib_stream.stop()
print("Stream stopped")
# Out:
# Stream stopped

# %% [markdown]
# <div style="background-color: #d4edda; color: #155724; padding: 12px; border-left: 5px solid #28a745; border-radius: 4px;">
#     <strong>🎉 Success!</strong> You've built a complete AI-powered baby crib monitoring system — from stream connection to real-time WebSocket alerts!
# </div>

# %% [markdown]
# **💡 What just happened?**
#
# - We connected to VideoDB's WebSocket for real-time event delivery
# - Created an alert that triggers when baby escape attempts are detected
# - Listened for 30 seconds and automatically received alerts
# - Each alert includes a video clip showing the exact moment of detection
#
# **⚡ Why WebSockets?**
# - **Instant delivery**: Alerts arrive in real-time as events happen
# - **Live dashboards**: Perfect for building interactive monitoring interfaces
# - **Two-way communication**: Can send and receive data on the same connection
#
# > **💡 Alternative: Webhooks**
# > You can also use webhooks for server-to-server delivery by providing a `callback_url` instead of `ws_connection_id`. Webhooks are great for automation workflows.

# %% [markdown]
# ---
#
# # 🏁 Conclusion: Baby Monitor, Reimagined
#
# Congratulations! You've successfully built a real-time AI baby crib monitor with VideoDB.
#
# ### What You Accomplished
#
# **👁️ SEE:**
# - ✅ Connected to the baby crib RTSP stream
# - ✅ Previewed live feed from the camera
#
# **🧠 UNDERSTAND:**
# - ✅ Indexed visual content with AI scene descriptions
# - ✅ Reviewed detected scenes
#
# **🎬 ACT:**
# - ✅ Created event detection for baby escape attempts
# - ✅ Received real-time WebSocket alerts
# - ✅ Replayed alert clips with explanations
#
# ---
#
# **Build the future of child safety with VideoDB — real-time AI for every parent.** 🎬
