# %% [markdown]
# # Flash Flood Detection with VideoDB RTStream
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/real_time_streaming/Flash_Flood_Detection.ipynb)
#
# This notebook builds a real-time environmental safety monitor for a flood-prone desert riverbed.
#
# You will use VideoDB RTStream to:
#
# - Connect to a live flood-monitoring RTSP feed.
# - Preview recent riverbed footage.
# - Continuously understand the stream with a VLM.
# - Continuously index the VLM output for search and alerts.
# - Detect flash floods, heavy rainfall, and possible rescue situations.
# - Receive WebSocket alerts and display evidence clips when available.
#
# After connecting the RTStream, wait 1-2 minutes before running this cell so VideoDB has enough buffered footage to generate a recent playback window.

# %% [markdown]
# ## 1. Install VideoDB
#
# Install VideoDB and notebook dependencies.

# %%
# !pip install -q videodb python-dotenv

# %% [markdown]
# ## 2. Connect to VideoDB
#
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import os
import time
import asyncio
from datetime import datetime
from getpass import getpass
from uuid import uuid4

from IPython.display import display
from videodb import connect, play_stream

api_key = getpass("Enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key

conn = connect()
coll = conn.get_collection()

print("Connected to VideoDB successfully.")
# Out:
# Enter your VideoDB API Key: ··········
# Connected to VideoDB

# %% [markdown]
# ## 3. Connect to the Arizona Flood RTSP Feed
#
# This sample feed monitors a flood-prone desert riverbed. If you already created an RTStream, you can reconnect by ID instead of creating a new stream.

# %%
rtsp_url = "rtsp://samples.rts.videodb.io:8554/floods"

flood_stream = coll.connect_rtstream(
    name="Arizona Flash Flood Monitor",
    url=rtsp_url,
    store=True,
)

print(f"RTStream ID: {flood_stream.id}")
print(f"Status: {flood_stream.status}")
# Out:
# RTStream ID: rts-019f3f5a-eac8-7740-88f5-82b5b24114ac
# Status: connected

# %%
# Reconnect to an existing stream instead of creating a new one:
# flood_stream = coll.get_rtstream("your-rtstream-id")

# %% [markdown]
# ## 4. Preview Recent Stream Footage
#
# RTStream playback uses Unix timestamps. Connect WebSocket, generate a recent stream window, then play `flood_stream.stream_url`.

# %%
# Connect WebSocket
ws_wrapper = conn.connect_websocket()
ws = await ws_wrapper.connect()
print(f"WebSocket connected! Connection ID: {ws.connection_id}")

# Preview last 2 minutes
now = int(time.time())
flood_stream.generate_stream(now - 120, now)
play_stream(flood_stream.stream_url)
# Out:
# INFO:videodb.websocket_client:WebSocket connected with ID: gTXr9O-OLQAYKEh3WA==
# WebSocket connected! Connection ID: gTXr9O-OLQAYKEh3WA==
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://videodb-rt-streaming-service-us-east-1.s3.us-east-1.amazonaws.com/manifests/rts-019f3f5a-eac8-7740-88f5-82b5b24114ac/1783474303000000-1783474423000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 5. Start Continuous Riverbed Understanding
#
# For RTStreams, `understand()` runs continuously. Here a VLM inspects every 7-second window and describes flood, rainfall, and rescue-relevant conditions.

# %%
riverbed_prompt = """
Monitor the desert riverbed and surrounding area for environmental safety risks.

Look for:
1. FLASH FLOOD: sudden moving water, muddy turbulent flow, or a dry riverbed rapidly filling with water.
2. HEAVY RAINFALL: visible strong rain, dark storm conditions, or rainfall that could trigger flooding.
3. HUMAN RESCUE: any person stranded, trapped, walking through floodwater, or needing assistance near the riverbed.

If a risk is visible, describe it with this structure:
Environmental Alert
Alert Type: flash_flood, heavy_rainfall, human_rescue, or multiple
Risk Level: low, medium, or high
Evidence: brief visual evidence
Recommended Action: concise next step

If no risk is visible, respond with:
No Environmental Risk Detected
"""

riverbed_understanding = flood_stream.understand(
    segmentation={"type": "time", "window": "7s"},
    analyzers=[
        {
            "type": "vlm",
            "name": "scene",
            "sampling": {"frame_count": 5},
            "config": {
                "model": "pro",
                "prompt": riverbed_prompt,
            },
        }
    ],
    store=True,
    ws_connection_id=ws.connection_id,
)

print(f"Understanding ID: {riverbed_understanding.id}")
print(f"Status: {riverbed_understanding.status}")
# Out:
# Understanding ID: und-14c8618f9e0ac450
# Status: running

# %% [markdown]
# ## 6. Continuously Index the Understanding Output
#
# The VLM output is a continuous source. `rtstream.index()` keeps indexing new windows as they are produced.

# %%
RIVERBED_INDEX_NAME = f"flash_flood_monitor_{uuid4().hex[:8]}"

riverbed_index = flood_stream.index(
    name=RIVERBED_INDEX_NAME,
    source=riverbed_understanding.outputs["scene"],
    use_for=["semantic"],
)

riverbed_index_id = getattr(riverbed_index, "id", riverbed_index)

if not hasattr(riverbed_index, "get_records"):
    print("Waiting for riverbed index to become available...")
    while True:
        try:
            riverbed_index = flood_stream.get_index(riverbed_index_id)
            break
        except Exception as exc:
            if "not found" not in str(exc).lower():
                raise
            time.sleep(5)

print(f"Index name: {RIVERBED_INDEX_NAME}")
print(f"Index ID: {riverbed_index_id}")
print(f"Status: {getattr(riverbed_index, 'status', 'running')}")
# Out:
# Index name: flash_flood_monitor_715c8238
# Index ID: idx-2f5d1db2410b2023
# Status: running

# %% [markdown]
# ## 7. Inspect Recent Indexed Windows
#
# RTStream understanding and indexing jobs stay `running` while the live feed is active. This cell checks recent indexed VLM windows before search and alerts.

# %%
def format_ts(ts):
    try:
        return datetime.fromtimestamp(float(ts)).strftime("%Y-%m-%d %H:%M:%S")
    except Exception:
        return str(ts)


def extract_record_text(record):
    data = record.get("data") if isinstance(record, dict) else None
    if isinstance(data, dict):
        return data.get("text") or data.get("description") or data.get("scene_description") or str(data)
    return record.get("text") or record.get("description") or str(record)


def get_recent_records(index, page_size=5):
    end = int(time.time()) - 30
    start = end - 300

    try:
        payload = index.get_records(start=start, end=end, page=1, page_size=page_size)
    except TypeError:
        payload = index.get_records(page_size=page_size)

    if isinstance(payload, dict):
        return payload.get("records") or payload.get("scenes") or []
    return payload or []


def wait_for_records(index, timeout=300, poll_interval=10):
    deadline = time.time() + timeout
    while time.time() < deadline:
        records = get_recent_records(index)
        if records:
            return records
        time.sleep(poll_interval)
    raise RuntimeError(
        "No indexed records were available yet. Confirm the RTStream preview is playable and the understanding/index jobs are running."
    )


print("Waiting for indexed riverbed observations. This can take 1-3 minutes...")
recent_records = wait_for_records(riverbed_index)

for record in recent_records[:5]:
    start = format_ts(record.get("start"))
    end = format_ts(record.get("end"))
    print("-" * 80)
    print(f"{start} -> {end}")
    print(extract_record_text(record))
# Out:
# Waiting for indexed riverbed observations. This can take 1-3 minutes...
# --------------------------------------------------------------------------------
# 2026-07-08 01:34:46 -> 2026-07-08 01:34:54
# Environmental Alert
# Alert Type: flash_flood
# Risk Level: medium
# Evidence: muddy, turbulent water and foam clearly flowing through a narrow desert riverbed and filling the channel.
# Recommended Action: avoid the riverbed and low-lying areas, move to higher ground, warn others nearby, and notify local emergency services if flow increases.
# --------------------------------------------------------------------------------
# 2026-07-08 01:34:36 -> 2026-07-08 01:34:44
# Environmental Alert
# Alert Type: multiple
# Risk Level: high
# Evidence: active turbulent runoff visible in the river channel and dark storm clouds approaching; shadows show people near the riverbed.
# ...

# %% [markdown]
# ## 8. Search for Safety Risks
#
# Search the indexed stream windows for flood, rainfall, or rescue-related moments and review matching timestamps and descriptions. Evidence clips are displayed from real-time alert payloads in the alert section.

# %%
query = "flash flood, heavy rainfall, stranded person, rescue needed, water surge in riverbed"

try:
    safety_results = flood_stream.search(
        query=query,
        index_id=riverbed_index_id,
        score_threshold=0.4,
    )
    shots = getattr(safety_results, "shots", None) or safety_results.get_shots()
except Exception as exc:
    print(f"No searchable safety results yet: {exc}")
    shots = []

if shots:
    for idx, shot in enumerate(shots[:5], start=1):
        text = getattr(shot, "text", "") or getattr(shot, "description", "")
        print(f"{idx}. {format_ts(shot.start)} -> {format_ts(shot.end)}")
        print(text[:500])
        print()
else:
    print("No matching windows yet. Let the stream run longer or lower the score threshold.")
# Out:
# 1. 2026-07-08 01:34:17 -> 2026-07-08 01:34:25
# Environmental Alert
# Alert Type: heavy_rainfall
# Risk Level: medium
# Evidence: dark storm clouds visible on the horizon over the dry riverbed — low-lying channel could fill quickly.
# Recommended Action: move people off and away from the riverbed to higher ground, avoid entering the channel, and monitor local weather/flash‑flood warnings.
#
# 2. 2026-07-08 01:34:27 -> 2026-07-08 01:34:35
# Environmental Alert
# Alert Type: heavy_rainfall
# Risk Level: medium
# Evidence: dark, low storm clouds and rain bands visible on the horizon above the dry river channel
# Recommended Action: move to higher ground away from the wash, avoid entering the riverbed, monitor weather/flash-flood warnings and notify local emergency services if rainfall increases
#
# 3. 2026-07-08 01:34:36 -> 2026-07-08 01:34:44
# Environmental Alert
# Alert Type: multiple
# Risk Level: high
# ...

# %% [markdown]
# ## 9. Create Environmental Safety Events
#
# Events define what should trigger alerts. This notebook creates events for flash floods, heavy rainfall, and human rescue situations.

# %%
flash_flood_event_id = conn.create_event(
    event_prompt="Detect sudden flash floods, water surges, or rapidly moving water in the riverbed.",
    label="flash_flood",
)

rainfall_event_id = conn.create_event(
    event_prompt="Detect heavy rainfall or storm conditions that may lead to flooding.",
    label="heavy_rainfall",
)

rescue_event_id = conn.create_event(
    event_prompt="Detect a person stranded, trapped, or needing rescue near floodwater or the riverbed.",
    label="human_rescue",
)

event_ids = {
    "flash_flood": flash_flood_event_id,
    "heavy_rainfall": rainfall_event_id,
    "human_rescue": rescue_event_id,
}

for label, event_id in event_ids.items():
    print(f"{label}: {event_id}")
# Out:
# flash_flood: 2c4bce90eaf2de01
# heavy_rainfall: e519615b8c2f88b6
# human_rescue: 6f03395ffc4d8ed9

# %% [markdown]
# ## 10. Attach Alerts
#
# Attach alerts to the riverbed index and receive alert events over the existing WebSocket. The callback URL is used for server-to-server delivery.

# %%
WEBHOOK_URL = "https://example.com/videodb-alerts"

alert_ids = {}
for label, event_id in event_ids.items():
    alert_ids[label] = riverbed_index.create_alert(
        event_id=event_id,
        callback_url=WEBHOOK_URL,
        ws_connection_id=ws.connection_id,
    )
    print(f"{label} alert: {alert_ids[label]}")
# Out:
# flash_flood alert: 839faed047505c86
# heavy_rainfall alert: 12b36b37a5758c70
# human_rescue alert: 4ae22f2b82917f8d

# %% [markdown]
# ## 11. Listen for Real-Time Alerts
#
# The listener runs for 30 seconds. If alerts arrive, the next cell can display the evidence clips.

# %%
received_alerts = []


async def listen_for_alerts(timeout=30):
    print(f"Listening for environmental safety alerts ({timeout} seconds)...")
    try:
        async with asyncio.timeout(timeout):
            async for msg in ws.receive():
                if msg.get("channel") != "alert":
                    continue

                received_alerts.append(msg)
                data = msg.get("data", {})
                print(f"\nAlert #{len(received_alerts)}")
                print(f"Label: {data.get('label', 'N/A')}")
                print(f"Confidence: {data.get('confidence', 'N/A')}")
                print(f"Explanation: {data.get('explanation', 'N/A')}")
    except asyncio.TimeoutError:
        print(f"\nListening complete. Alerts received: {len(received_alerts)}")
    except Exception as exc:
        print(f"\nWebSocket closed while listening: {exc}")
        print("Reconnect WebSocket, recreate alerts with the new connection ID, then listen again.")


await listen_for_alerts()
# Out:
# Listening for environmental safety alerts (30 seconds)...
#
# Alert #1
# Label: flash_flood
# Confidence: 0.97
# Explanation: Muddy, turbulent flow in a normally dry river channel together with storm clouds and a person in/near the water are strong indicators of a flash flood or rapid surge risk; immediate evacuation and emergency notification are warranted.
#
# Alert #2
# Label: heavy_rainfall
# Confidence: 0.95
# Explanation: Muddy, turbulent flow in a normally dry river channel combined with storm clouds and a person in/near the water indicates an imminent flash-flood hazard; immediate evacuation and emergency services are warranted.
#
# Alert #3
# Label: human_rescue
# Confidence: 0.96
# Explanation: A person is standing in a dry river channel with muddy, turbulent flow and dark storm clouds/rain visible, indicating imminent flash flood danger and warranting immediate evacuation and emergency response.
#
# Alert #4
# Label: flash_flood
# Confidence: 0.78
# ...

# %%
if received_alerts:
    for idx, alert in enumerate(received_alerts[:4], start=1):
        data = alert.get("data", {})
        clip_url = data.get("stream_url")

        print(f"\nAlert #{idx}")
        print(f"Label: {data.get('label', 'N/A')}")
        print(f"Confidence: {data.get('confidence', 'N/A')}")
        print(f"Explanation: {data.get('explanation', 'N/A')}")

        if clip_url:
            display(play_stream(clip_url))
        else:
            print("No evidence clip URL was included in this alert payload.")
else:
    print("No alerts received yet. Keep the stream running and listen again.")
# Out:
# Alert #1
# Label: flash_flood
# Confidence: 0.97
# Explanation: Muddy, turbulent flow in a normally dry river channel together with storm clouds and a person in/near the water are strong indicators of a flash flood or rapid surge risk; immediate evacuation and emergency notification are warranted.
# No evidence clip URL was included in this alert payload.
#
# Alert #2
# Label: heavy_rainfall
# Confidence: 0.95
# Explanation: Muddy, turbulent flow in a normally dry river channel combined with storm clouds and a person in/near the water indicates an imminent flash-flood hazard; immediate evacuation and emergency services are warranted.
# No evidence clip URL was included in this alert payload.
#
# Alert #3
# Label: human_rescue
# Confidence: 0.96
# Explanation: A person is standing in a dry river channel with muddy, turbulent flow and dark storm clouds/rain visible, indicating imminent flash flood danger and warranting immediate evacuation and emergency response.
# ...

# %% [markdown]
# ## 12. Alert Management and Cleanup
#
# Disable alerts and stop continuous jobs when you finish the demo to avoid unnecessary processing.

# %%
for label, alert_id in alert_ids.items():
    try:
        riverbed_index.disable_alert(alert_id)
        print(f"{label} alert disabled")
    except Exception as exc:
        print(f"{label} alert cleanup skipped: {exc}")

try:
    riverbed_index.stop()
    print("Index stopped")
except Exception as exc:
    print(f"Index stop skipped: {exc}")

try:
    riverbed_understanding.stop()
    print("Understanding stopped")
except Exception as exc:
    print(f"Understanding stop skipped: {exc}")

try:
    await ws_wrapper.close()
    print("WebSocket closed")
except Exception as exc:
    print(f"WebSocket cleanup skipped: {exc}")

try:
    flood_stream.stop()
    print("RTStream stopped")
except Exception as exc:
    print(f"RTStream stop skipped: {exc}")
# Out:
# flash_flood alert disabled
# heavy_rainfall alert disabled
# human_rescue alert disabled
# Index stopped
# Understanding stopped
# WebSocket closed
# RTStream stopped

# %% [markdown]
# ## Further Resources
#
# - [Understand and Index RTStreams](https://videodb-docs-indexing-search-v2.mintlify.app/pages/ingest/live-streams/rtstream-understand-index)
# - [Search and Retrieval](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/search-and-retrieval/natural-language-query)
#
# You now have a complete RTStream environmental-safety loop: live feed -> continuous visual understanding -> continuous index -> search and alerts -> evidence playback.
