# %% [markdown]
# # 🌊 Flash Flood Detection in Arizona Using VideoDB RTStream
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/real_time_streaming/Flash_Flood_Detection.ipynb)
#
# ## 📖 Storytime: Why This Matters
#
# The stunning Arizona deserts, known for their dry riverbeds and scenic beauty, hide a deadly risk.
# During the summer monsoon, sudden torrential rains can trigger **flash floods** in these seemingly harmless dry zones — with little or no warning.
#
# Conventional alert systems relying on rain gauges or weather satellites often fail to deliver timely, location-specific warnings. By the time a danger alert is sent, it might already be too late.
#
# **But we have a smarter way.**
#
# With **VideoDB RTStream**, we can install real-time cameras near flood-prone areas and let AI continuously monitor the visuals.
# As soon as the AI detects signs of a flash flood — like a sudden surge of water through dry land — it can instantly send alerts, giving local authorities and tourists precious moments to act.
#
# ---
#
# ## 🚀 What You’ll Build in This Notebook
#
# In this notebook, we’ll create a real-time flash flood detection system using **VideoDB RTStream**.
# By the end of this demo, you’ll learn how to:
# - Connect a live video stream to VideoDB
# - Use AI to continuously analyze scenes for signs of a flash flood
# - Detect a **flash flood event**
# - Trigger a real-time alert when detected
#
# Let’s build it together!

# %% [markdown]
# ---
#
# ## 📦 Step 1: Install Dependencies
#
# Before setting up our AI-powered flood monitor, let’s install the required VideoDB SDK.

# %%
# !pip install -q videodb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.3/70.3 kB 2.3 MB/s eta 0:00:00

# %% [markdown]
# ---
# ## 📦 Step 2: Connect to VideoDB
#
# Let's connect to VideoDB's API using your credentials to prepare for stream monitoring.
#
# Please enter your `VIDEO_DB_API_KEY` in the input box that appears below after you run this cell.
#
# Your input will be masked.

# %%
import videodb
import os
from getpass import getpass

api_key = getpass("Please enter your VideoDB API Key: ")

os.environ["VIDEO_DB_API_KEY"] = api_key

conn = videodb.connect()
coll = conn.get_collection()

print("Connected to VideoDB securely!")
# Out:
# Please enter your VideoDB API Key: ··········
# Connected to VideoDB securely!

# %% [markdown]
# ---
#
# ## 📦 Step 3: Connect to the Arizona Flood RTSP Stream
#
# Connect to the live camera stream monitoring a flood-prone desert area.
#
# In this demo, the stream is running at `rtsp://samples.rts.videodb.io:8554/floods`.

# %%
rtsp_url = "rtsp://samples.rts.videodb.io:8554/floods"
flood_stream = coll.connect_rtstream(
    name="Arizona Flood Stream",
    url=rtsp_url,
    store=True,
)
print(flood_stream)
# Out:
# RTStream(id=rts-019ec145-ff1c-7903-9b07-7f728a38bcff, name=Arizona Flood Stream, collection_id=c-5256e90f-4619-4451-9d23-071c1930bd34, created_at=2026-06-13T13:57:30.525000+00:00, sample_rate=30, status=connected, stream_url=None, player_url=None)

# %% [markdown]
# #### Let us list all the rtstreams in our collection.

# %%
def list_rtstreams():
    for rtstream in coll.list_rtstreams():
        print(f"""RTStream:
        ID            : {rtstream.id}
        Name          : {rtstream.name}
        Collection ID : {rtstream.collection_id}
        Created At    : {rtstream.created_at}
        Sample Rate   : {rtstream.sample_rate}
        Status        : {rtstream.status}
        """)
        print("-" * 80)

list_rtstreams()
# Out:
# RTStream:
#         ID            : rts-019ec145-ff1c-7903-9b07-7f728a38bcff
#         Name          : Arizona Flood Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T13:57:30.525000+00:00
#         Sample Rate   : 30
#         Status        : connected
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec13f-81be-77e1-ac01-7ffd8d1d4c45
#         Name          : Cricket Finals Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T13:50:25.214196+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec13a-efed-7de2-a74f-87cbe2323bd5
#         Name          : Baby Crib Monitor
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T13:45:25.741229+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec135-a980-7132-8f3e-f411a80d72d1
#         Name          : Baby Crib Monitor
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T13:39:40.032407+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec12b-df5c-77e1-b24e-f50f791980e8
#         Name          : Baby Crib Monitor
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T13:28:58.460948+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec11b-d824-7ad0-9cf4-eb1926e7c848
#         Name          : Arizona Flood Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T13:11:28.036867+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec101-bcaa-73a0-92e8-c1d4bfccc410
#         Name          : Arizona Flood Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T12:42:57.066625+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec100-0bf3-7a81-9106-dc286f9715d7
#         Name          : Arizona Flood Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T12:41:06.291336+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec0eb-e5fb-70f0-8ff4-1a40634d6bb9
#         Name          : Arizona Flood Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T12:19:05.851140+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec0e7-012f-7042-8e24-1f5cec83aa3d
#         Name          : Arizona Flood Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T12:13:45.135250+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------

# %% [markdown]
# #### If you have already connected the stream, run the below cell with the **rtstream id** to reconnect.

# %%
# flood_stream = coll.get_rtstream("")

# %%
# flood_stream.stop()
# print("Stream stopped")

# %%
# To start the stream
# flood_stream.start()

# %% [markdown]
# ---
# ### 👀 Let's have a look at the riverbed

# %% [markdown]
# #### 📺 Helper Functions: Search and Display
#
# This cell contains all the utility functions to search, fetch, and visualize video streams. You don't need to modify this code.

# %%
# To display the stream with relevant information

from IPython.display import HTML
import re
import time
from datetime import datetime, UTC
from videodb import play_stream


def display_stream(video_url, video_name="🎥 Camera Feed"):
    match = re.search(r"/(\d{16})-(\d{16})\.m3u8", video_url)
    if match:
        start_ts = int(match.group(1)) / 1e6
        end_ts = int(match.group(2)) / 1e6
        start_time = datetime.fromtimestamp(start_ts, UTC).strftime("%Y-%m-%d %H:%M:%S")
        end_time = datetime.fromtimestamp(end_ts, UTC).strftime("%Y-%m-%d %H:%M:%S")
        time_range = f"{start_time} → {end_time} UTC"
    else:
        time_range = "Time Unknown"

    video_player_html = play_stream(video_url)

    return HTML(f"""
    <div style="position:relative;width:640px;">
      {video_player_html._repr_html_() if hasattr(video_player_html, "_repr_html_") else video_player_html}
      <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
        <strong>{video_name}</strong><br>{time_range}
      </div>
    </div>
    """)


# To dynamically set the display duration


def prompt_to_time(prompt):
    now = int(time.time())
    prompt = (
        f"It's {now} in epoch seconds. "
        f"Convert the phrase '{prompt}' into JSON "
        f'with keys "from" and "to" (both epoch seconds)'
    )

    result = coll.generate_text(
        prompt=prompt,
        model_name="pro",
        response_type="json",
    )
    output = result.get("output", {})
    return output.get("from"), output.get("to")


# To fetch stream


def fetch_stream(rtstream):
    _from, to = prompt_to_time("Show me last 5 mins")
    rtstream.generate_stream(_from, to)
    return rtstream.stream_url

# %% [markdown]
# #### 🔗 Get & Display Recent Stream
#
# This cell uses the helper functions above to fetch and display the last few minutes of the stream.

# %%
# To get last few minutes stream link

video_url = fetch_stream(flood_stream)

video_name = "🌊 Arizona Desert · Flash Flood Detection"
display_stream(video_url , video_name)
# Out:
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781358868000000-1781359168000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>🌊 Arizona Desert · Flash Flood Detection</strong><br>2026-06-13 13:54:28 → 2026-06-13 13:59:28 UTC
#       </div>
#     </div>

# %% [markdown]
# ---
#
# ## 📦 Step 4: Index Scenes and Detect Flash Floods
#
# We’ll create a real-time scene index that periodically analyzes video frames and generates natural language descriptions of what’s happening in the stream.
#
# The AI will look for sudden visual cues of water flooding dry land and describe them.

# %%
flood_scene_index = flood_stream.index_visuals(
    batch_config={
        "type": "time",
        "value": 5,
        "frame_count": 3,
    },
    prompt="Monitor the dry riverbed and surrounding area. If moving water is detected across the land, identify it as a flash flood and describe the scene.",
    name="Flash_Flood_Detection_Index"
)
flood_index_id = flood_scene_index.rtstream_index_id
print("Scene Index ID:", flood_index_id)
# Out:
# Scene Index ID: 644e99cf63d55a7b

# %% [markdown]
# #### Let us list the scene indexes created on our rtstream.

# %%
def list_rtstream_indexes(rtstream):
    # List live stream indexes
    rtstream_indexes = rtstream.list_scene_indexes()
    for rtstream_index in rtstream_indexes:

        print(f"""RTStreamSceneIndex:
            Index ID       : {rtstream_index.rtstream_index_id}
            RTStream ID    : {rtstream_index.rtstream_id}
            Name           : {rtstream_index.name}
            Status         : {rtstream_index.status}
            Config         : {rtstream_index.extraction_config}
            Prompt         : {rtstream_index.prompt}
        """)
        print("-" * 80)

list_rtstream_indexes(flood_stream)
# Out:
# RTStreamSceneIndex:
#             Index ID       : 644e99cf63d55a7b
#             RTStream ID    : rts-019ec145-ff1c-7903-9b07-7f728a38bcff
#             Name           : Flash_Flood_Detection_Index
#             Status         : running
#             Config         : {'frame_count': '3', 'time': '5'}
#             Prompt         : Monitor the dry riverbed and surrounding area. If moving water is detected across the land, identify it as a flash flood and describe the scene.
#
# --------------------------------------------------------------------------------

# %% [markdown]
# #### If you have already created a scene index, run the below cell with your **scene index id** to reconnect.

# %%
# flood_index_id = ""
# flood_scene_index = flood_stream.get_scene_index(flood_index_id)

# %%
# To stop the index
# flood_scene_index.stop()

# %%
# To start the index
# flood_scene_index.start()

# %% [markdown]
# ---
# ### Let us see the result of the scene indexing

# %%
import time
from datetime import datetime
from zoneinfo import ZoneInfo

def _convert_to_ist(timestamp: float) -> str:
    """Convert UTC timestamp to IST (Asia/Kolkata) datetime string."""
    return (
        datetime.fromtimestamp(timestamp)
        .astimezone(ZoneInfo("Asia/Kolkata"))
        .strftime("%Y-%m-%d %H:%M:%S")
    )

def get_scenes(index):
    # Print indexed scenes
    scenes = index.get_scenes(page_size=5)
    if scenes:
        for scene in scenes.get("scenes"):
            start = _convert_to_ist(scene["start"])
            end = _convert_to_ist(scene["end"])
            description = scene["description"]
            print(f"{start}-{end}: {description}")
            print("-" * 80)
    else:
        print("Scenes not found for given index.")

get_scenes(flood_scene_index)
# Out:
# 2026-06-13 19:30:08-2026-06-13 19:30:15: **Flash Flood Detected!**
#
# The images show a rapid and significant increase in water flow through what appears to be a previously dry or low-flow riverbed.
#
# **Description of the scene:**
# A flash flood is actively occurring in a rocky, reddish-brown canyon or riverbed. The water, initially present in a smaller, somewhat clearer stream (Image 1), has rapidly transformed into a powerful, turbulent, and muddy torrent (Image 3). The water is now a dark, sediment-laden brown, churning with white foam as it rushes over and around the numerous large rocks that form the riverbed. The flow is strong enough to create visible rapids and fill a substantial portion of the channel. The surrounding area consists of arid landscape with sparse, scrubby vegetation and more reddish rock formations under a partly cloudy sky. The sudden surge and muddy appearance of the water are clear indicators of a flash flood event.
# --------------------------------------------------------------------------------
# 2026-06-13 19:30:00-2026-06-13 19:30:07: Moving water is detected in the riverbed.
#
# **Flash Flood Detected:** A flash flood is surging through the rocky riverbed.
#
# **Scene Description:**
# The scene depicts a flash flood actively flowing through a deeply incised, reddish-brown canyon or riverbed. Turbulent, white-foamed water rushes over and around numerous boulders and sculpted rock formations that line the channel. The current appears strong, creating ripples and froth as it navigates the rocky terrain. The riverbed itself is composed of large, angular and rounded rocks, some of which are partially submerged by the rapidly moving water. In the background, the landscape shows sparse, scrubby vegetation and more reddish earth under a partly cloudy sky, characteristic of an arid or semi-arid region where such sudden water events are common. Sunlight casts dramatic shadows across the textured rock walls, highlighting the depth and ruggedness of the environment.
# --------------------------------------------------------------------------------
# 2026-06-13 19:29:53-2026-06-13 19:29:59: Flash flood detected!
#
# **Description of the scene:**
# The previously dry, reddish-brown rocky riverbed is now filled with rapidly moving water. A surge of light-colored, turbulent water is flowing through the narrow, carved-out channel, indicating a significant and sudden influx. The water appears to be moving from the background towards the foreground, navigating the irregular rock formations. The surrounding landscape consists of sparse desert vegetation under a cloudy sky.
# --------------------------------------------------------------------------------
# 2026-06-13 19:29:45-2026-06-13 19:29:51: There is no moving water detected in the dry riverbed or the surrounding area in the provided images. The scene shows a rocky, reddish-brown dry riverbed under a partly cloudy sky, with sparse vegetation on the banks.
# --------------------------------------------------------------------------------

# %% [markdown]
# ---
# ### 🔌 Step 4.5: Connect WebSocket for Real-Time Alerts
#
# Before creating alerts, connect to VideoDB's WebSocket server.

# %%
import asyncio

ws_wrapper = conn.connect_websocket()
ws = await ws_wrapper.connect()

print(f"WebSocket connected!")
print(f"Connection ID: {ws.connection_id}")
# Out:
# INFO:videodb.websocket_client:WebSocket connected with ID: gQ2T8g6IYeO4KAIngA==
# WebSocket connected!
# Connection ID: gQ2T8g6IYeO4KAIngA==

# %% [markdown]
# ## 🎤 Audio Indexing & Transcription
#
# VideoDB RTStream also supports audio analysis for streams with audio content. You can:
# - **Index Audio**: Extract structured information from audio streams using AI prompts
# - **Start Transcription**: Get real-time speech-to-text transcription
#
# These features work alongside visual indexing to provide comprehensive stream analysis.

# %%
# # Audio Indexing Example (if stream has audio)
# audio_index = flood_stream.index_audio(
#     prompt="Detect sounds of rushing water, wind, rain, and warning sirens. Extract information about weather conditions and emergency alerts.",
#     batch_config={"type": "time", "value": 30},  # Segment every 30 seconds
#     name="Flood_Audio_Index"
# )
#
# # Real-time Transcription Example
# # Get speech-to-text transcription in real-time
# flood_stream.start_transcript(ws_connection_id=connection_id)
#
# # Poll transcript data
# transcript = flood_stream.get_transcript(
#     start=0,
#     end=None,
#     page=1,
#     page_size=100
# )
# print("Transcript data:", transcript)
#
# # Stop transcription when done
# flood_stream.stop_transcript(mode="graceful")

# %% [markdown]
# ---
#
# ## 📦 Step 5: Define a Flash Flood Event
#
# Now, we’ll define an event type in the system to detect visual signs of a flash flood.

# %%
flood_event_id = conn.create_event(
    event_prompt="Detect sudden flash floods or water surges.",
    label="flash_flood"
)
print("Event ID:", flood_event_id)
# Out:
# Event ID: 2bc66b3306d5ae6f

# %% [markdown]
# ---
# ## 📦 Step 6: Attach an Alert for the Flash Flood Event
#
# Alerts delivered instantly via WebSocket when a flood is detected.

# %%
flood_alert_id = flood_scene_index.create_alert(
    flood_event_id,
    callback_url="",
    ws_connection_id=ws.connection_id
)
print("Alert ID:", flood_alert_id)
# Out:
# Alert ID: 384cb52f2fb7f873

# %% [markdown]
# ---
# ## 📦 Step 7: Listen for Flash Flood Alerts
#
# Listen for incoming WebSocket alerts.

# %%
flood_alerts = []

async def listen_for_flood_alerts():
    timeout = 30
    print(f"Listening for flood alerts ({timeout} seconds)...")
    try:
        async with asyncio.timeout(timeout):
            async for msg in ws.receive():
                if msg.get("channel") == "alert":
                    flood_alerts.append(msg)
                    data = msg.get("data", {})
                    print(f"\nALERT #{len(flood_alerts)} RECEIVED!")
                    print(f"  Event     : {data.get('label', 'N/A')}")
                    print(f"  Time      : {msg.get('timestamp', 'N/A')}")
                    print(f"  Confidence: {data.get('confidence', 'N/A')}")
                    print(f"  Clip URL  : {data.get('stream_url', 'N/A')}")
                    print(f"  Details   : {data.get('explanation', 'N/A')}")
    except asyncio.TimeoutError:
        print(f"\nListening complete! {len(flood_alerts)} alert(s) received")

await listen_for_flood_alerts()
# Out:
# Listening for flood alerts (30 seconds)...
#
# ALERT #1 RECEIVED!
#   Event     : flash_flood
#   Time      : 2026-06-13T14:01:44.020392+00:00
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359286000000-1781359294000000.m3u8
#   Details   : The scene analysis explicitly states that moving water is clearly visible in a previously dry riverbed, indicating a flash flood. The scene description further confirms a flash flood is rapidly moving, directly matching the alert context to detect sudden flash floods.
#
# ALERT #2 RECEIVED!
#   Event     : flash_flood
#   Time      : 2026-06-13T14:01:47.878755+00:00
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359294000000-1781359302000000.m3u8
#   Details   : The scene analysis explicitly states 'Flash Flood Detected!' and describes a 'sudden and powerful surge of water' in a previously dry riverbed, which directly matches the alert context for detecting sudden flash floods or water surges.
#
# ALERT #3 RECEIVED!
#   Event     : flash_flood
#   Time      : 2026-06-13T14:02:03.167448+00:00
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359302000000-1781359310000000.m3u8
#   Details   : The scene explicitly states 'A flash flood is detected' and describes a dry riverbed rapidly filling with turbulent, forceful water, consistent with a flash flood or water surge in a desert canyon. Dark clouds also suggest contributing rainfall.
#
# ALERT #4 RECEIVED!
#   Event     : flash_flood
#   Time      : 2026-06-13T14:02:09.399876+00:00
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359310000000-1781359317000000.m3u8
#   Details   : The scene analysis explicitly identifies a 'flash flood' within the riverbed, which directly matches the alert context for detecting sudden flash floods or water surges. The scene description further supports this with details of turbulent, muddy water surging through a riverbed in an arid landscape, consistent with a flash flood event.
#
# ALERT #5 RECEIVED!
#   Event     : flash_flood
#   Time      : 2026-06-13T14:02:13.406545+00:00
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359318000000-1781359325000000.m3u8
#   Details   : The scene explicitly describes a 'powerful flash flood' actively flowing, with 'turbulent, muddy brown' water rushing rapidly and filling the riverbed, directly matching the alert context for detecting sudden flash floods or water surges.
#
# ALERT #6 RECEIVED!
#   Event     : flash_flood
#   Time      : 2026-06-13T14:02:28.113904+00:00
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359334000000-1781359341000000.m3u8
#   Details   : The scene analysis explicitly states 'Flash Flood Detected!' and describes powerful, rapidly flowing water in a dry riverbed, consistent with a sudden flash flood event.
#
# ALERT #7 RECEIVED!
#   Event     : flash_flood
#   Time      : 2026-06-13T14:02:40.029611+00:00
#   Confidence: 1.0
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359342000000-1781359349000000.m3u8
#   Details   : The scene analysis explicitly states 'Flash Flood Detected!' and describes a powerful surge of turbulent, foamy water rushing through a riverbed and slot canyon with immense power and velocity, which directly matches the alert context for detecting sudden flash floods or water surges.
#
# ALERT #8 RECEIVED!
#   Event     : flash_flood
#   Time      : 2026-06-13T14:02:45.599239+00:00
#   Confidence: 1.0
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359350000000-1781359357000000.m3u8
#   Details   : The scene analysis explicitly states 'Flash Flood Detected!' and describes a 'rapid influx of water into an arid channel' with 'turbid, foamy water rushing downstream' in a previously dry riverbed, which directly matches the alert context for detecting sudden flash floods or water surges.
#
# Listening complete! 8 alert(s) received

# %%
if flood_alerts:
    first = flood_alerts[0]
    clip_url = first.get("data", {}).get("stream_url")
    video_name = f"Arizona Desert · {first['data']['label']}"
    print(f"  Confidence : {first['data']['confidence']}")
    print(f"  Explanation: {first['data']['explanation']}\n")
    display(display_stream(clip_url, video_name))
else:
    print("No flood alerts received yet.")
# Out:
#   Confidence : 0.98
#   Explanation: The scene analysis explicitly states that moving water is clearly visible in a previously dry riverbed, indicating a flash flood. The scene description further confirms a flash flood is rapidly moving, directly matching the alert context to detect sudden flash floods.
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359286000000-1781359294000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>Arizona Desert · flash_flood</strong><br>2026-06-13 14:01:26 → 2026-06-13 14:01:34 UTC
#       </div>
#     </div>

# %% [markdown]
# #### Let us stop the flood index and proceed with the notebook to explore more possibilities.

# %%
# flood_scene_index.stop()

# %% [markdown]
# ---
# -  Let us disable the alert now.

# %%
flood_scene_index.disable_alert(flood_alert_id)
print("Flood alert disabled")
# Out:
# Flood alert disabled

# %% [markdown]
# # flood_scene_index.enable_alert(flood_alert_id)

# %%
flood_scene_index.enable_alert(flood_alert_id)

# %% [markdown]
# ---
# ### Let us set up some other alerts that are necessary
# 1. Heavy rainfall, detecting heavy rainfall early can help us predict a flash flood occurence
# 2. Detect the presence of a person stuck in the flash flood, for immediate rescue
#
# We can start with creating a new scene index for monitoring rainfall or a person stuck in the place.

# %%
riverbed_monitoring_scene_index = flood_stream.index_visuals(
    batch_config={
        "type": "time",
        "value": 15,
        "frame_count": 1,
    },
    prompt="Monitor the dry riverbed and surrounding area. In case you detect heavy rainfall mention 'heavy rainfall detected'. If you detect a person stuck in the area during rainfall or flash flood mention 'person detected, rescue needed'",
    name="Riverbed_Monitoring_Index"
)
riverbed_monitoring_index_id = riverbed_monitoring_scene_index.rtstream_index_id
print("Scene Index ID:", riverbed_monitoring_index_id)
# Out:
# Scene Index ID: 38fa58f953099771

# %% [markdown]
# #### Checking the list of indexes

# %%
list_rtstream_indexes(flood_stream)
# Out:
# RTStreamSceneIndex:
#             Index ID       : 38fa58f953099771
#             RTStream ID    : rts-019ec145-ff1c-7903-9b07-7f728a38bcff
#             Name           : Riverbed_Monitoring_Index
#             Status         : running
#             Config         : {'frame_count': '1', 'time': '15'}
#             Prompt         : Monitor the dry riverbed and surrounding area. In case you detect heavy rainfall mention 'heavy rainfall detected'. If you detect a person stuck in the area during rainfall or flash flood mention 'person detected, rescue needed'
#
# --------------------------------------------------------------------------------
# RTStreamSceneIndex:
#             Index ID       : 644e99cf63d55a7b
#             RTStream ID    : rts-019ec145-ff1c-7903-9b07-7f728a38bcff
#             Name           : Flash_Flood_Detection_Index
#             Status         : running
#             Config         : {'frame_count': '3', 'time': '5'}
#             Prompt         : Monitor the dry riverbed and surrounding area. If moving water is detected across the land, identify it as a flash flood and describe the scene.
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ---
# ### Let's have a look at generated scenes

# %%
get_scenes(riverbed_monitoring_scene_index)

# %% [markdown]
# ---
# ### Now we can setup events and alerts for the index
#
# 1. Rainfall Detection

# %%
# Create rainfall event
rainfall_event_id = conn.create_event(
    event_prompt="Detect heavy rainfall.",
    label="heavy_rainfall"
)
print("Event ID:", rainfall_event_id)
# Out:
# Event ID: 22e0f4ccb03d004c

# %%
rainfall_alert_id = riverbed_monitoring_scene_index.create_alert(
    rainfall_event_id,
    callback_url="",
    ws_connection_id=ws.connection_id
)
print("Rainfall Alert ID:", rainfall_alert_id)
# Out:
# Rainfall Alert ID: d36ae22b70a598ec

# %% [markdown]
# ---
# 2. Human detection for rescue

# %%
# Create rescue event
rescue_event_id = conn.create_event(
    event_prompt="Detect if there is a person",
    label="human_rescue"
)
print("Event ID:", rescue_event_id)
# Out:
# Event ID: 12b46c5e221ce791

# %%
rescue_alert_id = riverbed_monitoring_scene_index.create_alert(
    rescue_event_id,
    callback_url="",
    ws_connection_id=ws.connection_id
)
print("Rescue Alert ID:", rescue_alert_id)
# Out:
# Rescue Alert ID: 524113fde47a81e5

# %% [markdown]
# ---
# ### Let us see the list of alerts associated with the `riverbed_monitoring_scene_index`

# %%
def list_rtstream_alerts(rtstream, index_id):
    """
    Prints a list of alerts associated with a given scene index.
    """
    rtstream_scene_index = rtstream.get_scene_index(index_id)
    alerts = rtstream_scene_index.list_alerts()

    for alert in alerts:
        print(f"""🔔 RTStream Alert:
    Alert ID      : {alert['alert_id']}
    Event ID      : {alert['event_id']}
    Label         : {alert['label']}
    Prompt        : {alert['prompt']}
    Status        : {alert['status']}
        """)
        print("-" * 80)

list_rtstream_alerts(flood_stream, riverbed_monitoring_index_id)
# Out:
# 🔔 RTStream Alert:
#     Alert ID      : 524113fde47a81e5
#     Event ID      : 12b46c5e221ce791
#     Label         : human_rescue
#     Prompt        : Detect if there is a person
#     Status        : enabled
#
# --------------------------------------------------------------------------------
# 🔔 RTStream Alert:
#     Alert ID      : d36ae22b70a598ec
#     Event ID      : 22e0f4ccb03d004c
#     Label         : heavy_rainfall
#     Prompt        : Detect heavy rainfall.
#     Status        : enabled
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ---
# ## 📦 Step 8: Listen for Riverbed Monitoring Alerts
#
# Listen for `heavy_rainfall` and `human_rescue` alerts via WebSocket.

# %%
riverbed_alerts = []

async def listen_for_riverbed_alerts():
    timeout = 30
    print(f"Listening for riverbed alerts ({timeout} seconds)...")
    try:
        async with asyncio.timeout(timeout):
            async for msg in ws.receive():
                if msg.get("channel") == "alert":
                    riverbed_alerts.append(msg)
                    data = msg.get("data", {})
                    print(f"\nALERT #{len(riverbed_alerts)} RECEIVED!")
                    print(f"  Event     : {data.get('label', 'N/A')}")
                    print(f"  Confidence: {data.get('confidence', 'N/A')}")
                    print(f"  Clip URL  : {data.get('stream_url', 'N/A')}")
    except asyncio.TimeoutError:
        print(f"\nListening complete! {len(riverbed_alerts)} alert(s) received")

await listen_for_riverbed_alerts()
# Out:
# Listening for riverbed alerts (30 seconds)...
#
# ALERT #1 RECEIVED!
#   Event     : flash_flood
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359397000000-1781359405000000.m3u8
#
# ALERT #2 RECEIVED!
#   Event     : heavy_rainfall
#   Confidence: 0.95
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359402000000-1781359419000000.m3u8
#
# ALERT #3 RECEIVED!
#   Event     : flash_flood
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359413000000-1781359421000000.m3u8
#
# ALERT #4 RECEIVED!
#   Event     : flash_flood
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359421000000-1781359429000000.m3u8
#
# ALERT #5 RECEIVED!
#   Event     : flash_flood
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359405000000-1781359413000000.m3u8
#
# ALERT #6 RECEIVED!
#   Event     : flash_flood
#   Confidence: 0.98
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359437000000-1781359445000000.m3u8
#
# Listening complete! 6 alert(s) received

# %%
if riverbed_alerts:
    first = riverbed_alerts[0]
    clip_url = first.get("data", {}).get("stream_url")
    video_name = f"Arizona Desert · {first['data']['label']}"
    display(display_stream(clip_url, video_name))
else:
    print("No riverbed alerts received yet.")
# Out:
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019ec145-ff1c-7903-9b07-7f728a38bcff/1781359397000000-1781359405000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>Arizona Desert · flash_flood</strong><br>2026-06-13 14:03:17 → 2026-06-13 14:03:25 UTC
#       </div>
#     </div>

# %% [markdown]
# ---
#
# ## 📡 Example Alert Payload
#
# When the AI detected people near the flooding riverbed, the system sent this alert to the webhook url:
#
# ```json
# {
#   "event_id": "event-717a1bcf7a705ec7",
#   "label": "human_rescue",
#   "confidence": 0.95,
#   "explanation": "Flash flood is detected and a person is present, indicating a potential need for rescue. High confidence due to explicit rescue request.",
#   "timestamp": "2025-05-29T02:19:56.724411+00:00",
#   "start_time": "2025-05-29T07:49:49.789911+05:30",
#   "end_time": "2025-05-29T07:50:04.789911+05:30",
#   "stream_url": "https://rt.stream.videodb.io/manifests/rts-019719b2-0c84-7a71-a037-311855a8d160/1748485189000000-1748485205000000.m3u8"
# }
# ```

# %%
alert_stream_url = "https://rt.stream.videodb.io/manifests/rts-019719b2-0c84-7a71-a037-311855a8d160/1748485189000000-1748485205000000.m3u8"
video_name = "🌊 Arizona Desert · human_rescue"

display_stream(alert_stream_url, video_name)
# Out:
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019719b2-0c84-7a71-a037-311855a8d160/1748485189000000-1748485205000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>🌊 Arizona Desert · human_rescue</strong><br>2025-05-29 02:19:49 → 2025-05-29 02:20:05 UTC
#       </div>
#     </div>

# %% [markdown]
# ---
# -  Let us disable the alerts now.

# %% [markdown]
# **💡 What just happened?**
#
# - We connected to VideoDB's WebSocket for real-time event delivery
# - Created alerts for flash floods, heavy rainfall, and human rescue detection
# - Listened for 30 seconds and automatically received alerts
# - Each alert includes a video clip showing the exact moment of detection
#
# **⚡ Why WebSockets?**
# - **Instant delivery**: Alerts arrive in real-time as events happen
# - **Live dashboards**: Perfect for building interactive monitoring interfaces
# - **Two-way communication**: Can send and receive data on the same connection
#
# > **💡 Alternative: Webhooks**
# > You can also use webhooks for server-to-server delivery by providing a `callback_url` instead of `ws_connection_id`. Webhooks are great for automation workflows.

# %%
await ws_wrapper.close()
print("WebSocket closed")

flood_scene_index.disable_alert(flood_alert_id)
print("Flood alert disabled")

riverbed_monitoring_scene_index.disable_alert(rainfall_alert_id)
riverbed_monitoring_scene_index.disable_alert(rescue_alert_id)
print("Riverbed alerts disabled")
# Out:
# WebSocket closed
# Flood alert disabled
# Riverbed alerts disabled

# %% [markdown]
# - To enable the alert again

# %%
riverbed_monitoring_scene_index.enable_alert(rainfall_alert_id)
riverbed_monitoring_scene_index.enable_alert(rescue_alert_id)

# %% [markdown]
# - Now let us stop the stream

# %%
flood_stream.stop()
print("Stream stopped")
# Out:
# Stream stopped

# %% [markdown]
# <div style="background-color: #d4edda; color: #155724; padding: 12px; border-left: 5px solid #28a745; border-radius: 4px;">
#     <strong>🎉 Success!</strong> You've built a complete AI-powered flash flood detection system — from live stream to real-time WebSocket alerts!
# </div>

# %% [markdown]
# ---
#
# ## 🌙 Wrapping Up: Real-Time Environmental Safety
#
# With this system in place, communities, tourists, and local authorities in Arizona’s desert regions can receive **immediate alerts** when a dangerous flash flood occurs — gaining critical seconds to take cover, clear routes, or initiate rescues.
#
# ---
#
# ## 🔥 What Else Could We Monitor?
#
# This system isn’t limited to flash floods. The same AI-driven video monitoring approach can protect lives in other natural disasters too.
#
# ---
#
# ### 🌲 Forest Fire Detection
#
# **Why it’s needed:**
# In remote forest areas, smoke plumes and early fire flickers often go unnoticed for several minutes before traditional sensors or satellites pick them up.
#
# **How we can do it better:**
# With AI-powered cameras watching key zones, we can detect rapid smoke build-ups or visible flames long before automated sensors trigger.
#
# **Example indexing prompt:**
#
# ```markdown
# "Monitor the forest area carefully. Detect sudden rising smoke, increasing haze, or visible flames. Clearly describe if a fire outbreak is visibly starting."
# ```
#
# ---
#
# ### 🌊 Sudden Tsunami Detection
#
# **Why it’s needed:**
# Even with tsunami sensors and ocean buoys, near-shoreline towns often get only minutes of warning. Visual cues like water rapidly pulling away from shore or unusually large approaching waves are immediate, reliable signs.
#
# **How we can do it better:**
# Install AI cameras on popular beaches and coastlines to detect rapid water retreat or walls of water approaching.
#
# **Example indexing prompt:**
#
# ```markdown
# "Watch the beach and shoreline closely. Detect unusual rapid water withdrawal from the shore, or approaching large waves indicating a possible tsunami. Describe the situation clearly."
# ```
#
# ---
#
# ### 🏔️ Landslide / Avalanche Detection
#
# **Why it’s needed:**
# Mountain highways and tourist trails are often cut off by sudden landslides or snow avalanches, where every second matters for evacuation and road closures.
#
# **How we can do it better:**
# Place AI cameras at landslide-prone mountain slopes or snow-covered passes to detect falling rocks, moving soil, or snow slides in real time.
#
# **Example indexing prompt:**
#
# ```markdown
# "Monitor the mountain slope area carefully. Detect falling rocks, soil displacement, or sudden snow slides. Clearly describe if a landslide or avalanche is starting."
# ```
#
# ---
#
# ## 🌍 The Possibilities Are Endless
#
# Real-time AI video monitoring isn’t just for cities and homes — it can actively save lives in wild, unpredictable environments too.
#
# **What natural threat would *you* monitor next?**
