# %% [markdown]
# # 🏏 ICC World Cup Finals: Cricket Highlights Monitoring using VideoDB RTStream
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/real_time_streaming/Cricket_Match_Monitoring.ipynb)
# ## 📖 Storytime: Why This Matters
#
# Tonight is the **ICC World Cup finals between India and Pakistan**.
# Millions are watching the match live, and the competition to post match highlights — sixes, wickets, and spectacular catches — on social media is fiercer than ever.
#
# In the usual workflow, someone watches the match, waits for a moment to happen, then clips the video manually and uploads it online — often **several minutes too late**.
#
# But we have a smarter way.
#
# What if AI could monitor the match for you, detect key moments in real-time, and instantly send alerts when something exciting happens — giving you a headstart on posting highlights while everyone else scrambles?
#
# **Let’s build exactly that using VideoDB RTStream.**
#
# ---
#
# ## 🚀 What You’ll Build in This Notebook
#
# By the end of this notebook, you'll learn how to:
# - Connect a cricket match video stream to VideoDB
# - Use AI to continuously analyze match footage and describe key moments
# - Detect real-time events like **sixes**, **fours**, **catches**, and **wickets**
# - Trigger instant alerts for each event through webhooks
#
# Let’s get started!
#
# ---

# %% [markdown]
# ## 📦 Step 1: Install Dependencies
#
# We’ll begin by installing the VideoDB SDK

# %%
# !pip install -q videodb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.9/95.9 kB 2.1 MB/s eta 0:00:00

# %% [markdown]
# ---
# ## 📦 Step 2: Connect to VideoDB
#
# Let's connect to VideoDB's API using your credentials to prepare for stream monitoring.
#
# Please enter your `VIDEO_DB_API_KEY` in the input box that appears below after you run this cell.
#
# Your input will be masked.

# %%
import videodb
import os
from getpass import getpass

api_key = getpass("Please enter your VideoDB API Key: ")

os.environ["VIDEO_DB_API_KEY"] = api_key

conn = videodb.connect()
coll = conn.get_collection()

print("Connected to VideoDB securely!")
# Out:
# Please enter your VideoDB API Key: ··········
# Connected to VideoDB securely!

# %% [markdown]
# ---
#
# ## 📦 Step 3: Connect to the Cricket Match RTSP Stream
#
# We’ll now connect to the live video stream of the match using its RTSP URL.
# In this demo, the stream is running at `rtsp://samples.rts.videodb.io:8554/cricket`.

# %%
rtsp_url = "rtsp://samples.rts.videodb.io:8554/cricket"
cricket_stream = coll.connect_rtstream(
    name="Cricket Finals Stream",
    url=rtsp_url,
    store=True,
)
print(cricket_stream)
# Out:
# RTStream(id=rts-019fa379-b9a6-7083-88fe-7cb901cdef03, name=Cricket Finals Stream, collection_id=c-81fc6459-fe30-44ac-8c5b-ea0898c2e152, created_at=2026-07-27T12:08:11.430948+00:00, sample_rate=30, status=connected, stream_url=None, player_url=None)

# %% [markdown]
# #### Let us list all the rtstreams in our collection.

# %%
def list_rtstreams():
    for rtstream in coll.list_rtstreams():
        print(f"""RTStream:
        ID            : {rtstream.id}
        Name          : {rtstream.name}
        Collection ID : {rtstream.collection_id}
        Created At    : {rtstream.created_at}
        Sample Rate   : {rtstream.sample_rate}
        Status        : {rtstream.status}
        """)
        print("-" * 80)

list_rtstreams()
# Out:
# RTStream:
#         ID            : rts-019ec13f-81be-77e1-ac01-7ffd8d1d4c45
#         Name          : Cricket Finals Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T13:50:25.214196+00:00
#         Sample Rate   : 30
#         Status        : connected
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec13a-efed-7de2-a74f-87cbe2323bd5
#         Name          : Baby Crib Monitor
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T13:45:25.741229+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec135-a980-7132-8f3e-f411a80d72d1
#         Name          : Baby Crib Monitor
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
# ...

# %% [markdown]
# #### If you have already connected the stream, run the below cell with the **rtstream id** to reconnect.

# %%
# cricket_stream = coll.get_rtstream("")

# %%
# To stop the stream
# cricket_stream.stop()

# %%
# To start the stream
# cricket_stream.start()

# %% [markdown]
# ---
# ### 👀 Let us have a look at the cricket match

# %% [markdown]
# #### 📺 Helper Functions: Search and Display
#
# This cell contains all the utility functions to search, fetch, and visualize video streams. You don't need to modify this code.

# %%
# To display the stream with relevant information

from IPython.display import HTML
import re
import time
from datetime import datetime, UTC
from videodb import play_stream


def display_stream(video_url, video_name="🎥 Camera Feed"):
    match = re.search(r"/(\d{16})-(\d{16})\.m3u8", video_url)
    if match:
        start_ts = int(match.group(1)) / 1e6
        end_ts = int(match.group(2)) / 1e6
        start_time = datetime.fromtimestamp(start_ts, UTC).strftime("%Y-%m-%d %H:%M:%S")
        end_time = datetime.fromtimestamp(end_ts, UTC).strftime("%Y-%m-%d %H:%M:%S")
        time_range = f"{start_time} → {end_time} UTC"
    else:
        time_range = "Time Unknown"

    video_player_html = play_stream(video_url)

    return HTML(f"""
    <div style="position:relative;width:640px;">
      {video_player_html._repr_html_() if hasattr(video_player_html, "_repr_html_") else video_player_html}
      <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
        <strong>{video_name}</strong><br>{time_range}
      </div>
    </div>
    """)


# To dynamically set the display duration


def prompt_to_time(prompt):
    now = int(time.time())
    prompt = (
        f"It's {now} in epoch seconds. "
        f"Convert the phrase '{prompt}' into JSON "
        f'with keys "from" and "to" (both epoch seconds)'
    )

    result = coll.generate_text(
        prompt=prompt,
        model_name="pro",
        response_type="json",
    )
    output = result.get("output", {})
    return output.get("from"), output.get("to")


# To fetch stream


def fetch_stream(rtstream):
    _from, to = prompt_to_time("Show me last 2 mins")
    rtstream.generate_stream(_from, to)
    return rtstream.stream_url

# %% [markdown]
# #### 🔗 Get & Display Recent Stream
#
# This cell uses the helper functions above to fetch and display the last few minutes of the stream.

# %%
# To get last few minutes stream link

video_url = fetch_stream(cricket_stream)

video_name = "🏏 ICC World Cup · India vs Pakistan"
display_stream(video_url, video_name)
# Out:
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019ec13f-81be-77e1-ac01-7ffd8d1d4c45/1781358619000000-1781358739000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>🏏 ICC World Cup · India vs Pakistan</strong><br>2026-06-13 13:50:19 → 2026-06-13 13:52:19 UTC
#       </div>
#     </div>

# %% [markdown]
# ---
# ## 📦 Step 4: Understand Scenes and Describe Match Highlights
#
# We’ll continuously analyze seven-second windows, preserve a named cricket-scene output, and index that output for records and alerts.
#
# The AI model will look out for:
# - Sixes (ball hit over the boundary rope without bouncing)
# - Fours (ball crosses boundary rope after bouncing)
# - Catches (fielder catches the ball before it touches the ground)
# - Wickets (batsman is dismissed)

# %%
cricket_understanding = cricket_stream.understand(
    segmentation={"type": "time", "window": "7s"},
    analyzers=[
        {
            "type": "vlm",
            "name": "cricket_scene",
            "sampling": {"frame_count": 7},
            "config": {
                "prompt": "Identify and mention when a batsman hits a SIX (ball flying over the boundary rope), a FOUR (ball crosses boundary rope after bouncing), a CATCH OUT (fielder catches the ball mid-air before it touches ground) or a WICKET (when the wicket stumps are put down by the ball)."
            },
        }
    ],
    store=True,
)
cricket_scene_output = cricket_understanding.outputs.get("cricket_scene")
cricket_understanding_id = cricket_understanding.id
print("Continuous understanding ID:", cricket_understanding_id)
# Out:
# Continuous understanding ID: und-f572e78d924560d7

# %% [markdown]
# ### Create the Cricket Scene Index
#
# Create a continuous semantic index from the cricket-scene output for highlights and alerts.

# %%
cricket_index = cricket_stream.index(
    source=cricket_scene_output,
    name="Cricket_Match_Scene_Index",
    use_for=["semantic"],
)
cricket_index_id = cricket_index.id
print("Continuous index ID:", cricket_index_id)
# Out:
# Continuous index ID: idx-529a8bfe4ac80912

# %% [markdown]
# #### Let us list the continuous indexes created on our rtstream.

# %%
def list_rtstream_indexes(rtstream):
    # List continuous stream indexes
    rtstream_indexes = rtstream.list_indexes()
    for rtstream_index in rtstream_indexes:

        print(f"""RTStreamIndex:
            Index ID       : {rtstream_index.id}
            RTStream ID    : {rtstream_index.rtstream_id}
            Name           : {rtstream_index.name}
            Status         : {rtstream_index.status}
            Use For        : {rtstream_index.use_for}
            Understanding : {rtstream_index.source_understanding_id}
            Output        : {rtstream_index.output}
        """)
        print("-" * 80)

list_rtstream_indexes(cricket_stream)

# %% [markdown]
# #### If you have already created the continuous jobs, run the below cell with your **understanding id** and **index id** to reconnect.

# %%
# cricket_understanding_id = ""
# cricket_index_id = ""
# cricket_understanding = cricket_stream.get_understanding(cricket_understanding_id)
# cricket_index = cricket_stream.get_index(cricket_index_id)

# %%
# To stop the index
# cricket_index.stop()

# %%
# To start the index
# cricket_index.start()

# %% [markdown]
# ---
# ### Let us inspect records from the continuous index

# %%
import json
import time

range_end = time.time()
range_start = range_end - (15 * 60)
cricket_records_payload = cricket_index.get_records(
    start=range_start,
    end=range_end,
    page_size=5,
)
print(json.dumps(cricket_records_payload, indent=2, default=str))
# Out:
# {
#   "next_page": false,
#   "records": [
#     {
#       "description": "No SIX, FOUR, CATCH OUT, or WICKET is shown in these frames.",
#       "end": 1785154113.2340937,
#       "start": 1785154104.534087
#     },
#     {
#       "description": "FOUR.",
#       "end": 1785154122.2741024,
#       "start": 1785154114.2840946
#     },
#     {
#       "description": "- **6th over, last ball**: **SIX** \u2014 Rohit smashes it over the boundary.\n- **6th over**: **SIX** \u2014 the crowd shot confirms the ball cleared the rope.\n- **Later in the innings**: **FOUR** \u2014 the scoreboard shows a boundary four.\n- **6th over / end of over**: **SIX** \u2014 Rohit hits another six.\n- **9th over**: No wicket/catch/four/six shown in the final frame; it appears to be a dot ball.\n\n",
#       "end": 1785154132.244112,
#       "start": 1785154124.2441044
#     },
#     {
# ...

# %% [markdown]
# ---
# ### 🔌 Step 4.5: Connect WebSocket for Real-Time Alerts
#
# Before creating alerts, connect to VideoDB's WebSocket server.

# %%
import asyncio

ws_wrapper = conn.connect_websocket()
ws = await ws_wrapper.connect()

print(f"WebSocket connected!")
print(f"Connection ID: {ws.connection_id}")
# Out:
# INFO:videodb.websocket_client:WebSocket connected with ID: gVX2D--h3eO4KEj2wA==
# WebSocket connected!
# Connection ID: gVX2D--h3eO4KEj2wA==

# %% [markdown]
# ---
# ## 🎤 Audio Indexing & Transcription
#
# VideoDB RTStream also supports audio analysis for streams with audio content. You can:
# - **Index Audio**: Extract structured information from audio streams using AI prompts
# - **Start Transcription**: Get real-time speech-to-text transcription
#
# These features work alongside visual indexing to provide comprehensive stream analysis.

# %%
# # Audio Indexing Example (if stream has audio)
# audio_index = cricket_stream.index_audio(
#     prompt="Extract commentary, crowd reactions, and key events mentioned by commentators. Detect when goals, fouls, or significant moments are announced.",
#     batch_config={"type": "time", "value": 30},  # Segment every 30 seconds
#     name="Cricket_Match_Audio_Index"
# )

# %% [markdown]
# ### Start Real-Time Transcription (Optional)
#
# Start transcription and inspect the resulting speech-to-text records.

# %%
# # Real-time Transcription Example
# # Get speech-to-text transcription in real-time
# cricket_stream.start_transcript(ws_connection_id=ws.connection_id)
#
# # Poll transcript data
# transcript = cricket_stream.get_transcript(
#     start=0,
#     end=None,
#     page=1,
#     page_size=100
# )
# print("Transcript data:", transcript)
#
# # Stop transcription when done
# cricket_stream.stop_transcript()

# %% [markdown]
# ## 📦 Step 5: Define Events for Each Match Highlight
#
# Now, let’s define four events to detect each key match moment.

# %% [markdown]
# 1. Sixes (ball hit over the boundary rope without bouncing)

# %%
six_event_id = conn.create_event(
    event_prompt="Detect when a batsman hits a SIX.",
    label="six_hit"
)
print(f"Six Event ID: {six_event_id}")

four_event_id = conn.create_event(
    event_prompt="Detect when a batsman hits a FOUR (ball crosses boundary after bouncing).",
    label="four_hit"
)
print(f"Four Event ID: {four_event_id}")
# Out:
# Six Event ID: 7cdc37e095344921
# Four Event ID: 88380c69568f7715

# %% [markdown]
# 2. Fours (ball crosses boundary rope after bouncing)

# %%
catch_event_id = conn.create_event(
    event_prompt="Detect when a player takes a CATCH OUT.",
    label="catch_out"
)
print(f"Catch Event ID: {catch_event_id}")

wicket_event_id = conn.create_event(
    event_prompt="Detect when a batsman is dismissed (WICKET).",
    label="wicket"
)
print(f"Wicket Event ID: {wicket_event_id}")

print(f"\nAll events created:")
print(f"  Six    : {six_event_id}")
print(f"  Four   : {four_event_id}")
print(f"  Catch  : {catch_event_id}")
print(f"  Wicket : {wicket_event_id}")
# Out:
# Catch Event ID: ba9be5551553b39e
# Wicket Event ID: a6f5c8a2e23a4c63
#
# All events created:
#   Six    : 7cdc37e095344921
#   Four   : 88380c69568f7715
#   Catch  : ba9be5551553b39e
#   Wicket : a6f5c8a2e23a4c63

# %% [markdown]
# ---
# ## 📦 Step 6: Attach Alerts for Each Event
#
# We'll create four alerts — one per event — all delivered via WebSocket.

# %%
RTSTREAM_ALERT_CALLBACK_URL = "https://example.com"
six_alert_id = cricket_index.create_alert(
    event_id=six_event_id, callback_url=RTSTREAM_ALERT_CALLBACK_URL, ws_connection_id=ws.connection_id)
print(f"Six Alert ID: {six_alert_id}")

four_alert_id = cricket_index.create_alert(
    event_id=four_event_id, callback_url=RTSTREAM_ALERT_CALLBACK_URL, ws_connection_id=ws.connection_id)
print(f"Four Alert ID: {four_alert_id}")

catch_alert_id = cricket_index.create_alert(
    event_id=catch_event_id, callback_url=RTSTREAM_ALERT_CALLBACK_URL, ws_connection_id=ws.connection_id)
print(f"Catch Alert ID: {catch_alert_id}")

wicket_alert_id = cricket_index.create_alert(
    event_id=wicket_event_id, callback_url=RTSTREAM_ALERT_CALLBACK_URL, ws_connection_id=ws.connection_id)
print(f"Wicket Alert ID: {wicket_alert_id}")
# Out:
# Six Alert ID: a7f7cb467f228c98
# Four Alert ID: f8cfaf2828eff398
# Catch Alert ID: b79a4a048f28b429
# Wicket Alert ID: c4772a3c6931ce8d

# %% [markdown]
# ---
# ## 📦 Step 7: Listen for Real-Time Alerts
#
# Listen for SIX, FOUR, CATCH OUT, WICKET events.

# %%
import json

received_alerts = []

async def listen_for_alerts():
    timeout = 30
    print(f"Listening for cricket alerts ({timeout} seconds)...")
    print("Watching for SIX, FOUR, CATCH OUT, WICKET events\n")
    try:
        async with asyncio.timeout(timeout):
            async for msg in ws.receive():
                if not isinstance(msg, dict):
                    print("WebSocket message:", repr(msg))
                    continue
                if msg.get("channel") == "alert":
                    received_alerts.append(msg)
                    print(f"\nALERT #{len(received_alerts)} RECEIVED!")
                    print(json.dumps(msg, indent=2, default=str))
    except asyncio.TimeoutError:
        print(f"\nListening complete! {len(received_alerts)} alert(s) received")

await listen_for_alerts()
# Out:
# Listening for cricket alerts (30 seconds)...
# Watching for SIX, FOUR, CATCH OUT, WICKET events
#
#
# ALERT #1 RECEIVED!
# {
#   "channel": "alert",
#   "timestamp": "2026-07-27T12:10:22.632046+00:00",
#   "rtstream_id": "rts-019fa379-b9a6-7083-88fe-7cb901cdef03",
#   "rtstream_name": "Cricket Finals Stream",
#   "data": {
#     "event_id": "alert-a7f7cb467f228c98",
#     "label": "six_hit",
#     "triggered": true,
#     "confidence": 0.99,
#     "start": 1785154210.2242088,
#     "end": 1785154218.224219,
#     "player_url": "https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019fa379-b9a6-7083-88fe-7cb901cdef03/1785154210000000-1785154219000000.m3u8",
#     "stream_url": "https://rt.stream.videodb.io/manifests/rts-019fa379-b9a6-7083-88fe-7cb901cdef03/1785154210000000-1785154219000000.m3u8",
#     "explanation": "The scene analysis includes a SIX, which matches the alert context of detecting when a batsman hits a SIX."
#   }
# }
#
# ALERT #2 RECEIVED!
# ...

# %% [markdown]
# Lets check the evidence:

# %%
msg = received_alerts[2]
data = (msg.get("data") or msg) if isinstance(msg, dict) else None
data = data if isinstance(data, dict) else {}
clip_url = data.get("stream_url")
label = data.get("label", "unknown")
if isinstance(clip_url, str) and clip_url.strip():
    display(display_stream(clip_url, f"ICC World Cup · {label}"))
else:
    print("No playable stream_url was included. Raw payload:")
    print(json.dumps(msg, indent=2, default=str))
# Out:
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019fa379-b9a6-7083-88fe-7cb901cdef03/1785154229000000-1785154238000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>ICC World Cup · four_hit</strong><br>2026-07-27 12:10:29 → 2026-07-27 12:10:38 UTC
#       </div>
#     </div>

# %% [markdown]
# ---
# ### 📡 WebSocket Alert Message Format
#
# > This is an illustrative payload shape. Inspect the raw message before using optional fields such as `confidence` or `stream_url`.
#
# ```python
# {
#   "channel": "alert",
#   "timestamp": "2026-07-27T12:10:35.436714+00:00",
#   "rtstream_id": "rts-019fa379-b9a6-7083-88fe-7cb901cdef03",
#   "rtstream_name": "Cricket Finals Stream",
#   "data": {
#     "event_id": "alert-f8cfaf2828eff398",
#     "label": "four_hit",
#     "triggered": true,
#     "confidence": 0.96,
#     "start": 1785154219.2742205,
#     "end": 1785154227.2642307,
#     "player_url": "https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019fa379-b9a6-7083-88fe-7cb901cdef03/1785154219000000-1785154228000000.m3u8",
#     "stream_url": "https://rt.stream.videodb.io/manifests/rts-019fa379-b9a6-7083-88fe-7cb901cdef03/1785154219000000-1785154228000000.m3u8",
#     "explanation": "The scene analysis indicates a FOUR being celebrated, which matches the alert context for a boundary four."
#   }
# }
# ```

# %% [markdown]
# ---
# ## Cleanup
#
# Disable all alerts, stop the continuous index and understanding, stop the stream, then close the WebSocket last.

# %% [markdown]
# **💡 What just happened?**
#
# - We connected to VideoDB's WebSocket for real-time event delivery
# - Created alerts for Six, Four, Catch Out, and Wicket events
# - Listened for 30 seconds and automatically received highlights
# - When an alert includes a playable `stream_url`, the matching highlight can be replayed
#
# **⚡ Why WebSockets?**
# - **Instant delivery**: Alerts arrive in real-time as events happen
# - **Live dashboards**: Perfect for building interactive monitoring interfaces
# - **Two-way communication**: Can send and receive data on the same connection
#
# > **💡 Callback + WebSocket delivery**
# > Configure a public callback URL for alert delivery, and also pass `ws_connection_id` to receive the same alerts over the WebSocket.

# %%
cricket_index.disable_alert(six_alert_id)
cricket_index.disable_alert(four_alert_id)
cricket_index.disable_alert(catch_alert_id)
cricket_index.disable_alert(wicket_alert_id)
print("All alerts disabled")

cricket_index.stop()
cricket_understanding.stop()
print("Continuous index and understanding stopped")
# Out:
# All alerts disabled
# Continuous index and understanding stopped

# %%
cricket_stream.stop()
print("Stream stopped")

await ws_wrapper.close()
print("WebSocket closed")
# Out:
# Stream stopped
# WebSocket closed

# %% [markdown]
# <div style="background-color: #d4edda; color: #155724; padding: 12px; border-left: 5px solid #28a745; border-radius: 4px;">
#     <strong>🎉 Success!</strong> You've built a complete AI-powered cricket highlights monitoring system — from live stream to real-time WebSocket alerts!
# </div>

# %% [markdown]
# ---
# ## 🏆 Wrapping Up: Outpacing the Competition in Real Time
#
# In this notebook, we built a smart, AI-powered video monitoring system tailored for the high-pressure, real-time demands of live sports broadcasting.
#
# With this setup in place, broadcasters and content creators no longer have to wait, clip, and scramble.
# They can stay ahead of the crowd, instantly catching and sharing match-defining moments as they happen — turning every six, four, wicket, and catch into social media gold within seconds.
#
# ---
#
# **But this is just one story.**
#
# - What if the same system could monitor a **football match**, detecting goals, penalties, and crowd invasions in real time?
# - Or watch over an **esports championship**, capturing game-winning moves and viral moments?
# - Or even scan **live news broadcasts**, flagging breaking events or significant headlines for immediate clipping and distribution?
#
# The possibilities of real-time video intelligence in media and sports are endless.
#
# **What would *you* stream next?**
