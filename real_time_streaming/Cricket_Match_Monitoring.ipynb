# %% [markdown]
# # Cricket Match Highlights Monitoring with VideoDB RTStream
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/real_time_streaming/Cricket_Match_Monitoring.ipynb)
#
# This notebook builds a real-time cricket highlight monitor for an RTSP match feed.
#
# You will use VideoDB RTStream to:
#
# - Connect to a live cricket stream.
# - Preview recent match footage.
# - Continuously understand the stream with a VLM.
# - Continuously index the VLM output for search and alerts.
# - Detect sixes, fours, catches, and wickets.
# - Receive WebSocket alerts and display evidence clips when available.
#
# After connecting the RTStream, wait 1-2 minutes before running this cell so VideoDB has enough buffered footage to generate a recent playback window.

# %% [markdown]
# ## 1. Install VideoDB
#
# Install VideoDB and notebook dependencies.

# %%
# !pip install -q videodb python-dotenv

# %% [markdown]
# ## 2. Connect to VideoDB
#
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import os
import time
import asyncio
from datetime import datetime
from getpass import getpass
from uuid import uuid4

from IPython.display import display
from videodb import connect, play_stream

api_key = getpass("Enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key

conn = connect()
coll = conn.get_collection()

print("Connected to VideoDB successfully.")
# Out:
# Enter your VideoDB API Key: ··········
# Connected to VideoDB

# %% [markdown]
# ## 3. Connect to the Cricket Match RTSP Feed
#
# This sample feed behaves like a live cricket broadcast. If you already created an RTStream, you can reconnect by ID instead of creating a new stream.

# %%
rtsp_url = "rtsp://samples.rts.videodb.io:8554/cricket"

cricket_stream = coll.connect_rtstream(
    name="Cricket Match Highlight Monitor",
    url=rtsp_url,
    store=True,
)

print(f"RTStream ID: {cricket_stream.id}")
print(f"Status: {cricket_stream.status}")
# Out:
# RTStream ID: rts-019f3da4-41ce-72c3-a43d-40ab38b277b1
# Status: connected

# %%
# Reconnect to an existing stream instead of creating a new one:
# cricket_stream = coll.get_rtstream("your-rtstream-id")

# %% [markdown]
# ## 4. Preview Recent Stream Footage
#
# RTStream playback uses Unix timestamps. Connect WebSocket, generate a recent stream window, then play `cricket_stream.stream_url`.

# %%
# Connect WebSocket
ws_wrapper = conn.connect_websocket()
ws = await ws_wrapper.connect()
print(f"WebSocket connected! Connection ID: {ws.connection_id}")

# Preview last 2 minutes
now = int(time.time())
cricket_stream.generate_stream(now - 120, now)
play_stream(cricket_stream.stream_url)
# Out:
# INFO:videodb.websocket_client:WebSocket connected with ID: gTVf544R9QAYKEiaBA==
# WebSocket connected! Connection ID: gTVf544R9QAYKEiaBA==
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://videodb-rt-streaming-service-us-east-1.s3.us-east-1.amazonaws.com/manifests/rts-019f3da4-41ce-72c3-a43d-40ab38b277b1/1783445620000000-1783445740000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 5. Start Continuous Match Understanding
#
# For RTStreams, `understand()` runs continuously. Here a VLM inspects every 7-second window and describes key cricket moments.

# %%
cricket_prompt = """
Monitor the cricket match for highlight-worthy moments.

Look for:
1. SIX: the batter hits the ball over the boundary rope without bouncing.
2. FOUR: the ball crosses the boundary rope after touching the ground.
3. CATCH OUT: a fielder catches the ball before it touches the ground.
4. WICKET: the batter is dismissed, including bowled, caught, run out, stumped, or lbw.

If a highlight is visible, describe it with this structure:
Cricket Highlight
Highlight Type: six, four, catch_out, wicket, or multiple
Players/Teams: visible players or teams if known, otherwise Not Visible
Evidence: brief visual evidence

If no highlight is visible, respond with:
No Cricket Highlight Detected
"""

cricket_understanding = cricket_stream.understand(
    segmentation={"type": "time", "window": "7s"},
    analyzers=[
        {
            "type": "vlm",
            "name": "scene",
            "sampling": {"frame_count": 7},
            "config": {
                "model": "pro",
                "prompt": cricket_prompt,
            },
        }
    ],
    store=True,
    ws_connection_id=ws.connection_id,
)

print(f"Understanding ID: {cricket_understanding.id}")
print(f"Status: {cricket_understanding.status}")
# Out:
# Understanding ID: und-76d758ec8fb032c7
# Status: running

# %% [markdown]
# ## 6. Continuously Index the Understanding Output
#
# The VLM output is a continuous source. `rtstream.index()` keeps indexing new windows as they are produced.

# %%
CRICKET_INDEX_NAME = f"cricket_highlights_{uuid4().hex[:8]}"

cricket_index = cricket_stream.index(
    name=CRICKET_INDEX_NAME,
    source=cricket_understanding.outputs["scene"],
    use_for=["semantic"],
)

cricket_index_id = getattr(cricket_index, "id", cricket_index)

if not hasattr(cricket_index, "get_records"):
    print("Waiting for cricket index to become available...")
    while True:
        try:
            cricket_index = cricket_stream.get_index(cricket_index_id)
            break
        except Exception as exc:
            if "not found" not in str(exc).lower():
                raise
            time.sleep(5)

print(f"Index name: {CRICKET_INDEX_NAME}")
print(f"Index ID: {cricket_index_id}")
print(f"Status: {getattr(cricket_index, 'status', 'running')}")
# Out:
# Index name: cricket_highlights_75f549f3
# Index ID: idx-0de822e8954990ba
# Status: running

# %% [markdown]
# ## 7. Inspect Recent Indexed Windows
#
# RTStream understanding and indexing jobs stay `running` while the live feed is active. This cell checks recent indexed VLM windows before search and alerts.

# %%
def format_ts(ts):
    try:
        return datetime.fromtimestamp(float(ts)).strftime("%Y-%m-%d %H:%M:%S")
    except Exception:
        return str(ts)


def extract_record_text(record):
    data = record.get("data") if isinstance(record, dict) else None
    if isinstance(data, dict):
        return data.get("text") or data.get("description") or data.get("scene_description") or str(data)
    return record.get("text") or record.get("description") or str(record)


def get_recent_records(index, page_size=5):
    end = int(time.time()) - 30
    start = end - 300

    try:
        payload = index.get_records(start=start, end=end, page=1, page_size=page_size)
    except TypeError:
        payload = index.get_records(page_size=page_size)

    if isinstance(payload, dict):
        return payload.get("records") or payload.get("scenes") or []
    return payload or []


def wait_for_records(index, timeout=300, poll_interval=10):
    deadline = time.time() + timeout
    while time.time() < deadline:
        records = get_recent_records(index)
        if records:
            return records
        time.sleep(poll_interval)
    raise RuntimeError(
        "No indexed records were available yet. Confirm the RTStream preview is playable and the understanding/index jobs are running."
    )


print("Waiting for indexed cricket observations. This can take 1-3 minutes...")
recent_records = wait_for_records(cricket_index)

for record in recent_records[:5]:
    start = format_ts(record.get("start"))
    end = format_ts(record.get("end"))
    print("-" * 80)
    print(f"{start} -> {end}")
    print(extract_record_text(record))
# Out:
# Waiting for indexed cricket observations. This can take 1-3 minutes...
# --------------------------------------------------------------------------------
# 2026-07-07 17:35:48 -> 2026-07-07 17:35:55
# Cricket Highlight
# Highlight Type: wicket
# Players/Teams: India; Pakistan
# Evidence: Indian player appealing energetically with Pakistan batter at the crease; ball shown near the batter's pads/stumps and wicketkeeper close by, indicating a dismissal appeal.

# %% [markdown]
# ## 8. Search for Highlight Moments
#
# Search the indexed stream windows for likely highlights and review matching timestamps and descriptions. Evidence clips are displayed from real-time alert payloads in the alert section.

# %%
query = "cricket highlight, six, four, catch out, wicket, batter dismissed"

try:
    highlight_results = cricket_stream.search(
        query=query,
        index_id=cricket_index_id,
        score_threshold=0.4,
    )
    shots = getattr(highlight_results, "shots", None) or highlight_results.get_shots()
except Exception as exc:
    print(f"No searchable highlight results yet: {exc}")
    shots = []

if shots:
    for idx, shot in enumerate(shots[:5], start=1):
        text = getattr(shot, "text", "") or getattr(shot, "description", "")
        print(f"{idx}. {format_ts(shot.start)} -> {format_ts(shot.end)}")
        print(text[:500])
        print()
else:
    print("No matching windows yet. Let the stream run longer or lower the score threshold.")
# Out:
# 1. 2026-07-07 17:35:48 -> 2026-07-07 17:35:55
# Cricket Highlight
# Highlight Type: wicket
# Players/Teams: India; Pakistan
# Evidence: Indian player appealing energetically with Pakistan batter at the crease; ball shown near the batter's pads/stumps and wicketkeeper close by, indicating a dismissal appeal.

# %% [markdown]
# ## 9. Create Cricket Highlight Events
#
# Events define what should trigger alerts. This notebook creates one event for each major cricket highlight type.

# %%
six_event_id = conn.create_event(
    event_prompt="Detect when the batter hits a SIX: the ball clears the boundary rope without bouncing.",
    label="six_hit",
)

four_event_id = conn.create_event(
    event_prompt="Detect when the batter hits a FOUR: the ball reaches or crosses the boundary after touching the ground.",
    label="four_hit",
)

catch_event_id = conn.create_event(
    event_prompt="Detect when a fielder takes a CATCH OUT before the ball touches the ground.",
    label="catch_out",
)

wicket_event_id = conn.create_event(
    event_prompt="Detect when a WICKET falls or the batter is dismissed.",
    label="wicket",
)

event_ids = {
    "six_hit": six_event_id,
    "four_hit": four_event_id,
    "catch_out": catch_event_id,
    "wicket": wicket_event_id,
}

for label, event_id in event_ids.items():
    print(f"{label}: {event_id}")
# Out:
# six_hit: 28fdc8de2a03f4e7
# four_hit: 504bd3a1f3692aba
# catch_out: a1fc07c7a0ea615b
# wicket: 2abbf00851e518ae

# %% [markdown]
# ## 10. Attach Alerts
#
# Attach alerts to the cricket index and receive alert events over the existing WebSocket. The callback URL is used for server-to-server delivery.

# %%
WEBHOOK_URL = "https://example.com/videodb-alerts"

alert_ids = {}
for label, event_id in event_ids.items():
    alert_ids[label] = cricket_index.create_alert(
        event_id=event_id,
        callback_url=WEBHOOK_URL,
        ws_connection_id=ws.connection_id,
    )
    print(f"{label} alert: {alert_ids[label]}")
# Out:
# six_hit alert: 2fa4ff48ca0e2b3a
# four_hit alert: 1a0dc1bc01fde75a
# catch_out alert: ced7862079ab2757
# wicket alert: a5896bde8d72c9d6

# %% [markdown]
# ## 11. Listen for Real-Time Alerts
#
# The listener runs for 30 seconds. If alerts arrive, the next cell can display the evidence clips.

# %%
received_alerts = []


async def listen_for_alerts(timeout=30):
    print(f"Listening for cricket highlight alerts ({timeout} seconds)...")
    try:
        async with asyncio.timeout(timeout):
            async for msg in ws.receive():
                if msg.get("channel") != "alert":
                    continue

                received_alerts.append(msg)
                data = msg.get("data", {})
                print(f"\nAlert #{len(received_alerts)}")
                print(f"Label: {data.get('label', 'N/A')}")
                print(f"Confidence: {data.get('confidence', 'N/A')}")
                print(f"Explanation: {data.get('explanation', 'N/A')}")
    except asyncio.TimeoutError:
        print(f"\nListening complete. Alerts received: {len(received_alerts)}")
    except Exception as exc:
        print(f"\nWebSocket closed while listening: {exc}")
        print("Reconnect WebSocket, recreate alerts with the new connection ID, then listen again.")


await listen_for_alerts()
# Out:
# Listening for cricket highlight alerts (30 seconds)...
#
# Alert #1
# Label: four_hit
# Confidence: 0.98
# Explanation: Visual evidence shows the ball rolling to/along the boundary after touching the ground and the scoreboard updated from 196-6 to 200-6 with a four recorded, which together strongly indicate a FOUR.
#
# Alert #2
# Label: wicket
# Confidence: 0.98
# Explanation: Multiple strong cues indicate a dismissal: helmet discarded near stumps, wicketkeeper walking away, crowd celebration, and final scoreboard showing India win immediately after a dismissal — consistent with a wicket falling.
#
# Alert #3
# Label: four_hit
# Confidence: 0.95
# Explanation: Score increased from 16-0 to 20-0 with a displayed '4' icon, footage shows ball running to/near boundary and crowd celebration — consistent with a boundary four after the ball reached the rope.
#
# Alert #4
# Label: six_hit
# Confidence: 0.95
# ...

# %%
if received_alerts:
    for idx, alert in enumerate(received_alerts[:4], start=1):
        data = alert.get("data", {})
        clip_url = data.get("stream_url")

        print(f"\nAlert #{idx}")
        print(f"Label: {data.get('label', 'N/A')}")
        print(f"Confidence: {data.get('confidence', 'N/A')}")
        print(f"Explanation: {data.get('explanation', 'N/A')}")

        if clip_url:
            display(play_stream(clip_url))
        else:
            print("No evidence clip URL was included in this alert payload.")
else:
    print("No alerts received yet. Keep the stream running and listen again.")
# Out:
# Alert #1
# Label: four_hit
# Confidence: 0.98
# Explanation: Visual evidence shows the ball rolling to/along the boundary after touching the ground and the scoreboard updated from 196-6 to 200-6 with a four recorded, which together strongly indicate a FOUR.
# No evidence clip URL was included in this alert payload.
#
# Alert #2
# Label: wicket
# Confidence: 0.98
# Explanation: Multiple strong cues indicate a dismissal: helmet discarded near stumps, wicketkeeper walking away, crowd celebration, and final scoreboard showing India win immediately after a dismissal — consistent with a wicket falling.
# No evidence clip URL was included in this alert payload.
#
# Alert #3
# Label: four_hit
# Confidence: 0.95
# Explanation: Score increased from 16-0 to 20-0 with a displayed '4' icon, footage shows ball running to/near boundary and crowd celebration — consistent with a boundary four after the ball reached the rope.
# No evidence clip URL was included in this alert payload.
#
# Alert #4
# ...

# %% [markdown]
# ## 12. Alert Management and Cleanup
#
# Disable alerts and stop continuous jobs when you finish the demo to avoid unnecessary processing.

# %%
for label, alert_id in alert_ids.items():
    try:
        cricket_index.disable_alert(alert_id)
        print(f"{label} alert disabled")
    except Exception as exc:
        print(f"{label} alert cleanup skipped: {exc}")

try:
    cricket_index.stop()
    print("Index stopped")
except Exception as exc:
    print(f"Index stop skipped: {exc}")

try:
    cricket_understanding.stop()
    print("Understanding stopped")
except Exception as exc:
    print(f"Understanding stop skipped: {exc}")

try:
    await ws_wrapper.close()
    print("WebSocket closed")
except Exception as exc:
    print(f"WebSocket cleanup skipped: {exc}")

try:
    cricket_stream.stop()
    print("RTStream stopped")
except Exception as exc:
    print(f"RTStream stop skipped: {exc}")
# Out:
# six_hit alert disabled
# four_hit alert disabled
# catch_out alert disabled
# wicket alert disabled
# Index stopped
# Understanding stopped
# WebSocket closed
# RTStream stopped

# %% [markdown]
# ## Further Resources
#
# - [Understand and Index RTStreams](https://videodb-docs-indexing-search-v2.mintlify.app/pages/ingest/live-streams/rtstream-understand-index)
# - [Search and Retrieval](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/search-and-retrieval/natural-language-query)
#
# You now have a complete RTStream sports-highlight loop: live feed -> continuous visual understanding -> continuous index -> search and alerts -> evidence playback.
#
# The same workflow can support other live sports and media operations, such as football goal detection, basketball highlight clipping, player-celebration monitoring, or near-real-time editorial review.
#
# If you have questions or feedback, reach out through [Discord](https://discord.gg/py9P639jGz) or [GitHub](https://github.com/video-db).
