# %% [markdown]
# # 🏠 Smart Intruder Detection for Property Surveillance using VideoDB RTStream
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/real_time_streaming/Intrusion_Detection.ipynb)
# ## 📖 Storytime: Why This Matters
#
# Have you ever felt anxious leaving your home, shop, or property unattended?
# **What if someone’s lurking around your property?**
# **What if someone’s trying the door or peeking through windows?**
# Sure — you could install IP cameras, but who has the time to watch them 24/7?
#
# **Good news — you don’t have to anymore.**
#
# With **VideoDB RTStream**, you can build a smart, AI-powered property surveillance system that actively monitors live video streams, detects suspicious activity, and immediately sends alerts for escalating security breaches — all without human supervision.
#
# ---
#
# ## 🚀 What You’ll Build in This Notebook
#
# In this notebook, we’ll build a layered intruder detection system with **three levels of security breach detection**:
# - **🔸 Level 1: Loitering near the property perimeter**
# - **🔸 Level 2: Attempting to check the door lock (tampering / intrusion attempt)**
# - **🔸 Level 3: Physically entering the property (highest breach)**
#
# You’ll learn how to:
# - 📺 Connect a property surveillance video stream to VideoDB
# - 🤖 Use AI to continuously analyze scenes for suspicious activity
# - Detect and differentiate **three levels of security threats**
# - 🚨 Trigger separate real-time alerts for each level to a webhook
#
# Let’s build it!

# %% [markdown]
# ---
#
# ## 📦 Step 1: Install Dependencies
#
# We’ll begin by installing the VideoDB SDK

# %%
# !pip install -q videodb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.9/95.9 kB 2.0 MB/s eta 0:00:00

# %% [markdown]
# ---
# ## 📦 Step 2: Connect to VideoDB
#
# Let's connect to VideoDB's API using your credentials to prepare for stream monitoring.
#
# Please enter your `VIDEO_DB_API_KEY` in the input box that appears below after you run this cell.
#
# Your input will be masked.

# %%
import videodb
import os
from getpass import getpass

api_key = getpass("Please enter your VideoDB API Key: ")

os.environ["VIDEO_DB_API_KEY"] = api_key

conn = videodb.connect()
coll = conn.get_collection()

print("Connected to VideoDB securely!")
# Out:
# Please enter your VideoDB API Key: ··········
# Connected to VideoDB securely!

# %% [markdown]
# ---
#
# ## 📦 Step 3: Connect to the Property Surveillance RTSP Stream
#
# We’ll connect to the live video stream of your property’s security camera.
#
# In this demo, the stream is running at `rtsp://samples.rts.videodb.io:8554/intruder`.

# %%
rtsp_url = "rtsp://samples.rts.videodb.io:8554/intruder"
intruder_stream = coll.connect_rtstream(
    name="Property Security Stream",
    url=rtsp_url,
    store=True,
)
print(intruder_stream)
# Out:
# RTStream(id=rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc, name=Property Security Stream, collection_id=c-81fc6459-fe30-44ac-8c5b-ea0898c2e152, created_at=2026-07-27T11:00:00.025314+00:00, sample_rate=30, status=connected, stream_url=None, player_url=None)

# %% [markdown]
# #### Let us list all the rtstreams in our collection.

# %%
def list_rtstreams():
    for rtstream in coll.list_rtstreams():
        print(f"""RTStream:
        ID            : {rtstream.id}
        Name          : {rtstream.name}
        Collection ID : {rtstream.collection_id}
        Created At    : {rtstream.created_at}
        Sample Rate   : {rtstream.sample_rate}
        Status        : {rtstream.status}
        """)
        print("-" * 80)

list_rtstreams()
# Out:
# RTStream:
#         ID            : rts-019ec150-442e-7ab3-a042-431a2fa14f88
#         Name          : Property Security Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T14:08:43.566534+00:00
#         Sample Rate   : 30
#         Status        : connected
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec145-ff1c-7903-9b07-7f728a38bcff
#         Name          : Arizona Flood Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
#         Created At    : 2026-06-13T13:57:30.525000+00:00
#         Sample Rate   : 30
#         Status        : stopped
#
# --------------------------------------------------------------------------------
# RTStream:
#         ID            : rts-019ec13f-81be-77e1-ac01-7ffd8d1d4c45
#         Name          : Cricket Finals Stream
#         Collection ID : c-5256e90f-4619-4451-9d23-071c1930bd34
# ...

# %% [markdown]
# #### If you have already connected the stream, run the below cell with the **rtstream id** to reconnect.

# %%
# intruder_stream = coll.get_rtstream("")

# %%
# To stop the stream
# intruder_stream.stop()

# %%
# To start the stream
# intruder_stream.start()

# %% [markdown]
# ---
# ### 👀 Let us have a look at the camera feed

# %% [markdown]
# #### 📺 Helper Functions: Search and Display
#
# This cell contains all the utility functions to search, fetch, and visualize video streams. You don't need to modify this code.

# %%
# To display the stream with relevant information

from IPython.display import HTML
import re
import time
from datetime import datetime, UTC
from videodb import play_stream


def display_stream(video_url, video_name="🎥 Camera Feed"):
    match = re.search(r"/(\d{16})-(\d{16})\.m3u8", video_url)
    if match:
        start_ts = int(match.group(1)) / 1e6
        end_ts = int(match.group(2)) / 1e6
        start_time = datetime.fromtimestamp(start_ts, UTC).strftime("%Y-%m-%d %H:%M:%S")
        end_time = datetime.fromtimestamp(end_ts, UTC).strftime("%Y-%m-%d %H:%M:%S")
        time_range = f"{start_time} → {end_time} UTC"
    else:
        time_range = "Time Unknown"

    video_player_html = play_stream(video_url)

    return HTML(f"""
    <div style="position:relative;width:640px;">
      {video_player_html._repr_html_() if hasattr(video_player_html, "_repr_html_") else video_player_html}
      <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
        <strong>{video_name}</strong><br>{time_range}
      </div>
    </div>
    """)


# To dynamically set the display duration


def prompt_to_time(prompt):
    now = int(time.time())
    prompt = (
        f"It's {now} in epoch seconds. "
        f"Convert the phrase '{prompt}' into JSON "
        f'with keys "from" and "to" (both epoch seconds)'
    )

    result = coll.generate_text(
        prompt=prompt,
        model_name="pro",
        response_type="json",
    )
    output = result.get("output", {})
    return output.get("from"), output.get("to")


# To fetch stream


def fetch_stream(rtstream):
    _from, to = prompt_to_time("Show me last 5 mins")
    rtstream.generate_stream(_from, to)
    return rtstream.stream_url

# %% [markdown]
# #### 🔗 Get & Display Recent Stream
#
# This cell uses the helper functions above to fetch and display the last few minutes of the stream.

# %%
# To get last few minutes stream link

video_url = fetch_stream(intruder_stream)

video_name = "🚨 Private Property · Intruder Detection"
display_stream(video_url, video_name)
# Out:
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc/1785149828000000-1785150128000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>🚨 Private Property · Intruder Detection</strong><br>2026-07-27 10:57:08 → 2026-07-27 11:02:08 UTC
#       </div>
#     </div>

# %% [markdown]
# ---
#
# ## 📦 Step 4: Continuously Understand and Index Suspicious Activity
#
# We’ll create a continuous visual understanding job that periodically analyzes video frames and generates natural language descriptions of what’s happening on the property. Its stored scene output is continuously indexed for retrieval and alerts.
#
# The AI will look for:
# - People loitering
# - Approaching or physically interacting with the door/lock
# - Attempting to enter the property

# %%
intruder_understanding = intruder_stream.understand(
    segmentation={"type": "time", "window": "5s"},
    analyzers=[
        {
            "type": "vlm",
            "name": "scene",
            "sampling": {"frame_count": 2},
            "config": {"prompt": "Monitor the area around the house closely. Detect and classify human presence around the house as either loitering, interacting with the door/lock, or entering the house; otherwise, consider the area safe."},
        }
    ],
    store=True,
)

scene_output = intruder_understanding.outputs.get("scene")
intruder_understanding_id = intruder_understanding.id
print("Understanding ID:", intruder_understanding_id)
# Out:
# Understanding ID: und-755c480b6d77757e

# %% [markdown]
# ### Create the Intruder Detection Index
#
# Create a continuous semantic index from the suspicious-activity output for retrieval and alerts.

# %%
intruder_scene_index = intruder_stream.index(
    source=scene_output,
    name="Intruder_Detection_Index",
    use_for=["semantic"],
)
intruder_index_id = intruder_scene_index.id
print("Scene Index ID:", intruder_index_id)
# Out:
# Scene Index ID: idx-b2c26142c21629d8

# %% [markdown]
# #### Let us list the continuous indexes created on our rtstream.

# %%
def list_rtstream_indexes(rtstream):
    # List continuous indexes
    rtstream_indexes = rtstream.list_indexes()
    for rtstream_index in rtstream_indexes:
        print(f"""RTStreamIndex:
            Index ID       : {rtstream_index.id}
            RTStream ID    : {rtstream_index.rtstream_id}
            Name           : {rtstream_index.name}
            Status         : {rtstream_index.status}
            Use for        : {rtstream_index.use_for}
            Source job     : {rtstream_index.source_understanding_id}
            Output         : {rtstream_index.output}
        """)
        print("-" * 80)

list_rtstream_indexes(intruder_stream)
# Out:
# RTStreamIndex:
#             Index ID       : idx-b2c26142c21629d8
#             RTStream ID    : rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc
#             Name           : Intruder_Detection_Index
#             Status         : running
#             Use for        : ['semantic']
#             Source job     : und-755c480b6d77757e
#             Output         : scene
#
# --------------------------------------------------------------------------------

# %% [markdown]
# #### If you have already created the continuous understanding and index, run the cell below with both IDs to reconnect.

# %%
# intruder_understanding_id = ""
# intruder_index_id = ""
# intruder_understanding = intruder_stream.get_understanding(
#     intruder_understanding_id
# )
# scene_output = intruder_understanding.outputs["scene"]
# intruder_scene_index = intruder_stream.get_index(intruder_index_id)

# %% [markdown]
# ---
# ### Let us review recent continuous index records

# %%
import json
import time

range_end = time.time()
range_start = range_end - (15 * 60)
crib_records_payload = intruder_scene_index.get_records(
    start=range_start,
    end=range_end,
    page=1,
    page_size=5,
)
print(json.dumps(crib_records_payload, indent=2, default=str))
# Out:
# {
#   "next_page": true,
#   "records": [
#     {
#       "description": "Safe \u2014 no visible human presence, loitering, door/lock interaction, or entry detected.",
#       "end": 1785150019.9948697,
#       "start": 1785150013.974858
#     },
#     {
#       "description": "Safe. No human presence detected around the house in a way that indicates loitering, door/lock interaction, or entering.",
#       "end": 1785150027.9948852,
#       "start": 1785150021.9548736
#     },
#     {
#       "description": "**Status: Safe**\n\nA human is visible near the left side of the yard, moving along the edge of the house area, but there is **no clear loitering, door/lock interaction, or entering of the house** detected in these frames.",
#       "end": 1785150035.9849005,
#       "start": 1785150029.9548888
#     },
#     {
#       "description": "Safe: no human presence detected around the house.",
#       "end": 1785150043.984916,
#       "start": 1785150037.9449043
#     },
#     {
# ...

# %% [markdown]
# ---
# ### 🔌 Step 4.5: Connect WebSocket for Real-Time Alerts

# %%
import asyncio

ws_wrapper = conn.connect_websocket()
ws = await ws_wrapper.connect()

print(f"WebSocket connected!")
print(f"Connection ID: {ws.connection_id}")
# Out:
# INFO:videodb.websocket_client:WebSocket connected with ID: gVXiMe7M7eO4KEi4kA==
# WebSocket connected!
# Connection ID: gVXiMe7M7eO4KEi4kA==

# %% [markdown]
# ---
# ## 🔌 WebSocket Connection (Optional)
#
# The `understand()` method accepts an optional `ws_connection_id` for receiving real-time updates through a WebSocket connection. This provides a persistent, bidirectional connection for instant event delivery.

# %%
# # Optional: Use WebSocket for real-time updates
# # Reuse the WebSocket connection opened above.
#
# # This optional lesson starts its own continuous job for WebSocket updates.
# websocket_understanding = intruder_stream.understand(
#     segmentation={"type": "time", "window": "5s"},
#     analyzers=[
#         {
#             "type": "vlm",
#             "name": "scene",
#             "sampling": {"frame_count": 2},
#             "config": {"prompt": "Monitor the area around the house closely. Detect and classify human presence around the house as either loitering, interacting with the door/lock, or entering the house; otherwise, consider the area safe."},
#         }
#     ],
#     store=True,
#     ws_connection_id=ws.connection_id,
# )
#
# websocket_scene_output = websocket_understanding.outputs.get("scene")

# %% [markdown]
# ### Index the WebSocket Output (Optional)
#
# Create the continuous index from the WebSocket understanding output.

# %%
# websocket_scene_index = intruder_stream.index(
#     source=websocket_scene_output,
#     name="Intrusion_WebSocket_Index",
#     use_for=["semantic"],
# )
#
# # Stop the optional jobs when done.
# websocket_scene_index.stop()
# websocket_understanding.stop()

# %% [markdown]
# ---
# ## 🎤 Audio Indexing & Transcription
#
# VideoDB RTStream also supports audio analysis for streams with audio content. You can:
# - **Index Audio**: Extract structured information from audio streams using AI prompts
# - **Start Transcription**: Get real-time speech-to-text transcription
#
# These features work alongside visual indexing to provide comprehensive stream analysis.

# %%
# # Audio Indexing Example (if stream has audio)
# audio_index = intruder_stream.index_audio(
#     prompt="Detect suspicious sounds like glass breaking, door forcing, voices, or footsteps. Extract information about potential intrusion indicators.",
#     batch_config={"type": "time", "value": 30},  # Segment every 30 seconds
#     name="Property_Security_Audio_Index"
# )

# %% [markdown]
# ### Start Real-Time Transcription (Optional)
#
# Start transcription and inspect the resulting speech-to-text records.

# %%
# # Real-time Transcription Example
# # Get speech-to-text transcription in real-time
# intruder_stream.start_transcript(ws_connection_id=ws.connection_id)
#
# # Poll transcript data
# transcript = intruder_stream.get_transcript(
#     start=0,
#     end=None,
#     page=1,
#     page_size=100
# )
# print("Transcript data:", transcript)
#
# # Stop transcription when done
# intruder_stream.stop_transcript()

# %% [markdown]
# ---
# ## 🚨 Level 1 Breach: Loitering Near the Property
#
# We’ll start by creating an event to detect people **loitering or lingering around the property** without actually touching or interacting with it.
#
# Then, we’ll immediately attach an alert to this event, so you get notified in real time.

# %% [markdown]
# ---
# #### Step 5: Set Up Alerts

# %%
# Alert IDs will be stored here for cleanup
print("WebSocket ready. Creating alerts...")
# Out:
# WebSocket ready. Creating alerts...

# %% [markdown]
# ---
#
# ### 📦 Create Event for Loitering Detection
#
# This event will flag when someone is spotted loitering near your property boundary.

# %%
loitering_event_id = conn.create_event(
    event_prompt="Detect if a person is loitering near the house perimeter.",
    label="loitering_near_property"
)
print("Loitering Event ID:", loitering_event_id)
# Out:
# Loitering Event ID: 394f2811259c0685

# %% [markdown]
# ---
#
# ### 📦 Create Alert for Level 1 Breach
#
# As soon as the AI detects a loitering event, it’ll send a webhook alert notification.

# %%
import os

RTSTREAM_ALERT_CALLBACK_URL = "https://example.com"
loitering_alert_id = intruder_scene_index.create_alert(
    event_id=loitering_event_id,
    callback_url=RTSTREAM_ALERT_CALLBACK_URL,
    ws_connection_id=ws.connection_id,
)
print("Loitering Alert ID:", loitering_alert_id)
# Out:
# Loitering Alert ID: 31688c006682348f

# %% [markdown]
# ---
#
# ## 🚨 Level 2 Breach: Door Checking or Lock Tampering
#
# Next, we’ll set up an event to detect when someone moves close to the front door and appears to check or tamper with the lock — a higher severity intrusion attempt.
#
# Then, we’ll link a dedicated alert to this event.

# %% [markdown]
# ---
#
# ### 📦 Create Event for Intrusion Attempt
#
# This event will flag when a person approaches the property’s door and visibly interacts with it.

# %%
intrusion_event_id = conn.create_event(
    event_prompt="Detect if a person is interacting with the door or visibly checking the lock.",
    label="intrusion_attempt"
)
print("Intrusion Attempt Event ID:", intrusion_event_id)
# Out:
# Intrusion Attempt Event ID: 21353c133cf02b62

# %% [markdown]
# ---
#
# ### 📦 Create Alert for Level 2 Breach
#
# When AI detects this activity, an instant alert will be routed to your webhook.

# %%
intrusion_alert_id = intruder_scene_index.create_alert(
    event_id=intrusion_event_id,
    callback_url=RTSTREAM_ALERT_CALLBACK_URL,
    ws_connection_id=ws.connection_id,
)
print("Intrusion Alert ID:", intrusion_alert_id)
# Out:
# Intrusion Alert ID: ccd19c8bf01b8f41

# %% [markdown]
# ---
#
# ## 🚨 Level 3 Breach: Unauthorized Property Entry
#
# Lastly, we’ll define an event to catch the most serious scenario — **someone entering the property**.
#
# Then, we’ll configure a real-time alert for it.

# %% [markdown]
# ---
#
# ### 📦 Create Event for Property Entry
#
# This event triggers when AI spots someone crossing into the property, opening a door, or entering the house.

# %%
entry_event_id = conn.create_event(
    event_prompt="Detect if a person enters the house or crosses the property boundary unlawfully.",
    label="property_entry"
)
print("Property Entry Event ID:", entry_event_id)
# Out:
# Property Entry Event ID: 9dd8eec159e0f68b

# %% [markdown]
# ---
#
# ### 📦 Create Alert for Level 3 Breach
#
# The AI will send an immediate webhook alert for this highest-severity breach.

# %%
entry_alert_id = intruder_scene_index.create_alert(
    event_id=entry_event_id,
    callback_url=RTSTREAM_ALERT_CALLBACK_URL,
    ws_connection_id=ws.connection_id,
)
print("Entry Alert ID:", entry_alert_id)
# Out:
# Entry Alert ID: 42c8e56b67faa26e

# %% [markdown]
# ---
# ### Lets see the events and alerts we have set up

# %%
def list_rtstream_alerts(rtstream, index_id):
    """
    Prints a list of alerts associated with a given continuous index.
    """
    rtstream_index = rtstream.get_index(index_id)
    alerts = rtstream_index.list_alerts()

    for alert in alerts:
        print(f"""🔔 RTStream Alert:
    Alert ID      : {alert['alert_id']}
    Event ID      : {alert['event_id']}
    Label         : {alert['label']}
    Prompt        : {alert['prompt']}
    Status        : {alert['status']}
        """)
        print("-" * 80)

list_rtstream_alerts(intruder_stream, intruder_index_id)
# Out:
# 🔔 RTStream Alert:
#     Alert ID      : 31688c006682348f
#     Event ID      : 394f2811259c0685
#     Label         : loitering_near_property
#     Prompt        : Detect if a person is loitering near the house perimeter.
#     Status        : enabled
#
# --------------------------------------------------------------------------------
# 🔔 RTStream Alert:
#     Alert ID      : 42c8e56b67faa26e
#     Event ID      : 9dd8eec159e0f68b
#     Label         : property_entry
#     Prompt        : Detect if a person enters the house or crosses the property boundary unlawfully.
#     Status        : enabled
#
# --------------------------------------------------------------------------------
# 🔔 RTStream Alert:
#     Alert ID      : ccd19c8bf01b8f41
#     Event ID      : 21353c133cf02b62
#     Label         : intrusion_attempt
#     Prompt        : Detect if a person is interacting with the door or visibly checking the lock.
#     Status        : enabled
#
# ...

# %% [markdown]
# ---
# ## 📦 Step 6: Listen for Real-Time Alerts
#
# Listen for incoming WebSocket alerts across all 3 breach levels.

# %%
received_alerts = []

async def listen_for_alerts():
    timeout = 30
    print(f"Listening for intruder alerts ({timeout} seconds)...")
    print("Watching for loitering, intrusion attempt, and property entry\n")
    try:
        async with asyncio.timeout(timeout):
            async for msg in ws.receive():
                if isinstance(msg, dict) and msg.get("channel") == "alert":
                    received_alerts.append(msg)
                    data = msg.get("data") or msg
                    if not isinstance(data, dict):
                        data = {}
                    print(f"\nALERT #{len(received_alerts)} RECEIVED!")
                    print(f"  Event     : {data.get('label', 'N/A')}")
                    print(f"  Time      : {msg.get('timestamp', 'N/A')}")
                    print(f"  Confidence: {data.get('confidence', 'N/A')}")
                    print(f"  Clip URL  : {data.get('stream_url', 'N/A')}")
                    print(f"  Details   : {str(data.get('explanation', 'N/A'))[:150]}")
    except asyncio.TimeoutError:
        print(f"\nListening complete! {len(received_alerts)} alert(s) received")

await listen_for_alerts()
# Out:
# Listening for intruder alerts (30 seconds)...
# Watching for loitering, intrusion attempt, and property entry
#
#
# ALERT #1 RECEIVED!
#   Event     : loitering_near_property
#   Time      : 2026-07-27T11:03:49.317820+00:00
#   Confidence: 0.95
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc/1785150216000000-1785150224000000.m3u8
#   Details   : A person is present in the yard/drive area and appears to be lingering away from the door, which matches the loitering alert context.
#
# ALERT #2 RECEIVED!
#   Event     : intrusion_attempt
#   Time      : 2026-07-27T11:03:51.910338+00:00
#   Confidence: 0.93
#   Clip URL  : https://rt.stream.videodb.io/manifests/rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc/1785150216000000-1785150224000000.m3u8
#   Details   : A person is present in the yard/drive area and appears to be lingering away from the door rather than interacting with it, which matches the loitering
#
# ...

# %%
if received_alerts:
    first = received_alerts[0]
    data = (first.get("data") or first) if isinstance(first, dict) else {}
    data = data if isinstance(data, dict) else {}
    clip_url = data.get("stream_url")
    label = data.get("label", "intruder")
    video_name = f"Private Property · {label}"
    print(f"  Confidence : {data.get('confidence', 'N/A')}")
    print(f"  Explanation: {data.get('explanation', 'N/A')}\n")
    if isinstance(clip_url, str) and clip_url.strip():
        display(display_stream(clip_url, video_name))
    else:
        print("Alert received without a playable stream_url.")
else:
    print("No alerts received yet.")
# Out:
#   Confidence : 0.95
#   Explanation: A person is present in the yard/drive area and appears to be lingering away from the door, which matches the loitering alert context.
#     <div style="position:relative;width:640px;">
#
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc/1785150216000000-1785150224000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#
#       <div style="position:absolute;top:10px;left:10px;background:rgba(0,0,0,0.6);color:#fff;padding:6px 12px;border-radius:4px;font-size:13px;font-family:sans-serif;">
#         <strong>Private Property · loitering_near_property</strong><br>2026-07-27 11:03:36 → 2026-07-27 11:03:44 UTC
#       </div>
#     </div>

# %%
import json

if received_alerts:
    print(json.dumps(received_alerts[0], indent=2))
else:
    print("No alerts captured yet.")
# Out:
# {
#   "channel": "alert",
#   "timestamp": "2026-07-27T11:03:49.317820+00:00",
#   "rtstream_id": "rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc",
#   "rtstream_name": "Property Security Stream",
#   "data": {
#     "event_id": "alert-31688c006682348f",
#     "label": "loitering_near_property",
#     "triggered": true,
#     "confidence": 0.95,
#     "start": 1785150216.9952714,
#     "end": 1785150223.9452853,
#     "player_url": "https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc/1785150216000000-1785150224000000.m3u8",
#     "stream_url": "https://rt.stream.videodb.io/manifests/rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc/1785150216000000-1785150224000000.m3u8",
#     "explanation": "A person is present in the yard/drive area and appears to be lingering away from the door, which matches the loitering alert context."
#   }
# }

# %% [markdown]
# ---
# ### 📡 WebSocket Alert Payload (Live Integration Check)
#
# The display cells above preserve the payload fields used by this live demo. The SDK and documentation do not guarantee the received alert envelope or playback URL, so validate these fields against a live stream before relying on them in an integration.
#
# ```python
# {
#   "channel": "alert",
#   "timestamp": "2026-07-27T11:03:49.317820+00:00",
#   "rtstream_id": "rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc",
#   "rtstream_name": "Property Security Stream",
#   "data": {
#     "event_id": "alert-31688c006682348f",
#     "label": "loitering_near_property",
#     "triggered": true,
#     "confidence": 0.95,
#     "start": 1785150216.9952714,
#     "end": 1785150223.9452853,
#     "player_url": "https://console.videodb.io/player?url=https://rt.stream.videodb.io/manifests/rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc/1785150216000000-1785150224000000.m3u8",
#     "stream_url": "https://rt.stream.videodb.io/manifests/rts-019fa33b-4b99-7ed0-a1e3-6a0f809886cc/1785150216000000-1785150224000000.m3u8",
#     "explanation": "A person is present in the yard/drive area and appears to be lingering away from the door, which matches the loitering alert context."
#   }
# }
# ```

# %% [markdown]
# ---
# ## Cleanup
#
# Disable all alerts, stop the continuous index and understanding, stop the stream, then close the WebSocket.

# %% [markdown]
# **💡 What just happened?**
#
# - We connected to VideoDB's WebSocket for real-time event delivery
# - Created 3 alert levels: Loitering, Intrusion Attempt, and Property Entry
# - Listened for 30 seconds for alerts across the three stages
# - The received alert payload and optional clip URL must be verified against a live stream; the display and playback cells above preserve the demo integration
#
# **⚡ Why WebSockets?**
# - **Instant delivery**: Alerts arrive in real-time as events happen
# - **Live dashboards**: Perfect for building interactive monitoring interfaces
# - **Two-way communication**: Can send and receive data on the same connection
#
# > **💡 Callback + WebSocket delivery**
# > Configure a public callback URL for alert delivery, and also pass `ws_connection_id` to receive the same alerts over the WebSocket.

# %%
# The continuous index wrapper manages all three staged alert rules.
intruder_scene_index.disable_alert(loitering_alert_id)
intruder_scene_index.disable_alert(intrusion_alert_id)
intruder_scene_index.disable_alert(entry_alert_id)
print("All alerts disabled")

intruder_scene_index.stop()
intruder_understanding.stop()
print("Continuous index and understanding stopped")
# Out:
# All alerts disabled
# Continuous index and understanding stopped

# %% [markdown]
# - Stop the stream, then close the WebSocket last:

# %%
intruder_stream.stop()
print("Stream stopped")

await ws_wrapper.close()
print("WebSocket closed")
# Out:
# Stream stopped
# WebSocket closed

# %% [markdown]
# <div style="background-color: #d4edda; color: #155724; padding: 12px; border-left: 5px solid #28a745; border-radius: 4px;">
#     <strong>🎉 Success!</strong> You've built a complete AI-powered property intrusion detection system — from live stream to real-time WebSocket alerts!
# </div>

# %% [markdown]
# ---
#
# ## 🌙 Wrapping Up: Smarter Property Security Without Stress
#
# In this notebook, we built a **layered AI-powered video surveillance system** to protect your property in real time.
#
# With this in place, property owners can leave home without anxiety, knowing they’ll be immediately notified if anyone is:
# - **Loitering nearby**
# - **Interacting with the door**
# - **Or breaking in**
#
# ---
#
# ## 🔍 What Else Could We Secure?
#
# This layered security system isn’t limited to homes. It can just as easily protect:
# - 🏬 **Retail stores from shoplifters**
# - 🏢 **Warehouse perimeters and restricted areas**
# - 🛡️ **Military bases and government installations**
# - 🏫 **Schools and public buildings**
#
# **What would *you* secure next?**
