# %% [markdown]
# # Property Intrusion Detection with VideoDB RTStream
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/real_time_streaming/Intrusion_Detection.ipynb)
#
# This notebook builds a real-time property surveillance monitor for an RTSP security-camera feed.
#
# You will use VideoDB RTStream to:
#
# - Connect to a live property surveillance feed.
# - Preview recent camera footage.
# - Continuously understand the stream with a VLM.
# - Continuously index the VLM output for search and alerts.
# - Detect loitering, door/lock tampering, and property entry.
# - Receive WebSocket alerts and display evidence clips when available.
#
# After connecting the RTStream, wait 1-2 minutes before running this cell so VideoDB has enough buffered footage to generate a recent playback window.

# %% [markdown]
# ## 1. Install VideoDB
#
# Install VideoDB and notebook dependencies.

# %%
# !pip install -q videodb python-dotenv

# %% [markdown]
# ## 2. Connect to VideoDB
#
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import os
import time
import asyncio
from datetime import datetime
from getpass import getpass
from uuid import uuid4

from IPython.display import display
from videodb import connect, play_stream

api_key = getpass("Enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key

conn = connect()
coll = conn.get_collection()

print("Connected to VideoDB successfully.")
# Out:
# Enter your VideoDB API Key: ··········
# Connected to VideoDB

# %% [markdown]
# ## 3. Connect to the Property Surveillance RTSP Feed
#
# This sample feed behaves like a property security camera. If you already created an RTStream, you can reconnect by ID instead of creating a new stream.

# %%
rtsp_url = "rtsp://samples.rts.videodb.io:8554/intruder"

intruder_stream = coll.connect_rtstream(
    name="Property Intrusion Monitor",
    url=rtsp_url,
    store=True,
)

print(f"RTStream ID: {intruder_stream.id}")
print(f"Status: {intruder_stream.status}")
# Out:
# RTStream ID: rts-019f3f75-420e-7ba2-88a7-853b68c4ad87
# Status: connected

# %%
# Reconnect to an existing stream instead of creating a new one:
# intruder_stream = coll.get_rtstream("your-rtstream-id")

# %% [markdown]
# ## 4. Preview Recent Stream Footage
#
# RTStream playback uses Unix timestamps. Connect WebSocket, generate a recent stream window, then play `intruder_stream.stream_url`.

# %%
# Connect WebSocket
ws_wrapper = conn.connect_websocket()
ws = await ws_wrapper.connect()
print(f"WebSocket connected! Connection ID: {ws.connection_id}")

# Preview last 2 minutes
now = int(time.time())
intruder_stream.generate_stream(now - 120, now)
play_stream(intruder_stream.stream_url)
# Out:
# INFO:videodb.websocket_client:WebSocket connected with ID: gTX0i-4pgQAYKEh1XA==
# WebSocket connected! Connection ID: gTX0i-4pgQAYKEh1XA==
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://videodb-rt-streaming-service-us-east-1.s3.us-east-1.amazonaws.com/manifests/rts-019f3f75-420e-7ba2-88a7-853b68c4ad87/1783476063000000-1783476183000000.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 5. Start Continuous Security Understanding
#
# For RTStreams, `understand()` runs continuously. Here a VLM inspects every 7-second window and describes property security activity.

# %%
security_prompt = """
Monitor the property entrance, yard, and perimeter for security threats.

Look for:
1. LOITERING: a person lingering near the property without interacting with doors or windows.
2. INTRUSION ATTEMPT: a person checking, touching, forcing, or tampering with a door, lock, window, or entry point.
3. PROPERTY ENTRY: a person crossing into the property, opening a door, entering the house, or clearly breaching the protected area.

If suspicious activity is visible, describe it with this structure:
Security Alert
Breach Level: loitering_near_property, intrusion_attempt, property_entry, or multiple
Severity: low, medium, or high
Evidence: brief visual evidence
Recommended Action: concise next step

If the property appears safe, respond with:
Property Area Safe
"""

security_understanding = intruder_stream.understand(
    segmentation={"type": "time", "window": "7s"},
    analyzers=[
        {
            "type": "vlm",
            "name": "scene",
            "sampling": {"frame_count": 5},
            "config": {
                "model": "pro",
                "prompt": security_prompt,
            },
        }
    ],
    store=True,
    ws_connection_id=ws.connection_id,
)

print(f"Understanding ID: {security_understanding.id}")
print(f"Status: {security_understanding.status}")
# Out:
# Understanding ID: und-a11722939b77fb90
# Status: running

# %% [markdown]
# ## 6. Continuously Index the Understanding Output
#
# The VLM output is a continuous source. `rtstream.index()` keeps indexing new windows as they are produced.

# %%
SECURITY_INDEX_NAME = f"property_security_{uuid4().hex[:8]}"

security_index = intruder_stream.index(
    name=SECURITY_INDEX_NAME,
    source=security_understanding.outputs["scene"],
    use_for=["semantic"],
)

security_index_id = getattr(security_index, "id", security_index)

if not hasattr(security_index, "get_records"):
    print("Waiting for security index to become available...")
    while True:
        try:
            security_index = intruder_stream.get_index(security_index_id)
            break
        except Exception as exc:
            if "not found" not in str(exc).lower():
                raise
            time.sleep(5)

print(f"Index name: {SECURITY_INDEX_NAME}")
print(f"Index ID: {security_index_id}")
print(f"Status: {getattr(security_index, 'status', 'running')}")
# Out:
# Index name: property_security_ef7a1ef0
# Index ID: idx-722ebc45f87c6ac2
# Status: running

# %% [markdown]
# ## 7. Inspect Recent Indexed Windows
#
# RTStream understanding and indexing jobs stay `running` while the live feed is active. This cell checks recent indexed VLM windows before search and alerts.

# %%
def format_ts(ts):
    try:
        return datetime.fromtimestamp(float(ts)).strftime("%Y-%m-%d %H:%M:%S")
    except Exception:
        return str(ts)


def extract_record_text(record):
    data = record.get("data") if isinstance(record, dict) else None
    if isinstance(data, dict):
        return data.get("text") or data.get("description") or data.get("scene_description") or str(data)
    return record.get("text") or record.get("description") or str(record)


def get_recent_records(index, page_size=5):
    end = int(time.time()) - 30
    start = end - 300

    try:
        payload = index.get_records(start=start, end=end, page=1, page_size=page_size)
    except TypeError:
        payload = index.get_records(page_size=page_size)

    if isinstance(payload, dict):
        return payload.get("records") or payload.get("scenes") or []
    return payload or []


def wait_for_records(index, timeout=300, poll_interval=10):
    deadline = time.time() + timeout
    while time.time() < deadline:
        records = get_recent_records(index)
        if records:
            return records
        time.sleep(poll_interval)
    raise RuntimeError(
        "No indexed records were available yet. Confirm the RTStream preview is playable and the understanding/index jobs are running."
    )


print("Waiting for indexed security observations. This can take 1-3 minutes...")
recent_records = wait_for_records(security_index)

for record in recent_records[:5]:
    start = format_ts(record.get("start"))
    end = format_ts(record.get("end"))
    print("-" * 80)
    print(f"{start} -> {end}")
    print(extract_record_text(record))
# Out:
# Waiting for indexed security observations. This can take 1-3 minutes...
# --------------------------------------------------------------------------------
# 2026-07-08 02:03:22 -> 2026-07-08 02:03:30
# Security Alert
# Breach Level: property_entry
# Severity: medium
# Evidence: Person visible in multiple frames walking inside the yard near the left side of the property (nighttime), no visible interaction with doors or windows.
# Recommended Action: Do not approach — turn on exterior lights/siren if available, start a live camera feed, and contact local authorities with time-stamped video.
# --------------------------------------------------------------------------------
# 2026-07-08 02:03:12 -> 2026-07-08 02:03:20
# Security Alert
# Breach Level: loitering_near_property
# Severity: medium
# Evidence: Person visible walking/lingering along the left perimeter near the trees and fence at night; no door/window interaction or entry observed.
# ...

# %% [markdown]
# ## 8. Search for Security Risks
#
# Search the indexed stream windows for likely security breaches and review matching timestamps and descriptions. Evidence clips are displayed from real-time alert payloads in the alert section.

# %%
query = "loitering near property, door lock tampering, intrusion attempt, person entering house"

try:
    security_results = intruder_stream.search(
        query=query,
        index_id=security_index_id,
        score_threshold=0.4,
    )
    shots = getattr(security_results, "shots", None) or security_results.get_shots()
except Exception as exc:
    print(f"No searchable security results yet: {exc}")
    shots = []

if shots:
    for idx, shot in enumerate(shots[:5], start=1):
        text = getattr(shot, "text", "") or getattr(shot, "description", "")
        print(f"{idx}. {format_ts(shot.start)} -> {format_ts(shot.end)}")
        print(text[:500])
        print()
else:
    print("No matching windows yet. Let the stream run longer or lower the score threshold.")
# Out:
# 1. 2026-07-08 02:03:12 -> 2026-07-08 02:03:20
# Security Alert
# Breach Level: loitering_near_property
# Severity: medium
# Evidence: Person visible walking/lingering along the left perimeter near the trees and fence at night; no door/window interaction or entry observed.
# Recommended Action: Continue recording and monitor closely; notify homeowner or security and consider triggering a warning alarm/intercom; contact police if the person remains, approaches structures, or behavior escalates.

# %% [markdown]
# ## 9. Create Security Events
#
# Events define what should trigger alerts. This notebook creates one event for each security breach level.

# %%
loitering_event_id = conn.create_event(
    event_prompt="Detect when a person is loitering or lingering near the property perimeter without interacting with the property.",
    label="loitering_near_property",
)

intrusion_event_id = conn.create_event(
    event_prompt="Detect when a person approaches and visibly checks, touches, tampers with, or forces a door, lock, window, or entry point.",
    label="intrusion_attempt",
)

entry_event_id = conn.create_event(
    event_prompt="Detect when a person crosses into the protected property area, opens a door, or enters the house.",
    label="property_entry",
)

event_ids = {
    "loitering_near_property": loitering_event_id,
    "intrusion_attempt": intrusion_event_id,
    "property_entry": entry_event_id,
}

for label, event_id in event_ids.items():
    print(f"{label}: {event_id}")
# Out:
# loitering_near_property: e464a5f0124ef1ba
# intrusion_attempt: dbc8a85912e7c03f
# property_entry: ab820d284d93b000

# %% [markdown]
# ## 10. Attach Alerts
#
# Attach alerts to the security index and receive alert events over the existing WebSocket. The callback URL is used for server-to-server delivery.

# %%
WEBHOOK_URL = "https://example.com/videodb-alerts"

alert_ids = {}
for label, event_id in event_ids.items():
    alert_ids[label] = security_index.create_alert(
        event_id=event_id,
        callback_url=WEBHOOK_URL,
        ws_connection_id=ws.connection_id,
    )
    print(f"{label} alert: {alert_ids[label]}")
# Out:
# loitering_near_property alert: a506afa19db36027
# intrusion_attempt alert: 356030a93f929c49
# property_entry alert: c23a5382248047e0

# %% [markdown]
# ## 11. Listen for Real-Time Alerts
#
# The listener runs for 30 seconds. If alerts arrive, the next cell can display the evidence clips.

# %%
received_alerts = []


async def listen_for_alerts(timeout=30):
    print(f"Listening for property security alerts ({timeout} seconds)...")
    try:
        async with asyncio.timeout(timeout):
            async for msg in ws.receive():
                if msg.get("channel") != "alert":
                    continue

                received_alerts.append(msg)
                data = msg.get("data", {})
                print(f"\nAlert #{len(received_alerts)}")
                print(f"Label: {data.get('label', 'N/A')}")
                print(f"Confidence: {data.get('confidence', 'N/A')}")
                print(f"Explanation: {data.get('explanation', 'N/A')}")
    except asyncio.TimeoutError:
        print(f"\nListening complete. Alerts received: {len(received_alerts)}")
    except Exception as exc:
        print(f"\nWebSocket closed while listening: {exc}")
        print("Reconnect WebSocket, recreate alerts with the new connection ID, then listen again.")


await listen_for_alerts()
# Out:
# Listening for property security alerts (30 seconds)...
#
# Alert #1
# Label: loitering_near_property
# Confidence: 0.75
# Explanation: A faint human silhouette is visible lingering near the entrance/gate at the property edge without interacting with doors or windows, matching the loitering criterion; confidence is reduced by the faint/partial visibility.
#
# Alert #2
# Label: loitering_near_property
# Confidence: 0.75
# Explanation: A person is visible walking along the property perimeter near the building without interacting with doors or windows, which aligns with loitering_near_property criteria; intent is ambiguous so trigger alert with moderate confidence and recommend checking live feed and activating lights/recording.
#
# Alert #3
# Label: property_entry
# Confidence: 0.7
# ...

# %%
if received_alerts:
    for idx, alert in enumerate(received_alerts[:4], start=1):
        data = alert.get("data", {})
        clip_url = data.get("stream_url")

        print(f"\nAlert #{idx}")
        print(f"Label: {data.get('label', 'N/A')}")
        print(f"Confidence: {data.get('confidence', 'N/A')}")
        print(f"Explanation: {data.get('explanation', 'N/A')}")

        if clip_url:
            display(play_stream(clip_url))
        else:
            print("No evidence clip URL was included in this alert payload.")
else:
    print("No alerts received yet. Keep the stream running and listen again.")
# Out:
# Alert #1
# Label: loitering_near_property
# Confidence: 0.75
# Explanation: A faint human silhouette is visible lingering near the entrance/gate at the property edge without interacting with doors or windows, matching the loitering criterion; confidence is reduced by the faint/partial visibility.
# No evidence clip URL was included in this alert payload.
#
# Alert #2
# Label: loitering_near_property
# Confidence: 0.75
# Explanation: A person is visible walking along the property perimeter near the building without interacting with doors or windows, which aligns with loitering_near_property criteria; intent is ambiguous so trigger alert with moderate confidence and recommend checking live feed and activating lights/recording.
# No evidence clip URL was included in this alert payload.
#
# Alert #3
# Label: property_entry
# Confidence: 0.7
# ...

# %% [markdown]
# ## 12. Alert Management and Cleanup
#
# Disable alerts and stop continuous jobs when you finish the demo to avoid unnecessary processing.

# %%
for label, alert_id in alert_ids.items():
    try:
        security_index.disable_alert(alert_id)
        print(f"{label} alert disabled")
    except Exception as exc:
        print(f"{label} alert cleanup skipped: {exc}")

try:
    security_index.stop()
    print("Index stopped")
except Exception as exc:
    print(f"Index stop skipped: {exc}")

try:
    security_understanding.stop()
    print("Understanding stopped")
except Exception as exc:
    print(f"Understanding stop skipped: {exc}")

try:
    await ws_wrapper.close()
    print("WebSocket closed")
except Exception as exc:
    print(f"WebSocket cleanup skipped: {exc}")

try:
    intruder_stream.stop()
    print("RTStream stopped")
except Exception as exc:
    print(f"RTStream stop skipped: {exc}")
# Out:
# loitering_near_property alert disabled
# intrusion_attempt alert disabled
# property_entry alert disabled
# Index stopped
# Understanding stopped
# WebSocket closed
# RTStream stopped

# %% [markdown]
# ## Further Resources
#
# - [Understand and Index RTStreams](https://videodb-docs-indexing-search-v2.mintlify.app/pages/ingest/live-streams/rtstream-understand-index)
# - [Search and Retrieval](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/search-and-retrieval/natural-language-query)
#
# You now have a complete RTStream property-security loop: live feed -> continuous visual understanding -> continuous index -> search and alerts -> evidence playback.
