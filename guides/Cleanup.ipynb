# %% [markdown]
# ## Guide: Cleanup
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/guides/Cleanup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ⚠️ **WARNING** ⚠️
#
# 🔴 **PROCEED WITH CAUTION: This notebook contains operations that will permanently delete media files from your VideoDB account.**
#
# 🚨 **IMPORTANT: Make sure to carefully review all media files before deletion as this action cannot be undone.**
#
# This guide helps you delete media files and clean up storage from your VideoDB account. You'll learn how to:
#
# * Delete videos
# * Remove audio files
# * Clean up images

# %% [markdown]
# ## 🛠️ Setup
# ---

# %% [markdown]
# Before proceeding, ensure access to [VideoDB](https://videodb.io) API key.

# %%
# %pip install videodb
# Out:
# Requirement already satisfied: videodb in /Users/thexshivam/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages (0.4.4)
# Requirement already satisfied: requests>=2.25.1 in /Users/thexshivam/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages (from videodb) (2.33.1)
# Requirement already satisfied: backoff>=2.2.1 in /Users/thexshivam/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages (from videodb) (2.2.1)
# Requirement already satisfied: tqdm>=4.66.1 in /Users/thexshivam/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages (from videodb) (4.67.3)
# Requirement already satisfied: websockets>=11.0.3 in /Users/thexshivam/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages (from videodb) (16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/thexshivam/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages (from requests>=2.25.1->videodb) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thexshivam/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages (from requests>=2.25.1->videodb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/thexshivam/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages (from requests>=2.25.1->videodb) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/thexshivam/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages (from requests>=2.25.1->videodb) (2026.2.25)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import videodb
import os
from getpass import getpass

api_key = getpass("Please enter your VideoDB API Key: ")

os.environ["VIDEO_DB_API_KEY"] = api_key

conn = videodb.connect()
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# Cell In[2], line 5
#       1 import videodb
#       2 import os
#       3 from getpass import getpass
#       4
# ----> 5 api_key = getpass("Please enter your VideoDB API Key: ")
#       6
#       7 os.environ["VIDEO_DB_API_KEY"] = api_key
#       8
#
# File ~/.cache/uv/archive-v0/Ob95VHMdmQ-yPH8eoxiKx/lib/python3.12/site-packages/ipykernel/kernelbase.py:1377, in Kernel.getpass(self, prompt, stream)
#    1375 if not self._allow_stdin:
#    1376     msg = "getpass was called, but this frontend does not support input requests."
# -> 1377     raise StdinNotImplementedError(msg)
#    1378 if stream is not None:
#    1379     import warnings
#
# StdinNotImplementedError: getpass was called, but this frontend does not support input requests.

# %% [markdown]
# ## Review Collections
# ---

# %%
colls = conn.get_collections()

print(f"There are {len(colls)} collections")
print()

for coll in colls:
    videos = coll.get_videos()
    audios = coll.get_audios()
    images = coll.get_images()
    
    print(f"Collection '{coll.name}' (id: {coll.id})")
    print(f"  - Videos : {len(videos)}")
    print(f"  - Audio  : {len(audios)}")
    print(f"  - Images : {len(images)}")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 colls = conn.get_collections()
#       2
#       3 print(f"There are {len(colls)} collections")
#       4 print()
#
# NameError: name 'conn' is not defined

# %% [markdown]
# ## Set the Collection
# ---

# %% [markdown]
# Set the Collection you wish to cleanup to this id

# %%
collection_id = "YOUR_COLLECTION_ID_HERE"

# %% [markdown]
# ### ⚠️ Delete All Videos
# ---

# %%
coll = conn.get_collection(collection_id)
videos = coll.get_videos()

for video in videos:
    video.delete()
    print(f"Deleted video {video.name} ({video.id})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 coll = conn.get_collection(collection_id)
#       2 videos = coll.get_videos()
#       3
#       4 for video in videos:
#
# NameError: name 'conn' is not defined

# %% [markdown]
# ### ⚠️ Delete All Audios
#
# ---

# %%
coll = conn.get_collection(collection_id)
audios = coll.get_audios()

for audio in audios:
    audio.delete()
    print(f"Deleted audio {audio.name} ({audio.id})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 coll = conn.get_collection(collection_id)
#       2 audios = coll.get_audios()
#       3
#       4 for audio in audios:
#
# NameError: name 'conn' is not defined

# %% [markdown]
# ### ⚠️ Delete All Images
#
# ---

# %%
coll = conn.get_collection(collection_id)
images = coll.get_images()

for image in images:
    image.delete()
    print(f"Deleted image {image.name} ({image.id})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 coll = conn.get_collection(collection_id)
#       2 images = coll.get_images()
#       3
#       4 for image in images:
#
# NameError: name 'conn' is not defined
