# %% [markdown]
# # Generate Media with VideoDB
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/guides/genai.ipynb)
#
# This notebook is a practical tour of VideoDB's generative media APIs.
#
# You will learn how to:
#
# - Generate images from prompts.
# - Generate music and sound effects.
# - Generate AI voiceovers.
# - Generate short videos.
# - Search YouTube for source videos.
# - Translate a video transcript using `understand()` and text generation.
# - Dub an existing video into another language.
#
# The transcript translation section uses VideoDB's new understanding pipeline instead of the legacy spoken-word indexing flow.

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q videodb python-dotenv

# %% [markdown]
# ## 2. Connect to VideoDB
#
# Enter your VideoDB API key when prompted.
#
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import os
from getpass import getpass

from IPython.display import Audio, Image
from videodb import connect

os.environ["VIDEO_DB_API_KEY"] = getpass("Please enter your VideoDB API Key: ")

conn = connect()
coll = conn.get_collection()

print("Connected to VideoDB successfully.")
# Out:
# Please enter your VideoDB API Key: ··········
# Connected to VideoDB successfully.

# %% [markdown]
# ## 3. Generate an Image
#
# Use `generate_image()` to create an image from a text prompt.

# %%
image_prompt = "A cinematic neon jellyfish floating through a futuristic green-lit aquarium"

generated_image = coll.generate_image(
    prompt=image_prompt,
    aspect_ratio="9:16",
)

image_url = generated_image.generate_url()
print("Image URL:", image_url)
Image(url=image_url)
# Out:
# Image URL: https://storage.dev.videodb.io/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-z-019f26da-4a8e-73a3-800b-50e1e309631b/image?Expires=1783581686&KeyName=videodb-dev-storage-key-1&Signature=8l3uKT6psHQOgRjbIwYXDV9OTww
# <img src="https://storage.dev.videodb.io/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-z-019f26da-4a8e-73a3-800b-50e1e309631b/image?Expires=1783581686&KeyName=videodb-dev-storage-key-1&Signature=8l3uKT6psHQOgRjbIwYXDV9OTww"/>

# %% [markdown]
# ## 4. Generate Music
#
# Use `generate_music()` to create background music from a prompt.

# %%
music_prompt = "Upbeat electronic background music for a product launch video"

generated_music = coll.generate_music(
    prompt=music_prompt,
    duration=10,
)

music_url = generated_music.generate_url()
print("Music URL:", music_url)
Audio(url=music_url, filename="music.mp3")
# Out:
# Music URL: https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/a-z-019f26f5-a303-79b2-90cc-fbb8ae2a3b1d/audio?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=firebase-adminsdk-x61ng%40videodb-dev.iam.gserviceaccount.com%2F20260703%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260703T075109Z&X-Goog-Expires=604799&X-Goog-SignedHeaders=host&response-content-disposition=attachment%3B&X-Goog-Signature=...
#                 <audio  controls="controls" >
#                     <source src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/a-z-019f26f5-a303-79b2-90cc-fbb8ae2a3b1d/audio?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=firebase-adminsdk-x61ng%40videodb-dev.iam.gserviceaccount.com%2F20260703%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260703T075109Z&X-Goog-Expires=604799&X-Goog-SignedHeaders=host&response-content-disposition=attachment%3B&X-Goog-Signature=..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 5. Generate a Sound Effect
#
# Use `generate_sound_effect()` for short, scene-specific audio assets.

# %%
sfx_prompt = "Footsteps on wet gravel in a quiet alley, realistic and slightly echoey"

generated_sfx = coll.generate_sound_effect(
    prompt=sfx_prompt,
    duration=5,
)

sfx_url = generated_sfx.generate_url()
print("Sound effect URL:", sfx_url)
Audio(url=sfx_url, filename="sound-effect.mp3")
# Out:
# Sound effect URL: https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/a-z-019f26ee-6b11-7351-9a2b-86bbbc0dbeb3/audio?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=firebase-adminsdk-x61ng%40videodb-dev.iam.gserviceaccount.com%2F20260703%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260703T074310Z&X-Goog-Expires=604799&X-Goog-SignedHeaders=host&response-content-disposition=attachment%3B&X-Goog-Signature=...
#                 <audio  controls="controls" >
#                     <source src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/a-z-019f26ee-6b11-7351-9a2b-86bbbc0dbeb3/audio?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=firebase-adminsdk-x61ng%40videodb-dev.iam.gserviceaccount.com%2F20260703%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260703T074310Z&X-Goog-Expires=604799&X-Goog-SignedHeaders=host&response-content-disposition=attachment%3B&X-Goog-Signature=..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 6. Generate a Voiceover
#
# Use `generate_voice()` to turn text into spoken audio.

# %%
voiceover_text = (
    "Welcome to VideoDB. In this demo, we are generating images, music, "
    "sound effects, voiceovers, videos, and translated media from simple prompts."
)

generated_voice = coll.generate_voice(
    text=voiceover_text,
    voice_name="Aria",
)

voice_url = generated_voice.generate_url()
print("Voiceover URL:", voice_url)
Audio(url=voice_url, filename="voiceover.mp3")
# Out:
# Voiceover URL: https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/a-z-019f26ee-c455-7fa0-baf2-f272fc6d4b7d/audio?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=firebase-adminsdk-x61ng%40videodb-dev.iam.gserviceaccount.com%2F20260703%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260703T074335Z&X-Goog-Expires=604799&X-Goog-SignedHeaders=host&response-content-disposition=attachment%3B&X-Goog-Signature=...
#                 <audio  controls="controls" >
#                     <source src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/a-z-019f26ee-c455-7fa0-baf2-f272fc6d4b7d/audio?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=firebase-adminsdk-x61ng%40videodb-dev.iam.gserviceaccount.com%2F20260703%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260703T074335Z&X-Goog-Expires=604799&X-Goog-SignedHeaders=host&response-content-disposition=attachment%3B&X-Goog-Signature=..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 7. Generate a Short Video
#
# Use `generate_video()` to create a short video clip from a prompt.

# %%
video_prompt = (
    "Cinematic close-up of a majestic lion slowly turning its head, "
    "golden mane catching soft afternoon sunlight on the savanna."
)

generated_video = coll.generate_video(
    prompt=video_prompt,
    duration=7,
)

generated_video.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/e7d22b12-855a-42d7-952f-842a15cb7d23.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 8. Search YouTube
#
# Use `youtube_search()` to discover videos that can be uploaded or used as source material in your workflow.

# %%
search_query = "learn python programming"

youtube_results = conn.youtube_search(
    query=search_query,
    result_threshold=3,
    duration="medium",
)

for i, result in enumerate(youtube_results, 1):
    print(f"{i}. {result.get('title', 'Untitled')} - {result.get('link', '')}")
# Out:
# 1. How to learn Python coding fast - Step by step roadmap - https://www.youtube.com/watch?v=vOo3yFU_0Ws
# 2. How I would learn Python programming FAST (If I could start ... - https://www.youtube.com/watch?v=S5tOMUCvPFA
# 3. Do THIS instead of watching endless tutorials - how I'd learn ... - https://www.youtube.com/watch?v=mB0EBW-vDSQ
# 4. Python Tutorial for Beginners with VS Code - https://www.youtube.com/watch?v=6i3e-j3wSf0
# 5. Python Basics for Beginners | Python tutorial - https://www.youtube.com/watch?v=fLAfa-BQtOQ
# 6. Learn Python in Less than 10 Minutes for Beginners (Fast ... - https://www.youtube.com/watch?v=fWjsdhR3z3c
# 7. Do THIS instead of watching endless tutorials — how to learn ... - https://www.youtube.com/watch?v=DZIymFrEXik
# 8. Start coding with PYTHON in 5 minutes! - https://www.youtube.com/watch?v=Sg4GMVMdOPo
# 9. How I Would Learn Python FAST (If I Could Start Over) - https://www.youtube.com/watch?v=OEJv74QnduA&vl=en
# 10. How I Would Learn Python FAST (if I could start over) - https://www.youtube.com/watch?v=St48epdRDZw

# %% [markdown]
# ## 9. Translate a Video Transcript
#
# This section uses the new understanding pipeline.
#
# We will:
#
# 1. Upload a source video.
# 2. Run `understand()` with the `spoken_words` analyzer.
# 3. Convert the transcript artifact into plain text.
# 4. Translate the transcript with `generate_text()`.
#
# Because we only need transcript text for generation, no `video.index()` call is required.

# %%
source_video = coll.upload(url="https://www.youtube.com/watch?v=a9__D53WsUs")
source_video.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/b2580d2e-1c99-4781-a4b7-e4659b718850.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
transcript_understanding = source_video.understand(
    analyzers=[
        {
            "type": "spoken_words",
            "name": "transcript",
            "config": {
                "language": "en",
            },
        }
    ],
)

transcript_understanding.wait_until_complete(timeout=3600, poll_interval=15)
transcript_output = transcript_understanding.get_analyzer("transcript").get_output()

print("Transcript status:", transcript_output.get("status"))
print("Transcript scenes:", len(transcript_output.get("scenes", [])))
# Out:
# Transcript status: done
# Transcript scenes: 1

# %%
def build_transcript_text(transcript_output):
    text_parts = []

    for scene in transcript_output.get("scenes", []):
        data = scene.get("data", {})
        scene_text = data.get("text")

        if not scene_text:
            words = data.get("words", [])
            scene_text = " ".join(word.get("text", "") for word in words)

        scene_text = scene_text.strip()
        if scene_text:
            text_parts.append(scene_text)

    return "\n".join(text_parts)


transcript_text = build_transcript_text(transcript_output)
print("Transcript characters:", len(transcript_text))
print(transcript_text[:1000])
# Out:
# Transcript characters: 2725
# AWS is the world's most comprehensive and broad. Broadly adopted cloud platform. Millions of customers trust AWS to. Power their infrastructure and applications. Organizations of every type. Type and size are using AWS to lower costs, become more agile and. Innovate faster. AWS provides on demand delivery of. Technology services via the Internet. With pay as you go pricing, you can use. Busy services to build and run virtually any type of application without upfront costs. Or ongoing commitments. You only pay for what you use a day. AWS gives you more services and more features within those services than any other cloud provide. Provider. This makes it faster, easier and more cost effective to move. Your existing applications to the cloud and to build anything you can imagine. From infrastructure technologies like compute storage and databases. To emerging technologies such as machine learning and artificial intelligence. Data lakes and analytics, an Internet of things. Building on AWS

# %%
def extract_generated_text(response):
    if isinstance(response, dict):
        return response.get("output") or response.get("text") or str(response)
    return str(response)


target_language = "French"
translation_prompt = f"""
Translate the following transcript into {target_language}.
Preserve paragraph breaks where helpful. Return only the translated transcript.

Transcript:
{transcript_text[:14000]}
"""

translated_transcript = extract_generated_text(
    coll.generate_text(prompt=translation_prompt, model_name="pro")
).strip()

print(translated_transcript)
# Out:
# AWS est la plateforme cloud la plus complète et la plus largement adoptée au monde. Des millions de clients font confiance à AWS pour alimenter leur infrastructure et leurs applications.
#
# Des organisations de tous types et de toutes tailles utilisent AWS pour réduire les coûts, gagner en agilité et innover plus rapidement. AWS fournit à la demande des services technologiques via Internet. Avec une tarification à l'utilisation, vous pouvez utiliser ces services pour créer et exécuter pratiquement tout type d'application sans coûts initiaux ni engagements à long terme. Vous ne payez que pour ce que vous utilisez.
#
# AWS vous offre plus de services et plus de fonctionnalités au sein de ces services que tout autre fournisseur cloud. Cela facilite, accélère et réduit le coût de la migration de vos applications existantes vers le cloud et de la création de tout ce que vous pouvez imaginer.
#
# Des technologies d'infrastructure comme le calcul, le stockage et les bases de données, aux technologies émergentes telles que l'apprentissage automatique et l'intelligence artificielle, les lacs de données et l'analytique, et l'Internet des objets.
#
# Construire sur AWS signifie que vous pouvez choisir le bon outil pour la tâche. Par exemple, AWS propose la plus large variété de bases de données, conçues pour différents types d'applications. Avec AWS, vous pouvez exploiter les technologies les plus récentes pour expérimenter et innover plus rapidement.
#
# Nous accélérons continuellement notre rythme d'innovation pour inventer des technologies entièrement nouvelles que vous pouvez utiliser pour transformer votre entreprise, comme en pionnier de l'espace du calcul sans serveur avec le lancement d'AWS Lambda, qui permet aux développeurs d'exécuter leur code sans provisionner ni gérer de serveurs. AWS a également créé Amazon SageMaker, un service d'apprentissage automatique entièrement géré, qui permet aux développeurs et aux scientifiques, même sans expérience préalable, d'utiliser l'apprentissage automatique.
#
# Nous étendons constamment notre réseau mondial de régions AWS afin que vous puissiez accéder aux services AWS pour créer et exécuter vos applications depuis n'importe où dans le monde. Chacune de ces régions comporte plusieurs zones de disponibilité physiquement séparées les unes des autres et reliées par des réseaux à faible latence, à haut débit et hautement redondants. Cela facilite la conception et l'exploitation d'applications évolutives, tolérantes aux pannes et très disponibles.
#
# Notre infrastructure est conçue pour satisfaire les normes de sécurité des organisations les plus sensibles au risque. Vous avez également accès au réseau de partenaires AWS, qui comprend des milliers de systèmes intégrés spécialisés dans les services AWS et des dizaines de milliers d'éditeurs de logiciels indépendants qui adaptent leur technologie pour fonctionner sur AWS.
#
# Avec la plus grande communauté de clients dans tous les secteurs, AWS possède une expérience et une expertise opérationnelle inégalées sur lesquelles vous pouvez compter pour vos applications les plus importantes, dans tous les cas d'utilisation imaginables.

# %% [markdown]
# ## 10. Dub an Existing Video
#
# Use `dub_video()` when you want VideoDB to create a dubbed version of a video in another language.

# %%
dub_source_video = coll.upload(url="https://www.youtube.com/watch?v=FgrO9ADPZSA")
target_language_code = "hi"

dubbed_video = coll.dub_video(
    video_id=dub_source_video.id,
    language_code=target_language_code,
)

print("Dubbed video ID:", dubbed_video.id)
dubbed_video.play()
# Out:
# Dubbed video ID: m-z-019f26f4-6d2b-7c51-b858-7c267db5a9e6
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/03437e36-15d8-42dc-b1e0-10038a8a90f2.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Conclusion
#
# You now have a compact toolkit for generating and transforming media with VideoDB:
#
# - Images, music, sound effects, voiceovers, and videos from prompts.
# - YouTube discovery for source material.
# - Transcript translation through `understand(spoken_words)` and `generate_text()`.
# - Video dubbing for multilingual output.
#
# For workflows that only generate from an understanding artifact, you can use the artifact directly and skip indexing. Use `video.index()` when you need search, query, filtering, aggregation, or retrieval over the artifact.

# %% [markdown]
# ## Further Resources
#
# - [Understanding Artifacts](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/indexing-pipelines/understanding-artifacts)
# - [Create an Index](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/indexing-pipelines/create-an-index)
# - [Search and Retrieval](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/search-and-retrieval/natural-language-query)
#
# If you have questions or feedback, reach out through [Discord](https://discord.gg/py9P639jGz) or [GitHub](https://github.com/video-db).
