# %% [markdown]
# # 🗒️ Lecture and Meeting Videos into Concise Notes with VideoDB

# %% [markdown]
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/lecture_notes_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Taking notes during lectures or meetings can be tough, especially when trying to capture both what's on the screen and what's being said. In this tutorial, we'll use VideoDB to combine spoken transcripts with visual slide understanding, then generate concise notes for each scene.
#
# This workflow helps you quickly review key ideas from lectures, conference talks, webinars, and meetings that include slides or screen sharing.

# %% [markdown]
# ## Setup
# ---

# %% [markdown]
# ### 📦  Installing packages

# %% [markdown]
# Before diving in, make sure you have the necessary tools installed:
#
# * VideoDB: For video understanding, transcription, visual analysis, and thumbnails.
# * OpenAI: To generate concise text summaries.
# * Markdown2: For converting markdown summaries into HTML.
#
# To get started, install these packages:

# %%
# %pip install videodb openai markdown2
# Out:
# Requirement already satisfied: videodb in /usr/local/lib/python3.12/dist-packages (0.4.5)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.43.0)
# Collecting markdown2
#   Downloading markdown2-2.5.5-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: requests>=2.25.1 in /usr/local/lib/python3.12/dist-packages (from videodb) (2.34.2)
# Requirement already satisfied: backoff>=2.2.1 in /usr/local/lib/python3.12/dist-packages (from videodb) (2.2.1)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from videodb) (4.68.3)
# Requirement already satisfied: websockets>=11.0.3 in /usr/local/lib/python3.12/dist-packages (from videodb) (16.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.1->videodb) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25.1->videodb) (2.7.0)
# Downloading markdown2-2.5.5-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: markdown2
# Successfully installed markdown2-2.5.5

# %% [markdown]
# ## 🔑 API keys
# Before proceeding, ensure access to [VideoDB](https://videodb.io), [OpenAI](https://openai.com) API key. If not, sign up for API access on the respective platforms.
#
# > Get your API key from [VideoDB Console](https://console.videodb.io). ( Get $20 free credits. **No credit card needed** ) 🎉

# %%
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
videodb_api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = videodb_api_key

openai_api_key = getpass("Please enter your OpenAI API Key: ")
os.environ["OPENAI_API_KEY"] = openai_api_key
# Out:
# Please enter your VideoDB API Key: ··········
# Please enter your OpenAI API Key: ··········

# %% [markdown]
# ---

# %% [markdown]
# ## 📋 Step 1: Connect to VideoDB

# %%
from videodb import connect

conn = connect()
coll = conn.get_collection()
print("Connected to VideoDB successfully.")
# Out:
# Connected to VideoDB successfully!

# %% [markdown]
# ## 🎬 Step 2: Upload the Video

# %% [markdown]
# Next, let's upload our sample video:
#
# You can use any public url, Youtube link or local file on your system.
#
# This approach works particularly well with:
#
# * University lectures that include PowerPoint slides and detailed discussions.
# * Conference presentations where speakers use slides to illustrate their points.
# * Team meetings that involve screen sharing and in-depth explanations.
#
# In this tutorial, we're using an [explainer video](https://www.youtube.com/watch?v=QJNwK2uJyGs) focusing on “Introduction to Arrays”. This example is perfect for demonstrating how to capture and summarize key points from both visual aids and spoken explanations in an educational setting.

# %%
# Upload a video by url
video = coll.upload(url="https://www.youtube.com/watch?v=QJNwK2uJyGs")

# %% [markdown]
# ## 📸🗣️ Step 3: Understand the Video Across Modalities

# %% [markdown]
# Now comes the core VideoDB step. We will use the understanding pipeline to extract two reusable artifacts from the video:
#
# 1. `spoken_words` extracts a timestamped transcript of what is being said.
# 2. `vlm` extracts slide-aware visual descriptions from the video frames.
#
# We run these analyzers separately so the transcript and visual understanding outputs can be inspected independently.

# %% [markdown]
# #### 🗣️ Step 3A: Understand Spoken Content
#
# First, we transcribe the spoken content using the `spoken_words` analyzer.
#
# This produces a timestamped transcript artifact that we will later align with visual scene descriptions.

# %%
transcript_understanding = video.understand(
    analyzers=[
        {
            "type": "spoken_words",
            "name": "transcript",
            "config": {
                "language": "en",
            },
        }
    ],
)

transcript_understanding.wait_until_complete(timeout=3600, poll_interval=15)

transcript_output = transcript_understanding.get_analyzer("transcript").get_output()

print("Transcript status:", transcript_output.get("status"))
print("Transcript scenes:", len(transcript_output.get("scenes", [])))
# Out:
# Transcript status: done
# Transcript scenes: 10

# %% [markdown]
# #### Prepare Transcript Entries
#
# The spoken-word analyzer returns timestamped transcript records. We flatten them into one list so each visual scene can pull the transcript spoken during the same time range.

# %%
def flatten_transcript_entries(transcript_output):
    transcript = []

    for scene in transcript_output.get("scenes", []):
        data = scene.get("data", {})

        entries = data.get("entries") or data.get("words") or []
        if entries:
            transcript.extend(entries)
            continue

        text = data.get("text")
        if text:
            transcript.append(
                {
                    "start": scene.get("start"),
                    "end": scene.get("end"),
                    "text": text,
                }
            )

    seen = set()
    deduped = []

    for item in transcript:
        key = (item.get("start"), item.get("end"), item.get("text"))
        if key in seen:
            continue
        seen.add(key)
        deduped.append(item)

    return deduped


transcript = flatten_transcript_entries(transcript_output)

print("Transcript entries:", len(transcript))
print(transcript[:5])
# Out:
# Transcript entries: 1995
# [{'confidence': 0.9980469, 'end': 0.84, 'speaker': 'A', 'start': 0.64, 'text': 'Hey,'}, {'confidence': 0.9980469, 'end': 1.12, 'speaker': 'A', 'start': 0.84, 'text': 'everyone.'}, {'confidence': 0.9998372, 'end': 1.8, 'speaker': 'A', 'start': 1.36, 'text': 'Welcome'}, {'confidence': 1.0, 'end': 1.96, 'speaker': 'A', 'start': 1.8, 'text': 'to'}, {'confidence': 0.99853516, 'end': 2.12, 'speaker': 'A', 'start': 1.96, 'text': 'the'}]

# %% [markdown]
# #### 👁️ Step 3B: Understand Slide Visuals
#
# Next, we analyze the visible slide content with the VLM analyzer.
#
# We ask the model to describe readable text, diagrams, and educational concepts shown on screen. The output uses a structured `scene_description` field so the summarization step can consume it consistently.

# %%
slide_understanding = video.understand(
    analyzers=[
        {
            "type": "vlm",
            "name": "slide_notes",
            "config": {
                "model": "pro",
                "prompt": (
                    "Look at the video frame and describe the visible slide or screen content. "
                    "Focus on readable text, diagrams, and educational concepts shown on screen. "
                    "If no meaningful slide or screen content is visible, write None."
                ),
                "schema": {
                    "scene_description": "string",
                },
            },
        }
    ],
)

slide_understanding.wait_until_complete(timeout=1800, poll_interval=15)

slide_output = slide_understanding.get_analyzer("slide_notes").get_output()

print("Slide notes status:", slide_output.get("status"))
print("Slide scenes:", len(slide_output.get("scenes", [])))
# Out:
# Slide notes status: done
# Slide scenes: 10

# %% [markdown]
# #### 👁️ Preview the Slide Notes
#
# The VLM analyzer returns timestamped scene records. Each record contains the start time, end time, and structured data from our prompt.
#
# Let's preview a few scene descriptions before generating final lecture notes.

# %%
def preview_slide_notes(slide_output, limit=10):
    for i, scene in enumerate(slide_output.get("scenes", [])[:limit], 1):
        data = scene.get("data", {})
        description = data.get("scene_description", "")

        print(f"Scene {i}: {scene.get('start')} - {scene.get('end')}")
        print(description)
        print("----")


preview_slide_notes(slide_output)
# Out:
# Scene 1: 0.0 - 32.033
# Slide title: large text bars reading “DATA STRUCTURES” (yellow bar) and “ARRAYS” (blue bar). Secondary slide text (stacked colored bars) reads: vertical label “ARRAYS” on the left, and to the right three horizontal bars: “COLLECTION OF ITEMS” (blue), “STORED CONSECUTIVELY” (yellow), “IN THE MEMORY” (pink/red). Visual diagram: a grid of yellow squares representing contiguous memory cells. Dark background with faint binary digits (0 and 1) as a decorative backdrop.
# ----
# Scene 2: 32.033 - 60.767
# Dark grid background with yellow square tiles arranged in two horizontal groups. Top group shows number tiles: "2 5 9 1 0". Bottom group spells the word "ROADMAP" with individual letter tiles. A bracket/connector highlights the letter tiles with the caption "ITEMS HAVE SAME TYPE" and another bracket highlights the number tiles with the caption "FIXED IN SIZE". Faint binary-code/tech pattern visible in the backdrop. The slide conveys array-like concepts: fixed size and uniform item type.
# ----
# Scene 3: 60.767 - 109.133
# Slide titled 'ARRAYS IN C++' (top left). Main content shows C++ array examples in colored code:
# - int numbers[3] = {10, 59, 11};
# - string cars[3] = {"BMW", "Volvo", "Ford"};
# - char types[3] = {'A', 'G', 'U'};
# A yellow pointer/cursor is visible near the third line. Lower on the slide are array characteristics highlighted in boxed labels: 'FIXED IN SIZE' and 'CAN'T ALLOCATE MORE SPACE'. An example 'numbers[4] = 594;' is shown with a red X to indicate it’s invalid. Another label reads 'CAN'T HAVE MIXED TYPES'. Dark binary-style background pattern behind the text.
# ----
# Scene 4: 109.133 - 122.1
# Slide shows a lesson about arrays being fixed-size and not allowing mixed types. Prominent title text reads “FIXED IN SIZE” with a subtitle “CAN’T ALLOCATE MORE SPACE”, and below that “MIXED TYPES” with “WHY CAN’T WE HAVE THEM?”. A following frame displays the code snippet “int numbers[3] = {10, 59, 11};” (syntax-colored) above a large grid of yellow squares representing contiguous memory/array slots, illustrating array capacity and fixed allocation.
# ----
# Scene 5: 122.1 - 192.667
# A slide visualizing C-style arrays and memory layout. At top is code like "int numbers[3] = {10, 59, 11};" and later "numbers[3] = 594;" and variants "int numbers[] = {10, 59, 11};" and "int numbers[1000] = {10, 59, 11};". A grid of small squares represents contiguous memory cells; three yellow boxes inside the grid show the stored values "10 59 11." Blue squares illustrate other allocated but unused slots; a red square and a red X mark an out-of-bounds write to numbers[3]. A diagonal badge reads "FIXED IN SIZE." The slide teaches fixed-size arrays, contiguous memory allocation, wasted space with oversize arrays, and the danger of out-of-bounds indexing.
# ----
# Scene 6: 192.667 - 300.433
# Slide shows C-style array examples and a memory layout diagram. Readable code at top: “int numbers[3] = {10, 59, 11};”, “bool states[2] = {false, true};”, “char types[3] = {'A', 'G', 'U'};”. An annotation points out “2 BYTES EACH” for ints and “1 BYTE EACH” for bool/char. Later frames show “int numbers[3] = {4, 9, 6};” with a horizontal memory representation made of yellow 1-byte boxes labeled “MEMORY REPRESENTATION” and an arrow/label “1 BYTE”. Several boxes are filled with maroon blocks containing 4, 9, 6 and byte addresses printed underneath (20 through 32). Brackets under the boxes label “1ST”, “2ND”, “3RD”. Another example shows “mixed[3] = {4, "BMW", true};” with the memory diagram showing 4 in one byte, the string “BMW” occupying multiple adjacent bytes, and a T for true in its own byte. Overall the slide illustrates array initialization, element sizes, and contiguous memory layout with byte addresses.
# ----
# Scene 7: 300.433 - 317.7
# A title slide with bold stacked text on a dark background. A red diagonal banner at top reads “LANGUAGES SUCH AS JAVASCRIPT?”. Large yellow bars contain the phrases “FIXED IN” (part of a larger heading) and “MIXED TYPES” in big black type. A white bar between them reads “CAN’T ALLOCATE MORE SPACE”. A white bar at the bottom says “WHY CAN’T WE HAVE THEM?”. The slide poses a question about mixed types and fixed-size allocation in languages like JavaScript.
# ----
# Scene 8: 317.7 - 379.6
# Slide titled "ARRAYS IN JAVASCRIPT" showing code and a visual memory diagram. Readable code: "const numbers = [10, 59, 11];" on the first line and the subsequent calls "numbers.push(1);" and "numbers.push(20);". Below the code is a grid of small squares representing contiguous memory slots. Highlighted yellow squares show the array elements labeled "10", "59", "11" (and later "1" and "20" as push is demonstrated). Blue squares mark other allocated/free slots; a red square briefly appears to indicate a relocation/resize step. The sequence of frames illustrates the push operation: adding elements to the end of the array and the possible reallocation/copying of elements to a new region of memory.
# ----
# Scene 9: 379.6 - 471.967
# Slide titled "ARRAYS IN JAVASCRIPT" showing the code line: const mixed = [10, "BMW", true];. Arrows point from each array element to labels indicating their byte sizes: "2 BYTES" (for 10), "3 BYTES" (for "BMW"), and "1 BYTE" (for true). A highlighted note reads "MAXIMUM SIZE OF AN ELEMENT 3" and another box shows "TOTAL SIZE ALLOCATED 9". A large grid of yellow memory cells is used to visualize allocation; three grouped blocks are filled and labeled with the values (10, BMW, T) and bracketed captions underneath them read "1ST", "2ND", "3RD" to illustrate fixed-size slots per element. The slide communicates that mixed-type arrays allocate space based on the largest element, leading to wasted space.
# ----
# Scene 10: 471.967 - 596.133
# A series of instructional slides about array operations using JavaScript. The top shows the code: const numbers = [5, 9, 1, 6, 2, 1, 3]; with element indices labeled 0 through 6 above the array. One slide titled “ACCESSING AN ELEMENT AT INDEX” shows examples: console.log(numbers[0]); // Output: 5 and console.log(numbers[5]); // Output: 1, and lists the algorithmic complexity O(1). Another slide titled “INSERTING AT INDEX” displays a row of yellow boxes representing the array elements, an arrow indicating insertion of the value 3, and the resulting array with the new element and updated indices; the complexity shown is O(n). A “DELETING FROM INDEX” slide shows the array with an arrow at an index and notes algorithmic complexity O(n). An “UPDATING AT INDEX” slide shows replacing an element (one box highlighted with a new value 3) and notes complexity (implied O(1)). Finally a “TRAVERSING THE ARRAY” slide shows the sequence of array boxes and lists algorithmic complexity O(n). Overall the content demonstrates access, insert, delete, update, and traversal operations with their time complexities.
# ----

# %% [markdown]
# #### Build Scene Records and Thumbnails
#
# Now we convert the VLM output into simple timestamped scene records. Each record includes:
#
# - the scene start and end time
# - the VLM-generated slide description
# - a thumbnail generated from the midpoint of the scene
#
# These records will be combined with transcript text from the same time ranges.

# %%
GENERATE_THUMBNAILS = True


def build_slide_scenes(slide_output, video, generate_thumbnails=True):
    scenes = []

    for scene in slide_output.get("scenes", []):
        data = scene.get("data", {})

        start = float(scene.get("start", 0))
        end = float(scene.get("end", 0))
        thumbnail_time = (start + end) / 2 if end > start else start

        image_url = None
        if generate_thumbnails:
            try:
                thumbnail = video.generate_thumbnail(time=thumbnail_time)
                image_url = thumbnail.url
            except Exception as e:
                print(f"Thumbnail unavailable for {start}-{end}: {e}")

        scenes.append(
            {
                "start": start,
                "end": end,
                "image_url": image_url,
                "description": data.get("scene_description", ""),
            }
        )

    return scenes


scenes = build_slide_scenes(
    slide_output,
    video,
    generate_thumbnails=GENERATE_THUMBNAILS,
)

print("Slide scenes:", len(scenes))
print(scenes[:3])
# Out:
# Slide scenes: 10
# [{'start': 0.0, 'end': 32.033, 'image_url': 'https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-16.0165/image', 'description': 'Slide title: large text bars reading “DATA STRUCTURES” (yellow bar) and “ARRAYS” (blue bar). Secondary slide text (stacked colored bars) reads: vertical label “ARRAYS” on the left, and to the right three horizontal bars: “COLLECTION OF ITEMS” (blue), “STORED CONSECUTIVELY” (yellow), “IN THE MEMORY” (pink/red). Visual diagram: a grid of yellow squares representing contiguous memory cells. Dark background with faint binary digits (0 and 1) as a decorative backdrop.'}, {'start': 32.033, 'end': 60.767, 'image_url': 'https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-46.400000000000006/image', 'description': 'Dark grid background with yellow square tiles arranged in two horizontal groups. Top group shows number tiles: "2 5 9 1 0". Bottom group spells the word "ROADMAP" with individual letter tiles. A bracket/connector highlights the letter tiles with the caption "ITEMS HAVE SAME TYPE" and another bracket highlights the number tiles with the caption "FIXED IN SIZE". Faint binary-code/tech pattern visible in the backdrop. The slide conveys array-like concepts: fixed size and uniform item type.'}, {'start': 60.767, 'end': 109.133, 'image_url': 'https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-84.95/image', 'description': 'Slide titled \'ARRAYS IN C++\' (top left). Main content shows C++ array examples in colored code: \n- int numbers[3] = {10, 59, 11};\n- string cars[3] = {"BMW", "Volvo", "Ford"};\n- char types[3] = {\'A\', \'G\', \'U\'};\nA yellow pointer/cursor is visible near the third line. Lower on the slide are array characteristics highlighted in boxed labels: \'FIXED IN SIZE\' and \'CAN\'T ALLOCATE MORE SPACE\'. An example \'numbers[4] = 594;\' is shown with a red X to indicate it’s invalid. Another label reads \'CAN\'T HAVE MIXED TYPES\'. Dark binary-style background pattern behind the text.'}]

# %% [markdown]
# #### Verify Scene Inputs
#
# The `scenes` list is now ready for summarization. Before generating notes, let's verify that each visual scene aligns with transcript text from the same timestamp range.

# %%
def extract_transcript_for_scene(transcript, start_time, end_time):
    return " ".join(
        item.get("text", "")
        for item in transcript
        if item.get("start") is not None and start_time <= float(item.get("start")) < end_time
    )


for i, scene in enumerate(scenes[:5], 1):
    scene_transcript = extract_transcript_for_scene(
        transcript,
        scene["start"],
        scene["end"],
    )

    print(f"Scene {i}: {scene['start']} - {scene['end']}")
    print("Visual description:")
    print(scene["description"])
    print()
    print("Transcript excerpt:")
    print(scene_transcript[:500])
    print()
    print("Thumbnail URL:")
    print(scene.get("image_url"))
    print("----")
# Out:
# Scene 1: 0.0 - 32.033
# Visual description:
# Slide title: large text bars reading “DATA STRUCTURES” (yellow bar) and “ARRAYS” (blue bar). Secondary slide text (stacked colored bars) reads: vertical label “ARRAYS” on the left, and to the right three horizontal bars: “COLLECTION OF ITEMS” (blue), “STORED CONSECUTIVELY” (yellow), “IN THE MEMORY” (pink/red). Visual diagram: a grid of yellow squares representing contiguous memory cells. Dark background with faint binary digits (0 and 1) as a decorative backdrop.
#
# Transcript excerpt:
# Hey, everyone. Welcome to the second video of the Illustrated Data Structure series. In this video, we'll be discussing everything you need to know about the array data structure. We'll be. Talking about, what the arrays are, how they work. What are some of the limitations def. Operations you can perform on an array and the complexity of those operations. So what is. An array. An array is a collection of items that are stored consecutively in the memory. Let's say that we have this representatio
#
# Thumbnail URL:
# https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-16.0165/image
# ----
# Scene 2: 32.033 - 60.767
# Visual description:
# Dark grid background with yellow square tiles arranged in two horizontal groups. Top group shows number tiles: "2 5 9 1 0". Bottom group spells the word "ROADMAP" with individual letter tiles. A bracket/connector highlights the letter tiles with the caption "ITEMS HAVE SAME TYPE" and another bracket highlights the number tiles with the caption "FIXED IN SIZE". Faint binary-code/tech pattern visible in the backdrop. The slide conveys array-like concepts: fixed size and uniform item type.
#
# Transcript excerpt:
# have an array of numbers or an array of characters where. Each character is placed to the next character in the array. There are two features of an array that. You should keep in mind the first one is that all the items of an array have the same typ. So you can't have a mix of characters, numbers and strings. They all have to. Have the same type. And the second one is that Addie has to have the fixed size. So, for example, if you allocated five items for the array, you can't add the sixth item t
#
# Thumbnail URL:
# https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-46.400000000000006/image
# ----
# Scene 3: 60.767 - 109.133
# Visual description:
# Slide titled 'ARRAYS IN C++' (top left). Main content shows C++ array examples in colored code:
# - int numbers[3] = {10, 59, 11};
# - string cars[3] = {"BMW", "Volvo", "Ford"};
# - char types[3] = {'A', 'G', 'U'};
# A yellow pointer/cursor is visible near the third line. Lower on the slide are array characteristics highlighted in boxed labels: 'FIXED IN SIZE' and 'CAN'T ALLOCATE MORE SPACE'. An example 'numbers[4] = 594;' is shown with a red X to indicate it’s invalid. Another label reads 'CAN'T HAVE MIXED TYPES'. Dark binary-style background pattern behind the text.
#
# Transcript excerpt:
# look at some examples of arrays in C. Now don't worry if you are not familiar. With C as the concepts that we will cover in this video. They are same in the other languages. For example, here we have an array of three integers, an array of strings and an array of characters. Where each array has a type, we declare the type of items that the array is going. To hold, then we have the length of the array. That is how many items that the array can hold. At maximum. And lastly, we have the values or
#
# Thumbnail URL:
# https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-84.95/image
# ----
# Scene 4: 109.133 - 122.1
# Visual description:
# Slide shows a lesson about arrays being fixed-size and not allowing mixed types. Prominent title text reads “FIXED IN SIZE” with a subtitle “CAN’T ALLOCATE MORE SPACE”, and below that “MIXED TYPES” with “WHY CAN’T WE HAVE THEM?”. A following frame displays the code snippet “int numbers[3] = {10, 59, 11};” (syntax-colored) above a large grid of yellow squares representing contiguous memory/array slots, illustrating array capacity and fixed allocation.
#
# Transcript excerpt:
# Now, you might be. Wondering, why do we have these two limitations? Let's look at them both one by one, let's say. That we have this array of three integers which we have to represent in the memory. Now, at our. RAM is going to do is it is going to allocate
#
# Thumbnail URL:
# https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-115.6165/image
# ----
# Scene 5: 122.1 - 192.667
# Visual description:
# A slide visualizing C-style arrays and memory layout. At top is code like "int numbers[3] = {10, 59, 11};" and later "numbers[3] = 594;" and variants "int numbers[] = {10, 59, 11};" and "int numbers[1000] = {10, 59, 11};". A grid of small squares represents contiguous memory cells; three yellow boxes inside the grid show the stored values "10 59 11." Blue squares illustrate other allocated but unused slots; a red square and a red X mark an out-of-bounds write to numbers[3]. A diagonal badge reads "FIXED IN SIZE." The slide teaches fixed-size arrays, contiguous memory allocation, wasted space with oversize arrays, and the danger of out-of-bounds indexing.
#
# Transcript excerpt:
# three slots in the memory and then it is. Going to populate the values in those slots. Now, since the computer memory is not only specified, To us, and it is available for the other programs as well. Computer is going to keep. Using these memory slots and keep allocating the memory slots for the other things. Now, later on. On. Let's say that we try to add a fourth element to the array. Since our program allocated only three. Slots for the array. The fourth slot may or may not be available, and
#
# Thumbnail URL:
# https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-157.3835/image
# ----

# %% [markdown]
# ## 📋 Step 4: Process the Video and Summarize Each Scene

# %% [markdown]
# In this step, we combine each visual scene description with the transcript spoken during the same timestamp range. Then we ask the LLM to generate concise notes for each scene.
#
# This keeps the notebook multimodal: the final notes use both what appears on screen and what the speaker says.

# %% [markdown]
# ![](https://raw.githubusercontent.com/video-db/videodb-cookbook-assets/main/images/guides/lecture_notes_1.png)

# %%
import openai

summarize_prompt = """
Scene Description: {scene_description}
Scene Transcript: {scene_transcript}

You are an AI tasked with creating concise summary notes for scenes from a video, integrating both visual and spoken content.

For each scene, you will receive:
- A description of the visual content, such as slides, diagrams, images, or on-screen text.
- A transcript of the spoken content during that same scene.

Your goal is to synthesize both into a single coherent note that captures the main point being explained.

Task:
Identify key points from the spoken content.
Integrate those key points with the most relevant visual elements.
Focus on the main concept being discussed during this scene.

Constraints:
Do not describe every visual element separately.
Only include details that help explain the main topic.
Keep the summary concise, ideally 1-2 sentences.

Output Format:
Provide the summary in Markdown format under the heading "### Scene Summary."
"""


def summarize_scene(scene_description, scene_transcript):
    client = openai.Client()

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": (
                    "You create concise lecture notes by combining visual slide "
                    "content with spoken transcript context."
                ),
            },
            {
                "role": "user",
                "content": summarize_prompt.format(
                    scene_description=scene_description,
                    scene_transcript=scene_transcript,
                ),
            },
        ],
    )

    return response.choices[0].message.content


def process_video(transcript, scenes):
    summarized_scenes = []

    for scene in scenes:
        scene_transcript = extract_transcript_for_scene(
            transcript,
            scene["start"],
            scene["end"],
        )

        summary = summarize_scene(scene["description"], scene_transcript)

        summarized_scenes.append(
            {
                "start": scene["start"],
                "end": scene["end"],
                "image_url": scene.get("image_url"),
                "summary": summary,
            }
        )

    return summarized_scenes


summary = process_video(transcript, scenes)

print("Summaries generated:", len(summary))
print(summary[:2])
# Out:
# Summaries generated: 10
# [{'start': 0.0, 'end': 32.033, 'image_url': 'https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-16.0165/image', 'summary': '### Scene Summary\nArrays are collections of items stored consecutively in memory, allowing efficient access and manipulation of data within fixed-size blocks.'}, {'start': 32.033, 'end': 60.767, 'image_url': 'https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-46.400000000000006/image', 'summary': '### Scene Summary\nArrays have fixed size and uniform item type; all elements must be the same (e.g., numbers or characters) without mixing types.'}]

# %% [markdown]
# ## Step 5: Display Summaries
#
# Here we display the generated scene notes as HTML cards. Each card includes:
#
# - the scene thumbnail
# - the scene timestamp
# - the generated summary

# %%
from IPython.display import HTML, display
import markdown2

def create_summary_html(summaries):
    html_content = """
    <style>
        .summary-container {
            display: flex;
            overflow-x: auto;
            padding: 20px 0;
            scroll-snap-type: x mandatory;
            background-color: #f0f0f0;
        }
        .summary-item {
            flex: 0 0 auto;
            width: 300px;
            margin-right: 20px;
            border: 1px solid #ddd;
            padding: 15px;
            scroll-snap-align: start;
            background-color: white;
            box-shadow: 0 2px 5px rgba(0,0,0,0.1);
        }
        .summary-item img {
            width: 100%;
            height: 180px;
            object-fit: cover;
        }
        .summary-item h3 {
            margin-top: 10px;
            color: #333;
        }
        .markdown-body {
            font-family: Arial, sans-serif;
            line-height: 1.6;
            color: #333;
        }
        .markdown-body p {
            margin-bottom: 10px;
        }
    </style>
    <div class="summary-container">
    """

    for i, summary in enumerate(summaries, 1):
        markdown_summary = markdown2.markdown(summary["summary"])
        image_url = summary.get("image_url")

        image_html = ""
        if image_url:
            image_html = f"""
            <img src="{image_url}" alt="Scene {i}" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
            """

        html_content += f"""
        <div class="summary-item">
            {image_html}
            <h3>Scene {i} ({summary['start']:.2f}s - {summary['end']:.2f}s)</h3>
            <div class="markdown-body">{markdown_summary}</div>
        </div>
        """

    html_content += "</div>"
    return html_content


def display_summaries(summaries):
    html = create_summary_html(summaries)
    display(HTML(html))


display_summaries(summary)
# Out:
#     <style>
#         .summary-container {
#             display: flex;
#             overflow-x: auto;
#             padding: 20px 0;
#             scroll-snap-type: x mandatory;
#             background-color: #f0f0f0;
#         }
#         .summary-item {
#             flex: 0 0 auto;
#             width: 300px;
#             margin-right: 20px;
#             border: 1px solid #ddd;
#             padding: 15px;
#             scroll-snap-align: start;
#             background-color: white;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.1);
#         }
#         .summary-item img {
#             width: 100%;
#             height: 180px;
#             object-fit: cover;
#         }
#         .summary-item h3 {
#             margin-top: 10px;
#             color: #333;
#         }
#         .markdown-body {
#             font-family: Arial, sans-serif;
#             line-height: 1.6;
#             color: #333;
#         }
#         .markdown-body p {
#             margin-bottom: 10px;
#         }
#     </style>
#     <div class="summary-container">
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-16.0165/image" alt="Scene 1" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 1 (0.00s - 32.03s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>Arrays are collections of items stored consecutively in memory, allowing efficient access and manipulation of data within fixed-size blocks.</p>
# </div>
#         </div>
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-46.400000000000006/image" alt="Scene 2" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 2 (32.03s - 60.77s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>Arrays have fixed size and uniform item type; all elements must be the same (e.g., numbers or characters) without mixing types.</p>
# </div>
#         </div>
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-84.95/image" alt="Scene 3" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 3 (60.77s - 109.13s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>Arrays in C++ are fixed in size, cannot allocate more space, and must contain homogeneous types. Examples include integers, strings, and characters.</p>
# </div>
#         </div>
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-115.6165/image" alt="Scene 4" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 4 (109.13s - 122.10s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>Arrays are fixed in size and cannot hold mixed types. For example, <code>int numbers[3]</code> shows three contiguous memory slots, highlighting these allocation constraints.</p>
# </div>
#         </div>
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-157.3835/image" alt="Scene 5" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 5 (122.10s - 192.67s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>C-style arrays are fixed in size, allocating contiguous memory. Over-allocating reserves unnecessary space, risking out-of-bounds errors when adding elements.</p>
# </div>
#         </div>
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-246.55/image" alt="Scene 6" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 6 (192.67s - 300.43s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>Arrays in C must be of the same data type. Mixed types complicate memory access due to differing byte sizes, making element retrieval ambiguous.</p>
# </div>
#         </div>
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-309.0665/image" alt="Scene 7" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 7 (300.43s - 317.70s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>Languages like JavaScript handle mixed types and dynamic arrays using complex behind-the-scenes processes, leading to challenges in fixed-size allocation.</p>
# </div>
#         </div>
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-348.65/image" alt="Scene 8" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 8 (317.70s - 379.60s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>JavaScript arrays allocate memory dynamically. When adding elements with <code>push()</code>, if memory is insufficient, the array relocates to a new space, copying existing elements.</p>
# </div>
#         </div>
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-425.7835/image" alt="Scene 9" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 9 (379.60s - 471.97s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>JavaScript arrays allocate space based on the largest element's size—in this case, 3 bytes each for a mixed-type array, totaling 9 bytes, leading to potential wasted space.</p>
# </div>
#         </div>
#
#         <div class="summary-item">
#
#             <img src="https://storage.googleapis.com/videodb-dev.appspot.com/media/u-0d90f7ba-dc1d-4754-ad13-29168a0fedc2/img-m-z-019f22ed-96e8-7993-a204-6ccd7efff1f8-thumbnail-534.05/image" alt="Scene 10" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
#
#             <h3>Scene 10 (471.97s - 596.13s)</h3>
#             <div class="markdown-body"><h3>Scene Summary</h3>
#
# <p>Operations on arrays in JavaScript include accessing (O(1)), inserting (O(n)), deleting (O(n)), updating (O(1)), and traversing (O(n)) elements by their indices.</p>
# </div>
#         </div>
#         </div>

# %% [markdown]
# ## Conclusion
# ---

# %% [markdown]
# In this tutorial, we created concise lecture notes using VideoDB's new understanding pipeline.
#
# We extracted two reusable artifacts from the video:
#
# - A timestamped spoken-word transcript.
# - Slide-aware visual notes from the VLM analyzer.
#
# Then we generated thumbnails, aligned each visual scene with the matching transcript, and summarized both modalities into concise study notes.
#
# This workflow is useful for lectures, meetings, conference talks, webinars, and training videos.

# %% [markdown]
# ## Further Resources
#
# - [Understanding Artifacts](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/indexing-pipelines/understanding-artifacts)
# - [Create an Index](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/indexing-pipelines/create-an-index)
# - [Search and Retrieval](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/search-and-retrieval/natural-language-query)
#
# To learn more about visual understanding and retrieval patterns, explore:
#
# - [Scene Index Quickstart](../quickstart/Scene%20Index%20QuickStart.ipynb)
# - [Advanced Visual Search](../guides/scene-index/advanced_visual_search.ipynb)
# - [Custom Annotation Pipelines](../guides/scene-index/custom_annotations.ipynb)

# %% [markdown]
# ### 👨‍👩‍👧‍👦 Support & Community
#
# If you have any questions or feedback, feel free to reach out to us.
#
# * [Discord](https://colab.research.google.com/corgiredirector?site=https%3A%2F%2Fdiscord.gg%2Fpy9P639jGz)
# * [GitHub](https://github.com/video-db)
# * [Email](mailto:ashu@videodb.io)
