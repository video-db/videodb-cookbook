# %% [markdown]
# # 🗒️ Lecture and Meeting Videos into Concise Notes with VideoDB

# %% [markdown]
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/lecture_notes_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Taking notes during lectures or meetings can be tough, especially when trying to capture both what's on the screen and what's being said. To make it easier, we've developed a tool with VideoDB that combines different modalities into timed, browsable study notes. Now, you can review and share key moments from any session, whether it's a specific slide or a crucial point in the discussion.

# %% [markdown]
# ## Setup
# ---

# %% [markdown]
# ### 📦  Installing packages

# %% [markdown]
# Before diving in, make sure you have the necessary tools installed:
#
# * VideoDB: To understand spoken and visual lecture content.
# * Markdown2: To render the generated notes as HTML.
#
# To get started, install these packages:

# %%
# !pip install -q videodb
# !pip install -q markdown2
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 2.1 MB/s eta 0:00:00

# %% [markdown]
# ## 🔑 API key
# Before proceeding, ensure access to [VideoDB](https://videodb.io).
#
# > Get your API key from [VideoDB Console](https://console.videodb.io). ( Get $20 free credits. **No credit card needed** ) 🎉

# %%
import os
from getpass import getpass

# Prompt user for the VideoDB API key securely
videodb_api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = videodb_api_key
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ---

# %% [markdown]
# ## 📋 Step 1: Connect to VideoDB

# %%
from videodb import connect

conn = connect()
coll = conn.get_collection()

# %% [markdown]
# ## 🎬 Step 2: Upload the Video

# %% [markdown]
# Next, let's upload our sample video:
#
# You can use any public url, Youtube link or local file on your system.
#
# This approach works particularly well with:
#
# * University lectures that include PowerPoint slides and detailed discussions.
# * Conference presentations where speakers use slides to illustrate their points.
# * Team meetings that involve screen sharing and in-depth explanations.
#
# In this tutorial, we're using an [explainer video](https://www.youtube.com/watch?v=QJNwK2uJyGs) focusing on “Introduction to Arrays”. This example is perfect for demonstrating how to capture and summarize key points from both visual aids and spoken explanations in an educational setting.

# %%
# Upload a video by url
video = coll.upload(url="https://www.youtube.com/watch?v=QJNwK2uJyGs")

# %% [markdown]
# ## 📸🗣️ Step 3: Choose Slide Segmentation and Create Multimodal Notes

# %% [markdown]
# First, compare shot thresholds to find a configuration that captures each slide transition. Then run one understanding that pairs spoken content with the selected slide frame to create timed study notes.

# %% [markdown]
# #### 👁️ Prepare the Scene Preview

# %%
from videodb import SceneExtractionType
from IPython.display import Image, display
import requests


def display_scenes(scenes, images=True):
    for scene in scenes:
        print(f"{scene.id} : {scene.start}-{scene.end}")
        if images:
            for frame in scene.frames:
                image = Image(requests.get(frame.url, stream=True).content)
                display(image)
        print("----")

# %% [markdown]
# #### 📸 Find the Right Slide Segmentation

# %% [markdown]
# To learn more about the timed understanding artifact used in this tutorial:
#
# * [Understanding Artifacts](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/indexing-pipelines/understanding-artifacts) explains how to create reusable timed analyzer artifacts.
# * [Analyzer Outputs](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/indexing-pipelines/analyzer-outputs) documents the timed `scenes` and `data` records consumed below.

# %% [markdown]
# **1. Compare Shot Thresholds**
#
# Accurate notes depend on detecting every slide transition. Start with threshold 25 to inspect the initial result, then lower it to 10 and compare the extracted frames.

# %%
scene_collection_default = video.extract_scenes(
    extraction_type=SceneExtractionType.shot_based,
    extraction_config={"threshold": 25, "frame_count": 1},
)
display_scenes(scene_collection_default.scenes)
# Out:
# st25m15f1-0.0-32.033 : 0.0-32.033
# ----
# st25m15f1-32.033-60.767 : 32.033-60.767
# ----
# st25m15f1-60.767-109.133 : 60.767-109.133
# ----
# st25m15f1-109.133-115.667 : 109.133-115.667
# ----
# st25m15f1-115.667-122.1 : 115.667-122.1
# ----
# st25m15f1-122.1-192.667 : 122.1-192.667
# ----
# st25m15f1-192.667-300.033 : 192.667-300.033
# ----
# st25m15f1-300.0-317.7 : 300.0-317.7
# ----
# st25m15f1-317.7-379.6 : 317.7-379.6
# ----
# st25m15f1-379.6-434.633 : 379.6-434.633
# ----
# st25m15f1-434.633-471.967 : 434.633-471.967
# ----
# st25m15f1-471.967-596.133 : 471.967-596.133
# ----

# %% [markdown]
# A higher threshold can overlook subtle slide changes. Lower the threshold and preview the extracted frames again to make sure important slides are represented.

# %%
scene_collection = video.extract_scenes(
    extraction_type=SceneExtractionType.shot_based,
    extraction_config={"threshold": 10, "frame_count": 1},
)
display_scenes(scene_collection.scenes)
# Out:
# st10m15f1-0.0-21.333 : 0.0-21.333
# ----
# st10m15f1-21.333-25.867 : 21.333-25.867
# ----
# st10m15f1-25.867-32.033 : 25.867-32.033
# ----
# st10m15f1-32.033-60.767 : 32.033-60.767
# ----
# st10m15f1-60.767-109.133 : 60.767-109.133
# ----
# st10m15f1-109.133-115.567 : 109.133-115.567
# ----
# st10m15f1-115.567-122.1 : 115.567-122.1
# ----
# st10m15f1-122.1-192.667 : 122.1-192.667
# ----
# st10m15f1-192.667-202.467 : 192.667-202.467
# ----
# st10m15f1-202.467-218.6 : 202.467-218.6
# ----
# st10m15f1-218.6-300.033 : 218.6-300.033
# ----
# st10m15f1-300.0-317.7 : 300.0-317.7
# ----
# st10m15f1-317.7-321.067 : 317.7-321.067
# ----
# st10m15f1-321.067-379.6 : 321.067-379.6
# ----
# st10m15f1-379.6-422.167 : 379.6-422.167
# ----
# st10m15f1-422.167-434.633 : 422.167-434.633
# ----
# st10m15f1-434.633-471.967 : 434.633-471.967
# ----
# st10m15f1-471.967-478.533 : 471.967-478.533
# ----
# st10m15f1-478.533-586.3 : 478.533-586.3
# ----
# st10m15f1-586.3-596.133 : 586.3-596.133
# ----

# %% [markdown]
# Threshold 10 captures the slide transitions needed for the timed lecture notes, so use it for the final understanding.

# %% [markdown]
# **2. Create Multimodal Lecture Notes**
#
# Run the spoken-word and VLM analyzers together. The VLM receives the aligned transcript and returns one concise note for each timed slide segment.

# %%
understanding = video.understand(
    segmentation={"type": "shot", "threshold": 10},
    analyzers=[
        {"type": "spoken_words", "name": "transcript"},
        {
            "type": "vlm",
            "name": "lecture_notes",
            "inputs": ["transcript"],
            "sampling": {"strategy": "uniform", "frame_count": 1},
            "config": {
                "prompt": (
                    "Create concise student notes for this lecture segment. "
                    "Use the slide as visual evidence and the transcript for spoken context. "
                    "Keep only the key ideas a student should study.\n\n"
                    "Transcript:\n{{inputs.transcript}}"
                ),
                "schema": {"notes": "string"},
            },
        },
    ],
)

understanding.wait_until_complete()
transcript_analyzer = understanding.get_analyzer("transcript")
lecture_notes_analyzer = understanding.get_analyzer("lecture_notes")

lecture_notes = lecture_notes_analyzer.get_output()
note_scenes = lecture_notes["scenes"]
print(f"Preparing note cards from {len(note_scenes)} timed segments.")
# Out:
# Preparing note cards from 19 timed segments.

# %% [markdown]
# ## 📋 Step 4: Prepare Timed Note Cards

# %% [markdown]
# The VLM has already combined the slide and its matching transcript into each generated note, so the next step prepares those timed results for display.

# %% [markdown]
# ![](https://raw.githubusercontent.com/video-db/videodb-cookbook-assets/main/images/guides/lecture_notes_1.png)

# %%
from math import isfinite

valid_note_scenes = []

for scene in note_scenes:
    if not isinstance(scene, dict):
        continue

    start = scene.get("start")
    end = scene.get("end")
    data = scene.get("data") or {}
    notes = data.get("notes")

    if not isinstance(start, (int, float)) or not isinstance(end, (int, float)):
        continue

    midpoint = (start + end) / 2

    if (
        isinstance(start, bool)
        or isinstance(end, bool)
        or not isfinite(start)
        or not isfinite(end)
        or end <= start
        or midpoint <= 0
        or not isinstance(notes, str)
        or not notes.strip()
    ):
        continue

    valid_note_scenes.append((start, end, midpoint, notes))

summary = []

for start, end, midpoint, notes in sorted(
    valid_note_scenes, key=lambda item: item[0]
):
    thumbnail = video.generate_thumbnail(time=midpoint)
    image_url = thumbnail.generate_url()

    summary.append(
        {
            "start": start,
            "end": end,
            "image_url": image_url,
            "summary": notes,
        }
    )

# %% [markdown]
# ## Step 5 : Display Summaries

# %% [markdown]
# Here we display summaries of video scenes using HTML. The summaries include images, scene timing, and text descriptions formatted with Markdown. The `create_summary_html` function generates the HTML structure, styling each summary as a card with an image and formatted text. The `display_summaries` function renders the generated HTML in an interactive, scrollable format, making it easy to visualize and review multiple scenes at once.

# %%
from IPython.display import HTML, display
import markdown2

def create_summary_html(summaries):
    html_content = """
    <style>
        .summary-container {
            display: flex;
            overflow-x: auto;
            padding: 20px 0;
            scroll-snap-type: x mandatory;
            background-color: #f0f0f0;
        }
        .summary-item {
            flex: 0 0 auto;
            width: 300px;
            margin-right: 20px;
            border: 1px solid #ddd;
            padding: 15px;
            scroll-snap-align: start;
            background-color: white;
            box-shadow: 0 2px 5px rgba(0,0,0,0.1);
        }
        .summary-item img {
            width: 100%;
            height: 180px;
            object-fit: cover;
        }
        .summary-item h3 {
            margin-top: 10px;
            color: #333;
        }
        .markdown-body {
            font-family: Arial, sans-serif;
            line-height: 1.6;
            color: #333;
        }
        .markdown-body p {
            margin-bottom: 10px;
        }
    </style>
    <div class="summary-container">
    """

    for i, summary in enumerate(summaries, 1):
        markdown_summary = markdown2.markdown(summary['summary'])
        html_content += f"""
        <div class="summary-item">
            <img src="{summary['image_url']}" alt="Scene {i}" onerror="this.onerror=null;this.src='https://via.placeholder.com/300x180.png?text=Image+Not+Available';">
            <h3>Scene {i} ({summary['start']:.2f}s - {summary['end']:.2f}s)</h3>
            <div class="markdown-body">{markdown_summary}</div>
        </div>
        """

    html_content += "</div>"
    return html_content

def display_summaries(summaries):
    html = create_summary_html(summaries)
    display(HTML(html))

display_summaries(summary)
# Out:
#     <style>
#         .summary-container {
#             display: flex;
#             overflow-x: auto;
#             padding: 20px 0;
#             scroll-snap-type: x mandatory;
#             background-color: #f0f0f0;
#         }
#         .summary-item {
#             flex: 0 0 auto;
#             width: 300px;
#             margin-right: 20px;
#             border: 1px solid #ddd;
#             padding: 15px;
#             scroll-snap-align: start;
#             background-color: white;
#             box-shadow: 0 2px 5px rgba(0,0,0,0.1);
#         }
#         .summary-item img {
#             width: 100%;
#             height: 180px;
#             object-fit: cover;
#         }
#         .summary-item h3 {
#             margin-top: 10px;
#             color: #333;
#         }
#         .markdown-body {
#             font-family: Arial, sans-serif;
#             line-height: 1.6;
#             color: #333;
#         }
#         .markdown-body p {
# ...

# %% [markdown]
# ## Conclusion
# ---

# %% [markdown]
# In this tutorial, we've explored a multimodal understanding that aligns spoken explanations with slide frames to produce timed notes from lecture and meeting videos. This workflow creates detailed study notes that keep crucial discussion points connected to the slides in a presentation.
#
# This approach is highly adaptable and can be applied to various scenarios where summarization is essential, such as:
#
# * Summarizing Board Meetings: Capture key decisions by linking spoken discussions with slides or whiteboard content.
# * Creating Training Notes: Combine screen recordings with spoken instructions to develop comprehensive step-by-step notes.
# * Documenting Q&A Sessions: Summarize questions and answers with matching on-screen and spoken context.

# %% [markdown]
# ### 👨‍👩‍👧‍👦 Support & Community
#
# If you have any questions or feedback. Feel free to reach out to us 🙌🏼
#
# * [Discord](https://colab.research.google.com/corgiredirector?site=https%3A%2F%2Fdiscord.gg%2Fpy9P639jGz)
# * [GitHub](https://github.com/video-db)
# * [Email](mailto:ashu@videodb.io)
