# %% [markdown]
# ## VideoDB - Effortlessly Remove Inappropriate Content from Video
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/Content_Moderation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
#
# Content moderation usually involves complex pipelines:
#
# **VideoDB** simplifies this into a "Prompt-and-Filter" workflow.
#
# In this tutorial, we will:
# 1.  **Upload** a video containing mixed content (e.g., action scenes).
# 2.  **Analyze** five-second scenes with a **"Moderator Prompt"** that returns structured `CONTENT_SAFE` or `CONTENT_UNSAFE` labels and reasons.
# 3.  **Select** `CONTENT_SAFE` scenes with an exact structured filter and summarize label counts.
# 4.  **Compile** the safe segments into a clean version.

# %% [markdown]
# ## Setup

# %% [markdown]
# ---
# ### Install VideoDB

# %%
# !pip install -q videodb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 kB 4.0 MB/s eta 0:00:00

# %% [markdown]
# #### 🔑 API Key
# You only need your **VideoDB API Key**.
# > Get your API key from [VideoDB Console](https://console.videodb.io). (Free for first 50 uploads, **No credit card required**).

# %%
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ---
# ## Implementation
#
# ### 🌐 Step 1: Connect to VideoDB

# %%
from videodb import connect

# Connect to VideoDB
conn = connect()
coll = conn.get_collection()

# %% [markdown]
# ### 🎥 Step 2: Upload Video
# We will use a clip from "Breaking Bad" that contains some intense scenes, which makes it a perfect candidate for moderation testing.

# %%
# Upload the video
video = coll.upload(url='https://www.youtube.com/watch?v=Xa7UaHgOGfM')
print(f"Uploaded Video ID: {video.id}")
# Out:
# Uploaded Video ID: m-z-019f90d8-02e3-7df0-bbb7-59257b5d90bf

# %% [markdown]
# Play the video

# %%
video.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/1f75531a-1279-46ff-87dc-fab7c60c88d0.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🔍 Step 3: Analyze with a Structured Moderator Prompt
# This is the core of our solution. Give the AI a **Role** and a **Strict Output Format**.
#
# The moderator analyzes five-second segments, inspects three frames, and checks for violence, weapons, blood or gore, drug use, and sexual content. It returns exactly `CONTENT_SAFE` or `CONTENT_UNSAFE` plus a brief reason.
#
# These exact fields support reliable filtering and counting.

# %%
moderation_prompt = """
You are a Content Moderator. Analyze the visual content for inappropriate elements:
1. Violence (fighting, hitting, shooting)
2. Weapons (guns, knives)
3. Blood or gore
4. Drug use
5. Sexual content

Set moderation_label to exactly CONTENT_UNSAFE if any of these are present.
Otherwise, set moderation_label to exactly CONTENT_SAFE.
Set reason to a brief explanation of the decision.
"""

print("Analyzing video for moderation... this might take some time.")

moderation_understanding = video.understand(
    segmentation={"type": "time", "seconds": 5},
    analyzers=[
        {
            "type": "vlm",
            "name": "moderation",
            "sampling": {
                "strategy": "uniform",
                "frame_count": 3,
            },
            "config": {
                "prompt": moderation_prompt,
                "schema": {
                    "moderation_label": "string",
                    "reason": "string",
                },
            },
        },
    ],
)
moderation_understanding.wait_until_complete()

moderation_analyzer = moderation_understanding.get_analyzer("moderation")
# Out:
# Analyzing video for moderation... this might take some time.

# %% [markdown]
# ### Build the Moderation Index
#
# Create the query and aggregate index from the completed moderation artifact.

# %%
moderation_index = video.index(
    name="content_moderation",
    source=moderation_analyzer,
    use_for=["query", "aggregate"],
    fields={
        "filter": ["moderation_label"],
        "aggregate": ["moderation_label"],
    },
)

moderation_index.wait_until_complete()

print("✅ Moderation index is ready!")
# Out:
# ✅ Moderation index is ready!

# %% [markdown]
# Inspect a few structured moderation results.

# %%
moderation_output = moderation_analyzer.get_output()
moderation_scenes = moderation_output["scenes"]

import json

for i, scene in enumerate(moderation_scenes[:5]):
    print(f"Scene {i + 1}:\n{json.dumps(scene, indent=2)}\n")
# Out:
# Scene 1:
# {
#   "data": {
#     "moderation_label": "CONTENT_SAFE",
#     "reason": "Title card image with green smoke reading \u2018Breaking Bad Compilation\u2019 \u2014 no visible violence, weapons, blood, drug use, or sexual content."
#   },
#   "end": 5.0,
#   "metadata": {},
#   "scene_id": "scene-0.000-5.000",
#   "start": 0.0
# }
#
# Scene 2:
# {
#   "data": {
#     "moderation_label": "CONTENT_SAFE",
#     "reason": "No visible violence, weapons, blood, drug use, or sexual content in the frames; just people standing indoors."
#   },
#   "end": 10.0,
#   "metadata": {},
#   "scene_id": "scene-5.000-10.000",
#   "start": 5.0
# }
#
# Scene 3:
# {
#   "data": {
#     "moderation_label": "CONTENT_SAFE",
#     "reason": "No visible violence, weapons, blood/gore, drug use, or sexual content in the frames; just people in an indoor setting."
#   },
#   "end": 15.0,
#   "metadata": {},
#   "scene_id": "scene-10.000-15.000",
#   "start": 10.0
# }
#
# Scene 4:
# {
#   "data": {
# ...

# %% [markdown]
# ### 🔎 Step 4: Filter for Safe Content
# Use an exact structured filter to select only `CONTENT_SAFE` scenes, then summarize the safe and unsafe label counts.

# %%
moderation_counts = video.aggregate(
    index_name=moderation_index.name,
    group_by="moderation_label",
    metric="count",
    limit=10,
)

print("Moderation summary:")
for row in moderation_counts:
    print(f"{row['moderation_label']}: {row['value']}")

safe_results = video.query(
    index_name=moderation_index.name,
    filter=[
        {
            "field": "moderation_label",
            "op": "==",
            "value": "CONTENT_SAFE",
        }
    ],
    limit=100,
    sort=[("start", "asc")],
    return_fields=[moderation_index.name],
)

safe_shots = safe_results.get_shots()

print(f"Found {len(safe_shots)} safe segments.")

for i, shot in enumerate(safe_shots[:3]):
    moderation_rows = (
        (shot.metadata or {})
        .get("indexes", {})
        .get(moderation_index.name, [])
    )
    reason = moderation_rows[0].get("reason", "") if moderation_rows else ""
    reason_text = f": {reason}" if reason else ""
    print(
        f"Segment {i + 1} ({shot.start}s - {shot.end}s)"
        f"{reason_text}"
    )
# Out:
# Moderation summary:
# CONTENT_SAFE: 75.0
# CONTENT_UNSAFE: 36.0
# None: 5.0
# Found 75 safe segments.
# Segment 1 (0.0s - 5.0s)
# Segment 2 (5.0s - 10.0s)
# Segment 3 (10.0s - 15.0s)

# %% [markdown]
# ### ✂️ Step 5: Play the Clean Version
# Compile the safe shots into one stream and play the clean version.

# %%
clean_stream_url = safe_results.compile()
print("Stream URL Clean Version:", clean_stream_url)
safe_results.play()
# Out:
# Stream URL Clean Version: https://stream.videodb.io/v3/published/manifests/2f7710ee-c941-4c7e-acc4-743699ed297b.m3u8
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://stream.videodb.io/v3/published/manifests/2f7710ee-c941-4c7e-acc4-743699ed297b.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### ⚠️ Compile Removed/Moderated Content
#
# Now, let's compile and play the segments that were identified as `CONTENT_UNSAFE` or had no moderation label (`None`), effectively showing the 'removed' or 'moderated' content.

# %%
print("\n--- Compiling Removed/Moderated Scenes ---")

# Query for UNSAFE and None segments, treating them as 'removed' or 'moderated'
removed_results = video.query(
    index_name=moderation_index.name,
    filter=[
        {
            "field": "moderation_label",
            "op": "!=",
            "value": "CONTENT_SAFE",
        }
    ],
    limit=100, # Adjust limit as needed, previously 100 was used for safe_results
    sort=[("start", "asc")],
    return_fields=[moderation_index.name],
)

removed_shots = removed_results.get_shots()
print(f"Found {len(removed_shots)} removed/moderated segments.")

# Compile the removed/moderated shots into one stream
removed_stream_url = removed_results.compile()
print("Stream URL of Removed/Moderated Version:", removed_stream_url)

# Play the compiled stream
removed_results.play()
# Out:
# --- Compiling Removed/Moderated Scenes ---
# Found 41 removed/moderated segments.
# Stream URL of Removed/Moderated Version: https://stream.videodb.io/v3/published/manifests/3152741c-5eab-402a-8455-c85ab210cce1.m3u8
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://stream.videodb.io/v3/published/manifests/3152741c-5eab-402a-8455-c85ab210cce1.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🎉 Conclusion
#
# You just built a **Content Moderation Engine** without using any external vision APIs.
#
# **Key Takeaways:**
# 1.  **Structured Prompt and Schema:** Exact labels and reasons turn video analysis into reliable structured data.
# 2.  **Exact Query and Aggregate:** Structured filtering selects safe scenes while aggregate counts summarize each label.
# 3.  **Instant Compilation and Playback:** Compile and play the clean version immediately.
#
# Explore more at [docs.videodb.io](https://docs.videodb.io/).
