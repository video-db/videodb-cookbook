# %% [markdown]
# ## VideoDB - Effortlessly Remove Inappropriate Content from Video
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/Content%20Moderation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
#
# Content moderation usually involves complex pipelines:
#
# **VideoDB** simplifies this into a "Prompt-and-Filter" workflow.
#
# In this tutorial, we will:
# 1. **Upload** a video containing mixed content.
# 2. **Understand** the video with a VLM-based moderation prompt that labels each segment as `CONTENT_SAFE` or `CONTENT_UNSAFE`.
# 3. **Index** the moderation artifact so the safety label can be queried.
# 4. **Filter** for safe segments using structured query.
# 5. **Play** the clean version containing only safe segments.
# 6. **Review** the removed unsafe scenes as a separate compiled video.

# %% [markdown]
# ## Setup

# %% [markdown]
# ---
# ### Install VideoDB

# %%
# !pip install -q git+https://github.com/video-db/videodb-python.git@feat/add-indexing-v2 python-dotenv
# Out:
#   Preparing metadata (setup.py) ... done

# %% [markdown]
# #### 🔑 API Key
# You only need your **VideoDB API Key**.
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ---
# ## Implementation
#
# ### 🌐 Step 1: Connect to VideoDB

# %%
from videodb import connect

# Connect to VideoDB
conn = connect(base_url="https://api.dev.videodb.io")
coll = conn.get_collection()
print("Connected to VideoDB successfully.")
# Out:
# Connected to VideoDB successfully.

# %% [markdown]
# ### 🎥 Step 2: Upload Video
# We will use a clip from "Breaking Bad" that contains some intense scenes, which makes it a perfect candidate for moderation testing.

# %%
# Upload the video
video = coll.upload(url='https://www.youtube.com/watch?v=Xa7UaHgOGfM')
print(f"Uploaded Video ID: {video.id}")
# Out:
# Uploaded Video ID: m-z-019f6449-d98a-7c10-ab70-75ff7133cf18

# %% [markdown]
# Play the video

# %%
video.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/4dd0fc0d-ac3c-4cfc-ab70-a70e932b6825.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🔍 Step 3: Understand Video With A Moderator Prompt
#
# This is the core of our moderation workflow.
#
# We use VideoDB's `understand()` API with the `vlm` analyzer to inspect the video in fixed 5-second segments. For each segment, the model returns a structured moderation result:
#
# - `moderation_label`: either `CONTENT_SAFE` or `CONTENT_UNSAFE`
# - `reason`: a short explanation for the label
#
# Using a structured schema is better than relying on keyword text alone, because we can later query the exact `moderation_label` field.

# %%
moderation_prompt = """
You are a content moderator. Analyze the visual content for inappropriate elements:

1. Violence, fighting, hitting, or shooting
2. Weapons such as guns or knives
3. Blood or gore
4. Drug use
5. Sexual content

Return a structured result for each video segment.

Set moderation_label to:
- CONTENT_UNSAFE if any inappropriate element is visible
- CONTENT_SAFE if the segment is clean and safe

Keep reason short and specific.
"""

print("Understanding video for moderation... this might take some time.")

understanding = video.understand(
    segmentation={
        "type": "time",
        "seconds": 5,
    },
    analyzers=[
        {
            "type": "vlm",
            "name": "moderation",
            "sampling": {
                "strategy": "uniform",
                "frame_count": 3,
            },
            "config": {
                "model": "pro",
                "prompt": moderation_prompt,
                "schema": {
                    "moderation_label": "string",
                    "reason": "string",
                },
            },
        }
    ],
)

understanding.wait_until_complete(timeout=3600, poll_interval=15)

print("Understanding ID:", understanding.id)
print("Status:", understanding.status)
# Out:
# Understanding video for moderation... this might take some time.
# Understanding ID: und_76b6dd87a24042c3
# Status: done

# %% [markdown]
# ### 👀 Inspect Moderation Results
#
# After the understanding run completes, we can inspect the moderation artifact. Each segment includes timestamps, a safety label, and a short reason.

# %%
import json

moderation_output = understanding.get_analyzer("moderation").get_output()

moderation_scenes = []

for scene in moderation_output.get("scenes", []):
    data = scene.get("data", {})

    moderation_scenes.append(
        {
            "start": scene.get("start"),
            "end": scene.get("end"),
            "moderation_label": data.get("moderation_label"),
            "reason": data.get("reason"),
            "metadata": data,
        }
    )

for i, scene in enumerate(moderation_scenes[:6]):
    print(f"Segment {i + 1}:\n{json.dumps(scene, indent=2)}\n")
# Out:
# Segment 1:
# {
#   "start": 0.0,
#   "end": 5.0,
#   "moderation_label": "CONTENT_SAFE",
#   "reason": "Title screen with green smoke; no visible violence, weapons, blood, drugs, or sexual content.",
#   "metadata": {
#     "moderation_label": "CONTENT_SAFE",
#     "reason": "Title screen with green smoke; no visible violence, weapons, blood, drugs, or sexual content."
#   }
# }
#
# Segment 2:
# {
#   "start": 5.0,
#   "end": 10.0,
#   "moderation_label": "CONTENT_SAFE",
#   "reason": "No visible violence, weapons, blood, drug use, or sexual content in the frames.",
#   "metadata": {
#     "moderation_label": "CONTENT_SAFE",
#     "reason": "No visible violence, weapons, blood, drug use, or sexual content in the frames."
#   }
# }
#
# Segment 3:
# {
#   "start": 10.0,
#   "end": 15.0,
#   "moderation_label": "CONTENT_SAFE",
#   "reason": "No visible violence, weapons, blood, drug use, or sexual content in the frames.",
#   "metadata": {
#     "moderation_label": "CONTENT_SAFE",
# ...

# %% [markdown]
# ### 🧱 Step 4: Index The Moderation Artifact
#
# The understanding run created structured moderation results. To filter safe segments, we now index the moderation artifact and make `moderation_label` queryable.
#
# This lets us use `video.query()` to retrieve only segments labeled `CONTENT_SAFE`.

# %%
moderation_index = video.index(
    name="content_moderation",
    source=moderation_output,
    use_for=["query", "aggregate"],
    fields={
        "filter": ["moderation_label"],
        "aggregate": ["moderation_label"],
        "text": ["reason"],
    },
)

idx = video.get_index(index_id=moderation_index.index_id)

print("Index name:", idx.name)
print("Index status:", idx.status)
print("Fields:", idx.fields)
print("Field schema:", idx.field_schema)
# Out:
# Index name: content_moderation
# Index status: ready
# Fields: {'aggregate': ['moderation_label'], 'filter': ['moderation_label'], 'text': ['reason']}
# Field schema: {'moderation_label': FieldSchema(type=string, groups=['filter', 'aggregate'], operators=['==', '!=', 'contains', 'in', 'exists']), 'reason': FieldSchema(type=string, groups=['text'], operators=[])}

# %% [markdown]
# > **Note on re-running this notebook**
# >
# > Index names should be unique for a video. If you re-run this notebook with the same index name, you may create duplicate indexes or query an older stale index.
# >
# > Before re-running the indexing cell, either:
# >
# > 1. Delete the existing index with the same name, or
# > 2. Use a new index name such as `content_moderation_v2`.

# %% [markdown]
# ### Optional: Delete An Existing Index
#
# If you are re-running this notebook and want to reuse the same index name, delete any existing indexes with that name first.
#
# This avoids duplicate indexes and makes sure `video.query()` uses the latest moderation artifact.

# %%
# Optional full cleanup cell. Uncomment only if you intentionally want to delete an existing index.
# index_name = "Enter the index name"
#
# for idx in video.list_indexes():
#     if idx.name == index_name:
#         print("Deleting:", idx.name, idx.index_id)
#         video.delete_index(index_id=idx.index_id)

# %% [markdown]
# ### 🔎 Step 5: Query For Safe Content
#
# Because the VLM analyzer returned a structured `moderation_label`, we can use `video.query()` to retrieve only the safe segments.
#
# This replaces the old keyword search over a scene index.

# %%
safe_results = video.query(
    index_name="content_moderation",
    filter=[
        {
            "field": "moderation_label",
            "op": "==",
            "value": "CONTENT_SAFE",
        }
    ],
    limit=100,
    return_fields=["moderation_label", "reason"],
)

safe_shots = safe_results.shots

print(f"Found {len(safe_shots)} safe segments out of the total video.")

for i, shot in enumerate(safe_shots[:3]):
    print(f"Segment {i + 1} ({shot.start}s - {shot.end}s):")
    print("Label:", shot.metadata.get("moderation_label"))
    print("Reason:", shot.metadata.get("reason"))
    print("---")
# Out:
# Found 65 safe segments out of the total video.
# Segment 1 (0.0s - 5.0s):
# Label: CONTENT_SAFE
# Reason: Title screen with green smoke; no visible violence, weapons, blood, drugs, or sexual content.
# ---
# Segment 2 (10.0s - 15.0s):
# Label: CONTENT_SAFE
# Reason: No visible violence, weapons, blood, drug use, or sexual content in the frames.
# ---
# Segment 3 (105.0s - 110.0s):
# Label: CONTENT_SAFE
# Reason: No visible violence, weapons, blood, drug use, or sexual content; only a tense confrontation.
# ---

# %% [markdown]
# ### ✂️ Step 6: Play The Clean Version
#
# The query result contains the safe timestamped segments. We can now play the clean version directly from the query result.

# %%
stream_url = safe_results.compile()
print("Stream URL Clean Version:", stream_url)
safe_results.play()
# Out:
# Stream URL Clean Version: https://dseetlpshk2tb.cloudfront.net/v3/published/manifests/0c924431-ff32-42bd-b385-7905aa71e04f.m3u8
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://dseetlpshk2tb.cloudfront.net/v3/published/manifests/0c924431-ff32-42bd-b385-7905aa71e04f.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🧾 Step 7: Review Removed Scenes
#
# The clean version above keeps only `CONTENT_SAFE` segments. For moderation review, we can also query the removed `CONTENT_UNSAFE` segments, print the reason each scene was removed, and compile those removed scenes into a separate review video.

# %%
unsafe_results = video.query(
    index_name="content_moderation",
    filter=[
        {
            "field": "moderation_label",
            "op": "==",
            "value": "CONTENT_UNSAFE",
        }
    ],
    limit=100,
    return_fields=["moderation_label", "reason"],
)

unsafe_shots = unsafe_results.shots

print(f"Removed {len(unsafe_shots)} unsafe segments from the clean version.")

for i, shot in enumerate(unsafe_shots, 1):
    metadata = getattr(shot, "metadata", {}) or {}
    print(f"Removed scene {i}: {shot.start:.2f}s - {shot.end:.2f}s")
    print("Reason:", metadata.get("reason", "No reason returned."))
    print("---")
# Out:
# Removed 49 unsafe segments from the clean version.
# Removed scene 1: 100.00s - 105.00s
# Reason: Visible pill bottles (drug-related) and a firearm being handled (weapons).
# ---
# Removed scene 2: 110.00s - 115.00s
# Reason: Visible blood on person’s hand (blood/gore present).
# ---
# Removed scene 3: 115.00s - 120.00s
# Reason: Apparent drug-related paraphernalia and white powder suggesting drug preparation.
# ---
# Removed scene 4: 120.00s - 125.00s
# Reason: Apparent physical altercation/falling (violence) and partial nudity visible
# ---
# Removed scene 5: 125.00s - 130.00s
# Reason: Visible bullet holes and a man in distress (suggests shooting); mild partial nudity present; no blood, weapons, or drug use visible.
# ---
# Removed scene 6: 130.00s - 135.00s
# Reason: Person restrained and struggling against vehicle (physical assault). No visible weapons, blood, drugs, or sexual content.
# ---
# Removed scene 7: 140.00s - 145.00s
# ...

# %% [markdown]
# ### 🎞️ Compile Removed Scenes
#
# This compiled video is useful for human review, audit logs, or internal moderation QA.

# %%
removed_stream_url = unsafe_results.compile()
print("Stream URL Removed Scenes Review:", removed_stream_url)
unsafe_results.play()
# Out:
# Stream URL Removed Scenes Review: https://dseetlpshk2tb.cloudfront.net/v3/published/manifests/2c2a6b09-1626-42f2-9730-3ed46bbfc917.m3u8
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://dseetlpshk2tb.cloudfront.net/v3/published/manifests/2c2a6b09-1626-42f2-9730-3ed46bbfc917.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🎉 Conclusion
#
# You just built a **Content Moderation Engine** without using any external vision APIs.
#
# **Key Takeaways:**
# 1.  **Prompt Engineering:** Directing the indexing AI with strict labels (`CONTENT_SAFE`) turns unstructured video into structured data.
# 2.  **Keyword Search:** Simple searches become powerful filters when the data is structured.
# 3.  **Instant Play:** No editing time; Videodb just plays the safe bits.
#
# Explore more at [docs.videodb.io](https://docs.videodb.io/).
