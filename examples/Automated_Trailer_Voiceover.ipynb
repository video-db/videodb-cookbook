# %% [markdown]
# # 🔊 Elevating Trailers with Automated Narration
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/Automated_Trailer_Voiceover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
#
# Narration is the heartbeat of trailers, injecting excitement and intrigue into every frame. With **VideoDB**, adding narration becomes a seamless, creative process.
#
# In this tutorial, we will:
# 1.  **Analyze** a movie trailer to understand its scenes.
# 2.  **Plan** short, connected narration lines for each scene.
# 3.  **Synthesize** each trailer-style voiceover line separately.
# 4.  **Edit** the narration into precise time slots that match the video's pacing.
# 5.  **Overlay** a movie poster at the end.
#
# All using a single SDK.

# %% [markdown]
# ---
#
# ## Setup

# %% [markdown]
# ### 📦  Installing packages

# %%
# !pip install -q videodb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 kB 1.1 MB/s eta 0:00:00

# %% [markdown]
# ### 🔑 API Keys
# You only need your **VideoDB API Key**.
# > Get your API key from [VideoDB Console](https://console.videodb.io). (Free for first 50 uploads, **No credit card required**).

# %%
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### 🌐 Step 1: Connect to VideoDB
# Establish a connection to your VideoDB project.

# %%
from videodb import connect

# Connect to VideoDB
conn = connect()
coll = conn.get_collection()

# %% [markdown]
# ### 🎬 Step 2: Upload the Trailer
# We'll upload a sample movie trailer (Chase) to VideoDB. This creates the base video asset we will edit.

# %%
video = coll.upload(url='https://www.youtube.com/watch?v=WQmGwmc-XUY')
print(f"Uploaded Video ID: {video.id}")
# Out:
# Uploaded Video ID: m-z-019f9352-484c-7731-b7ef-07b0a4e8fb32

# %% [markdown]
# ### 🔍 Step 3: Analyze 10-Second Scenes
# Divide the trailer into 10-second visual segments so each narration line can respond to what is on screen and fit inside its own time slot.

# %%
print("Analyzing trailer scenes... this might take a moment.")

scene_understanding = video.understand(
    segmentation={"type": "time", "seconds": 10},
    analyzers=[
        {
            "type": "vlm",
            "name": "scene",
            "config": {
                "prompt": "Describe the key action, mood, and story beat in this trailer segment.",
                "schema": {
                    "description": "string",
                },
            },
        },
    ],
)
scene_understanding.wait_until_complete()

scene_analyzer = scene_understanding.get_analyzer("scene")
# Out:
# Analyzing trailer scenes... this might take a moment.

# %% [markdown]
# Let's view the description of first scene from the video

# %%
scene_output = scene_analyzer.get_output()

video_scenes = [
    {
        "start": scene["start"],
        "end": scene["end"],
        "description": scene["data"]["description"],
    }
    for scene in scene_output["scenes"]
]

import json
print(json.dumps(video_scenes[0], indent=2))
# Out:
# {
#   "start": 0.0,
#   "end": 10.0,
#   "description": "A slow aerial sunrise/dusk shot of a lit city skyline that cuts to a cold, gray river with birds skimming the surface. Key action: quiet establishing visuals \u2014 city lights then a lone, flowing river. Mood: contemplative, slightly melancholic and brooding. Story beat: an opening location-and-tone setup that shifts from urban bustle to solitude, suggesting a transition or the beginning of a subdued, possibly ominous journey."
# }

# %% [markdown]
# ### 🔊 Step 4: Plan Scene-Aware Narration
# Use VideoDB's `generate_text` to create one short narration line per timed segment. The lines follow the visuals while forming one connected trailer story.

# %%
scene_context = json.dumps(video_scenes, indent=2)

prompt = f"""
Craft a gripping, dramatic movie-trailer narration that weaves a compelling story through these timed visual segments:
{scene_context}

Requirements:
- Style: Intense, gritty, like a blockbuster action movie trailer.
- Return exactly {len(video_scenes)} voiceovers, one per segment, in the same order.
- Each voiceover must be a single impactful sentence of 10 to 12 words, building a continuous, dramatic narrative.
- Crucially, do not simply describe the on-screen action; instead, interpret and advance the overarching plot dramatically.
- Do not include stage directions, timestamps, labels, or sound cues.

Return only JSON in this exact structure:
{{
  "voiceovers": [
    {{"text": "Short narration for segment 1"}},
    {{"text": "Short narration for segment 2"}}
  ]
}}
"""

script_response = coll.generate_text(
    prompt=prompt,
    model_name="pro",
    response_type="json",
)

voiceover_lines = script_response["output"]["voiceovers"]
narration_plan = [
    {
        "start": scene["start"],
        "end": scene["end"],
        "text": voiceover_lines[index]["text"],
    }
    for index, scene in enumerate(video_scenes)
]

print("--- Narration Plan ---")
for line in narration_plan:
    print(f"{line['start']:.1f}s: {line['text']}")
# Out:
# --- Narration Plan ---
# 0.0s: When the city slept, a solitary river carried a secret nobody knew.
# 10.0s: From fogged outskirts to towering glass, a conspiracy moved its pieces.
# 20.0s: The sea remembered debts, tides rising to erase fragile, borrowed lives.
# 30.0s: After the fire, one survivor chose exile over answers and vengeance.
# 40.0s: He would learn the ocean wasn't refuge but an unforgiving judge.
# 50.0s: Back in the city, sirens hunted hope while children vanished into darkness.
# 60.0s: A hidden hand stitched chaos to headlines, pulling strings from shadows.
# 70.0s: Now, dawn's pale emblem promises a reckoning neither forgiving nor forgetful.

# %% [markdown]
# Each line is deliberately brief, leaving breathing room before the next 10-second narration slot.

# %% [markdown]
# ### 🎙️ Step 5: Generate Voiceover Audio
# Generate each narration line as a separate audio asset so it can be placed independently on the timeline.

# %%
voiceovers = []

for line in narration_plan:
    audio = coll.generate_voice(
        text=line["text"],
        voice_name="Brian",
    )
    voiceovers.append({**line, "audio": audio})
    print(
        f"Generated {float(audio.length):.1f}s voiceover "
        f"for {line['start']:.1f}s: {audio.id}"
    )
# Out:
# Generated 3.8s voiceover for 0.0s: a-z-019f9359-e845-7040-ac45-4a8a7b1cb9a8
# Generated 4.2s voiceover for 10.0s: a-z-019f935a-11da-7933-84b2-55a283a8528d
# Generated 4.9s voiceover for 20.0s: a-z-019f935a-2e58-75c2-b23a-8a7018f502d1
# Generated 3.9s voiceover for 30.0s: a-z-019f935a-4f25-7853-af7b-9bed489cfe1b
# Generated 3.8s voiceover for 40.0s: a-z-019f935a-749a-7911-aaa3-0fd269aebb5b
# Generated 4.3s voiceover for 50.0s: a-z-019f935a-9088-7af3-b053-c450026f409e
# Generated 4.5s voiceover for 60.0s: a-z-019f935a-be0d-7233-9b78-4cf84e79f1a8
# Generated 4.7s voiceover for 70.0s: a-z-019f935a-e8f7-7d23-8117-6c7b1fcd10a0

# %% [markdown]
# ### 🎥 Step 6: Edit the Timeline
# Place every voiceover at the start of its matching segment. Each clip is capped at the segment boundary, so consecutive narration can never overlap.

# %%
from videodb.editor import Timeline, Track, Clip, VideoAsset, AudioAsset

timeline = Timeline(conn)

# --- 1. Main Video Track ---
main_track = Track()
video_asset = VideoAsset(id=video.id, volume=0.5)
video_clip = Clip(asset=video_asset, duration=float(video.length))
main_track.add_clip(0, video_clip)
timeline.add_track(main_track)

# --- 2. Scene-Aware Narration Track ---
audio_track = Track()

for voiceover in voiceovers:
    audio = voiceover["audio"]
    segment_duration = float(voiceover["end"] - voiceover["start"])
    clip_duration = min(float(audio.length), segment_duration)

    audio_asset = AudioAsset(id=audio.id, start=0, volume=2.0)
    audio_clip = Clip(asset=audio_asset, duration=clip_duration)
    audio_track.add_clip(float(voiceover["start"]), audio_clip)

timeline.add_track(audio_track)

# %% [markdown]
# ### 🪄 Step 7: Review and Share
# Preview the trailer with the integrated narration to ensure it aligns with your vision. Once satisfied, share the trailer with others to experience the enhanced storytelling.

# %%
from videodb import play_stream

stream_url = timeline.generate_stream()
play_stream(stream_url)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/a96e9c01-1000-4c51-bf40-257bc5cb99e6.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🎬 Bonus - Add Movie Poster
# Let's add a "Coming Soon" style movie poster at the very end of the trailer. We'll upload an image URL and overlay it on the video.

# %%
from videodb import MediaType

# Upload movie poster
poster_url = "https://img.freepik.com/free-photo/darkly-atmospheric-retail-environment-rendering_23-2151153755.jpg"
image = coll.upload(url=poster_url, media_type=MediaType.image)
print(f"Uploaded Image ID: {image.id}")
# Out:
# Uploaded Image ID: img-z-019f935b-2076-7671-854d-16b859a362cd

# %%
from videodb.editor import ImageAsset

# Create an overlay track for the poster
image_track = Track()

# Show poster at the 10 seconds of the trailer
image_asset = ImageAsset(id=image.id)
image_clip = Clip(
    asset=image_asset,
    duration=10.0,
    fit="contain"
)

image_track.add_clip(float(video.length) - 10, image_clip)
timeline.add_track(image_track)

# %% [markdown]
# Lets play it!

# %%
stream_url = timeline.generate_stream()
play_stream(stream_url)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/f500d6fa-8a0c-4958-8dac-74c8fc126c19.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🎉 Conclusion
#
# You've successfully built a sophisticated video editing workflow:
# * **Analysis:** Automated scene understanding.
# * **Generation:** AI Scripting and Voice synthesis.
# * **Composition:** Non-linear editing with multi-track audio and image overlays.
#
# Explore more possibilities at [docs.videodb.io](https://docs.videodb.io/).
