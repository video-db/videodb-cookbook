# %% [markdown]
# # 🔊 Elevating Trailers with Automated Narration
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/Automated_Trailer_Voiceover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
#
# Narration is the heartbeat of trailers, injecting excitement and intrigue into every frame. With **VideoDB**, adding narration becomes a seamless, creative process.
#
# In this tutorial, we will:
# 1. **Understand** a movie trailer using VideoDB's VLM analyzer.
# 2. **Generate** a dramatic script using VideoDB's text generation.
# 3. **Synthesize** a deep, trailer-style voiceover using VideoDB's voice generation.
# 4. **Edit** the narration into the trailer timeline to match the video's pacing.
# 5. **Overlay** a movie poster at the end while keeping narration clear of the closing credits.
#
# All using a single SDK.

# %% [markdown]
# ---
#
# ## Setup

# %% [markdown]
# ### 📦  Installing packages

# %%
# !pip install -q git+https://github.com/video-db/videodb-python.git@feat/add-indexing-v2 python-dotenv
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# ### 🔑 API Keys
# You only need your **VideoDB API Key**.
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### 🌐 Step 1: Connect to VideoDB
# Establish a connection to your VideoDB project.

# %%
from videodb import connect

# Connect to VideoDB
conn = connect(base_url="https://api.dev.videodb.io")
coll = conn.get_collection()
print("Connected to VideoDB successfully.")
# Out:
# Connected to VideoDB successfully.

# %% [markdown]
# ### 🎬 Step 2: Upload the Trailer
# We'll upload a sample movie trailer (Chase) to VideoDB. This creates the base video asset we will edit.

# %%
video = coll.upload(url='https://www.youtube.com/watch?v=WQmGwmc-XUY')
print(f"Uploaded Video ID: {video.id}")
# Out:
# Uploaded Video ID: m-z-019f65be-631d-7332-bb9c-f6182872da3b

# %% [markdown]
# ### 🔍 Step 3: Understand Scenes
#
# We need to understand the trailer's visual pacing before writing narration for it.
#
# We use VideoDB's `understand()` API with the `vlm` analyzer to generate timestamped scene descriptions. These descriptions help the narration match the trailer's action, mood, suspense, and pacing.
#
# For production-quality trailer narration, we use the `pro` model. You can switch to `base` for lower cost or `ultra` for the highest-quality visual reasoning.

# %%
print("Understanding scenes... this might take a moment.")

understanding = video.understand(
    segmentation={
        "type": "shot",
        "threshold": 30,
    },
    analyzers=[
        {
            "type": "vlm",
            "name": "scene",
            "sampling": {
                "strategy": "uniform",
                "frame_count": 8,
            },
            "config": {
                "model": "pro",
                "prompt": (
                    "Describe this movie trailer scene in detail for writing dramatic "
                    "trailer narration. Focus on action, characters, setting, mood, "
                    "visual intensity, suspense, conflict, and pacing."
                ),
                "schema": {
                    "scene_description": "string"
                },
            },
        }
    ],
)

understanding.wait_until_complete(timeout=3600, poll_interval=15)

print("Understanding ID:", understanding.id)
print("Status:", understanding.status)
# Out:
# Understanding scenes... this might take a moment.
# Understanding ID: und_3037360f8b4a4cf3
# Status: done

# %% [markdown]
# ### 👀 Let's View The Description Of The First Scene
#
# After the understanding run completes, we can inspect the VLM analyzer output.
#
# The new understanding output stores scene descriptions inside the analyzer artifact. We convert that output into a simple `video_scenes` list with `description`, `start`, and `end` fields so the rest of the notebook can use the same structure as before.

# %%
import json

scene_output = understanding.get_analyzer("scene").get_output()

video_scenes = []

for scene in scene_output.get("scenes", []):
    data = scene.get("data", {})
    description = data.get("scene_description", "")

    video_scenes.append(
        {
            "description": description,
            "start": scene.get("start"),
            "end": scene.get("end"),
            "metadata": data,
        }
    )

print(json.dumps(video_scenes[0], indent=2))
# Out:
# {
#   "description": "It opens in absolute black \u2014 a long, pregnant beat \u2014 then the frame explodes with fire. A towering column of orange and gold fills the widescreen, flames licking outward, folding and re-forming like a living thing. The camera sits close, every flare and ember magnified: heat becomes texture, light becomes threat. There are no faces yet, only the sound of a roar building \u2014 crackle, snap, an almost-human cadence \u2014 as if the blaze itself is a character with purpose. The mood is primal and urgent: something precious is being erased, and the flames are relentless. Cuts are rapid, tempo rising; each new burst of light ratchets up the stakes and leaves a question smoldering \u2014 what was lost, who will stand against it? The sequence ends on the inferno\u2019s hungry sway, a visual cliffhanger that promises collision, sacrifice, and a conflict measured in ash and flame.",
#   "start": 0.0,
#   "end": 1.043,
#   "metadata": {
# ...

# %% [markdown]
# ### 🔊 Step 4: Generate Narration Script
#
# We use VideoDB's `generate_text` to write a dramatic trailer narration script. The prompt includes the VLM scene descriptions generated in the previous step so the narration matches the visual action, tone, and pacing.

# %%
# Construct prompt with scene context
scene_context = "\n".join([f"- {scene['description']}" for scene in video_scenes])

prompt = f"""
Craft a dynamic, dramatic narration script for a movie trailer based on these visual descriptions:
{scene_context}

Requirements:
- Style: Intense, gritty, like a blockbuster action movie trailer.
- Pace: Slow, deliberate, and cinematic. Use short lines with breathing room.
- Keep the narration concise enough to fit naturally over the trailer and finish before the closing poster/credits.
- Output: Only provide the script for direct voice generation, no stage directions or narration.
"""

script_response = coll.generate_text(
    prompt=prompt,
    model_name="pro"
)

voiceover_script = script_response["output"] if isinstance(script_response, dict) else script_response

print("--- Generated Script ---")
print(voiceover_script)
# Out:
# --- Generated Script ---
# Black.
#
# Then fire.
#
# Not a mistake.
#
# A thing with teeth.
#
# It eats memory.
#
# It makes a question of us.
#
# This city keeps its own counsel.
#
# Some lights don't belong to who they say.
#
# Everything here is watching.
#
# And tonight, something answers.
#
# Cold river. Bare branches. A waiting undercurrent.
#
# Steel and glass. A thousand quiet windows. One lonely beacon.
#
# Concrete veins. Cars like blood. Paths about to cross.
#
# A coastline that does not forgive hesitation.
#
# One boarder alone against a reef.
#
# A rooftop hatch. A single point of heat.
#
# Blue monitors. A hand that refuses to blink.
#
# A doorframe becomes a mouth of flame.
#
# Run.
#
# A corridor. Headlights breathing down your neck.
#
# A heartbeat in the dark.
#
# Listen.
#
# Decisions sink like stones.
#
# Plans go up in fire.
#
# Every choice has a wake.
#
# When the light finds you, nothing stays the same.
#
# Count the ash.
#
# Count the lights.
#
# ...

# %% [markdown]
# You can refine the narration script prompt using the VLM understanding output to improve synchronization with the trailer's pacing.

# %% [markdown]
# ### 🎙️ Step 5: Generate Slower Voiceover Audio
#
# Now we synthesize the narration script into a trailer-style voiceover. The prompt above keeps the narration sparse and deliberate so the generated voice has natural breathing room and does not crowd the closing poster.

# %%
print("Generating voiceover audio...")

audio = coll.generate_voice(
    text=voiceover_script,
    voice_name="Brian"
)

print(f"Generated Audio ID: {audio.id}")
# Out:
# Generating voiceover audio...
# Generated Audio ID: a-z-019f65c3-7e3f-7883-aded-8d7c4a115e96

# %% [markdown]
# ### 🕒 Step 6: Set Timeline Timing
#
# The narration starts after the opening beat and is capped before the final poster section, so it does not run into the end card.

# %%
VOICEOVER_START = 4.0
POSTER_DURATION = 8.0
POSTER_START = max(0.0, float(video.length) - POSTER_DURATION)
VOICEOVER_END = max(VOICEOVER_START + 1.0, POSTER_START - 0.5)
VOICEOVER_DURATION = min(float(audio.length), VOICEOVER_END - VOICEOVER_START)

if VOICEOVER_DURATION <= 0:
    VOICEOVER_DURATION = min(float(audio.length), float(video.length) - VOICEOVER_START)

print("Voiceover starts at:", VOICEOVER_START)
print("Voiceover duration used:", VOICEOVER_DURATION)
print("Poster starts at:", POSTER_START)
# Out:
# Voiceover starts at: 4.0
# Voiceover duration used: 64.679184
# Poster starts at: 71.0

# %% [markdown]
# ### 🎥 Step 7: Edit the Timeline
# Now we combine the video and generated voiceover.

# %%
from videodb.editor import Timeline, Track, Clip, VideoAsset, AudioAsset

timeline = Timeline(conn)

# --- 1. Main Video Track ---
main_track = Track()
video_asset = VideoAsset(id=video.id, volume=0.5)
video_clip = Clip(asset=video_asset, duration=float(video.length))
main_track.add_clip(0, video_clip)
timeline.add_track(main_track)

# --- 2. Narration Track ---
audio_track = Track()
audio_asset1 = AudioAsset(id=audio.id, start=0, volume=2.0)
audio_clip1 = Clip(asset=audio_asset1, duration=VOICEOVER_DURATION)
audio_track.add_clip(VOICEOVER_START, audio_clip1)
timeline.add_track(audio_track)

# %% [markdown]
# ### 🪄 Step 8: Review and Share
# Preview the trailer with the integrated narration to ensure it aligns with your vision. Once satisfied, share the trailer with others to experience the enhanced storytelling.

# %%
from videodb import play_stream

stream_url = timeline.generate_stream()
print(f"Stream URL: {stream_url}")
play_stream(stream_url)
# Out:
# Stream URL: https://d1zudc7ewmc6ey.cloudfront.net/v1/27320813-37cf-4498-a952-b55c6c6ce942.m3u8
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/27320813-37cf-4498-a952-b55c6c6ce942.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🎬 Bonus - Add Movie Poster With End Sync
# Let's add a "Coming Soon" style movie poster at the very end of the trailer. The voiceover timeline above is capped before this final poster section, so narration does not drift into the closing credits.

# %%
from videodb import MediaType

# Upload movie poster
poster_url = "https://img.freepik.com/free-photo/darkly-atmospheric-retail-environment-rendering_23-2151153755.jpg"
image = coll.upload(url=poster_url, media_type=MediaType.image)
print(f"Uploaded Image ID: {image.id}")
# Out:
# Uploaded Image ID: img-z-019f65c3-ab8c-7cb0-a89b-e0fcdb51cbec

# %%
from videodb.editor import ImageAsset

image_track = Track()

image_asset = ImageAsset(id=image.id)
image_clip = Clip(
    asset=image_asset,
    duration=POSTER_DURATION,
    fit="contain"
)

poster_start = POSTER_START
image_track.add_clip(poster_start, image_clip)

timeline.add_track(image_track)

# %% [markdown]
# Lets play it!

# %%
stream_url = timeline.generate_stream()
play_stream(stream_url)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/b407ef7f-52f2-455c-a0f9-0414f04bbe1f.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🎉 Conclusion
#
# You've successfully built a sophisticated video editing workflow:
# * **Analysis:** Automated scene understanding.
# * **Scriptwriting:** AI-generated narration based on the trailer visuals.
# * **Voiceover:** Synthetic speech as a VideoDB audio asset.
# * **Editing:** Timeline composition with video, narration, auto captions, and an end poster.
#
# Explore more at [docs.videodb.io](https://docs.videodb.io/).
