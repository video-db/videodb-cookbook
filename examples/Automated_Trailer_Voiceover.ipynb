# %% [markdown]
# # 🔊 Elevating Trailers with Automated Narration
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/Automated_Trailer_Voiceover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
#
# Narration is the heartbeat of trailers, injecting excitement and intrigue into every frame. With **VideoDB**, adding narration becomes a seamless, creative process.
#
# In this tutorial, we will:
# 1. **Understand** a movie trailer using VideoDB's VLM analyzer.
# 2. **Generate** a dramatic script using VideoDB's text generation.
# 3. **Synthesize** a deep, trailer-style voiceover using VideoDB's voice generation.
# 4. **Edit** the narration into the trailer timeline to match the video's pacing.
# 5. **Overlay** a movie poster at the end.
#
# All using a single SDK.

# %% [markdown]
# ---
#
# ## Setup

# %% [markdown]
# ### 📦  Installing packages

# %%
# !pip install -q videodb python-dotenv

# %% [markdown]
# ### 🔑 API Keys
# You only need your **VideoDB API Key**.
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### 🌐 Step 1: Connect to VideoDB
# Establish a connection to your VideoDB project.

# %%
from videodb import connect

# Connect to VideoDB
conn = connect()
coll = conn.get_collection()
print("Connected to VideoDB successfully.")
# Out:
# Connected to VideoDB

# %% [markdown]
# ### 🎬 Step 2: Upload the Trailer
# We'll upload a sample movie trailer (Chase) to VideoDB. This creates the base video asset we will edit.

# %%
video = coll.upload(url='https://www.youtube.com/watch?v=WQmGwmc-XUY')
print(f"Uploaded Video ID: {video.id}")
# Out:
# Uploaded Video ID: m-z-019f1c11-387e-7791-8866-dbfcbdabe89e

# %% [markdown]
# ### 🔍 Step 3: Understand Scenes
#
# We need to understand the trailer's visual pacing before writing narration for it.
#
# We use VideoDB's `understand()` API with the `vlm` analyzer to generate timestamped scene descriptions. These descriptions help the narration match the trailer's action, mood, suspense, and pacing.
#
# For production-quality trailer narration, we use the `pro` model. You can switch to `base` for lower cost or `ultra` for the highest-quality visual reasoning.

# %%
print("Understanding scenes... this might take a moment.")

understanding = video.understand(
    segmentation={
        "type": "shot",
        "threshold": 30,
    },
    analyzers=[
        {
            "type": "vlm",
            "name": "scene",
            "sampling": {
                "strategy": "uniform",
                "frame_count": 8,
            },
            "config": {
                "model": "pro",
                "prompt": (
                    "Describe this movie trailer scene in detail for writing dramatic "
                    "trailer narration. Focus on action, characters, setting, mood, "
                    "visual intensity, suspense, conflict, and pacing."
                ),
                "schema": {
                    "scene_description": "string"
                },
            },
        }
    ],
)

understanding.wait_until_complete(timeout=3600, poll_interval=15)

print("Understanding ID:", understanding.id)
print("Status:", understanding.status)
# Out:
# Understanding scenes... this might take a moment.
# Understanding ID: und_f8629ccfaba24990
# Status: done

# %% [markdown]
# ### 👀 Let's View The Description Of The First Scene
#
# After the understanding run completes, we can inspect the VLM analyzer output.
#
# The new understanding output stores scene descriptions inside the analyzer artifact. We convert that output into a simple `video_scenes` list with `description`, `start`, and `end` fields so the rest of the notebook can use the same structure as before.

# %%
import json

scene_output = understanding.get_analyzer("scene").get_output()

video_scenes = []

for scene in scene_output.get("scenes", []):
    data = scene.get("data", {})
    description = data.get("scene_description", "")

    video_scenes.append(
        {
            "description": description,
            "start": scene.get("start"),
            "end": scene.get("end"),
            "metadata": data,
        }
    )

print(json.dumps(video_scenes[0], indent=2))
# Out:
# {
#   "description": "Black frames split the screen \u2014 a heartbeat of silence \u2014 then the darkness rips open. A furnace of yellow and orange fills the frame: towering, incandescent flames crawl and twist, an unmoored column of heat. The camera is tight, intimate; we never see what burns, only the living, hungry fire consuming the center of the frame. Churning tongues of light sculpt shadows at the edges, while the image\u2019s letterbox bars make the inferno feel cinematic and claustrophobic. The mood is raw and immediate \u2014 too close to safety, too far from reason \u2014 every flicker a promise of escalation. There are no faces here, only the implication of conflict: something has ignited, and the aftermath is already claiming space. The pacing is urgent and sparing \u2014 a flash of violence, held long enough to register danger, then cut: the trailer\u2019s first warning.",
#   "start": 0.0,
#   "end": 1.043,
#   "metadata": {
#     "scene_description": "Black frames split the screen \u2014 a heartbeat of silence \u2014 then the darkness rips open. A furnace of yellow and orange fills the frame: towering, incandescent flames crawl and twist, an unmoored column of heat. The camera is tight, intimate; we never see what burns, only the living, hungry fire consuming the center of the frame. Churning tongues of light sculpt shadows at the edges, while the image\u2019s letterbox bars make the inferno feel cinematic and claustrophobic. The mood is raw and immediate \u2014 too close to safety, too far from reason \u2014 every flicker a promise of escalation. There are no faces here, only the implication of conflict: something has ignited, and the aftermath is already claiming space. The pacing is urgent and sparing \u2014 a flash of violence, held long enough to register danger, then cut: the trailer\u2019s first warning."
#   }
# }

# %% [markdown]
# ### 🔊 Step 4: Generate Narration Script
#
# We use VideoDB's `generate_text` to write a dramatic trailer narration script. The prompt includes the VLM scene descriptions generated in the previous step so the narration matches the visual action, tone, and pacing.

# %%
# Construct prompt with scene context
scene_context = "\n".join(
    [
        f"- {scene['start']:.2f}s to {scene['end']:.2f}s: {scene['description']}"
        for scene in video_scenes
    ]
)

prompt = f"""
Craft a dynamic, dramatic narration script for a movie trailer based on these timestamped visual descriptions:
{scene_context}

Requirements:
- Style: Intense, gritty, like a blockbuster action movie trailer.
- Keep the narration concise enough to fit naturally over the trailer.
- Output: Only provide the script for direct voice generation, no stage directions or titles.
"""

script_response = coll.generate_text(
    prompt=prompt,
    model_name="pro"
)

voiceover_script = script_response["output"] if isinstance(script_response, dict) else script_response

print("--- Generated Script ---")
print(voiceover_script)
# Out:
# --- Generated Script ---
# It starts with a flame.
#
# Too close to safety. Too far from reason.
#
# From above, the city holds its breath.
#
# A spine of light—and everything else a map.
#
# A cold river keeps its secrets.
#
# Wings cut the air like warnings.
#
# Glass canyons. Private fires. One rooftop is a weakness.
#
# Roads like arteries—every turn a choice.
#
# The ocean doesn't forgive. It waits. It tests.
#
# A small blaze becomes a message.
#
# Who struck the match?
#
# One man rides the swell—balance against hunger.
#
# The reef waits like a jaw.
#
# The tide keeps coming.
#
# Lights without sirens. A van. A cluster of shadows.
#
# A meeting in the dark. A decision in motion.
#
# He runs—headlong into light and pursuit.
#
# One breath.
#
# They thought it was over. They were wrong.
#
# A ribbon of fire—an impossible doorway.
#
# No room to turn. Only one way through.
#
# Something above tilts, focuses, hunts.
#
# No more hiding.
#
# This ends now.
#
# Into the blue—irreversible.
#
# Hands on a keyboard. Code reflected in fire.
#
# They pull the wire; the city answers in flames.
#
# They thought the darkness would hide them.
#
# In the silence, the truth waits.
#
# Hold your breath.
#
# The city closes its jaws.
#
# One point of heat—then nothing.
#
# When the light returns, everything will have changed.

# %% [markdown]
# You can refine the narration script prompt using the timestamps from the VLM understanding output to improve synchronization with the trailer's pacing.

# %% [markdown]
# ### 🎙️ Step 5: Generate Voiceover Audio
#
# Now we synthesize the narration script into a trailer-style voiceover.

# %%
print("Generating voiceover audio...")

audio = coll.generate_voice(
    text=voiceover_script,
    voice_name="Brian"
)

print(f"Generated Audio ID: {audio.id}")
# Out:
# Generating voiceover audio...
# Generated Audio ID: a-z-019f1c19-d841-7341-a9e8-90955d9a4660

# %% [markdown]
# ### 🎥 Step 6: Edit the Timeline
# Now we combine the video and audio.

# %%
from videodb.editor import Timeline, Track, Clip, VideoAsset, AudioAsset

timeline = Timeline(conn)

# --- 1. Main Video Track ---
main_track = Track()
video_asset = VideoAsset(id=video.id, volume=0.5)
video_clip = Clip(asset=video_asset, duration=float(video.length))
main_track.add_clip(0, video_clip)
timeline.add_track(main_track)

# --- 2. Narration Track---
audio_track = Track()
audio_asset1 = AudioAsset(id=audio.id, start=0, volume=2.0)
audio_clip1 = Clip(asset=audio_asset1, duration=float(audio.length))
audio_track.add_clip(4, audio_clip1)

timeline.add_track(audio_track)

# %% [markdown]
# ### 🪄 Step 7: Review and Share
# Preview the trailer with the integrated narration to ensure it aligns with your vision. Once satisfied, share the trailer with others to experience the enhanced storytelling.

# %%
from videodb import play_stream

stream_url = timeline.generate_stream()
print(f"Stream URL: {stream_url}")
play_stream(stream_url)
# Out:
# Stream URL: https://d1zudc7ewmc6ey.cloudfront.net/v1/2d899163-e664-4032-9a25-c1c3acae8881.m3u8
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/2d899163-e664-4032-9a25-c1c3acae8881.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🎬 Bonus - Add Movie Poster
# Let's add a "Coming Soon" style movie poster at the very end of the trailer. We'll upload an image URL and overlay it on the video.

# %%
from videodb import MediaType

# Upload movie poster
poster_url = "https://img.freepik.com/free-photo/darkly-atmospheric-retail-environment-rendering_23-2151153755.jpg"
image = coll.upload(url=poster_url, media_type=MediaType.image)
print(f"Uploaded Image ID: {image.id}")
# Out:
# Uploaded Image ID: img-z-019f1c21-a354-7df2-b7c9-f6b50564a9f3

# %%
from videodb.editor import ImageAsset

image_track = Track()

image_asset = ImageAsset(id=image.id)
image_clip = Clip(
    asset=image_asset,
    duration=10.0,
    fit="contain"
)

poster_start = max(0, float(video.length) - 10)
image_track.add_clip(poster_start, image_clip)

timeline.add_track(image_track)

# %% [markdown]
# Lets play it!

# %%
stream_url = timeline.generate_stream()
print(f"Stream URL: {stream_url}")
play_stream(stream_url)
# Out:
# Stream URL: https://d1zudc7ewmc6ey.cloudfront.net/v1/a8226634-53bc-4cc2-9f35-e8ea61e67e8c.m3u8
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/a8226634-53bc-4cc2-9f35-e8ea61e67e8c.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🎉 Conclusion
#
# You've successfully built a sophisticated video editing workflow:
# * **Analysis:** Automated scene understanding.
# * **Generation:** AI Scripting and Voice synthesis.
# * **Composition:** Non-linear editing with multi-track audio and image overlays.
#
# Explore more possibilities at [docs.videodb.io](https://docs.videodb.io/).
