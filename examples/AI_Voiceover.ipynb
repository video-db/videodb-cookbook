# %% [markdown]
# # 🔊 Adding AI Generated voiceovers to silent footage

# %% [markdown]
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/AI_Voiceover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
#
# Voiceovers are the secret sauce that turns silent footage into captivating stories. They add depth, emotion, and excitement, elevating the viewing experience.
#
# Traditionally, this workflow required stitching together multiple tools: one for script writing (LLM), one for voice generation (TTS), and another for video editing.
#
# **VideoDB** simplifies this by bringing everything under one roof. In this tutorial, we will:
# 1.  **Upload** a silent video.
# 2. **Understand** the video using VideoDB's VLM analyzer to describe its visual content.
# 3.  **Generate** a narration script using VideoDB's text generation.
# 4.  **Generate** a professional AI voiceover using VideoDB's voice generation.
# 5.  **Merge** them instantly into a final video.

# %% [markdown]
# We will take [this silent footage](https://youtu.be/RcRjY5kzia8) of underwater life and automatically generate a nature-documentary style narration for it.

# %% [markdown]
# ---

# %% [markdown]
# ## Setup

# %% [markdown]
# ### 📦  Installing VideoDB

# %%
# !pip install -q videodb python-dotenv

# %% [markdown]
# ### 🔑 API Keys
# You only need your **VideoDB API Key**.
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ---

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### 🌐 Step 1: Connect to VideoDB
# Connect to VideoDB using your API key to establish a session.

# %%
from videodb import connect

# Connect to VideoDB
conn = connect()
coll = conn.get_collection()
print("Connected to VideoDB successfully.")
# Out:
# Connected to VideoDB successfully!

# %% [markdown]
# ### 🎥 Step 2: Upload Video
# We'll upload the silent underwater footage directly from YouTube.

# %%
# Upload a video by URL
video = coll.upload(url='https://youtu.be/RcRjY5kzia8')
print(f"Uploaded ID: {video.id}")
# Out:
# Uploaded ID: m-z-019f1c01-ec5a-7961-8d47-0ac0b34f6bfa

# %% [markdown]
# Lets have a look at the video

# %%
video.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/497a19f4-6b75-4024-8702-6abfab36730d.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🔍 Step 3: Understand Visuals
#
# We need to understand what is happening in the silent footage before generating a narration script.
#
# We use VideoDB's `understand()` API with the `vlm` analyzer to create scene-level visual descriptions. These descriptions capture the underwater environment, marine life, movement, colors, and mood of the footage.
#
# For production-quality narration, we use the `pro` model. You can switch to `base` for lower cost or `ultra` for the highest quality.

# %%
print("Understanding scenes... this might take a moment.")

understanding = video.understand(
    segmentation={
        "type": "time",
        "seconds": 10,
    },
    analyzers=[
        {
            "type": "vlm",
            "name": "scene",
            "sampling": {
                "strategy": "uniform",
                "frame_count": 8,
            },
            "config": {
                "model": "pro",
                "prompt": (
                    "Describe the visual content of this underwater scene in detail "
                    "for writing a nature-documentary style voiceover. Focus on marine life, "
                    "movement, environment, colors, lighting, mood, and how the visuals progress."
                ),
                "schema": {
                    "scene_description": "string"
                },
            },
        }
    ],
)

understanding.wait_until_complete(timeout=3600, poll_interval=15)

print("Understanding ID:", understanding.id)
print("Status:", understanding.status)
# Out:
# Understanding scenes... this might take a moment.
# Understanding ID: und_0af2aefef51c44c9
# Status: done

# %% [markdown]
# ### 👀 Let's View The Description Of The First Scene
#
# After the understanding run completes, we can inspect the VLM analyzer output.
#
# The new understanding output stores scene descriptions inside the analyzer artifact. We convert it into a simple `video_scenes` list with `description`, `start`, and `end` fields so the rest of the notebook can use the same structure as before.

# %%
import json

scene_output = understanding.get_analyzer("scene").get_output()

video_scenes = []

for scene in scene_output.get("scenes", []):
    data = scene.get("data", {})
    description = data.get("scene_description", "")

    video_scenes.append(
        {
            "description": description,
            "start": scene.get("start"),
            "end": scene.get("end"),
            "metadata": data,
        }
    )

print(json.dumps(video_scenes[0], indent=2))
# Out:
# {
#   "description": "A vast, living carpet of fish fills the frame, hundreds \u2014 perhaps thousands \u2014 of small, disk-shaped bodies packed shoulder-to-shoulder. From the first second the image is almost abstract: overlapping silhouettes in a palette of turquoise and deep ocean blue, punctuated by paler, almost luminous edges where light catches scales. Hints of yellow-green flash between them, a subtle accent that gives depth to the mass. \n\nLight filters down from above, soft and diffused, creating a veil of dappled illumination that skitters across the school. The surface above is suggested rather than seen; instead, the camera is immersed in midwater, surrounded by motion. The overall mood is both serene and electric \u2014 a quiet choreography with an undercurrent of tension. \n\nMovement is rhythmic and continuous. Small, synchronized pulses travel through the group like ripples across a fabric: a pocket of fish slows, the surrounding bodies tilt and slip, and that small change fans outward as a wave. Over the ten seconds the school remains cohesive, constantly reshaping \u2014 tightening into denser clusters, opening momentary channels where the blue of the water shows through, then sealing back up. Occasionally a single fish or a thin strand will drift against the main flow, their silhouettes momentarily distinct before they are absorbed again. \n\nThe visuals read like a living mosaic: repeating forms, shifting patterns, and shimmering highlights that make the whole scene feel both immense and intimately detailed \u2014 a testimony to the silent, communal life of the ocean.",
#   "start": 0.0,
#   "end": 10.0,
#   "metadata": {
#     "scene_description": "A vast, living carpet of fish fills the frame, hundreds \u2014 perhaps thousands \u2014 of small, disk-shaped bodies packed shoulder-to-shoulder. From the first second the image is almost abstract: overlapping silhouettes in a palette of turquoise and deep ocean blue, punctuated by paler, almost luminous edges where light catches scales. Hints of yellow-green flash between them, a subtle accent that gives depth to the mass. \n\nLight filters down from above, soft and diffused, creating a veil of dappled illumination that skitters across the school. The surface above is suggested rather than seen; instead, the camera is immersed in midwater, surrounded by motion. The overall mood is both serene and electric \u2014 a quiet choreography with an undercurrent of tension. \n\nMovement is rhythmic and continuous. Small, synchronized pulses travel through the group like ripples across a fabric: a pocket of fish slows, the surrounding bodies tilt and slip, and that small change fans outward as a wave. Over the ten seconds the school remains cohesive, constantly reshaping \u2014 tightening into denser clusters, opening momentary channels where the blue of the water shows through, then sealing back up. Occasionally a single fish or a thin strand will drift against the main flow, their silhouettes momentarily distinct before they are absorbed again. \n\nThe visuals read like a living mosaic: repeating forms, shifting patterns, and shimmering highlights that make the whole scene feel both immense and intimately detailed \u2014 a testimony to the silent, communal life of the ocean."
#   }
# }

# %% [markdown]
# ### 📝 Step 4: Generate Script
# Now, we use VideoDB's `generate_text` method to write a voiceover script based on the scene descriptions we just retrieved.

# %%
# Construct a prompt with the scene context
scene_context = "\n".join([f"- {scene['description']}" for scene in video_scenes])

prompt = f"""
Here is a visual description of a video about the underwater world:
{scene_context}

Based on this, write a short, engaging voiceover script in the style of a nature documentary narrator (like David Attenborough).
Keep it synced to the flow of the visuals described.
Return ONLY the raw text of the narration, no stage directions or titles.
"""

# Generate the script using VideoDB
script_response = coll.generate_text(
    prompt=prompt,
    model_name="pro"
)

# Extract text if response is JSON, otherwise use directly
voiceover_script = script_response["output"] if isinstance(script_response, dict) else script_response

print("--- Generated Script ---")
print(voiceover_script)
# Out:
# --- Generated Script ---
# Beneath the surface a living carpet fills the blue — hundreds, perhaps thousands, of disk‑shaped bodies pressed shoulder to shoulder. At first they are almost abstract: overlapping silhouettes of turquoise and ocean indigo, each edge catching light like a tiny, luminous seam. Pale flashes of yellow‑green punctuate the mass as waves of motion ripple through it — a single pocket slows, the surrounding bodies tilt and slip, and that change fans outward in a silent, synchronized pulse.
#
# The shoal breathes and briefly parts, revealing slender, iridescent individuals — lavender and sky‑blue flanks catching shafts of filtered sunlight. Tiny columns of bubbles pick out pinpricks of highlight as the water deepens to cobalt. Then the scene opens: the dense school gives way to a planted landscape of golden‑green stems and a lush wall of foliage. Bright orange‑red minnows and slower silver fish weave through the plants, motion layered from frenzied darting at the front to tranquil gliding among the stems.
#
# A sunlit reef appears — a dome of orange coral studded with living polyps, pale branches and yellow sponges adding warm accents against the blue. Minute fish dart from crevice to crevice, while light scatters through the water, painting textures in soft, shimmering bands. Along a sculpted coral wall a disk‑shaped fish slips into a slot, nuzzling the rock in a small, intimate choreography of approach and pause.
#
# Tighter still, two warm‑toned reef fish feather through a narrow crevice; then, as the view widens, a ribbon of amber‑gold fish sweeps past the reef. Golden shoals pass over bleached rock, then part to reveal a lone diver — human and marine life moving together as the school skirts his path.
#
# Everywhere, the reef hums: clownfish weaving through anemones, tangs and surgeonfish cutting clean arcs, a slate‑blue resident marked with a flash of yellow gliding past canyon walls, the brief shadow of a predator passing by. Tiny silvery clouds rise and tremble in sunlit water as coral towers teem with orange sparks.
#
# This is a world of texture and timing — a compact metropolis of color and motion, where each pulse, dart and hush is part of a continuous, living choreography beneath the waves.

# %% [markdown]
# ### 🎙️ Step 5: Generate Voiceover Audio
# We can now turn that text into speech using `generate_voice`. This returns an Audio object directly, so we don't need to save or upload files manually.

# %%
print("Generating voiceover audio...")

# Generate speech directly as a VideoDB Audio Asset
audio = coll.generate_voice(
    text=voiceover_script,
    voice_name="Default"
)

print(f"Generated Audio Asset ID: {audio.id}")
# Out:
# Generating voiceover audio...
# Generated Audio Asset ID: a-z-019f1c05-76cc-7f61-a4b5-9b8ca82f5360

# %% [markdown]
# ### 🎬 Step 6: Compose the Video
# We have the video and the generated voiceover. Now we merge them using the Timeline Editor.

# %%
from videodb.editor import Timeline, Track, Clip, VideoAsset, AudioAsset

# Create a timeline
timeline = Timeline(conn)

# 1. Create a Video Track
video_track = Track()
video_asset = VideoAsset(id=video.id)
# Add the video clip
video_clip = Clip(asset=video_asset, duration=float(video.length))
video_track.add_clip(0, video_clip)

# 2. Create an Audio Track for the voiceover
audio_track = Track()
# Use the audio object we generated in Step 5
audio_asset = AudioAsset(id=audio.id)
audio_clip = Clip(asset=audio_asset, duration=float(audio.length))
audio_track.add_clip(0, audio_clip)

# Add tracks to timeline
timeline.add_track(video_track)
timeline.add_track(audio_track)

# %% [markdown]
# ### 🪄 Step 7: Review and Share
# Generate the final stream URL and watch your AI-narrated video!

# %%
from videodb import play_stream

stream_url = timeline.generate_stream()
print(f"Stream URL: {stream_url}")
play_stream(stream_url)
# Out:
# Stream URL: https://d1zudc7ewmc6ey.cloudfront.net/v1/ac4d27cb-e507-4462-8ed6-a132523fb001.m3u8
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/ac4d27cb-e507-4462-8ed6-a132523fb001.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---

# %% [markdown]
# ### 🎉 Conclusion:
# Congratulations! You have successfully automated the process of creating custom and personalized voiceovers based on a simple prompt and raw video footage using VideoDB.
#
# By leveraging advanced AI technologies, you can enhance the storytelling and immersive experience of your video content. Experiment with different prompts and scene analysis techniques to further improve the quality and accuracy of the voiceovers. Enjoy creating captivating narratives with AI-powered voiceovers using VideoDB!
#
# Explore more at [docs.videodb.io](https://docs.videodb.io/).
