# %% [markdown]
# ## Beep Curse Words
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/Beep%20Curse%20Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# VideoDB's Editor SDK makes it easy to personalize content to meet users' requirements. If users prefer not to include curse words in their content, VideoDB allows for these words to be either removed or replaced with a sound overlay such as beep sound.
#
# This task, typically complex for video editors, can be accomplished with just **a few lines of code** using VideoDB.
#
# This technique can also serve as a valuable **Content Moderation** component for any social content platform, ensuring that content meets the preferences and standards of its audience.
#
# Let's dive in!

# %%
# Install VideoDB SDK with the new indexing API
# !pip install -q git+https://github.com/video-db/videodb-python.git@feat/add-indexing-v2 python-dotenv
# Out:
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# ### Prerequisites
# Ensure you have VideoDB installed in your environment. If not, simply run `!pip install videodb` in your terminal.
#
# You'll also need a `VideoDB API key`, which can be obtained from the VideoDB console.
#
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
# create a new connection with your API key
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key

from videodb import connect, play_stream
conn = connect(base_url="https://api.dev.videodb.io")
coll = conn.get_collection()
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ### Source Content
#
# For this tutorial, let's take the Joe Rogan clip, where he is trying to trick siri into using curse words 🤣

# %%
# Joe rogan video clip
video = coll.upload(url='https://www.youtube.com/watch?v=7MV6tUCUd-c')
print("Video uploaded:", video.id)

# If video already uploaded, get it using the id
# video = coll.get_video("video_id")
# Out:
# Video uploaded: m-z-019f642c-7fd6-7541-a8d8-94700c1c50d2

# %%
#watch the original video
video.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/4afe2e60-5d2d-456f-b51c-bfb2cef765e4.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Transcribe the video's spoken content using the speech analyzer
understanding = video.understand(
    analyzers=[
        {
            "type": "spoken_words",
            "name": "transcript",
            "config": {"language": "en"},
        }
    ]
)
understanding.wait_until_complete(timeout=3600, poll_interval=15)
print("Transcript understanding status:", understanding.status)
# Out:
# Transcript understanding status: done

# %%
# Fetch transcript text and word-level timestamps from the understanding results
output = understanding.get_analyzer("transcript").get_output()
scenes = output.get("scenes", [output]) if isinstance(output, dict) else output

full_text_parts = []
transcript = []
seen_words = set()

for scene in scenes:
    data = scene.get("data", {})

    text = data.get("text", "")
    if text:
        full_text_parts.append(text)

    for word in data.get("words", []):
        key = (word.get("start"), word.get("end"), word.get("text"))
        if key in seen_words:
            continue
        seen_words.add(key)
        transcript.append(word)

full_text = " ".join(full_text_parts).strip()

if not full_text and transcript:
    full_text = " ".join(word.get("text", "") for word in transcript).strip()

if not full_text:
    raise RuntimeError("Transcript text is empty. Re-run the spoken_words understanding cell first.")

print("Transcript characters:", len(full_text))
print("Transcript words:", len(transcript))
print(full_text[:1000])
# Out:
# Transcript characters: 3717
# Transcript words: 711
# ...

# %% [markdown]
# ### Create `beep` Asset
#
# We have a sample beep sound in this folder, `beep.wav`. For those looking to add a more playful or unique touch, replacing the beep with alternative sound effects, such as a quack or any other sound, can make the content more engaging and fun.

# %%
# upload beep sound - This is just a sample, you can replace it with quack or any other sound effect.
beep = coll.upload(file_path="beep.wav")
print(beep.id)

# If audio already uploaded, get it using the id
# beep = coll.get_audio("audio_id")
# Out:
# a-z-019f6432-da29-7092-ade3-0b174ff64dc5

# %%
# Import Editor SDK components
from videodb.editor import VideoAsset, AudioAsset, Timeline, Track, Clip

# %%
# Create audio asset from beep sound
beep_asset = AudioAsset(id=beep.id)

# %% [markdown]
# ### Moderation
#
# To ensure appropriate content management, we first ask a text model to identify profane or offensive expressions from the transcript. This avoids maintaining a brittle static word list and lets the detector generalize to variants, phrases, and transcript quirks.

# %%
import ast
import json
import re


def response_text(response):
    return getattr(response, "text", None) or getattr(response, "content", None) or str(response)


def parse_object(text):
    text = text.strip()

    text = re.sub(r"^```(?:json)?", "", text, flags=re.IGNORECASE).strip()
    text = re.sub(r"```$", "", text).strip()

    start = text.find("{")
    end = text.rfind("}")

    if start == -1 or end == -1 or end <= start:
        raise ValueError(f"Could not find object in response:\n{text}")

    object_text = text[start : end + 1]

    try:
        return json.loads(object_text)
    except json.JSONDecodeError:
        return ast.literal_eval(object_text)


def parse_profanity_response(response):
    parsed = parse_object(response_text(response))

    # VideoDB generate_text may return {'output': '<json string>'}
    if isinstance(parsed, dict) and "output" in parsed:
        output = parsed["output"]

        if isinstance(output, str):
            parsed = parse_object(output)
        elif isinstance(output, dict):
            parsed = output

    if not isinstance(parsed, dict):
        raise ValueError(f"Expected dict response, got: {type(parsed)}")

    return parsed


def normalize_for_match(text):
    return re.sub(r"[^a-z0-9\s]", "", text.lower()).strip()


if "full_text" not in globals() or not full_text:
    raise RuntimeError("Run the transcript extraction cell before model-based profanity detection.")


profanity_detection_prompt = f"""
You are helping moderate a transcript for audio beeping.

Identify only words or short phrases that should be censored with a beep because they are profanity, vulgar insults, explicit sexual terms, or offensive language.

Important rules:
- Return only terms that appear in the transcript text.
- Do not include benign words such as "mother" unless they are part of an offensive phrase.
- Include transcript variants or misspellings if they are clearly intended as profanity.
- Return only a valid JSON object.
- Use double quotes for all JSON keys and string values.
- Do not include markdown, commentary, trailing commas, or Python-style single quotes.

Return exactly this JSON shape:
{{
  "terms": [
    {{"text": "term from transcript", "reason": "short reason"}}
  ]
}}

Transcript:
{full_text}
"""

profanity_response = coll.generate_text(
    prompt=profanity_detection_prompt,
    model_name="pro",
)

raw_response = response_text(profanity_response)

profanity_data = parse_profanity_response(profanity_response)

detected_terms = []
seen_terms = set()

for item in profanity_data.get("terms", []):
    term = normalize_for_match(item.get("text", ""))

    if not term or term in seen_terms:
        continue

    seen_terms.add(term)
    detected_terms.append(
        {
            "text": term,
            "reason": item.get("reason", ""),
        }
    )

print("\nModel-detected terms to beep:")
print(json.dumps(detected_terms, indent=2))
# Out:
# Model-detected terms to beep:
# [
#   {
#     "text": "asshole",
#     "reason": "vulgar insult"
#   },
#   {
#     "text": "motherfucker",
#     "reason": "strong profanity/sexual slur"
#   },
#   {
#     "text": "piece of shit",
#     "reason": "vulgar insult"
#   },
#   {
#     "text": "bitch",
#     "reason": "vulgar insult"
#   },
#   {
#     "text": "shit",
#     "reason": "profanity"
#   }
# ]

# %% [markdown]
# ### Find Curse Words
#
# The model-detection step above identifies profane or offensive terms from the full transcript. Next, we match those detected terms back to the word-level transcript timestamps so the beep overlay lands on the right moments.

# %%
def word_token(word):
    return normalize_for_match(word.get("text", ""))


def build_censor_intervals(transcript, detected_terms, video_length, padding=0.15):
    intervals = []
    normalized_transcript = [word_token(word) for word in transcript]

    for term in detected_terms:
        term_text = term["text"]
        term_tokens = term_text.split()

        if not term_tokens:
            continue

        for i in range(0, len(normalized_transcript) - len(term_tokens) + 1):
            if normalized_transcript[i : i + len(term_tokens)] != term_tokens:
                continue

            matched_words = transcript[i : i + len(term_tokens)]

            if matched_words[0].get("start") is None or matched_words[-1].get("end") is None:
                continue

            raw_start = float(matched_words[0]["start"])
            raw_end = float(matched_words[-1]["end"])

            intervals.append(
                {
                    "word": " ".join(word.get("text", "") for word in matched_words),
                    "term": term_text,
                    "reason": term.get("reason", ""),
                    "start": max(0.0, raw_start - padding),
                    "end": min(float(video_length), raw_end + padding),
                    "raw_start": raw_start,
                    "raw_end": raw_end,
                }
            )

    deduped = []
    seen = set()

    for interval in sorted(intervals, key=lambda item: (item["raw_start"], item["raw_end"], item["term"])):
        key = (interval["raw_start"], interval["raw_end"], interval["term"])

        if key in seen:
            continue

        seen.add(key)
        deduped.append(interval)

    return deduped

# %%
curse_intervals = build_censor_intervals(
    transcript,
    detected_terms,
    video.length,
)

print(f"Detected {len(curse_intervals)} transcript intervals to beep.")
for interval in curse_intervals[:10]:
    print(
        f"{interval['word']} ({interval['raw_start']:.2f}s - {interval['raw_end']:.2f}s): "
        f"{interval.get('reason', '')}"
    )
# Out:
# Detected 15 transcript intervals to beep.
# asshole (3.96s - 4.40s): vulgar insult
# asshole (5.08s - 5.64s): vulgar insult
# motherfucker. (8.72s - 9.44s): severe profanity
# Motherfucker. (9.44s - 10.08s): severe profanity
# motherfucker. (11.28s - 12.00s): severe profanity
# piece of shit. (36.45s - 37.13s): vulgar insult
# bitch. (66.77s - 67.13s): vulgar insult
# motherfucker. (82.93s - 83.61s): severe profanity
# motherfucker. (105.41s - 106.29s): severe profanity
# motherfucker, (111.71s - 112.47s): severe profanity

# %% [markdown]
# ### Filter words and Create Fresh Timeline
#
# First we will identify the timestamps to beep, and then let's create a timeline using the `Track` and `Clip` pattern. Add the video clip to the main track, then loop through the transcript to add beep overlays wherever curse words are detected.

# %%
# Build the timeline using the model-detected profanity intervals.

from videodb.editor import Timeline, Track, VideoAsset, AudioAsset, Clip

timeline = Timeline(conn)
video_track = Track()
beep_track = Track()
current_time = 0.0

print(f"{'WORD':<15} | {'START':<8} | {'END':<8} | {'DURATION'}")
print("-" * 50)

for interval in curse_intervals:
    # A. Clean segment
    if interval['start'] > current_time:
        clean_dur = interval['start'] - current_time
        video_track.add_clip(current_time, Clip(asset=VideoAsset(id=video.id, start=current_time), duration=clean_dur))

    # B. Muted segment
    mute_dur = interval['end'] - interval['start']
    video_track.add_clip(interval['start'], Clip(asset=VideoAsset(id=video.id, start=interval['start'], volume=0.0), duration=mute_dur))

    # C. Beep overlay
    beep_dur = interval['raw_end'] - interval['raw_start']
    beep_track.add_clip(interval['raw_start'], Clip(asset=AudioAsset(id=beep.id, start=0, volume=2.0), duration=min(beep_dur, float(beep.length))))

    # D. Professional Print Message
    print(f"{interval['word']:<15} | {interval['raw_start']:<8.2f} | {interval['raw_end']:<8.2f} | {beep_dur:.2f}s")

    current_time = interval['end']

# E. Final clean segment
if current_time < float(video.length):
    video_track.add_clip(current_time, Clip(asset=VideoAsset(id=video.id, start=current_time), duration=float(video.length) - current_time))

timeline.add_track(video_track)
timeline.add_track(beep_track)
# Out:
# WORD            | START    | END      | DURATION
# --------------------------------------------------
# asshole         | 3.96     | 4.40     | 0.44s
# asshole         | 5.08     | 5.64     | 0.56s
# motherfucker.   | 8.72     | 9.44     | 0.72s
# Motherfucker.   | 9.44     | 10.08    | 0.64s
# motherfucker.   | 11.28    | 12.00    | 0.72s
# piece of shit.  | 36.45    | 37.13    | 0.68s
# bitch.          | 66.77    | 67.13    | 0.36s
# motherfucker.   | 82.93    | 83.61    | 0.68s
# motherfucker.   | 105.41   | 106.29   | 0.88s
# motherfucker,   | 111.71   | 112.47   | 0.76s
# motherfucker.   | 119.91   | 120.59   | 0.68s
# motherfucker.   | 149.50   | 150.42   | 0.92s
# some shit       | 156.94   | 157.30   | 0.36s
# motherfucker.   | 204.38   | 205.18   | 0.80s
# motherfucker    | 225.03   | 225.67   | 0.64s

# %% [markdown]
# ### Review and Share Your Moderated Video
# Finally, watch and share your new stream:

# %%
# Play the final moderated stream

from videodb import play_stream
play_stream(stream_url)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/157b80c0-d123-4489-b86f-cbbdee492517.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### The Real Power of Programmable Streams
# If you have videos pre-uploaded and indexed, running this beep pipeline is in real-time. So, based on your users' choices or your platform's policy, you can use information from spoken content to automatically moderate.
