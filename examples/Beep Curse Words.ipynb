# %% [markdown]
# ## Beep Curse Words
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/Beep%20Curse%20Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# VideoDB's Editor SDK makes it easy to personalize content to meet users' requirements. If users prefer not to include curse words in their content, VideoDB allows for these words to be either removed or replaced with a sound overlay such as beep sound.
#
# This task, typically complex for video editors, can be accomplished with just **a few lines of code** using VideoDB.
#
# This technique can also serve as a valuable **Content Moderation** component for any social content platform, ensuring that content meets the preferences and standards of its audience.
#
# Let's dive in!

# %%
# Install VideoDB SDK with the new indexing API
# !pip install -q videodb python-dotenv

# %% [markdown]
# ### Prerequisites
# Ensure you have VideoDB installed in your environment. If not, simply run `!pip install videodb` in your terminal.
#
# You'll also need a `VideoDB API key`, which can be obtained from the VideoDB console.
#
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
# create a new connection with your API key
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key

from videodb import connect, play_stream
conn = connect()
coll = conn.get_collection()
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ### Source Content
#
# For this tutorial, let's take the Joe Rogan clip, where he is trying to trick siri into using curse words 🤣

# %%
# Joe rogan video clip
video = coll.upload(url='https://www.youtube.com/watch?v=7MV6tUCUd-c')
print("Video uploaded:", video.id)

# If video already uploaded, get it using the id
# video = coll.get_video("video_id")
# Out:
# Video uploaded: m-z-019f11e9-edae-7df1-8bff-cf2a61b5f38b

# %%
#watch the original video
video.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/871a38ce-c29c-49d8-a528-3f192f6475c4.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Transcribe the video's spoken content using the speech analyzer
understanding = video.understand(
    analyzers=[{"type": "spoken_words", "config": {"language": "en"}}]
)
understanding.wait_until_complete(timeout=3600, poll_interval=15)
# Out:
# Understanding(id=und_a91829bf4d064b5f, video_id=m-z-019f11e9-edae-7df1-8bff-cf2a61b5f38b, status=done, analyzers=1)

# %% [markdown]
# ### Create `beep` Asset
#
# We have a sample beep sound in this folder, `beep.wav`. For those looking to add a more playful or unique touch, replacing the beep with alternative sound effects, such as a quack or any other sound, can make the content more engaging and fun.

# %%
# upload beep sound - This is just a sample, you can replace it with quack or any other sound effect.
beep = coll.upload(file_path="beep.wav")
print(beep.id)

# If audio already uploaded, get it using the id
# beep = coll.get_audio("audio_id")
# Out:
# a-z-019f11eb-4f75-74c3-a3a6-5483cc39b5f2

# %%
# Import Editor SDK components
from videodb.editor import VideoAsset, AudioAsset, Timeline, Track, Clip

# %%
# Create audio asset from beep sound
beep_asset = AudioAsset(id=beep.id)

# %% [markdown]
# ### Moderation
# To ensure appropriate content management, it's necessary to have a method for identifying profanity and applying a predefined overlay to censor it. In this tutorial, we've included a list of curse words. Feel free to customize this list according to your requirements.

# %%
curse_words_list = ['shit', 'ass', 'shity' 'fuck', 'motherfucker','damn', 'fucking', 'motherfuker', 'bitch', 'hole', 'mother', 'asshole']

# %%
# Fetch word-level transcript from the understanding results
output = understanding.get_analyzer("transcript").get_output()
scenes = output.get("scenes", [output]) if isinstance(output, dict) else output

# Full transcript text
full_text = " ".join(s.get("data", {}).get("text", "") for s in scenes)
print(full_text)

# Word-level timestamps (start, end, text, speaker, confidence)
transcript = []
for scene in scenes:
    for word in scene.get("data", {}).get("words", []):
        transcript.append(word)
print(transcript)
# Out:
# Do you have a lot of home like Siri and Alexa's at your house? No, I don't trust those. That That asshole thing, or is that. Asshole that you. You can make Siri say, oh, motherfucker, motherfucker, motherfucker. motherfucker. Yeah. You can make make Siri say motherfucker. Yeah. People think I was joking about that. Let me show you how to do that. Watch this. Folks. Here we go. What is the dep? Definition.  Taco bell. That's a mistake. What's the definition of mother? Come on, you piece of shit. There's no need for that. Oh, the piece. Late. Change. Sorry. I'm sorry about that. What's What's the definition of mother? As a noun, it means a woman in relation to child or children to. Whom she has given birth. Do you want to hear the next one? Yes, as of. Verb. It means bring up a child with care and affection. Do you want to hear the last one? Yes. As a verb, it means give birth to. Oh, my God. Siri. You bitch. You took it from me. Yeah, Yeah, they removed removed it. You know it. Also, Also, they removed Apple. Apple. Come on. Was funny. How did they leave it in there and then take it out? Did they took took out the dead body? One. Remember the first one? That's That's a crazy one. Short for motherfucker. Yeah. It would say as a. You know? Yeah, I bet alexis alexis still still has it. I think I. Tweeted what it said, what exactly it said. Yeah, I did it. I did it the day you did it. It took me a couple of tries because I didn't say it right. But it ended up doing says as a noun short. For motherfucker. But it could be a verb as well, right? Yeah. If you're actually a motherfucker, ask here with with mother means and it gives you the correct F. Definition. Then it asks you, do you want to hear the next one? If you say yes, it says as a noun, it means short for mother. Fucker. Yeah, I got it right, right, but it was weird to hear. Like, I heard. And I was like, what? That's real. Like, imagine if that's, like, your mom and she's, like, teaching. A little kid how to use Siri like Mommy. How do I know what. Mommy is. Well, we can ask Siri, sweetie. We can ask Siri what mother means I'm. Okay, let's do it. Do you want to hear the. Next one. Okay, as a noun, short for motherfuck. A little kid like what? Mommy, what did they say? What does Siri say if you ask if Santa's real or some shit like that? Good question. Oh, is Santa real? I'm going to pretend you. Didn't ask that. I don't want you to get a lump of coal this year.  Alexa tells you Anne Anne uses shares a needle. Siri. Are you allowed to swear? I don't. Have the answer to that. Is there something else I can help you with? I just want. Want to know if you stopped using curse words recently. I'm not sure I understand. Well, earlier in this week, I had asked. You what mother means. And you gave me one definition. Then you said, do you want to? The next one. And you said as a noun, it means short for motherfucker. I just thought that was weird. That's not nice. She doesn't care. Siri, you sound like. Like a crazy person. Like, I'm trying to talk to you about this issue that you and I are having about communication. And what do you say to me? You say, that's not nice. Well, it's not nice for you to say. Motherfucker in front of that little three year old just learning how to talk. But. But. Wow. This is the future. Here's some of the Google stuff I was telling you about. This is the future. We're going to be having arguments. arguments. With our digital devices like that. That's a crude like. Helper. Like a super crude helper. Right? Like what Siri could do and not. Do. It's very crude, but this is just like the iPhone. One, right? Maybe they're absolutely going to have. Have some sort of AI that can keep up with the conversation. For sure that's going to happen.
# [{'confidence': 0.99365234, 'end': 0.16, 'speaker': 'A', 'start': 0.08, 'text': 'Do'}, {'confidence': 1.0, 'end': 0.24, 'speaker': 'A', 'start': 0.16, 'text': 'you'}, {'confidence': 1.0, 'end': 0.32, 'speaker': 'A', 'start': 0.24, 'text': 'have'}, {'confidence': 0.9995117, 'end': 0.4, 'speaker': 'A', 'start': 0.32, 'text': 'a'}, {'confidence': 1.0, 'end': 0.48, 'speaker': 'A', 'start': 0.4, 'text': 'lot'}, {'confidence': 0.9980469, 'end': 0.6, 'speaker': 'A', 'start': 0.48, 'text': 'of'}, {'confidence': 0.9995117, 'end': 0.88, 'speaker': 'A', 'start': 0.6, 'text': 'home'}, {'confidence': 0.9951172, 'end': 1.2, 'speaker': 'A', 'start': 0.96, 'text': 'like'}, {'confidence': 0.8826497, 'end': 1.64, 'speaker': 'A', 'start': 1.2, 'text': 'Siri'}, {'confidence': 0.99658203, 'end': 1.8, 'speaker': 'A', 'start': 1.64, 'text': 'and'}, {'confidence': 0.91381836, 'end': 2.4, 'speaker': 'A', 'start': 1.8, 'text': "Alexa's"}, {'confidence': 0.9995117, 'end': 2.56, 'speaker': 'A', 'start': 2.4, 'text': 'at'}, {'confidence': 0.9995117, 'end': 2.64, 'speaker': 'A', 'start': 2.56, 'text': 'your'}, {'confidence': 0.9995117, 'end': 2.8, 'speaker': 'A', 'start': 2.64, 'text': 'house?'}, {'confidence': 0.57421875, 'end': 2.96, 'speaker': 'A', 'start': 2.8, 'text': 'No,'}, {'confidence': 0.99853516, 'end': 3.04, 'speaker': 'A', 'start': 2.96, 'text': 'I'}, {'confidence': 0.9998372, 'end': 3.12, 'speaker': 'A', 'start': 3.04, 'text': "don't"}, {'confidence': 0.99975586, 'end': 3.28, 'speaker': 'A', 'start': 3.12, 'text': 'trust'}, {'confidence': 0.95947266, 'end': 3.52, 'speaker': 'A', 'start': 3.28, 'text': 'those.'}, {'confidence': 0.9760742, 'end': 3.96, 'speaker': 'A', 'start': 3.68, 'text': 'That'}, {'confidence': 0.9760742, 'end': 3.96, 'speaker': 'A', 'start': 3.68, 'text': 'That'}, {'confidence': 0.87561035, 'end': 4.4, 'speaker': 'A', 'start': 3.96, 'text': 'asshole'}, {'confidence': 0.99853516, 'end': 4.52, 'speaker': 'A', 'start': 4.4, 'text': 'thing,'}, {'confidence': 0.9765625, 'end': 4.68, 'speaker': 'A', 'start': 4.52, 'text': 'or'}, {'confidence': 0.9770508, 'end': 4.84, 'speaker': 'A', 'start': 4.68, 'text': 'is'}, {'confidence': 0.9692383, 'end': 5.01, 'speaker': 'A', 'start': 4.84, 'text': 'that.'}, {'confidence': 0.99975586, 'end': 5.68, 'speaker': 'A', 'start': 5.16, 'text': 'Asshole'}, {'confidence': 1.0, 'end': 5.92, 'speaker': 'A', 'start': 5.68, 'text': 'that'}, {'confidence': 0.63720703, 'end': 6.12, 'speaker': 'A', 'start': 5.92, 'text': 'you.'}, {'confidence': 1.0, 'end': 6.28, 'speaker': 'A', 'start': 6.12, 'text': 'You'}, {'confidence': 1.0, 'end': 6.4, 'speaker': 'A', 'start': 6.28, 'text': 'can'}, {'confidence': 0.99902344, 'end': 6.68, 'speaker': 'A', 'start': 6.4, 'text': 'make'}, {'confidence': 0.8339844, 'end': 7.56, 'speaker': 'A', 'start': 6.92, 'text': 'Siri'}, {'confidence': 0.99902344, 'end': 7.88, 'speaker': 'A', 'start': 7.56, 'text': 'say,'}, {'confidence': 0.9328613, 'end': 8.52, 'speaker': 'A', 'start': 8.04, 'text': 'oh,'}, {'confidence': 0.99970704, 'end': 9.4, 'speaker': 'A', 'start': 8.68, 'text': 'motherfucker,'}, {'confidence': 0.99970704, 'end': 9.4, 'speaker': 'A', 'start': 8.68, 'text': 'motherfucker,'}, {'confidence': 0.9984375, 'end': 10.01, 'speaker': 'A', 'start': 9.4, 'text': 'motherfucker.'}, {'confidence': 0.9984375, 'end': 10.01, 'speaker': 'A', 'start': 9.4, 'text': 'motherfucker.'}, {'confidence': 0.9949544, 'end': 10.28, 'speaker': 'A', 'start': 10.08, 'text': 'Yeah.'}, {'confidence': 0.99316406, 'end': 10.4, 'speaker': 'A', 'start': 10.28, 'text': 'You'}, {'confidence': 0.99609375, 'end': 10.52, 'speaker': 'A', 'start': 10.4, 'text': 'can'}, {'confidence': 0.99658203, 'end': 10.72, 'speaker': 'A', 'start': 10.52, 'text': 'make'}, {'confidence': 0.99658203, 'end': 10.72, 'speaker': 'A', 'start': 10.52, 'text': 'make'}, {'confidence': 0.85546875, 'end': 11.08, 'speaker': 'A', 'start': 10.72, 'text': 'Siri'}, {'confidence': 0.9628906, 'end': 11.28, 'speaker': 'A', 'start': 11.08, 'text' ...

# %% [markdown]
# ### Find Curse Words
# We'll use few NLP techniques to identify all variations of any offensive words, eliminating the need to manually find and include each form. Additionally, by analyzing the transcript, you can gain insights into how these sounds are transcribed, acknowledging the possibility of errors.

# %%
#install spacy
# !pip -q install spacy

#install dataset english core
# !python -m spacy download en_core_web_sm

# load the english corpus
import spacy
import re
nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 60.7 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
def get_root_word(word):
    """
    This function convert each word into its root word
    """
    try:
        #clean punctuations
        cleaned_word = re.sub(r'[^\w\s]', '', word)

        # Process the sentence
        doc = nlp(cleaned_word)

        # Lemmatize the word
        lemmatized_word = [token.lemma_ for token in doc][0]  # Assuming single word input

        return lemmatized_word.lower()
    except Exception as e:
        print(f"some issue with lemma for the word {word}")
        return word.lower()

# %% [markdown]
# ### Filter words and Create Fresh Timeline
#
# First we will identify the timestamps to beep, and then let's create a timeline using the `Track` and `Clip` pattern. Add the video clip to the main track, then loop through the transcript to add beep overlays wherever curse words are detected.

# %%
# 1. Filter and prepare curse metadata
padding = 0.15
curse_intervals = [
    {
        'word': w.get('text'),
        'start': max(0.0, float(w['start']) - padding),
        'end': min(float(video.length), float(w['end']) + padding),
        'raw_start': float(w['start']),
        'raw_end': float(w['end'])
    }
    for w in transcript
    if w.get('text') != '-' and get_root_word(w.get('text')) in curse_words_list
]

# 2. Building the Timeline

from videodb.editor import Timeline, Track, VideoAsset, AudioAsset, Clip

timeline = Timeline(conn)
video_track = Track()
beep_track = Track()
current_time = 0.0

print(f"{'WORD':<15} | {'START':<8} | {'END':<8} | {'DURATION'}")
print("-" * 50)

for interval in curse_intervals:
    # A. Clean segment
    if interval['start'] > current_time:
        clean_dur = interval['start'] - current_time
        video_track.add_clip(current_time, Clip(asset=VideoAsset(id=video.id, start=current_time), duration=clean_dur))

    # B. Muted segment
    mute_dur = interval['end'] - interval['start']
    video_track.add_clip(interval['start'], Clip(asset=VideoAsset(id=video.id, start=interval['start'], volume=0.0), duration=mute_dur))

    # C. Beep overlay
    beep_dur = interval['raw_end'] - interval['raw_start']
    beep_track.add_clip(interval['raw_start'], Clip(asset=AudioAsset(id=beep.id, start=0, volume=2.0), duration=min(beep_dur, float(beep.length))))

    # D. Professional Print Message
    print(f"{interval['word']:<15} | {interval['raw_start']:<8.2f} | {interval['raw_end']:<8.2f} | {beep_dur:.2f}s")

    current_time = interval['end']

# E. Final clean segment
if current_time < float(video.length):
    video_track.add_clip(current_time, Clip(asset=VideoAsset(id=video.id, start=current_time), duration=float(video.length) - current_time))

timeline.add_track(video_track)
timeline.add_track(beep_track)

stream_url = timeline.generate_stream()
print(f"\nProcessing complete. Stream URL: {stream_url}")
# Out:
# WORD            | START    | END      | DURATION
# --------------------------------------------------
# asshole         | 3.96     | 4.40     | 0.44s
# Asshole         | 5.16     | 5.68     | 0.52s
# motherfucker,   | 8.68     | 9.40     | 0.72s
# motherfucker,   | 8.68     | 9.40     | 0.72s
# motherfucker.   | 9.40     | 10.01    | 0.61s
# motherfucker.   | 9.40     | 10.01    | 0.61s
# motherfucker.   | 11.28    | 12.00    | 0.72s
# mother?         | 34.60    | 34.96    | 0.36s
# shit.           | 36.72    | 37.16    | 0.44s
# mother?         | 44.68    | 45.01    | 0.33s
# bitch.          | 66.80    | 67.16    | 0.36s
# motherfucker.   | 82.88    | 83.60    | 0.72s
# motherfucker.   | 105.44   | 106.36   | 0.92s
# motherfucker,   | 111.72   | 112.48   | 0.76s
# mother          | 113.60   | 113.88   | 0.28s
# mother.         | 119.84   | 120.01   | 0.17s
# mother          | 138.96   | 139.24   | 0.28s
# shit            | 157.04   | 157.28   | 0.24s
# mother          | 195.76   | 196.12   | 0.36s
# motherfucker.   | 204.32   | 205.01   | 0.69s
# Motherfucker    | 225.16   | 225.68   | 0.52s
#
# Processing complete. Stream URL: https://d1zudc7ewmc6ey.cloudfront.net/v1/f9849060-314c-465c-be53-cf5eddf9b9b0.m3u8

# %% [markdown]
# ### Review and Share Your Moderated Video
# Finally, watch and share your new stream:

# %%
# Play the final moderated stream

from videodb import play_stream
play_stream(stream_url)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/f9849060-314c-465c-be53-cf5eddf9b9b0.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### The Real Power of Programmable Streams
# If you have videos pre-uploaded and indexed, running this beep pipeline is in real-time. So, based on your users' choices or your platform's policy, you can use information from spoken content to automatically moderate.
