# %% [markdown]
# ## Beep Curse Words
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/examples/Beep%20Curse%20Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# VideoDB's Editor SDK makes it easy to personalize content to meet users' requirements. If users prefer not to include curse words in their content, VideoDB allows for these words to be either removed or replaced with a sound overlay such as beep sound.
#
# This task, typically complex for video editors, can be accomplished with just **a few lines of code** using VideoDB.
#
# This technique can also serve as a valuable **Content Moderation** component for any social content platform, ensuring that content meets the preferences and standards of its audience.
#
# Let's dive in!

# %%
# !pip install -q videodb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 kB 3.3 MB/s eta 0:00:00

# %% [markdown]
# ### Prerequisites
# Run the install cell above and have a VideoDB API key, which you can obtain from the VideoDB console.

# %%
# create a new connection with your API key
import videodb
import os
from getpass import getpass

# Prompt user for API key securely
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key

from videodb import connect, play_stream
conn = connect()
coll = conn.get_collection()
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ### Source Content
#
# For this tutorial, let's take the Joe Rogan clip, where he is trying to trick siri into using curse words 🤣

# %%
# Joe rogan video clip
video = coll.upload(url='https://www.youtube.com/watch?v=7MV6tUCUd-c')
print("Video uploaded:", video.id)

# If video already uploaded, get it using the id
# video = coll.get_video("video_id")
# Out:
# Video uploaded: m-z-019f90db-a5bc-7712-9cb4-9c4907d3a02f

# %%
#watch the original video
video.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/f2784d88-5b7b-4636-a532-900f2c5625ec.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Create a timed transcript artifact
transcript_understanding = video.understand(
    analyzers=[
        {
            "type": "spoken_words",
            "name": "transcript",
        },
    ],
)
transcript_understanding.wait_until_complete()

transcript_analyzer = transcript_understanding.get_analyzer("transcript")

# %% [markdown]
# ### Create `beep` Asset
#
# We have a sample beep sound in this folder, `beep.wav`. For those looking to add a more playful or unique touch, replacing the beep with alternative sound effects, such as a quack or any other sound, can make the content more engaging and fun.

# %%
# upload beep sound - This is just a sample, you can replace it with quack or any other sound effect.
beep_audio = conn.upload(url="https://raw.githubusercontent.com/Nischay-VideoDB/my-assets/main/cookbook/beep.wav")
print(beep_audio.id)

# If audio already uploaded, get it using the id
# beep = coll.get_audio("audio_id")
# Out:
# a-z-019f90dd-7029-7292-af40-7f92d440d600

# %%
# Import Editor SDK components
from videodb.editor import VideoAsset, AudioAsset, Timeline, Track, Clip

# %%
# Create audio asset from beep sound
beep_asset = AudioAsset(id=beep_audio.id)

# %% [markdown]
# ### Moderation Policy
# Define the terms that should be censored. The transcript artifact provides timed word records, so the detector checks each word while keeping its original timestamps.

# %%
transcript_output = transcript_analyzer.get_output()

spoken_text = " ".join(
    word["text"]
    for scene in transcript_output["scenes"]
    for word in scene.get("data", {}).get("words", [])
    if word.get("text")
)

moderation_response = coll.generate_text(
    prompt=f"""
Review the spoken transcript below and identify words that should be censored
with a beep because they contain profanity, abusive language, or explicit insults.

Return lowercase base forms so variations such as "fucking" can match "fuck".
Only include terms that occur in this transcript.

Return this JSON structure:
{{
    "curse_words": ["word", "another_word"]
}}

Transcript:
{spoken_text}
""",
    model_name="pro",
    response_type="json",
)

curse_words_list = [
    word.lower()
    for word in moderation_response["output"]["curse_words"]
]

print("Words selected for censoring:", curse_words_list)
# Out:
# Words selected for censoring: ['asshole', 'motherfucker', 'shit', 'bitch', 'crazy']

# %%
from math import isfinite

transcript = []

for scene in transcript_output.get("scenes", []):
    for word in scene.get("data", {}).get("words", []):
        text = word.get("text")
        start = word.get("start")
        end = word.get("end")

        if (
            isinstance(text, str)
            and text.strip()
            and text != "-"
            and isinstance(start, (int, float))
            and not isinstance(start, bool)
            and isinstance(end, (int, float))
            and not isinstance(end, bool)
            and isfinite(start)
            and isfinite(end)
            and end > start
        ):
            transcript.append(
                {
                    "text": text,
                    "start": start,
                    "end": end,
                }
            )

transcript.sort(key=lambda entry: (entry["start"], entry["end"]))

print("Transcript:")
print(" ".join(entry["text"] for entry in transcript))
print(f"\nFound {len(transcript)} timed transcript words.")
# Out:
# Transcript:
# Do you have a lot of home like Siri and Alexa's at your house? No, I don't trust those. That That asshole thing? Or is that asshole that you. You can make Siri say, oh, motherfucker. motherfucker. Motherfucker. Motherfucker. Yeah. You can make make Siri say motherfucker. Yeah. People think I was joking about that. Let me show you how to do that. Watch this, folks. Here we go. What is the definition? Taco Taco bell. That's a mistake. What's the definition of mother? Come on, you piece of shit. There's no need for that late change. Sorry. I'm sorry about that. What's What's the definition of mother? As a noun, it means a woman in relation to child or children to whom she has given birth. Do you want to hear the next one? Yes, as a verb, it means bring up a child with care and affection. Do you want to hear the last one? Yes, as a verb, it means give birth to. Oh, my God, Sir. You bitch. You took it from me. Yeah, Yeah, they. They. They removed removed it. You know it. it. Apple. Apple. Come on. It was funny. How did they leave it in there and then take it out? Did they take take out the dead body one? Remember the first one? That's That's a crazy one. Short for motherfucker. Yeah, it would say as a. You know. Yeah, I bet Alexis Alexis still still has it. I think I tweeted what it said. What exactly it said? Yeah, I did it. I did it the day you did it. It took me a couple of tries because I didn't say it right, but it ended up doing. Says as a noun, short for motherfucker. But it could be a verb as well, right? Yeah. If you're actually a motherfucker, ask sir with with mother means, and it gives you the correct definition. Then it asks you, do you want to hear the next one? If you say yes, it says, as a noun, it means short for motherfucker. Yeah, I got it. Right. Right. But it was weird to hear. Like, I heard it, and I was like, what? That's real? Like, imagine if that's, like, your mom and she's, like, teaching a little kid how to use Siri, like, mommy. How do I know what mommy is? Well, we can ask Siri, sweetie. We can ask Siri what mother means. Okay. Okay, let's do it. Do you want to hear the next one? Okay. As a noun, short for motherfucker. The little kids like, what, Mommy? What did they say? What does Siri say if you ask if Santa's real or some shit like that? Ooh, good question. Oh, is Santa real? I'm going to pretend you didn't ask that. I don't want you to get a lump of coal this year. Alexa tells you and and uses shares a needle. Siri, are you allowed to swear? I don't have the answer to that. Is there something else I can help you with? I just want to know if you stopped using curse words recently. I'm not sure I understand. Well, earlier in this week I had asked you what mother means and you gave me one definition. Then you said, do you want to hear the next one? And you said as a noun, it means short for motherfucker. I just thought that was weird. That's not nice. She doesn't care. Siri, you sound like a crazy person. Like I'm trying to talk to you about this issue that you and I are having about communication. And what do you say to me? You say that's not nice? Well, it's not nice for you to say motherfucker in front of that little three year old just learning how to talk. But. But wow. This is the future. Here's some of the stuff I was telling you about. This is the future. We're going to be having arguments arguments with our digital devices. Like that that's a crude helper. Like it's super crude helper, right? Like what Siri could do and not do. It's very crude. But this is just like the iPhone one, right? Maybe they're absolutely going to have some sort of AI that can keep up with the conversation. For sure that's going to happen.
#
# Found 729 timed transcript words.

# %% [markdown]
# ### Find Timed Words to Censor
# Use lemmatization to check each timed transcript word against the moderation policy. Matching words keep their server-provided start and end times for editing.

# %%
#install spacy
# !pip -q install spacy

#install dataset english core
# !python -m spacy download en_core_web_sm

# load the english corpus
import spacy
import re
nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 103.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
def contains_curse_word(text):
    """
    Return True when a timed transcript word matches the moderation list.
    """
    cleaned_text = re.sub(r"[^\w\s]", " ", text)
    doc = nlp(cleaned_text)

    return any(
        token.lemma_.lower() in curse_words_list
        for token in doc
        if token.text.strip()
    )

# %% [markdown]
# ### Filter Timed Words and Create Fresh Timeline
#
# Identify the artifact-provided word ranges that match policy terms, then use the Track and Clip pattern to mute those ranges and place beep overlays at the same original timings.

# %%
# 1. Filter timed transcript words and prepare moderation metadata
padding = 0.15
curse_intervals = [
    {
        'word': w.get('text'),
        'start': max(0.0, float(w['start']) - padding),
        'end': min(float(video.length), float(w['end']) + padding),
        'raw_start': float(w['start']),
        'raw_end': float(w['end'])
    }
    for w in transcript
    if contains_curse_word(w.get('text', ''))
]

# 2. Building the Timeline

from videodb.editor import Timeline, Track, VideoAsset, AudioAsset, Clip

timeline = Timeline(conn)
video_track = Track()
beep_track = Track()
current_time = 0.0

print(f"{'WORD':<30} | {'START':<8} | {'END':<8} | {'DURATION'}")
print("-" * 65)

for interval in curse_intervals:
    # A. Clean segment
    if interval['start'] > current_time:
        clean_dur = interval['start'] - current_time
        video_track.add_clip(current_time, Clip(asset=VideoAsset(id=video.id, start=current_time), duration=clean_dur))

    # B. Muted segment
    mute_dur = interval['end'] - interval['start']
    video_track.add_clip(interval['start'], Clip(asset=VideoAsset(id=video.id, start=interval['start'], volume=0.0), duration=mute_dur))

    # C. Beep overlay
    beep_dur = interval['raw_end'] - interval['raw_start']
    beep_track.add_clip(interval['raw_start'], Clip(asset=AudioAsset(id=beep_audio.id, start=0, volume=2.0), duration=min(beep_dur, float(beep_audio.length))))

    # D. Professional Print Message
    print(f"{interval['word']:<30} | {interval['raw_start']:<8.2f} | {interval['raw_end']:<8.2f} | {beep_dur:.2f}s")

    current_time = interval['end']

# E. Final clean segment
if current_time < float(video.length):
    video_track.add_clip(current_time, Clip(asset=VideoAsset(id=video.id, start=current_time), duration=float(video.length) - current_time))

timeline.add_track(video_track)
timeline.add_track(beep_track)

stream_url = timeline.generate_stream()
print(f"\nProcessing complete. Stream URL: {stream_url}")
# Out:
# WORD                           | START    | END      | DURATION
# -----------------------------------------------------------------
# asshole                        | 3.96     | 4.40     | 0.44s
# asshole                        | 5.08     | 5.64     | 0.56s
# motherfucker.                  | 8.72     | 9.44     | 0.72s
# motherfucker.                  | 8.72     | 9.44     | 0.72s
# Motherfucker.                  | 9.44     | 10.08    | 0.64s
# Motherfucker.                  | 9.44     | 10.08    | 0.64s
# motherfucker.                  | 11.28    | 12.00    | 0.72s
# shit.                          | 36.73    | 37.13    | 0.40s
# bitch.                         | 66.77    | 67.13    | 0.36s
# crazy                          | 81.73    | 82.09    | 0.36s
# motherfucker.                  | 82.93    | 83.61    | 0.68s
# motherfucker.                  | 105.41   | 106.29   | 0.88s
# motherfucker,                  | 111.71   | 112.47   | 0.76s
# motherfucker.                  | 119.91   | 120.59   | 0.68s
# motherfucker.                  | 149.50   | 150.42   | 0.92s
# shit                           | 157.10   | 157.30   | 0.20s
# motherfucker.                  | 204.38   | 205.18   | 0.80s
# crazy                          | 215.43   | 215.87   | 0.44s
# motherfucker                   | 225.03   | 225.67   | 0.64s
#
# Processing complete. Stream URL: https://play.videodb.io/v1/0d990ad5-d731-4136-ad10-e5c977cbdc13.m3u8

# %% [markdown]
# ### Review and Share Your Moderated Video
# Finally, watch and share your new stream:

# %%
# Play the final moderated stream

from videodb import play_stream
play_stream(stream_url)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/0d990ad5-d731-4136-ad10-e5c977cbdc13.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### The Real Power of Programmable Streams
# Once a video's transcript artifact is available, this moderation pipeline can be applied on demand. Your platform policy determines which terms trigger censorship, while artifact timestamps keep every edit aligned with the spoken content.
