# %% [markdown]
# # 🎥 Multimodal Quickstart
#
# <a href="https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/quickstart/Multimodal_Quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
#
# Let’s first look at the example query that we want to unlock in our video library.
#
# > 📸🗣️ __Show me where the narrator discusses the formation of the solar system and visualize the milky way galaxy__
#
# Implementing this multimodal search query involves following steps with VideoDB:
#
# 1. 🎬 **Upload, Understand, and Index the Video**:
#      - Upload the video and create transcript and visual-description artifacts in one understanding run.
#      - Analyze visual content in two-second segments using two uniformly distributed frames, then create one semantic index for each modality.
# 2. 🧩 **Query Transformation**: Divide the query into spoken and visual parts for their respective indexes.
# 3. 🔎 **Perform Semantic Searches**: Search each semantic index with its matching transformed query.
# 4. 🔀 **Combine Search Results of Both Modalities**: Integrate results from both indexes for precise video segment identification.
# 5. **Stream the Footage**: Generate and play a video stream from the combined segments.

# %% [markdown]
# ## Setup
# ---

# %% [markdown]
# ### 📦  Installing packages

# %%
# !pip install -q videodb

# %% [markdown]
# ### 🔑 API keys
# Before proceeding, ensure access to [VideoDB](https://videodb.io). If not, sign up for API access.
#
# > Get your API key from [VideoDB Console](https://console.videodb.io). ( Free for first 50 uploads, **No credit card required** ) 🎉

# %%
import videodb
import os
from getpass import getpass

# Get VideoDB API Key
api_key = getpass("Please enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key
# Out:
# Please enter your VideoDB API Key: ··········

# %% [markdown]
# ## Building Multimodal Search
#
# ---

# %% [markdown]
# ### 📋 Step 1: Connect to VideoDB
#
# Gear up by establishing a connection to VideoDB

# %%
from videodb import connect
from videodb import play_stream

# Connect to VideoDB using your API key
conn = connect()
coll = conn.get_collection()

# %% [markdown]
# ### 🎬 Step 2: Upload the Video

# %%
video = coll.upload(url="https://www.youtube.com/watch?v=libKVRa01L8")

print(f"Video ID : {video.id}")
print(f"Title    : {video.name}")
print(f"Duration : {video.length:.0f}s ({video.length/60:.1f} min)")
# Out:
# Video ID : m-z-019f8f56-106b-7232-9133-151dd61eff91
# Title    : Solar System 101 | National Geographic
# Duration : 250s (4.2 min)

# %%
video.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/9f66e51d-ccc8-47af-be05-1c61796bc486.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 📸🗣️ Step 3: Understand and Index Each Modality

# %% [markdown]
# #### 🗣️ Understand and Index Spoken Content
#
# Create a timed transcript artifact, then build a semantic index from its text before searching.

# %%
print("Analyzing spoken content... this might take some time.")

transcript_understanding = video.understand(
    analyzers=[
        {
            "type": "spoken_words",
            "name": "transcript",
        },
    ],
)
transcript_understanding.wait_until_complete()

transcript_analyzer = transcript_understanding.get_analyzer("transcript")
# Out:
# Analyzing spoken content... this might take some time.

# %% [markdown]
# #### Index Spoken Content
#
# Create the semantic transcript index before searching it.

# %%
transcript_index = video.index(
    name="transcript",
    source=transcript_analyzer,
    use_for=["semantic"],
    fields={"semantic": ["text"]},
)

transcript_index.wait_until_complete()

print("✅ Transcript index is ready!")
# Out:
# ✅ Transcript index is ready!

# %% [markdown]
# #### 📸️ Understand and Index Visual Content
#
# Create a separate visual-description artifact from two-second segments using two uniformly distributed frames, then build its semantic index.

# %%
print("Analyzing visual content... this might take some time.")

scene_understanding = video.understand(
    segmentation={"type": "time", "seconds": 2},
    analyzers=[
        {
            "type": "vlm",
            "name": "scene",
            "sampling": {
                "strategy": "uniform",
                "frame_count": 2,
            },
            "config": {
                "prompt": "Describe the scene in detail",
                "schema": {
                    "description": "string",
                },
            },
        },
    ],
)
scene_understanding.wait_until_complete()

scene_analyzer = scene_understanding.get_analyzer("scene")
# Out:
# Analyzing visual content... this might take some time.

# %% [markdown]
# #### Index Visual Content
#
# Create the semantic scene index before searching it.

# %%
scene_index = video.index(
    name="scene",
    source=scene_analyzer,
    use_for=["semantic"],
    fields={"semantic": ["description"]},
)

scene_index.wait_until_complete()

print("✅ Scene index is ready!")
# Out:
# ✅ Scene index is ready!

# %% [markdown]
# ### 🧩 Step 4: Query Transformation

# %%
transformation_prompt = """
Split the following multimodal video query into one query for spoken content and one query for visual content.
Return JSON with exactly these fields:
{{"spoken_query": "string", "visual_query": "string"}}

Query: {query}
"""

def divide_query(query):
    response = coll.generate_text(
        prompt=transformation_prompt.format(query=query),
        model_name="pro",
        response_type="json",
    )

    divided_query = response["output"]
    return divided_query["spoken_query"], divided_query["visual_query"]


# Test the query
query = "Show me where the narrator discusses the formation of the solar system and visualize the milky way galaxy"

spoken_query, visual_query = divide_query(query)
print(f"Spoken Query: {spoken_query}")
print(f"Visual Query: {visual_query}")
# Out:
# Spoken Query: Sections where the narrator explains the formation of the solar system, using phrases like "formation of the solar system", "nebular hypothesis", "protoplanetary disk", "accretion", "planet formation", or "early solar nebula".
# Visual Query: Visuals showing the Milky Way galaxy: images or animations of the Milky Way/spiral galaxy (top-down or edge-on), the galactic center, star fields, galaxy rotation, or labeled Milky Way maps.

# %% [markdown]
# ### 🔍 Step 5: Perform Semantic Searches
# Now that we have our divided queries, search the transcript and visual semantic indexes independently:

# %% [markdown]
# 🗣️ **Search the Transcript Index**

# %%
# Perform semantic search using the spoken query
spoken_results = video.semantic_search(
    query=spoken_query,
    index_names=[transcript_index.name],
    top_k=10,
)

# View the results
spoken_results.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://stream.videodb.io/v3/published/manifests/363ab0bf-ff5b-4c50-bc93-21ab7631dc0c.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# 📸️ **Search the Visual Index**

# %%
# Perform semantic search using the visual query
scene_results = video.semantic_search(
    query=visual_query,
    index_names=[scene_index.name],
    top_k=10,
    score_threshold=0.1,
)

# View the results
scene_results.play()
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://stream.videodb.io/v3/published/manifests/743caac0-4972-4552-bddf-ef336e0987f3.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 🔀 Step 6: Combining Spoken & Scene Search results

# %% [markdown]
# Each search result provides a list of timestamps that are relevant to the query in the relevant modality (semantic & scene/ visual, in this case).
#
# There are two ways to combine these search results:
#
# - **Union**: This method takes all the timestamps from every search result, creating a comprehensive list that includes every relevant time, even if some timestamps appear in only one result.
#
# <img src="https://raw.githubusercontent.com/video-db/videodb-cookbook-assets/main/images/guides/multimodal_quickstart_union.png" alt="Example Image" width="500"/>
#
# - **Intersection**: This method only includes timestamps that appear in all the search results, resulting in a smaller list with times that are universally relevant across all results.
#
# <img src="https://raw.githubusercontent.com/video-db/videodb-cookbook-assets/main/images/guides/multimodal_quickstart_intersection.png" alt="Example Image" width="500"/>
#
#
# Depending on which method you prefer, you can pass the appropriate argument to the `combine_results()` function below.

# %%
# Define a Function to Find Intersections
def process_shots(l1, l2, operation):
    def merge_intervals(intervals):
        if not intervals:
            return []
        intervals.sort(key=lambda x: x[0])
        merged = [intervals[0]]
        for interval in intervals[1:]:
            if interval[0] <= merged[-1][1]:
                merged[-1][1] = max(merged[-1][1], interval[1])
            else:
                merged.append(interval)
        return merged

    def intersection(intervals1, intervals2):
        i, j = 0, 0
        result = []
        while i < len(intervals1) and j < len(intervals2):
            low = max(intervals1[i][0], intervals2[j][0])
            high = min(intervals1[i][1], intervals2[j][1])
            if low < high:
                result.append([low, high])
            if intervals1[i][1] < intervals2[j][1]:
                i += 1
            else:
                j += 1
        return result

    if operation.lower() == "intersection":
        return intersection(merge_intervals(l1), merge_intervals(l2))
    elif operation.lower() == "union":
        return merge_intervals(l1 + l2)
    else:
        raise ValueError("Invalid operation. Please choose 'intersection' or 'union'.")


def combine_results(spoken_results, scene_results, operation):
    spoken_timestamps = [[shot.start, shot.end] for shot in spoken_results.get_shots()]
    scene_timestamps = [[shot.start, shot.end] for shot in scene_results.get_shots()]
    result = process_shots(spoken_timestamps, scene_timestamps, operation)
    print("Spoken results: ", spoken_timestamps)
    print("Scene results: ", scene_timestamps)
    print("Combined results: ", result)
    return result


# Combine results
results = combine_results(spoken_results, scene_results, "intersection")
# Out:
# Spoken results:  [[0.0, 64.131], [24.124, 39.406], [39.406, 64.131], [88.322, 95.562], [107.741, 139.84], [159.292, 163.296], [177.31, 237.337], [192.059, 199.666], [199.666, 220.754], [220.754, 237.337]]
# Scene results:  [[6.0, 8.0], [10.0, 12.0], [24.0, 40.0], [26.0, 28.0], [28.0, 30.0], [30.0, 32.0], [32.0, 34.0], [34.0, 36.0], [36.0, 38.0], [38.0, 40.0]]
# Combined results:  [[6.0, 8.0], [10.0, 12.0], [24.0, 40.0]]

# %% [markdown]
# ### 🪄 Step7 : View Combined Results

# %% [markdown]
# Finally, let's generate a stream of the intersecting segments and play it:

# %%
from videodb import play_stream
print(f"Multimodal Query: {query}")
stream_link = video.generate_stream(results)
play_stream(stream_link)
# Out:
# Multimodal Query: Show me where the narrator discusses the formation of the solar system and visualize the milky way galaxy
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/bbcc95f5-67fb-4beb-830a-6f834cb34b35.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Further Steps
# ---

# %% [markdown]
# In this guide, we've demonstrated how to perform multimodal search on educational videos using VideoDB.
#
# If you have any questions or feedback. Feel free to reach out to us 🙌🏼
#
# * [Discord](https://colab.research.google.com/corgiredirector?site=https%3A%2F%2Fdiscord.gg%2Fpy9P639jGz)
# * [GitHub](https://github.com/video-db)
# * [Email](ashu@videodb.io)
