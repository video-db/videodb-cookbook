# %% [markdown]
# # Multimodal Quickstart
#
# This notebook shows how to search a video using both spoken narration and visual scene understanding.
#
# We will use VideoDB to:
#
# - Upload an educational video about the solar system.
# - Transcribe narration with `understand(spoken_words)`.
# - Describe visual moments with `understand(vlm)`.
# - Build separate searchable indexes for spoken and visual records.
# - Search each modality with `semantic_search()`.
# - Intersect timestamps from both modalities and play the matching clips.

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q videodb python-dotenv

# %% [markdown]
# ## 2. Connect to VideoDB
#
# Enter your VideoDB API key when prompted.
#
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import json
import os
import time
from getpass import getpass
from uuid import uuid4

from IPython.display import display
from videodb import connect, play_stream

os.environ["VIDEO_DB_API_KEY"] = getpass("Please enter your VideoDB API Key: ")

conn = connect()
coll = conn.get_collection()

print("Connected to VideoDB successfully.")
# Out:
# Please enter your VideoDB API Key: ··········
# Connected to VideoDB successfully.

# %% [markdown]
# ## 3. Upload the Video
#
# We use a short National Geographic educational video about the solar system. You can replace this URL with your own video.

# %%
video = coll.upload(url="https://www.youtube.com/watch?v=libKVRa01L8")
print("Video ID:", video.id)

preview_stream = video.generate_stream()
display(play_stream(preview_stream))
# Out:
# Video ID: m-z-019f383f-9103-76d3-a313-4ddbb38f081b
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/6b3ad281-95f7-4c75-addc-9c40683a9610.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 4. Understand Spoken Narration
#
# The spoken-word analyzer returns a transcript artifact. We keep this artifact separate from indexing so you can inspect or transform it before retrieval.

# %%
spoken_understanding = video.understand(
    analyzers=[
        {
            "type": "spoken_words",
            "name": "transcript",
            "config": {
                "language": "en",
            },
        }
    ],
)

spoken_understanding.wait_until_complete(timeout=3600, poll_interval=15)
transcript_output = spoken_understanding.get_analyzer("transcript").get_output()

print("Transcript status:", transcript_output.get("status"))
print("Transcript scenes:", len(transcript_output.get("scenes", [])))
# Out:
# Transcript status: done
# Transcript scenes: 24

# %% [markdown]
# ## 5. Build Transcript Windows
#
# For semantic retrieval, medium-sized transcript windows usually work better than individual words. Each record keeps the start and end timestamps required for clip playback.

# %%
def flatten_transcript_words(transcript_output):
    words = []

    for scene in transcript_output.get("scenes", []):
        words.extend(scene.get("data", {}).get("words", []))

    seen = set()
    deduped = []

    for word in words:
        key = (word.get("start"), word.get("end"), word.get("text"))
        if key in seen:
            continue
        seen.add(key)
        deduped.append(word)

    return sorted(deduped, key=lambda word: float(word.get("start", 0)))


def build_transcript_windows(transcript_output, window_seconds=35):
    words = flatten_transcript_words(transcript_output)
    windows = []
    current_words = []
    current_start = None
    current_end = None

    for word in words:
        if word.get("start") is None or word.get("end") is None or not word.get("text"):
            continue

        word_start = float(word["start"])
        word_end = float(word["end"])

        if current_start is None:
            current_start = word_start

        if current_words and word_start - current_start >= window_seconds:
            windows.append(
                {
                    "start": current_start,
                    "end": current_end,
                    "text": " ".join(current_words).strip(),
                }
            )
            current_words = []
            current_start = word_start

        current_words.append(word["text"])
        current_end = word_end

    if current_words:
        windows.append(
            {
                "start": current_start,
                "end": current_end,
                "text": " ".join(current_words).strip(),
            }
        )

    return windows


transcript_windows = build_transcript_windows(transcript_output)
print("Transcript windows:", len(transcript_windows))
print(json.dumps(transcript_windows[:2], indent=2))
# Out:
# Transcript windows: 7
# [
#   {
#     "start": 2.56,
#     "end": 37.4,
#     "text": "Our solar system is one of over 500. Hundred known solar systems in the entire Milky Way galaxy. The solar system came into being about 4.5 billion years ago, when ECL. Cloud of interstellar gas and dust collapsed, resulting in a solar nebula, a. Swirling disk of material that collided to form the solar system. The solar system is located in the Milky Way's Orion star cluster. Only 15% of stars in the galaxy host planetary systems. And one of those stars is our own sun."
#   },
#   {
#     "start": 40.32,
#     "end": 75.01,
# ...

# %% [markdown]
# ## 6. Understand Visual Scenes
#
# The VLM analyzer describes what appears on screen. We use concise time-based records so visual search stays fast enough for a quickstart.

# %%
visual_prompt = (
    "Describe the visible scene in 1-2 concise sentences for visual search. "
    "Mention important space visuals, planets, galaxies, diagrams, labels, and actions."
)

visual_understanding = video.understand(
    segmentation={
        "type": "time",
        "seconds": 10,
    },
    analyzers=[
        {
            "type": "vlm",
            "name": "visual_scenes",
            "sampling": {
                "strategy": "uniform",
                "frame_count": 2,
            },
            "config": {
                "model": "pro",
                "prompt": visual_prompt,
                "schema": {
                    "scene_description": "string",
                    "primary_visual_topic": "string",
                },
            },
        }
    ],
)

visual_understanding.wait_until_complete(timeout=3600, poll_interval=15)
visual_output = visual_understanding.get_analyzer("visual_scenes").get_output()

print("Visual status:", visual_output.get("status"))
print("Visual scenes:", len(visual_output.get("scenes", [])))
# Out:
# Visual status: done
# Visual scenes: 26

# %% [markdown]
# ## 7. Build Visual Search Records
#
# We normalize the VLM artifact into custom temporal records with `start`, `end`, and `description`, then index every non-empty visual record returned by the analyzer.

# %%
def extract_visual_description(scene):
    data = scene.get("data", {}) or {}
    return (
        data.get("scene_description")
        or data.get("description")
        or data.get("text")
        or scene.get("description")
        or ""
    ).strip()


def build_visual_records(visual_output):
    records = []

    for scene in visual_output.get("scenes", []):
        description = extract_visual_description(scene)
        if not description:
            continue

        records.append(
            {
                "start": float(scene["start"]),
                "end": float(scene["end"]),
                "description": description,
            }
        )

    return records


visual_records = build_visual_records(visual_output)
print("Visual records indexed for this quickstart:", len(visual_records))
print(json.dumps(visual_records[:3], indent=2))
# Out:
# Visual records indexed for this quickstart: 26
# [
#   {
#     "start": 0.0,
#     "end": 10.0,
#     "description": "A star-filled Milky Way background with on-screen text labels reading \"OUR SOLAR SYSTEM\" and \"ONE OF OVER 500 IN THE MILKY WAY GALAXY,\" and a lower title banner displaying \"SCIENCE 101 | THE SOLAR SYSTEM.\""
#   },
#   {
#     "start": 10.0,
#     "end": 20.0,
#     "description": "Wide view of the Milky Way galaxy filling the starry night sky above the glowing limb of Earth, with a portion of the International Space Station structure visible at the top; a title overlay reads \"VIEW OF THE MILKY WAY FROM THE INTERNATIONAL SPACE STATION\" and a small credit label appears at the bottom. The scene is a stationary orbiting perspective showing stars, galactic core detail, and the ISS solar panel silhouette."
#   },
#   {
#     "start": 20.0,
#     "end": 30.0,
# ...

# %% [markdown]
# ## 8. Index Both Modalities
#
# `video.index()` turns the transcript windows and visual records into searchable indexes. Unique names make reruns safe.

# %%
SPOKEN_INDEX_NAME = f"multimodal_spoken_{uuid4().hex[:8]}"
VISUAL_INDEX_NAME = f"multimodal_visual_{uuid4().hex[:8]}"
INDEX_READY_STATUSES = {"ready", "done"}
INDEX_ACTIVE_STATUSES = {"building", "processing"}


def wait_until_index_ready(video, index, timeout=1800, poll_interval=10):
    deadline = time.time() + timeout
    latest_index = index

    while time.time() < deadline:
        status = getattr(latest_index, "status", None)

        if status in INDEX_READY_STATUSES:
            return latest_index

        if status and status not in INDEX_ACTIVE_STATUSES:
            raise RuntimeError(f"Index build ended with status: {status}")

        time.sleep(poll_interval)

        try:
            latest_index = video.get_index(index_id=index.index_id)
        except Exception as exc:
            if "not found" in str(exc).lower():
                continue
            raise

    raise TimeoutError(f"Index was not ready within {timeout} seconds.")


spoken_index = video.index(
    name=SPOKEN_INDEX_NAME,
    source=transcript_windows,
    use_for=["semantic"],
    fields={
        "semantic": ["text"],
        "text": ["text"],
    },
)

visual_index = video.index(
    name=VISUAL_INDEX_NAME,
    source=visual_records,
    use_for=["semantic"],
    fields={
        "semantic": ["description"],
        "text": ["description"],
    },
)

spoken_index = wait_until_index_ready(video, spoken_index)
visual_index = wait_until_index_ready(video, visual_index)

print("Spoken index:", SPOKEN_INDEX_NAME, spoken_index.index_id, spoken_index.status)
print("Visual index:", VISUAL_INDEX_NAME, visual_index.index_id, visual_index.status)
# Out:
# Spoken index: multimodal_spoken_8bbda504 fa426453a64d4ba5 ready
# Visual index: multimodal_visual_8bc09343 d04b0a85a4c24476 ready

# %% [markdown]
# ## 9. Split the Multimodal Query
#
# A multimodal prompt often contains a spoken intent and a visual intent. Here we keep the split explicit so the retrieval calls remain easy to inspect.

# %%
query = "Show me where the narrator discusses the formation of the solar system and visualize the milky way galaxy"

spoken_query = "narrator discusses the formation of the solar system"
visual_query = "Milky Way galaxy visuals, space, stars, and galaxy diagrams"

print("Multimodal query:", query)
print("Spoken query:", spoken_query)
print("Visual query:", visual_query)
# Out:
# Multimodal query: Show me where the narrator discusses the formation of the solar system and visualize the milky way galaxy
# Spoken query: narrator discusses the formation of the solar system
# Visual query: Milky Way galaxy visuals, space, stars, and galaxy diagrams

# %% [markdown]
# ## 10. Search Spoken and Visual Indexes
#
# Use `semantic_search()` for direct semantic retrieval over a specific index. The index names tell VideoDB exactly where to search.

# %%
spoken_results = video.semantic_search(
    query=spoken_query,
    index_names=[SPOKEN_INDEX_NAME],
    top_k=5,
    return_fields=["text"],
)

visual_results = video.semantic_search(
    query=visual_query,
    index_names=[VISUAL_INDEX_NAME],
    top_k=5,
    return_fields=["description"],
)

print("Top spoken matches:")
for shot in spoken_results.shots:
    metadata = getattr(shot, "metadata", {}) or {}
    print(f"{shot.start:.2f}s - {shot.end:.2f}s:", metadata.get("text", "")[:220])

print("\nTop visual matches:")
for shot in visual_results.shots:
    metadata = getattr(shot, "metadata", {}) or {}
    print(f"{shot.start:.2f}s - {shot.end:.2f}s:", metadata.get("description", "")[:220])
# Out:
# Top spoken matches:
# 2.56s - 37.40s:
# 216.88s - 231.52s:
# 181.88s - 216.88s:
# 146.52s - 181.88s:
# 110.44s - 145.01s:
#
# Top visual matches:
# 20.00s - 30.00s:
# 0.00s - 10.00s:
# 10.00s - 20.00s:
# 30.00s - 40.00s:
# 220.00s - 230.00s:

# %% [markdown]
# ## 11. Combine Timestamps
#
# The spoken and visual searches each return timestamped shots. Intersecting the two timelines finds moments where the narration and visuals are relevant at the same time.

# %%
def merge_intervals(intervals):
    if not intervals:
        return []

    sorted_intervals = sorted(intervals, key=lambda interval: interval[0])
    merged = [sorted_intervals[0]]

    for start, end in sorted_intervals[1:]:
        if start <= merged[-1][1]:
            merged[-1][1] = max(merged[-1][1], end)
        else:
            merged.append([start, end])

    return merged


def intersect_intervals(left, right):
    left = merge_intervals(left)
    right = merge_intervals(right)
    intersections = []
    i = 0
    j = 0

    while i < len(left) and j < len(right):
        start = max(left[i][0], right[j][0])
        end = min(left[i][1], right[j][1])

        if start < end:
            intersections.append([start, end])

        if left[i][1] < right[j][1]:
            i += 1
        else:
            j += 1

    return intersections


def shots_to_timeline(search_results):
    return [[float(shot.start), float(shot.end)] for shot in search_results.shots]


spoken_timeline = shots_to_timeline(spoken_results)
visual_timeline = shots_to_timeline(visual_results)
combined_timeline = intersect_intervals(spoken_timeline, visual_timeline)

if not combined_timeline:
    combined_timeline = merge_intervals(spoken_timeline + visual_timeline)

print("Spoken timeline:", spoken_timeline)
print("Visual timeline:", visual_timeline)
print("Combined timeline:", combined_timeline)
# Out:
# Spoken timeline: [[2.56, 37.4], [216.88, 231.52], [181.88, 216.88], [146.52, 181.88], [110.44, 145.01]]
# Visual timeline: [[20.0, 30.0], [0.0, 40.0], [10.0, 20.0], [30.0, 40.0], [220.0, 230.0]]
# Combined timeline: [[2.56, 37.4], [220.0, 230.0]]

# %% [markdown]
# ## 12. Play the Combined Results
#
# Generate a stream from the combined timestamps and display the VideoDB player.

# %%
if combined_timeline:
    stream_link = video.generate_stream(combined_timeline)
    player = play_stream(stream_link)
    display(player)
else:
    print("No matching multimodal moments found. Try a broader spoken or visual query.")
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/1cb8b449-be15-4569-b317-268d3c806b16.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Further Resources
#
# - [Understanding Artifacts](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/indexing-pipelines/understanding-artifacts)
# - [Create an Index](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/indexing-pipelines/create-an-index)
# - [Search and Retrieval](https://videodb-docs-indexing-search-v2.mintlify.app/pages/understand/search-and-retrieval/natural-language-query)
