# %% [markdown]
# # ♟️ Chess Move Montage: AI-Powered Highlight Reel
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/editor/creative/chess_montage.ipynb)
#
# ---
#
# Turn a long chess match into a **punchy highlight reel** — automatically!
#
# ## The Pipeline
#
# 1. **Upload** chess video + background music
# 2. **Analyze** eight-second scenes with structured binary move detection ("Player Moved" / "No Move")
# 3. **Extract timestamps** directly from scenes marked "Player Moved"
# 4. **Build timeline** — selected 5-second clips with transitions, filters, and music
#
# No manual editing. No frame-by-frame scrubbing. Just code → montage.

# %% [markdown]
# ---
#
# ## Step 1: Setup

# %%
# !pip install -q videodb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.5/86.5 kB 5.4 MB/s eta 0:00:00

# %% [markdown]
# ### Connect to VideoDB

# %%
import videodb
import os
from getpass import getpass

api_key = getpass("Enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key

conn = videodb.connect()
coll = conn.get_collection()
print("✓ Connected!")
# Out:
# Enter your VideoDB API Key: ··········
# ✓ Connected!

# %% [markdown]
# ---
#
# ## Step 2: Upload Assets
#
# We need two assets:
# - **Chess video** — the full match
# - **Background music** — energetic audio for the montage

# %%
from videodb import MediaType

# Upload chess video
chess_video = coll.upload(url="https://www.youtube.com/watch?v=dhDe-RcoyAU")
print(f"✓ Chess video uploaded: {chess_video.id}")

# chess_video = coll.get_video("your_video_id")
# Out:
# ✓ Chess video uploaded: m-z-019f8f76-a02f-7af2-a3c7-9937e16a1ab5

# %%
# Upload background music
bg_music = coll.upload(
    url="https://www.youtube.com/watch?v=S19UcWdOA-I",
    media_type=MediaType.audio
)
print(f"✓ Background music uploaded: {bg_music.id}")

# bg_music = coll.get_audio("your_audio_id")
# Out:
# ✓ Background music uploaded: a-z-019f8f76-fc1a-7442-8a0e-a0489a8c5857

# %% [markdown]
# ### Preview the chess video

# %%
from videodb import play_stream
play_stream(chess_video.generate_stream())
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/448b1ad9-a7b9-4cbe-a8a6-be0bcaa97db4.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---
#
# ## Step 3: Analyze Scenes with Structured Move Detection
#
# Analyze the video in eight-second segments with a **strict binary prompt**. Each scene returns `move_status` as exactly "Player Moved" when a chess move is evidenced across the sampled frames, or "No Move" otherwise.
#
# No complex move identification — just detecting WHEN a move happens.

# %%
print("Analyzing scenes for move detection...")

moves_understanding = chess_video.understand(
    segmentation={"type": "time", "seconds": 8},
    analyzers=[
        {
            "type": "vlm",
            "name": "move_detection",
            "sampling": {
                "strategy": "uniform",
                "frame_count": 5,
            },
            "config": {
                "prompt": """Look at this chess scene and focus on the chess board. Your task is to detect when pieces are moved.

Set move_status to exactly "Player Moved" only when a chess move is evidenced across the sampled frames. Otherwise, set move_status to exactly "No Move" (same position, paused, talking, etc.).

Be strict. Only set move_status to "Player Moved" if you clearly see a chess piece moved.""",
                "schema": {
                    "move_status": "string",
                },
            },
        },
    ],
)
moves_understanding.wait_until_complete()

moves_analyzer = moves_understanding.get_analyzer("move_detection")
# Out:
# Analyzing scenes for move detection...

# %% [markdown]
# ### View the structured move detections

# %%
import json
moves_output = moves_analyzer.get_output()
moves_scenes = moves_output.get("scenes", [])
print(json.dumps(moves_scenes, indent=2))
# Out:
# [
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 8.0,
#     "metadata": {},
#     "scene_id": "scene-0.000-8.000",
#     "start": 0.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 16.0,
#     "metadata": {},
#     "scene_id": "scene-8.000-16.000",
#     "start": 8.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 24.0,
#     "metadata": {},
#     "scene_id": "scene-16.000-24.000",
#     "start": 16.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 32.0,
#     "metadata": {},
#     "scene_id": "scene-24.000-32.000",
#     "start": 24.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 40.0,
#     "metadata": {},
#     "scene_id": "scene-32.000-40.000",
#     "start": 32.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 48.0,
#     "metadata": {},
#     "scene_id": "scene-40.000-48.000",
#     "start": 40.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 56.0,
#     "metadata": {},
#     "scene_id": "scene-48.000-56.000",
#     "start": 48.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 64.0,
#     "metadata": {},
#     "scene_id": "scene-56.000-64.000",
#     "start": 56.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 72.0,
#     "metadata": {},
#     "scene_id": "scene-64.000-72.000",
#     "start": 64.0
#   },
#   {
#     "data": {
#       "error": {
#         "code": "BadRequestError",
#         "message": "Error code: 400 - {'error': {'message': 'Your input image may contain content that is not allowed by our content safety system.', 'type': 'invalid_request_error', 'param': None, 'code': 'content_policy_violation'}}",
#         "retryable": true
#       }
#     },
#     "end": 80.0,
#     "metadata": {},
#     "scene_id": "scene-72.000-80.000",
#     "start": 72.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 88.0,
#     "metadata": {},
#     "scene_id": "scene-80.000-88.000",
#     "start": 80.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 96.0,
#     "metadata": {},
#     "scene_id": "scene-88.000-96.000",
#     "start": 88.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 104.0,
#     "metadata": {},
#     "scene_id": "scene-96.000-104.000",
#     "start": 96.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 112.0,
#     "metadata": {},
#     "scene_id": "scene-104.000-112.000",
#     "start": 104.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 120.0,
#     "metadata": {},
#     "scene_id": "scene-112.000-120.000",
#     "start": 112.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 128.0,
#     "metadata": {},
#     "scene_id": "scene-120.000-128.000",
#     "start": 120.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 136.0,
#     "metadata": {},
#     "scene_id": "scene-128.000-136.000",
#     "start": 128.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 144.0,
#     "metadata": {},
#     "scene_id": "scene-136.000-144.000",
#     "start": 136.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 152.0,
#     "metadata": {},
#     "scene_id": "scene-144.000-152.000",
#     "start": 144.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 160.0,
#     "metadata": {},
#     "scene_id": "scene-152.000-160.000",
#     "start": 152.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 168.0,
#     "metadata": {},
#     "scene_id": "scene-160.000-168.000",
#     "start": 160.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 176.0,
#     "metadata": {},
#     "scene_id": "scene-168.000-176.000",
#     "start": 168.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 184.0,
#     "metadata": {},
#     "scene_id": "scene-176.000-184.000",
#     "start": 176.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 192.0,
#     "metadata": {},
#     "scene_id": "scene-184.000-192.000",
#     "start": 184.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 200.0,
#     "metadata": {},
#     "scene_id": "scene-192.000-200.000",
#     "start": 192.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 208.0,
#     "metadata": {},
#     "scene_id": "scene-200.000-208.000",
#     "start": 200.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 216.0,
#     "metadata": {},
#     "scene_id": "scene-208.000-216.000",
#     "start": 208.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 224.0,
#     "metadata": {},
#     "scene_id": "scene-216.000-224.000",
#     "start": 216.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 232.0,
#     "metadata": {},
#     "scene_id": "scene-224.000-232.000",
#     "start": 224.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 240.0,
#     "metadata": {},
#     "scene_id": "scene-232.000-240.000",
#     "start": 232.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 248.0,
#     "metadata": {},
#     "scene_id": "scene-240.000-248.000",
#     "start": 240.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 256.0,
#     "metadata": {},
#     "scene_id": "scene-248.000-256.000",
#     "start": 248.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 264.0,
#     "metadata": {},
#     "scene_id": "scene-256.000-264.000",
#     "start": 256.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 272.0,
#     "metadata": {},
#     "scene_id": "scene-264.000-272.000",
#     "start": 264.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 280.0,
#     "metadata": {},
#     "scene_id": "scene-272.000-280.000",
#     "start": 272.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 288.0,
#     "metadata": {},
#     "scene_id": "scene-280.000-288.000",
#     "start": 280.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 296.0,
#     "metadata": {},
#     "scene_id": "scene-288.000-296.000",
#     "start": 288.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 304.0,
#     "metadata": {},
#     "scene_id": "scene-296.000-304.000",
#     "start": 296.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 312.0,
#     "metadata": {},
#     "scene_id": "scene-304.000-312.000",
#     "start": 304.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 320.0,
#     "metadata": {},
#     "scene_id": "scene-312.000-320.000",
#     "start": 312.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 328.0,
#     "metadata": {},
#     "scene_id": "scene-320.000-328.000",
#     "start": 320.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 336.0,
#     "metadata": {},
#     "scene_id": "scene-328.000-336.000",
#     "start": 328.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 344.0,
#     "metadata": {},
#     "scene_id": "scene-336.000-344.000",
#     "start": 336.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 352.0,
#     "metadata": {},
#     "scene_id": "scene-344.000-352.000",
#     "start": 344.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 360.0,
#     "metadata": {},
#     "scene_id": "scene-352.000-360.000",
#     "start": 352.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 368.0,
#     "metadata": {},
#     "scene_id": "scene-360.000-368.000",
#     "start": 360.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 376.0,
#     "metadata": {},
#     "scene_id": "scene-368.000-376.000",
#     "start": 368.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 384.0,
#     "metadata": {},
#     "scene_id": "scene-376.000-384.000",
#     "start": 376.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 392.0,
#     "metadata": {},
#     "scene_id": "scene-384.000-392.000",
#     "start": 384.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 400.0,
#     "metadata": {},
#     "scene_id": "scene-392.000-400.000",
#     "start": 392.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 408.0,
#     "metadata": {},
#     "scene_id": "scene-400.000-408.000",
#     "start": 400.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 416.0,
#     "metadata": {},
#     "scene_id": "scene-408.000-416.000",
#     "start": 408.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 424.0,
#     "metadata": {},
#     "scene_id": "scene-416.000-424.000",
#     "start": 416.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 432.0,
#     "metadata": {},
#     "scene_id": "scene-424.000-432.000",
#     "start": 424.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 440.0,
#     "metadata": {},
#     "scene_id": "scene-432.000-440.000",
#     "start": 432.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 448.0,
#     "metadata": {},
#     "scene_id": "scene-440.000-448.000",
#     "start": 440.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 456.0,
#     "metadata": {},
#     "scene_id": "scene-448.000-456.000",
#     "start": 448.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 464.0,
#     "metadata": {},
#     "scene_id": "scene-456.000-464.000",
#     "start": 456.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 472.0,
#     "metadata": {},
#     "scene_id": "scene-464.000-472.000",
#     "start": 464.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 480.0,
#     "metadata": {},
#     "scene_id": "scene-472.000-480.000",
#     "start": 472.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 488.0,
#     "metadata": {},
#     "scene_id": "scene-480.000-488.000",
#     "start": 480.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 496.0,
#     "metadata": {},
#     "scene_id": "scene-488.000-496.000",
#     "start": 488.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 504.0,
#     "metadata": {},
#     "scene_id": "scene-496.000-504.000",
#     "start": 496.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 512.0,
#     "metadata": {},
#     "scene_id": "scene-504.000-512.000",
#     "start": 504.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 520.0,
#     "metadata": {},
#     "scene_id": "scene-512.000-520.000",
#     "start": 512.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 528.0,
#     "metadata": {},
#     "scene_id": "scene-520.000-528.000",
#     "start": 520.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 536.0,
#     "metadata": {},
#     "scene_id": "scene-528.000-536.000",
#     "start": 528.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 544.0,
#     "metadata": {},
#     "scene_id": "scene-536.000-544.000",
#     "start": 536.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 552.0,
#     "metadata": {},
#     "scene_id": "scene-544.000-552.000",
#     "start": 544.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 560.0,
#     "metadata": {},
#     "scene_id": "scene-552.000-560.000",
#     "start": 552.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 568.0,
#     "metadata": {},
#     "scene_id": "scene-560.000-568.000",
#     "start": 560.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 576.0,
#     "metadata": {},
#     "scene_id": "scene-568.000-576.000",
#     "start": 568.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 584.0,
#     "metadata": {},
#     "scene_id": "scene-576.000-584.000",
#     "start": 576.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 592.0,
#     "metadata": {},
#     "scene_id": "scene-584.000-592.000",
#     "start": 584.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 600.0,
#     "metadata": {},
#     "scene_id": "scene-592.000-600.000",
#     "start": 592.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 608.0,
#     "metadata": {},
#     "scene_id": "scene-600.000-608.000",
#     "start": 600.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 616.0,
#     "metadata": {},
#     "scene_id": "scene-608.000-616.000",
#     "start": 608.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 624.0,
#     "metadata": {},
#     "scene_id": "scene-616.000-624.000",
#     "start": 616.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 632.0,
#     "metadata": {},
#     "scene_id": "scene-624.000-632.000",
#     "start": 624.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 640.0,
#     "metadata": {},
#     "scene_id": "scene-632.000-640.000",
#     "start": 632.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 648.0,
#     "metadata": {},
#     "scene_id": "scene-640.000-648.000",
#     "start": 640.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 656.0,
#     "metadata": {},
#     "scene_id": "scene-648.000-656.000",
#     "start": 648.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 664.0,
#     "metadata": {},
#     "scene_id": "scene-656.000-664.000",
#     "start": 656.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 672.0,
#     "metadata": {},
#     "scene_id": "scene-664.000-672.000",
#     "start": 664.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 680.0,
#     "metadata": {},
#     "scene_id": "scene-672.000-680.000",
#     "start": 672.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 688.0,
#     "metadata": {},
#     "scene_id": "scene-680.000-688.000",
#     "start": 680.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 696.0,
#     "metadata": {},
#     "scene_id": "scene-688.000-696.000",
#     "start": 688.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 704.0,
#     "metadata": {},
#     "scene_id": "scene-696.000-704.000",
#     "start": 696.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 712.0,
#     "metadata": {},
#     "scene_id": "scene-704.000-712.000",
#     "start": 704.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 720.0,
#     "metadata": {},
#     "scene_id": "scene-712.000-720.000",
#     "start": 712.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 728.0,
#     "metadata": {},
#     "scene_id": "scene-720.000-728.000",
#     "start": 720.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 736.0,
#     "metadata": {},
#     "scene_id": "scene-728.000-736.000",
#     "start": 728.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 744.0,
#     "metadata": {},
#     "scene_id": "scene-736.000-744.000",
#     "start": 736.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 752.0,
#     "metadata": {},
#     "scene_id": "scene-744.000-752.000",
#     "start": 744.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 760.0,
#     "metadata": {},
#     "scene_id": "scene-752.000-760.000",
#     "start": 752.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 768.0,
#     "metadata": {},
#     "scene_id": "scene-760.000-768.000",
#     "start": 760.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 776.0,
#     "metadata": {},
#     "scene_id": "scene-768.000-776.000",
#     "start": 768.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 784.0,
#     "metadata": {},
#     "scene_id": "scene-776.000-784.000",
#     "start": 776.0
#   },
#   {
#     "data": {
#       "error": {
#         "code": "BadRequestError",
#         "message": "Error code: 400 - {'error': {'message': 'Unable to download image from https://saunderstandingdev1trdn6.blob.core.windows.net/videodb-understanding/understandings/frame-cache/m-z-019f8f76-a02f-7af2-a3c7-9937e16a1ab5/t_9876750915fea165/frames/790667.jpg?se=2026-07-23T21%3A25%3A48Z&sp=r&sv=2026-06-06&sr=b&sig=REDACTED.', 'type': 'invalid_request_error', 'param': None, 'code': None}}",
#         "retryable": true
#       }
#     },
#     "end": 792.0,
#     "metadata": {},
#     "scene_id": "scene-784.000-792.000",
#     "start": 784.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 800.0,
#     "metadata": {},
#     "scene_id": "scene-792.000-800.000",
#     "start": 792.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 808.0,
#     "metadata": {},
#     "scene_id": "scene-800.000-808.000",
#     "start": 800.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 816.0,
#     "metadata": {},
#     "scene_id": "scene-808.000-816.000",
#     "start": 808.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 824.0,
#     "metadata": {},
#     "scene_id": "scene-816.000-824.000",
#     "start": 816.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 832.0,
#     "metadata": {},
#     "scene_id": "scene-824.000-832.000",
#     "start": 824.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 840.0,
#     "metadata": {},
#     "scene_id": "scene-832.000-840.000",
#     "start": 832.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 848.0,
#     "metadata": {},
#     "scene_id": "scene-840.000-848.000",
#     "start": 840.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 856.0,
#     "metadata": {},
#     "scene_id": "scene-848.000-856.000",
#     "start": 848.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 864.0,
#     "metadata": {},
#     "scene_id": "scene-856.000-864.000",
#     "start": 856.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 872.0,
#     "metadata": {},
#     "scene_id": "scene-864.000-872.000",
#     "start": 864.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 880.0,
#     "metadata": {},
#     "scene_id": "scene-872.000-880.000",
#     "start": 872.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 888.0,
#     "metadata": {},
#     "scene_id": "scene-880.000-888.000",
#     "start": 880.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 896.0,
#     "metadata": {},
#     "scene_id": "scene-888.000-896.000",
#     "start": 888.0
#   },
#   {
#     "data": {
#       "move_status": "Player Moved"
#     },
#     "end": 904.0,
#     "metadata": {},
#     "scene_id": "scene-896.000-904.000",
#     "start": 896.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 912.0,
#     "metadata": {},
#     "scene_id": "scene-904.000-912.000",
#     "start": 904.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 920.0,
#     "metadata": {},
#     "scene_id": "scene-912.000-920.000",
#     "start": 912.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 928.0,
#     "metadata": {},
#     "scene_id": "scene-920.000-928.000",
#     "start": 920.0
#   },
#   {
#     "data": {
#       "move_status": "No Move"
#     },
#     "end": 928.52,
#     "metadata": {},
#     "scene_id": "scene-928.000-928.520",
#     "start": 928.0
#   }
# ]

# %% [markdown]
# ---
#
# ## Step 4: Extract Move Timestamps
#
# Each structured scene carries a `move_status`. Select the `start` timestamp directly when `move_status` is "Player Moved", preserving artifact order.

# %%
timestamps = [
    scene["start"]
    for scene in moves_scenes
    if "move_status" in scene["data"] and scene["data"]["move_status"] == "Player Moved"
]

print("✓ Move timestamps extracted!")
# Out:
# ✓ Move timestamps extracted!

# %% [markdown]
# ### Review the timestamps

# %%
print(f"✓ Found {len(timestamps)} moves")
print(f"Timestamps: {timestamps}")
# Out:
# ✓ Found 71 moves
# Timestamps: [16.0, 32.0, 40.0, 48.0, 56.0, 64.0, 80.0, 96.0, 104.0, 120.0, 128.0, 136.0, 144.0, 168.0, 176.0, 184.0, 192.0, 208.0, 216.0, 224.0, 240.0, 248.0, 256.0, 264.0, 272.0, 280.0, 288.0, 296.0, 304.0, 320.0, 328.0, 336.0, 344.0, 368.0, 376.0, 400.0, 408.0, 424.0, 432.0, 440.0, 456.0, 464.0, 472.0, 488.0, 504.0, 512.0, 560.0, 568.0, 576.0, 600.0, 624.0, 632.0, 648.0, 656.0, 680.0, 696.0, 704.0, 712.0, 728.0, 744.0, 752.0, 760.0, 776.0, 800.0, 808.0, 816.0, 824.0, 832.0, 864.0, 888.0, 896.0]

# %% [markdown]
# ---
#
# ## Step 5: Build the Timeline
#
# Now we assemble the montage step-by-step:
# 1. Create timeline
# 2. Add selected 5-second video clips
# 3. Apply filters and transitions
# 4. Add background music

# %% [markdown]
# ### 5.1 Initialize Timeline with Intro Text

# %%
from videodb import play_stream
from videodb.editor import (
    Timeline, Track, Clip, VideoAsset, AudioAsset,
    Filter, Transition, TextAsset, Font, Background,
    Alignment, HorizontalAlignment, VerticalAlignment, TextAlignment,
    Position, Offset
)

timeline = Timeline(conn)
timeline.background = "#000000"

# Create intro text: "Let the Match Begin"
intro_text = TextAsset(
    text="Let the Match Begin",
    font=Font(family="Clear Sans", size=56, color="#FFFFFF"),
    background=Background(
        width=600,
        height=120,
        color="#000000",
        border_width=2.0,
        text_alignment=TextAlignment.center
    ),
    alignment=Alignment(
        horizontal=HorizontalAlignment.center,
        vertical=VerticalAlignment.center
    ),
)

intro_clip = Clip(
    asset=intro_text,
    duration=3,
    transition=Transition(in_="fade", out="fade", duration=0.5)
)

intro_track = Track()
intro_track.add_clip(0, intro_clip)
timeline.add_track(intro_track)

print("✓ Timeline initialized with 3-second intro")

# Preview the intro
stream_url = timeline.generate_stream()
print(f"Stream URL: {stream_url}")
play_stream(stream_url)
# Out:
# ✓ Timeline initialized with 3-second intro
# Stream URL: https://play.videodb.io/v1/76bab772-adeb-4497-a7cb-bb9a0fece18c.m3u8
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/76bab772-adeb-4497-a7cb-bb9a0fece18c.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 5.2 Add Video Clips
#
# Each selected move gets a **5-second clip** with:
# - **Contrast filter** — for a dramatic look
# - **Fade transitions** — smooth in/out between clips

# %%
CLIP_DURATION = 5  # seconds per clip
TARGET_CLIPS = 10  # approximately how many clips we want

# Sample timestamps evenly across the full list
total_detected = len(timestamps)
step = max(1, total_detected // TARGET_CLIPS)  # e.g., 69 // 10 = 6, so pick every 6th
sampled_timestamps = timestamps[::step][:TARGET_CLIPS]  # Take every Nth, limit to TARGET_CLIPS

print(f"Detected {total_detected} moves, sampling {len(sampled_timestamps)} clips (every {step}th)")
print(f"Sampled timestamps: {sampled_timestamps}")

video_track = Track()
timeline_position = 3

for i, start_time in enumerate(sampled_timestamps):
    clip = Clip(
        asset=VideoAsset(
            id=chess_video.id,
            start=max(0, start_time - 1),
            volume=0  # Muting the original audio
        ),
        duration=CLIP_DURATION,
        filter=Filter.contrast,
        transition=Transition(in_="fade", out="fade", duration=1)
    )

    video_track.add_clip(timeline_position, clip)
    timeline_position += CLIP_DURATION
    print(f"Clip {i+1}: source {start_time}s → timeline {timeline_position - CLIP_DURATION}s")

timeline.add_track(video_track)

total_duration = len(sampled_timestamps) * CLIP_DURATION + 3
print(f"\n✓ Added {len(sampled_timestamps)} clips to timeline")
print(f"✓ Total montage duration: {total_duration}s")

stream_url = timeline.generate_stream()
play_stream(stream_url)
# Out:
# Detected 71 moves, sampling 10 clips (every 7th)
# Sampled timestamps: [16.0, 96.0, 176.0, 248.0, 304.0, 400.0, 472.0, 600.0, 704.0, 800.0]
# Clip 1: source 16.0s → timeline 3s
# Clip 2: source 96.0s → timeline 8s
# Clip 3: source 176.0s → timeline 13s
# Clip 4: source 248.0s → timeline 18s
# Clip 5: source 304.0s → timeline 23s
# Clip 6: source 400.0s → timeline 28s
# Clip 7: source 472.0s → timeline 33s
# Clip 8: source 600.0s → timeline 38s
# Clip 9: source 704.0s → timeline 43s
# Clip 10: source 800.0s → timeline 48s
#
# ✓ Added 10 clips to timeline
# ✓ Total montage duration: 53s
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/27ebcb42-7d6d-4474-afcb-b701fe2cea91.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 5.3 Add Background Music

# %%
# Calculate total montage duration
music_duration = total_duration

# Add music track
music_clip = Clip(
    asset=AudioAsset(
        id=bg_music.id,
        start=0,
        volume=0.7
    ),
    duration=total_duration
)

audio_track = Track()
audio_track.add_clip(0, music_clip)
timeline.add_track(audio_track)

print(f"✓ Added {total_duration}s of background music")

stream_url = timeline.generate_stream()
play_stream(stream_url)
# Out:
# ✓ Added 53s of background music
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/86d281dc-2a55-46c4-82bb-d8a5af4a1561.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---
#
# ## 🎉 What We Built
#
# **Input:** Long chess match video + background music
#
# **Output:** Punchy highlight reel from up to ten selected moves
#
# ### The Pipeline
#
# | Step | What Happens |
# |------|--------------|
# | **Upload** | Chess video + music to VideoDB |
# | **Analyze** | Structured binary detection: "Player Moved" / "No Move" |
# | **Extract** | Select start timestamps directly from matching scenes |
# | **Build** | Up to ten selected 5-second clips + contrast filter + fade transitions + music |
# | **Generate** | Final montage stream |
#
# ### Key Techniques
#
# - **Structured prompting** — binary labels keep move detection focused
# - **Direct timestamp selection** — use artifact timestamps without extra parsing
# - **Even sampling** — select at most ten move scenes for a concise montage
# - **Filter + Transition** — instant polish with one-liners
