# %% [markdown]
# # Chess Move Montage: AI-Powered Highlight Reel
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/editor/creative/chess_montage.ipynb)
#
# Turn a long chess match into a punchy highlight reel automatically.
#
# This notebook uses VideoDB to:
#
# - Upload a chess video and a background music track.
# - Run `understand(vlm)` over time-based visual segments.
# - Detect whether each segment contains a chess move.
# - Extract move timestamps from the structured VLM output.
# - Build a short montage with 5-second clips, transitions, a contrast filter, intro text, and background music.

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q videodb python-dotenv

# %% [markdown]
# ## 2. Connect to VideoDB
#
# Enter your VideoDB API key when prompted.
#
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import os
import time
from getpass import getpass

from IPython.display import display
from videodb import MediaType, connect, play_stream

os.environ["VIDEO_DB_API_KEY"] = getpass("Please enter your VideoDB API Key: ")

conn = connect()
coll = conn.get_collection()

print("Connected to VideoDB successfully.")
# Out:
# Please enter your VideoDB API Key: ··········
# Connected to VideoDB successfully.

# %% [markdown]
# ## 3. Upload Assets
#
# We need the chess match video and an energetic background music track.

# %%
chess_video = coll.upload(url="https://www.youtube.com/watch?v=dhDe-RcoyAU")
print("Chess video uploaded:", chess_video.id)

bg_music = coll.upload(
    url="https://www.youtube.com/watch?v=S19UcWdOA-I",
    media_type=MediaType.audio,
)
print("Background music uploaded:", bg_music.id)
# Out:
# Chess video uploaded: m-z-019f3b40-27d8-7302-a6a3-c6744a26dee5
# Background music uploaded: a-z-019f3b40-a831-7241-978c-c57f32c284e4

# %% [markdown]
# ### Preview the Chess Video

# %%
display(play_stream(chess_video.generate_stream()))
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/908edd1c-66f8-49da-9d5f-b6363b7eb7e7.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 4. Detect Chess Moves with `understand(vlm)`
#
# The original notebook used legacy scene indexing with a binary prompt. Here, we use `understand(vlm)` with the same idea, but ask for structured fields so the timestamps can be extracted directly.
#
# Each 8-second segment is classified as `player_moved` or `no_move`.

# %%
move_detection_prompt = """Look at this chess scene and focus on the chess board.
Detect whether a player moves a chess piece during this segment.

Classify move_status as exactly one of these values:
- player_moved: a chess piece is clearly moved during the segment
- no_move: no chess piece movement is visible, the position is static, people are talking, or the board is not clear

Be strict. Only use player_moved when a move is visible.
Also provide a short visual_description explaining what you saw.
"""

move_understanding = chess_video.understand(
    segmentation={
        "type": "time",
        "seconds": 8,
    },
    analyzers=[
        {
            "type": "vlm",
            "name": "move_detection",
            "sampling": {
                "strategy": "uniform",
                "frame_count": 5,
            },
            "config": {
                "model": "pro",
                "prompt": move_detection_prompt,
                "schema": {
                    "move_status": "string",
                    "visual_description": "string",
                },
            },
        }
    ],
)

move_understanding.wait_until_complete(timeout=3600, poll_interval=15)
move_output = move_understanding.get_analyzer("move_detection").get_output()
move_scenes = move_output.get("scenes", [])

print("Move understanding status:", move_understanding.status)
print("Analyzed segments:", len(move_scenes))
# Out:
# Move understanding status: done
# Analyzed segments: 117

# %% [markdown]
# ## 5. Preview Move Detection Results
#
# Inspect the structured VLM output before creating the montage. For your own videos, tune the prompt, segment length, or frame count here.

# %%
def scene_value(scene, field, default=""):
    data = scene.get("data", {}) or {}
    return scene.get(field) or data.get(field) or default


def normalize_move_status(value):
    normalized = str(value or "").strip().lower().replace(" ", "_").replace("-", "_")

    if normalized in {"player_moved", "moved", "move"}:
        return "player_moved"

    return "no_move"


move_records = []
for scene in move_scenes:
    start = float(scene.get("start", 0))
    end = float(scene.get("end", start))
    move_status = normalize_move_status(scene_value(scene, "move_status"))
    visual_description = str(scene_value(scene, "visual_description")).strip()

    if end <= start:
        continue

    move_records.append(
        {
            "start": start,
            "end": end,
            "move_status": move_status,
            "visual_description": visual_description,
        }
    )

print("Move records:", len(move_records))
print("Detected move segments:", sum(1 for record in move_records if record["move_status"] == "player_moved"))

for record in move_records[:10]:
    print(f"{record['start']:.1f}s - {record['end']:.1f}s | {record['move_status']}")
    print(record["visual_description"])
    print("----")
# Out:
# Move records: 117
# Detected move segments: 85
# 0.0s - 8.0s | player_moved
# Both players approach the board and in the last frames you can see hands on the pieces — the player on the right reaching toward the board and adjusting/placing a piece (a visible piece manipulation/move).
# ----
# 8.0s - 16.0s | player_moved
# Hands of both players are actively moving pieces on the board — the right-side player pushes a black pawn forward while the left-side player also lifts/adjusts a white piece. Movement of pieces is clearly visible across the frames.
# ----
# 16.0s - 24.0s | player_moved
# The player on the left reaches over the board and clearly lifts and places a white piece (pawn) forward — hand movement and piece placement are visible across the frames.
# ----
# 24.0s - 32.0s | no_move
# No visible piece movement. Both players are sitting and thinking with hands near their faces; all pieces remain on their starting squares and the board position is unchanged.
# ----
# ...

# %% [markdown]
# ## 6. Extract Highlight Timestamps
#
# Because `understand(vlm)` produced structured labels, we can extract move timestamps deterministically instead of asking another LLM to parse a scene index.
#
# To keep the final montage short, we sample evenly across the detected moves.

# %%
move_timestamps = [
    record["start"]
    for record in move_records
    if record["move_status"] == "player_moved"
]

TARGET_CLIPS = 10
CLIP_DURATION = 5
INTRO_DURATION = 3

if not move_timestamps:
    raise RuntimeError("No chess moves were detected. Try increasing frame_count or adjusting the prompt.")

step = max(1, len(move_timestamps) // TARGET_CLIPS)
sampled_timestamps = move_timestamps[::step][:TARGET_CLIPS]
total_duration = INTRO_DURATION + (len(sampled_timestamps) * CLIP_DURATION)

print("Detected move timestamps:", len(move_timestamps))
print("Sampled montage timestamps:", sampled_timestamps)
print("Montage duration:", total_duration, "seconds")
# Out:
# Detected move timestamps: 85
# Sampled montage timestamps: [0.0, 80.0, 144.0, 240.0, 304.0, 400.0, 480.0, 584.0, 664.0, 752.0]
# Montage duration: 53 seconds

# %% [markdown]
# ## 7. Build the Timeline
#
# Now we create an intro card, add 5-second chess clips, apply a contrast filter and fade transitions, and add background music.

# %%
from videodb.editor import (
    Alignment,
    AudioAsset,
    Background,
    Clip,
    Filter,
    Font,
    HorizontalAlignment,
    TextAlignment,
    TextAsset,
    Timeline,
    Track,
    Transition,
    VerticalAlignment,
    VideoAsset,
)

timeline = Timeline(conn)
timeline.background = "#000000"

intro_text = TextAsset(
    text="Let the Match Begin",
    font=Font(family="Clear Sans", size=56, color="#FFFFFF"),
    background=Background(
        width=640,
        height=130,
        color="#000000",
        border_width=2.0,
        text_alignment=TextAlignment.center,
    ),
    alignment=Alignment(
        horizontal=HorizontalAlignment.center,
        vertical=VerticalAlignment.center,
    ),
)

intro_track = Track()
intro_track.add_clip(
    0,
    Clip(
        asset=intro_text,
        duration=INTRO_DURATION,
        transition=Transition(in_="fade", out="fade", duration=0.5),
    ),
)
timeline.add_track(intro_track)

video_track = Track()
timeline_position = INTRO_DURATION

for index, start_time in enumerate(sampled_timestamps, start=1):
    source_start = max(0, float(start_time) - 1)

    clip = Clip(
        asset=VideoAsset(
            id=chess_video.id,
            start=source_start,
            volume=0,
        ),
        duration=CLIP_DURATION,
        filter=Filter.contrast,
        transition=Transition(in_="fade", out="fade", duration=1),
    )

    video_track.add_clip(timeline_position, clip)
    print(f"Clip {index}: source {source_start:.1f}s -> timeline {timeline_position:.1f}s")
    timeline_position += CLIP_DURATION

timeline.add_track(video_track)

music_clip = Clip(
    asset=AudioAsset(
        id=bg_music.id,
        start=0,
        volume=0.7,
    ),
    duration=total_duration,
)

audio_track = Track()
audio_track.add_clip(0, music_clip)
timeline.add_track(audio_track)

print("Added clips:", len(sampled_timestamps))
print("Final montage duration:", total_duration, "seconds")
# Out:
# Clip 1: source 0.0s -> timeline 3.0s
# Clip 2: source 79.0s -> timeline 8.0s
# Clip 3: source 143.0s -> timeline 13.0s
# Clip 4: source 239.0s -> timeline 18.0s
# Clip 5: source 303.0s -> timeline 23.0s
# Clip 6: source 399.0s -> timeline 28.0s
# Clip 7: source 479.0s -> timeline 33.0s
# Clip 8: source 583.0s -> timeline 38.0s
# Clip 9: source 663.0s -> timeline 43.0s
# Clip 10: source 751.0s -> timeline 48.0s
# Added clips: 10
# Final montage duration: 53 seconds

# %% [markdown]
# ## 8. Generate and Play the Montage

# %%
montage_stream = timeline.generate_stream()
display(play_stream(montage_stream))
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/3450ba1f-6d26-454c-b1f0-7a838ac9a7a3.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## What We Built
#
# The final output is a short chess highlight reel assembled from automatically detected move moments.
#
# Key techniques:
#
# - Structured VLM understanding for binary move detection.
# - Direct timestamp extraction from analyzer output.
# - Even sampling to keep the montage concise.
# - Timeline editing with text, video clips, filters, transitions, and background music.
#
# Further resources:
#
# - Understanding Artifacts: https://docs.videodb.io/pages/understand/
# - Timeline Editing: https://docs.videodb.io/
