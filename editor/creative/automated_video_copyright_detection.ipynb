# %% [markdown]
# # 🔍 AI-Assisted Video Copyright Review - Complete Cookbook
#
# **Protect your video content by screening for visually similar reuse candidates**
#
# Manually checking every new upload or submission against a rights-controlled video catalog does not scale. This notebook creates timestamped visual descriptions, retrieves semantically similar moments, and generates side-by-side clips for copyright review.
#
# Semantic relevance is a triage signal—not proof of copying, ownership, licensing status, infringement, or grounds for an automated takedown.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/video-db/videodb-cookbook/blob/main/editor/creative/automated_video_copyright_detection.ipynb)
#
# ---
#
# ## 📋 What You'll Build
#
# ✅ Create semantic indexes from rights-controlled portfolio descriptions
# ✅ Screen a video for visually similar reuse candidates
# ✅ Generate side-by-side comparison clips for human review
# ✅ Group temporally adjacent candidates as review context
# ✅ Create copyright-review reports with retrieval relevance scores
#
# **Time to complete:** 30-45 minutes
# **Difficulty:** Intermediate
# **Cost:** Free tier available (50 videos)
#
# ---
#
# ## 🎯 Use Cases
#
# - **YouTube Creators**: Screen possible reuploads against original footage
# - **Production Companies**: Triage potential reuse of rights-controlled footage
# - **Brand Agencies**: Review candidate uses of campaign assets
# - **Stock Platforms**: Screen submissions against authorized reference videos
#
# ---
#
# ## 📚 Table of Contents
#
# 1. Setup & Installation
# 2. Understanding the System
# 3. Part 1: Index Your Portfolio
# 4. Part 2: Screen a Video for Potential Reuse
# 5. Generate a Copyright Review Package
# 6. Next Steps

# %% [markdown]
# ---
#
# # 📦 1. Setup & Installation
#
# First, let's install all required packages and set up authentication.

# %%
# Install required packages
# !pip install -q videodb
# !pip install -q numpy pandas scikit-learn matplotlib seaborn tqdm ipywidgets

print("✅ All packages installed successfully!")
# Out:
# ✅ All packages installed successfully!

# %%
# Import libraries
import videodb
from videodb import connect
from videodb.editor import Timeline, Track, Clip, VideoAsset, Position, Fit

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from typing import List, Dict, Tuple, Optional
from dataclasses import dataclass, asdict
import json
from tqdm.auto import tqdm
import warnings
warnings.filterwarnings('ignore')
import os
from getpass import getpass

# Set style for plots
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %% [markdown]
# ## 🔑 Authentication
#
# Get your free API key from [VideoDB Console](https://console.videodb.io/)
#
# **Free Tier:** 50 video uploads, no credit card required

# %%
api_key = getpass("Enter your VideoDB API Key: ")
os.environ["VIDEO_DB_API_KEY"] = api_key

conn = connect()
collection = conn.get_collection()
print("✅ Connected to VideoDB successfully!")
print(f"📁 Collection ID: {collection.id}")
# Out:
# Enter your VideoDB API Key: ··········
# ✅ Connected to VideoDB successfully!
# 📁 Collection ID: c-cf94b46d-c82f-4db3-ad69-c3c22889a2a6

# %% [markdown]
# ---
#
# # 🧠 2. Understanding the System
#
# Manually comparing every upload against a large reference catalog is slow. This workflow narrows that catalog to timestamped candidates that a rights holder can review for provenance, authorization, and licensing context.
#
# ## How It Works
#
# ```
# YOUR VIDEO PORTFOLIO
#         │
#         ▼
# UNDERSTAND + SEMANTIC INDEX
# • Segment visual scenes
# • Generate visual descriptions (VLM)
# • Build semantic retrieval for descriptions
#         │
#         ▼
# PORTFOLIO RETRIEVAL INDEXES
# • Timestamped visual descriptions
#
# VIDEO TO SCREEN FOR POSSIBLE REUSE
#         │
#         ▼
# VISUAL UNDERSTANDING
# • Generate timestamped descriptions
#         │
#         ▼
# SEMANTIC CANDIDATE RETRIEVAL
# • Rank visually similar portfolio moments
# • Group adjacent candidates for review
#         │
#         ▼
# COPYRIGHT REVIEW CANDIDATES
# • High-relevance candidates
# • Sequential candidate groups
# • Side-by-side comparison clips
# ```
#
# The sample-first search and portfolio expansion below prioritize review candidates; they are not an exhaustive detector.
#
# ## Key Concepts
#
# ### 1. Visual Understanding and Indexing
# VideoDB uses shot-based segmentation and a Vision Language Model (VLM) to create timestamped visual descriptions. A semantic index makes those descriptions retrievable across the portfolio.
#
# ### 2. Retrieval Relevance Scores
# Semantic search ranks candidate moments by retrieval relevance. A configurable cutoff such as `0.70` helps prioritize review; it is not a probability, identity measurement, or legal conclusion.
#
# ### 3. Sequential Candidate Grouping
# Multiple temporally adjacent candidates from the same portfolio video provide stronger review context than isolated candidates. Human review remains necessary before any policy, rights, or legal action.

# %% [markdown]
# ---
#
# # 🎬 3. Part 1: Index Your Portfolio
#
# Let's build the core system to index reference videos you own or are authorized to review.

# %% [markdown]
# ## 📚 Portfolio Indexer Class
#
# This class handles uploading and indexing your video portfolio.

# %%
from typing import Optional, Dict, Tuple, List

class PortfolioIndexer:
    """Creates reusable visual indexes for a portfolio."""

    DEFAULT_SCENE_PROMPT = (
        "Describe the visual content in detail: "
        "people, objects, actions, setting, colors, composition, "
        "camera angle, lighting, and any visible text or logos."
    )
    ANALYZER_NAME = "portfolio_scene"
    INDEX_NAME = "portfolio_visual"

    def __init__(self, collection):
        self.collection = collection
        self.portfolio_db = []

    def _wait_for_ready_index(self, index):
        index.wait_until_complete()
        return index

    def _get_or_create_visual_index(self, video, threshold: int):
        index_name = f"{self.INDEX_NAME}_{video.id}"

        existing_index = next(
            (
                index
                for index in video.list_indexes()
                if index.name == index_name
            ),
            None,
        )

        if existing_index is not None:
            print(f"  ♻️ Reusing index: {existing_index.index_id}")
            return self._wait_for_ready_index(existing_index)

        print("  🔍 Creating visual understanding...")
        understanding = video.understand(
            segmentation={"type": "shot", "threshold": threshold},
            analyzers=[
                {
                    "type": "vlm",
                    "name": self.ANALYZER_NAME,
                    "config": {
                        "prompt": self.DEFAULT_SCENE_PROMPT,
                        "schema": {"description": "string"},
                    },
                },
            ],
        )
        understanding.wait_until_complete()

        scene_analyzer = understanding.get_analyzer(self.ANALYZER_NAME)

        scene_index = video.index(
            name=index_name,
            source=scene_analyzer,
            use_for=["semantic"],
            fields={"semantic": ["description"]},
        )
        return self._wait_for_ready_index(scene_index)

    def index_existing_video(self, video, metadata: Optional[Dict] = None, threshold: int = 20) -> Tuple:
        scene_index = self._get_or_create_visual_index(video, threshold)
        self.portfolio_db.append(
            {
                "video_id": video.id,
                "video_name": video.name,
                "index_id": scene_index.index_id,
                "upload_date": datetime.now().isoformat(),
                "custom_metadata": metadata or {},
            }
        )
        return video, scene_index.index_id

    def upload_and_index_video(self, video_path: str, metadata: Optional[Dict] = None, threshold: int = 20) -> Tuple:
        print(f"📤 Uploading: {video_path}")
        video = self.collection.upload(url=video_path)
        print(f"  ✅ Uploaded: {video.name} (ID: {video.id})")
        return self.index_existing_video(video, metadata, threshold)

    def batch_index_portfolio(self, video_urls: List[str]) -> List[Dict]:
        results = []
        for _, url in enumerate(tqdm(video_urls, desc="Indexing portfolio"), 1):
            try:
                video, index_id = self.upload_and_index_video(url)
                results.append({"status": "success", "url": url, "video_id": video.id, "index_id": index_id})
            except Exception as e:
                print(f"  ❌ Error: {e}")
                results.append({"status": "failed", "url": url, "error": str(e)})
        return results

    def save_portfolio(self, filename: str = "portfolio_index.json"):
        with open(filename, "w") as f:
            json.dump(self.portfolio_db, f, indent=2)
        print(f"💾 Portfolio saved: {len(self.portfolio_db)} videos")

    def load_portfolio(self, filename: str = "portfolio_index.json"):
        with open(filename, "r") as f:
            self.portfolio_db = json.load(f)
        print(f"📂 Loaded: {len(self.portfolio_db)} videos")

    def get_stats(self) -> Dict:
        if not self.portfolio_db:
            return {"total_videos": 0, "videos": []}
        return {"total_videos": len(self.portfolio_db), "videos": [item["video_name"] for item in self.portfolio_db]}

print("✅ PortfolioIndexer ready")
# Out:
# ✅ PortfolioIndexer ready

# %% [markdown]
# ## 🎥 Index Your Videos
#
# Now let's index your video portfolio. Replace these URLs with your actual videos.

# %%
# Initialize indexer
indexer = PortfolioIndexer(collection)

# Define a reference portfolio of videos you own or are authorized to review.
# Replace these demonstration URLs with your authorized reference videos.
my_videos = [
    "https://www.youtube.com/watch?v=dQw4w9WgXcQ",  # Example video 1
    # Add more videos here:
    "https://youtu.be/tNI57rl_Xoo?si=MP9O8n_XcdynSIh4",
    "https://youtu.be/RoN2LO5E-QA?si=5GrtNUHL5cWw5UZ0",
]

print(f"📚 Portfolio size: {len(my_videos)} videos")
print("\n⚠️  Note: Indexing takes ~5-10 minutes per hour of video")
# Out:
# 📚 Portfolio size: 3 videos
#
# ⚠️  Note: Indexing takes ~5-10 minutes per hour of video

# %%
# ========================================
# IMPORT EXISTING VIDEOS
# ========================================

print("🔍 Checking for existing videos in your VideoDB collection...\n")
all_videos = collection.get_videos()
print(f"📦 Total videos in collection: {len(all_videos)}")
print(f"📚 Videos in portfolio index: {len(indexer.portfolio_db)}")

missing_videos = [
    video for video in all_videos
    if not any(item["video_id"] == video.id for item in indexer.portfolio_db)
]

if missing_videos:
    print(f"\n⚠️ Found {len(missing_videos)} videos not in the portfolio:\n")
    for idx, video in enumerate(missing_videos, 1):
        print(f"  {idx}. {video.name}")
        print(f"     ID: {video.id}\n")

    # Keep this True only when every collection video is an authorized reference.
    import_all = True
    if import_all:
        print("\n🔄 Importing existing videos...\n")
        for video in tqdm(missing_videos, desc="Processing videos"):
            try:
                print(f"📹 {video.name}")
                _, index_id = indexer.index_existing_video(video, metadata={"imported_from_existing": True})
                print(f"  ✅ Added index: {index_id}\n")
            except Exception as e:
                print(f"  ❌ Error: {e}\n")
        indexer.save_portfolio()
        print(f"\n✅ Portfolio updated: {len(indexer.portfolio_db)} videos")
    else:
        print("\n💡 Set import_all = True above to import these videos")
else:
    print("\n✅ All collection videos are already in the portfolio!")
# Out:
# 🔍 Checking for existing videos in your VideoDB collection...
#
# 📦 Total videos in collection: 4
# 📚 Videos in portfolio index: 0
#
# ⚠️ Found 4 videos not in the portfolio:
#
#   1. The BEST of Phil Dunphy (Mashup) | Modern Family | TBS
#      ID: m-z-019f9031-6b27-73c2-906d-5b03eaca281a
#
#   2. Brooklyn Nine-Nine having world class writing for 23 minutes straight
#      ID: m-z-019f902a-31b5-7b60-9d3c-571870e1b6a2
#
#   3. Rick Astley - Never Gonna Give You Up (Official Video) (4K Remaster)
#      ID: m-z-019f9027-0a86-7c81-8993-8e4d7ea9cb61
#
#   4. TinyFish Head of Product Presentation @ AI+ Renaissance Conference 2026
#      ID: m-z-019f8aa1-67a7-7bd2-b6fa-c8c30dfec7ce
#
#
# 🔄 Importing existing videos...
# Processing videos:   0%|          | 0/4 [00:00<?, ?it/s]
# 📹 The BEST of Phil Dunphy (Mashup) | Modern Family | TBS
#   🔍 Creating visual understanding...
#   ✅ Added index: e7bd76e42b564936
#
# 📹 Brooklyn Nine-Nine having world class writing for 23 minutes straight
# ...

# %%
# Run the indexing

results = indexer.batch_index_portfolio(my_videos)

# Show results
print("\n" + "="*70)
print("INDEXING RESULTS")
print("="*70)

success_count = sum(1 for r in results if r['status'] == 'success')
failed_count = sum(1 for r in results if r['status'] == 'failed')

print(f"✅ Successful: {success_count}")
print(f"❌ Failed: {failed_count}")

# Save portfolio
indexer.save_portfolio()
# Out:
# Indexing portfolio:   0%|          | 0/3 [00:00<?, ?it/s]
# 📤 Uploading: https://www.youtube.com/watch?v=dQw4w9WgXcQ
#   ✅ Uploaded: Rick Astley - Never Gonna Give You Up (Official Video) (4K Remaster) (ID: m-z-019f907e-3cc0-71f1-9613-51378f4536a5)
#   🔍 Creating visual understanding...
# 📤 Uploading: https://youtu.be/tNI57rl_Xoo?si=MP9O8n_XcdynSIh4
#   ✅ Uploaded: Brooklyn Nine-Nine having world class writing for 23 minutes straight (ID: m-z-019f9081-fa24-7621-9c52-93dfced6c76c)
#   🔍 Creating visual understanding...
# 📤 Uploading: https://youtu.be/RoN2LO5E-QA?si=5GrtNUHL5cWw5UZ0
#   ✅ Uploaded: The BEST of Phil Dunphy (Mashup) | Modern Family | TBS (ID: m-z-019f9089-fd67-77f0-9020-e1b183a204d3)
#   🔍 Creating visual understanding...
#
# ...
# INDEXING RESULTS
# ...
# ✅ Successful: 3
# ❌ Failed: 0
# 💾 Portfolio saved: 7 videos

# %%
# View portfolio statistics
stats = indexer.get_stats()

print("📊 Portfolio Statistics")
print("="*50)
print(f"Total Videos: {stats['total_videos']}")
print("\nVideos in Portfolio:")
for idx, name in enumerate(stats['videos'], 1):
    print(f"  {idx}. {name}")
# Out:
# 📊 Portfolio Statistics
# ...
# Total Videos: 7
#
# Videos in Portfolio:
#   1. The BEST of Phil Dunphy (Mashup) | Modern Family | TBS
#   2. Brooklyn Nine-Nine having world class writing for 23 minutes straight
#   3. Rick Astley - Never Gonna Give You Up (Official Video) (4K Remaster)
#   4. TinyFish Head of Product Presentation @ AI+ Renaissance Conference 2026
#   5. Rick Astley - Never Gonna Give You Up (Official Video) (4K Remaster)
#   6. Brooklyn Nine-Nine having world class writing for 23 minutes straight
#   7. The BEST of Phil Dunphy (Mashup) | Modern Family | TBS

# %% [markdown]
# ---
#
# # 🔎 4. Part 2: Screen a Video for Potential Reuse
#
# Compare a suspected reupload or submission against the rights-controlled portfolio and prioritize candidate moments for copyright review.

# %%
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
from typing import List, Dict
import math

class VisualSimilarityReviewer:
    """Retrieves visual similarity candidates for human review."""

    MATCH_COLUMNS = [
        "suspect_video_id", "suspect_scene_start", "suspect_scene_end",
        "suspect_description", "portfolio_video_id", "portfolio_video_name",
        "portfolio_scene_start", "portfolio_scene_end", "similarity_score",
    ]

    def __init__(self, collection, portfolio_db: List[Dict]):
        self.collection = collection
        self.portfolio = portfolio_db
        self.portfolio_by_video_id = {item["video_id"]: item for item in self.portfolio}
        print(f"Loaded portfolio: {len(self.portfolio)} videos")

    def _artifact_scenes(self, analyzer) -> List[Dict]:
        output = analyzer.get_output()
        artifacts = []
        for scene in output["scenes"]:
            scene_data = scene.get("data", {})
            description = scene_data.get("description")
            # Only include scenes that have a valid, non-empty string description
            if description and isinstance(description, str) and description.strip():
                artifacts.append({
                    "start": scene["start"],
                    "end": scene["end"],
                    "description": description,
                })
        return artifacts

    def review(self, suspect_video, suspect_analyzer, sample_size: int = 30, relevance_threshold: float = 0.70, auto_expand: bool = True) -> Dict:
        print("=" * 70)
        print("VISUAL SIMILARITY REVIEW")
        print("=" * 70)
        suspect_scenes_all = self._artifact_scenes(suspect_analyzer)
        total_scenes = len(suspect_scenes_all)
        print(f"\nVideo under review: {suspect_video.name}")
        print(f"Visual scenes: {total_scenes}")
        sample_indices = self._get_distributed_sample(total_scenes, sample_size)
        sample_matches = self._compare_scenes_batch(
            suspect_video.id,
            [suspect_scenes_all[index] for index in sample_indices],
            self.portfolio,
        )
        high_similarity_sample = sample_matches[sample_matches["similarity_score"] >= relevance_threshold]
        if high_similarity_sample.empty:
            return {
                "review_required": False,
                "matches": sample_matches,
                "high_similarity_only": high_similarity_sample,
                "summary": "No candidates met the configured relevance cutoff.",
            }

        top_portfolio_id = high_similarity_sample["portfolio_video_id"].value_counts().index[0]
        top_portfolio_item = self.portfolio_by_video_id[top_portfolio_id]
        if not auto_expand:
            return {
                "review_required": True,
                "review_priority": "medium",
                "top_match": top_portfolio_item["video_name"],
                "matches": sample_matches,
                "high_similarity_only": high_similarity_sample,
                "summary": f"Found {len(high_similarity_sample)} candidates above the cutoff.",
            }

        full_matches = self._compare_scenes_batch(suspect_video.id, suspect_scenes_all, [top_portfolio_item])
        high_similarity_full = full_matches[full_matches["similarity_score"] >= relevance_threshold]
        sequences = self._detect_sequences(high_similarity_full)
        return {
            "review_required": True,
            "review_priority": "high" if sequences else "medium",
            "top_match": top_portfolio_item["video_name"],
            "total_matches": len(full_matches),
            "high_similarity_matches": len(high_similarity_full),
            "sequential_segments": len(sequences),
            "matches": full_matches,
            "high_similarity_only": high_similarity_full,
            "sequences": sequences,
            "summary": f"Found {len(high_similarity_full)} candidates above the cutoff with {top_portfolio_item['video_name']}.",
        }

    def _get_distributed_sample(self, total: int, sample_size: int) -> List[int]:
        if total <= sample_size:
            return list(range(total))
        step = total / sample_size
        return [int(index * step) for index in range(sample_size)]

    def _compare_scenes_batch(self, suspect_video_id: str, suspect_scenes: List[Dict], portfolio_items: List[Dict], max_results_per_scene: int = 1) -> pd.DataFrame:
        all_matches = []
        portfolio_by_video_id = {item["video_id"]: item for item in portfolio_items}
        portfolio_index_ids = list(dict.fromkeys(item["index_id"] for item in portfolio_items))
        for suspect_scene in tqdm(suspect_scenes, desc="Comparing"):
            results = self.collection.semantic_search(
                query=suspect_scene["description"],
                index_ids=portfolio_index_ids,
                top_k=max_results_per_scene,
            )
            for shot in results.get_shots()[:max_results_per_scene]:
                portfolio_item = portfolio_by_video_id.get(shot.video_id)
                score = shot.search_score
                if (
                    portfolio_item is None
                    or not isinstance(score, (int, float)) or isinstance(score, bool)
                    or not math.isfinite(score)
                    or not isinstance(shot.start, (int, float)) or isinstance(shot.start, bool)
                    or not math.isfinite(shot.start)
                    or not isinstance(shot.end, (int, float)) or isinstance(shot.end, bool)
                    or not math.isfinite(shot.end)
                    or shot.end <= shot.start
                ):
                    continue
                all_matches.append(
                    {
                        "suspect_video_id": suspect_video_id,
                        "suspect_scene_start": suspect_scene["start"],
                        "suspect_scene_end": suspect_scene["end"],
                        "suspect_description": suspect_scene["description"][:150],
                        "portfolio_video_id": shot.video_id,
                        "portfolio_video_name": portfolio_item["video_name"],
                        "portfolio_scene_start": shot.start,
                        "portfolio_scene_end": shot.end,
                        "similarity_score": float(score),
                    }
                )
        return pd.DataFrame(all_matches, columns=self.MATCH_COLUMNS)

    def _detect_sequences(self, matches_df: pd.DataFrame, max_gap: float = 10.0, min_length: int = 3) -> List[Dict]:
        if matches_df.empty:
            return []
        sequences = []
        for portfolio_video_id, group in matches_df.groupby("portfolio_video_id"):
            ordered = group.sort_values(["suspect_scene_start", "portfolio_scene_start"])
            current_sequence = []
            for _, row in ordered.iterrows():
                candidate = row.to_dict()
                if not current_sequence:
                    current_sequence = [candidate]
                    continue
                previous = current_sequence[-1]
                suspect_moves_forward = candidate["suspect_scene_start"] > previous["suspect_scene_start"]
                portfolio_moves_forward = candidate["portfolio_scene_start"] > previous["portfolio_scene_start"]
                suspect_gap = candidate["suspect_scene_start"] - previous["suspect_scene_end"]
                portfolio_gap = candidate["portfolio_scene_start"] - previous["portfolio_scene_end"]
                if (
                    suspect_moves_forward
                    and portfolio_moves_forward
                    and 0 <= suspect_gap
                    and suspect_gap <= max_gap
                    and 0 <= portfolio_gap
                    and portfolio_gap <= max_gap
                ):
                    current_sequence.append(candidate)
                else:
                    if len(current_sequence) >= min_length:
                        sequences.append(self._sequence_summary(portfolio_video_id, current_sequence))
                    current_sequence = [candidate]
            if len(current_sequence) >= min_length:
                sequences.append(self._sequence_summary(portfolio_video_id, current_sequence))
        return sorted(sequences, key=lambda item: item["avg_score"], reverse=True)

    def _sequence_summary(self, portfolio_video_id: str, sequence: List[Dict]) -> Dict:
        return {
            "portfolio_video_id": portfolio_video_id,
            "portfolio_video_name": sequence[0]["portfolio_video_name"],
            "num_scenes": len(sequence),
            "duration": sequence[-1]["suspect_scene_end"] - sequence[0]["suspect_scene_start"],
            "avg_score": np.mean([item["similarity_score"] for item in sequence]),
            "start": sequence[0]["suspect_scene_start"],
            "end": sequence[-1]["suspect_scene_end"],
            "portfolio_start": sequence[0]["portfolio_scene_start"],
            "portfolio_end": sequence[-1]["portfolio_scene_end"],
        }

    def generate_report(self, result: Dict) -> None:
        print("\n" + "=" * 70)
        print("VISUAL SIMILARITY REVIEW REPORT")
        print("=" * 70)
        if result["review_required"]:
            print("\nREVIEW: HIGH-SIMILARITY CANDIDATES FOUND")
            print("Semantic relevance scores rank candidates; they do not establish copying, ownership, infringement, or a legal conclusion.")
            print(f"Review priority: {result.get('review_priority', 'medium')}")
            if "top_match" in result:
                print(f"\nTop portfolio candidate: {result['top_match']}")
            if "total_matches" in result:
                print("\nStatistics:")
                print(f"  Retrieved candidates: {result['total_matches']}")
                print(f"  Above cutoff: {result['high_similarity_matches']}")
                print(f"  Sequential candidate groups: {result['sequential_segments']}")
            if result.get("sequences"):
                print("\nSequential Candidate Groups:")
                for index, sequence in enumerate(result["sequences"][:5], 1):
                    print(f"  {index}. {sequence['num_scenes']} adjacent scenes from {sequence['portfolio_video_name']}")
                    print(f"     Duration: {sequence['duration']:.1f}s")
                    print(f"     Avg relevance: {sequence['avg_score']:.3f}")
                    print(f"     Suspect time: {sequence['start']:.1f}s - {sequence['end']:.1f}s")
            candidates = result.get("high_similarity_only")
            if candidates is not None and not candidates.empty:
                print("\nTop Individual Candidates:")
                try:
                    from IPython.display import display
                    display(candidates.nlargest(10, "similarity_score")[["portfolio_video_name", "similarity_score", "suspect_scene_start", "portfolio_scene_start"]])
                except ImportError:
                    print("  (Install IPython.display for full candidate display functionality)")
                    print(candidates.nlargest(10, "similarity_score")[["portfolio_video_name", "similarity_score", "suspect_scene_start", "portfolio_scene_start"]])
        else:
            print("\nNo candidates met the configured relevance cutoff.")
            print(f"\n{result.get('summary', 'Review other search settings if needed.')}")
        print("=" * 70)

print("VisualSimilarityReviewer ready")
# Out:
# VisualSimilarityReviewer ready

# %% [markdown]
# ## 🔍 Run Copyright Similarity Screening
#
# Screen a video against the selected portfolio indexes. The result identifies review candidates; it does not determine plagiarism or infringement.

# %%
# Initialize the similarity reviewer with your portfolio
similarity_reviewer = VisualSimilarityReviewer(collection, indexer.portfolio_db)

# Enter video URL
suspect_url = "https://youtu.be/jKBRCloTK4w?si=QKTg1nAZdE7zkmm9"

print(f"🔎 Video under review: {suspect_url}")
# Out:
# Loaded portfolio: 7 videos
# 🔎 Video under review: https://youtu.be/jKBRCloTK4w?si=QKTg1nAZdE7zkmm9

# %%
# Upload the video to review
print(f"🔎 Uploading video for review: {suspect_url}")
suspect_video = collection.upload(url=suspect_url)
print(f"✅ Uploaded: {suspect_video.name}")
# Out:
# 🔎 Uploading video for review: https://youtu.be/jKBRCloTK4w?si=QKTg1nAZdE7zkmm9
# ✅ Uploaded: Phil Dunphy's Best Moments

# %% [markdown]
# ### 🧠 Create a Visual Artifact
#
# Analyze the uploaded video before comparing it with the reference portfolio.

# %%
print("🔍 Creating visual understanding...")
suspect_understanding = suspect_video.understand(
    segmentation={"type": "shot", "threshold": 20},
    analyzers=[
        {
            "type": "vlm",
            "name": PortfolioIndexer.ANALYZER_NAME,
            "config": {
                "prompt": PortfolioIndexer.DEFAULT_SCENE_PROMPT,
                "schema": {"description": "string"},
            },
        },
    ],
)
suspect_understanding.wait_until_complete()
suspect_analyzer = suspect_understanding.get_analyzer(PortfolioIndexer.ANALYZER_NAME)
print("✅ Visual artifact is ready")
# Out:
# 🔍 Creating visual understanding...
# ✅ Visual artifact is ready

# %%
# Run visual similarity review
result = similarity_reviewer.review(
    suspect_video=suspect_video,
    suspect_analyzer=suspect_analyzer,
    sample_size=30,
    relevance_threshold=0.70,
    auto_expand=True,
)

# Show the review summary
similarity_reviewer.generate_report(result)
# Out:
# ...
# VISUAL SIMILARITY REVIEW
# ...
#
# Video under review: Phil Dunphy's Best Moments
# Visual scenes: 166
# ...
# Comparing:   0%|          | 0/166 [00:00<?, ?it/s]
# ...
# VISUAL SIMILARITY REVIEW REPORT
# ...
#
# REVIEW: HIGH-SIMILARITY CANDIDATES FOUND
# Semantic relevance scores rank candidates; they do not establish copying, ownership, infringement, or a legal conclusion.
# Review priority: medium
#
# Top portfolio candidate: Brooklyn Nine-Nine having world class writing for 23 minutes straight
#
# Statistics:
#   Retrieved candidates: 166
#   Above cutoff: 86
#   Sequential candidate groups: 0
#
# Top Individual Candidates:
#                                   portfolio_video_name  similarity_score  \
# 19   Brooklyn Nine-Nine having world class writing ...          0.836268
# 5    Brooklyn Nine-Nine having world class writing ...          0.831331
# 43   Brooklyn Nine-Nine having world class writing ...          0.826281
# 11   Brooklyn Nine-Nine having world class writing ...          0.825795
# ...

# %% [markdown]
# ## 📋 Generate a Copyright Review Package

# %%
# Generate side-by-side review clips
evidence_clips = []

if result["review_required"] and "high_similarity_only" in result and not result["high_similarity_only"].empty:
    print("🎬 Generating Review Clips")
    print("="*70)

    from videodb.editor import Timeline, Track, Clip, VideoAsset, Position, Fit

    high_similarity = result["high_similarity_only"]
    num_clips = min(5, len(high_similarity))

    for idx, (_, match) in enumerate(high_similarity.head(num_clips).iterrows(), 1):
        print(f"\nClip {idx}/{num_clips}:")
        print(f"  Relevance: {match['similarity_score']:.3f}")

        try:
            # Calculate duration
            duration = min(
                match['portfolio_scene_end'] - match['portfolio_scene_start'],
                match['suspect_scene_end'] - match['suspect_scene_start']
            )

            # Create timeline
            timeline = Timeline(conn)

            # Create assets
            portfolio_asset = VideoAsset(
                id=match['portfolio_video_id'],
                start=match['portfolio_scene_start']
            )

            suspect_asset = VideoAsset(
                id=match['suspect_video_id'],
                start=match['suspect_scene_start']
            )

            # Create clips
            left_clip = Clip(
                asset=portfolio_asset,
                duration=duration,
                position=Position.left,
                fit=Fit.crop,
                scale=0.5
            )

            right_clip = Clip(
                asset=suspect_asset,
                duration=duration,
                position=Position.right,
                fit=Fit.crop,
                scale=0.5
            )

            # Add to timeline
            track = Track()
            track.add_clip(start=0, clip=left_clip)
            track.add_clip(start=0, clip=right_clip)  # Both start at 0 to play simultaneously
            timeline.add_track(track)

            # Generate stream
            stream_url = timeline.generate_stream()

            evidence_clips.append({
                "clip_number": idx,
                "url": stream_url,
                "similarity": match['similarity_score']
            })

            print(f"  ✅ Generated: {stream_url}")

        except Exception as e:
            print(f"  ❌ Error: {e}")
            import traceback
            traceback.print_exc()

    if evidence_clips:
        print(f"\n✅ Generated {len(evidence_clips)} review clips")
        print("\n📋 Review URLs:")
        for clip in evidence_clips:
            print(f"  {clip['clip_number']}. Score: {clip['similarity']:.3f}")
            print(f"     {clip['url']}")
    else:
        print("\n❌ No clips generated")
else:
    print("No high-similarity candidates met the configured cutoff")
# Out:
# 🎬 Generating Review Clips
# ...
#
# Clip 1/5:
#   Relevance: 0.701
#   ✅ Generated: https://play.videodb.io/v1/451038a7-a43e-4d22-9d85-ef5d975597b0.m3u8
#
# Clip 2/5:
#   Relevance: 0.726
#   ✅ Generated: https://play.videodb.io/v1/73e99443-16a8-4da7-9ecf-c5ef7c0a5120.m3u8
#
# Clip 3/5:
#   Relevance: 0.719
#   ✅ Generated: https://play.videodb.io/v1/e4ff06dc-3086-49f8-8971-3e17964688d3.m3u8
#
# Clip 4/5:
#   Relevance: 0.831
#   ✅ Generated: https://play.videodb.io/v1/27440deb-225d-44c0-bd16-20f28cf73af6.m3u8
#
# Clip 5/5:
#   Relevance: 0.818
#   ✅ Generated: https://play.videodb.io/v1/7238d3fd-74ac-4d33-be11-15d65ea8a448.m3u8
#
# ✅ Generated 5 review clips
#
# 📋 Review URLs:
#   1. Score: 0.701
#      https://play.videodb.io/v1/451038a7-a43e-4d22-9d85-ef5d975597b0.m3u8
#   2. Score: 0.726
#      https://play.videodb.io/v1/73e99443-16a8-4da7-9ecf-c5ef7c0a5120.m3u8
#   3. Score: 0.719
#      https://play.videodb.io/v1/e4ff06dc-3086-49f8-8971-3e17964688d3.m3u8
#   4. Score: 0.831
# ...

# %% [markdown]
# ### Preview a comparison clip

# %%
from videodb import play_stream

print("Playing the first evidence clip:")
play_stream(evidence_clips[0]["url"])
# Out:
# Playing the first evidence clip:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://play.videodb.io/v1/451038a7-a43e-4d22-9d85-ef5d975597b0.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---
#
# # 🎯 5. Next Steps
#
# ## 🎓 What You Learned
#
# ✅ How to build a rights-controlled reference portfolio with visual understanding and semantic indexes
# ✅ How to screen a new video for potential reuse candidates
# ✅ How to rank candidate moments with timestamps and relevance scores
# ✅ How to group adjacent candidates as copyright-review context
# ✅ How to generate side-by-side clips for human review
#
# ## 🚀 Take It Further
#
# 1. **Scale Up**: Index your entire video portfolio
# 2. **Automate**: Schedule submission screening against authorized references
# 3. **Integrate**: Route candidate packages to an internal rights-review queue
# 4. **Enrich**: Add provenance and license metadata for reviewers
# 5. **Customize**: Tune the relevance cutoff for your review process
#
#
# ## 💬 Get Help
#
# - **Discord**: [discord.gg/py9P639jGz](https://discord.gg/py9P639jGz)
# - **Email**: support@videodb.io
# - **Docs**: [VideoDB documentation](https://videodb-docs-indexing-search-v2.mintlify.site/)
#
# ## 🎉 You're Done!
#
# **Congratulations!** You've built an AI-assisted copyright-review workflow.
#
# Review candidates carefully: semantic similarity does not establish copying, ownership, licensing status, infringement, or a legal remedy.
#
# ---
#
# **Built with ❤️ using VideoDB**
