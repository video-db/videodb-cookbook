# %% [markdown]
# # Automated Video Copyright Detection with VideoDB
#
# Build a visual plagiarism detector that can compare a suspect video against protected content and generate a side-by-side evidence clip.
#
# This notebook uses VideoDB to:
#
# - Upload a protected portfolio video and a suspect video.
# - Run `understand(vlm)` to create structured visual fingerprints.
# - Index the protected video's visual artifact with `video.index()`.
# - Compare suspect segments against the protected index with `semantic_search()`.
# - Identify high-confidence and sequential matches.
# - Generate a side-by-side evidence clip for review or a takedown workflow.
#
# For a deterministic cookbook demo, the suspect URL is set to the same sample video as the protected asset. Replace it with an external reupload or modified copy in your own workflow.

# %% [markdown]
# ## 1. Install Dependencies

# %%
# !pip install -q videodb python-dotenv pandas

# %% [markdown]
# ## 2. Connect to VideoDB
#
# Enter your VideoDB API key when prompted.
#
# Enter your VideoDB API key when prompted. You can get one from the [VideoDB Console](https://console.videodb.io). Get $20 free credits. **No credit card needed**.

# %%
import os
import time
from getpass import getpass
from uuid import uuid4

import pandas as pd
from IPython.display import display
from videodb import connect, play_stream

os.environ["VIDEO_DB_API_KEY"] = getpass("Please enter your VideoDB API Key: ")

conn = connect()
coll = conn.get_collection()

print("Connected to VideoDB successfully.")
# Out:
# Please enter your VideoDB API Key: ··········
# Connected to VideoDB successfully.

# %% [markdown]
# ## 3. Upload Protected and Suspect Videos
#
# The protected video represents content you own. The suspect video represents a reupload or derivative that you want to check.
#
# For this demo, both URLs use the same sample video so the notebook produces a clear positive match.

# %%
protected_url = "https://www.youtube.com/watch?v=libKVRa01L8"
suspect_url = protected_url

protected_video = coll.upload(url=protected_url)
suspect_video = coll.upload(url=suspect_url)

print("Protected video ID:", protected_video.id)
print("Suspect video ID:", suspect_video.id)
# Out:
# Protected video ID: m-z-019f3b5d-6ab1-7dc0-88a3-80f49a60c09e
# Suspect video ID: m-z-019f3b5d-f048-7341-b477-acbb9cf4152d

# %% [markdown]
# ### Preview the Protected Video

# %%
display(play_stream(protected_video.generate_stream()))
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/a4be95eb-28c7-4602-a204-8f6b28c70116.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 4. Create Visual Fingerprints with `understand(vlm)`
#
# The VLM analyzer creates searchable visual fingerprints for each segment. The prompt asks for concrete visual details that tend to survive trims, captions, and light edits.

# %%
fingerprint_prompt = """Describe this video segment for visual copyright matching.
Focus on persistent visual evidence: setting, objects, people, diagrams, overlays, text, logos, camera composition, color palette, and notable actions.
Return concise but specific fields that can be used for semantic similarity search.
"""

fingerprint_analyzer = {
    "type": "vlm",
    "name": "visual_fingerprint",
    "sampling": {
        "strategy": "uniform",
        "frame_count": 3,
    },
    "config": {
        "model": "pro",
        "prompt": fingerprint_prompt,
        "schema": {
            "scene_description": "string",
            "visual_fingerprint": "string",
            "visible_text": "string",
            "visual_topic": "string",
        },
    },
}

def understand_visual_fingerprints(video, label):
    understanding = video.understand(
        segmentation={
            "type": "time",
            "seconds": 10,
        },
        analyzers=[fingerprint_analyzer],
    )

    understanding.wait_until_complete(timeout=3600, poll_interval=15)
    output = understanding.get_analyzer("visual_fingerprint").get_output()
    scenes = output.get("scenes", [])

    print(f"{label} understanding status:", output.get("status"))
    print(f"{label} visual segments:", len(scenes))

    return output


protected_output = understand_visual_fingerprints(protected_video, "Protected")
suspect_output = understand_visual_fingerprints(suspect_video, "Suspect")
# Out:
# Protected understanding status: done
# Protected visual segments: 26
# Suspect understanding status: done
# Suspect visual segments: 26

# %% [markdown]
# ## 5. Preview Visual Fingerprints
#
# Inspect a few records before indexing. If your own videos include logos, captions, or repeated branded layouts, make sure those details appear in the output.

# %%
def scene_data(scene):
    return scene.get("data", {}) or {}


for scene in protected_output.get("scenes", [])[:5]:
    data = scene_data(scene)
    print(f"{scene.get('start'):.2f}s - {scene.get('end'):.2f}s")
    print("Topic:", data.get("visual_topic", ""))
    print("Description:", data.get("scene_description", "")[:400])
    print("Visible text:", data.get("visible_text", ""))
    print("----")
# Out:
# 0.00s - 10.00s
# Topic: Branded astronomy title card / educational sequence (Science 101) with National Geographic yellow rectangle logo
# Description: Night-sky setting: dense starfield and vertical Milky Way band (purple/pink nebula tones) fills full frame. Persistent lower-third black translucent title bar spans full width, left-aligned label 'SCIENCE' in large white sans-serif, center '101' in bold yellow, right 'THE SOLAR SYSTEM' in smaller white. Small category words above bar: 'ANATOMY', 'SPACE', 'DISCOVERIES' separated by thin tick marks.
# Visible text: SCIENCE 101 | THE SOLAR SYSTEM
# ANATOMY   SPACE   DISCOVERIES
# ONE OF OVER 500
# OUR SOLAR SYSTEM
# ONE OF OVER 500 IN THE MILKY WAY GALAXY
# ----
# 10.00s - 20.00s
# Topic: Exterior space view from International Space Station — Milky Way starfield with Earth limb and ISS structure
# ...

# %% [markdown]
# ## 6. Index the Protected Video
#
# Create a searchable index from the protected video's visual artifact. We use a unique index name so repeated notebook runs do not collide.

# %%
PROTECTED_INDEX_NAME = f"copyright_protected_{uuid4().hex[:8]}"
INDEX_READY_STATUSES = {"ready", "done"}
INDEX_ACTIVE_STATUSES = {"building", "processing"}


def wait_until_index_ready(video, index, timeout=1800, poll_interval=10):
    deadline = time.time() + timeout
    latest_index = index

    while time.time() < deadline:
        status = getattr(latest_index, "status", None)

        if status in INDEX_READY_STATUSES:
            return latest_index

        if status and status not in INDEX_ACTIVE_STATUSES:
            raise RuntimeError(f"Index build ended with status: {status}")

        time.sleep(poll_interval)

        try:
            latest_index = video.get_index(index_id=index.index_id)
        except Exception as exc:
            if "not found" in str(exc).lower():
                continue
            raise

    raise TimeoutError(f"Index was not ready within {timeout} seconds.")


protected_index = protected_video.index(
    name=PROTECTED_INDEX_NAME,
    source=protected_output,
    use_for=["semantic", "query"],
    fields={
        "semantic": ["scene_description", "visual_fingerprint", "visible_text", "visual_topic"],
        "text": ["scene_description", "visual_fingerprint", "visible_text", "visual_topic"],
        "filter": ["visual_topic"],
    },
)

protected_index = wait_until_index_ready(protected_video, protected_index)

print("Protected index name:", PROTECTED_INDEX_NAME)
print("Protected index ID:", protected_index.index_id)
print("Protected index status:", protected_index.status)
# Out:
# Protected index name: copyright_protected_bdf717c5
# Protected index ID: e19bb94c338144ea
# Protected index status: ready

# %% [markdown]
# ## 7. Compare Suspect Segments Against the Protected Index
#
# For each suspect segment, we search the protected visual index using the suspect segment's fingerprint text. High-scoring matches are possible copyright-review candidates.

# %%
def get_shot_score(shot):
    for attr in ("search_score", "score"):
        value = getattr(shot, attr, None)
        if value is not None:
            return float(value)

    metadata = getattr(shot, "metadata", {}) or {}
    for key in ("search_score", "score"):
        if metadata.get(key) is not None:
            return float(metadata[key])

    return 0.0


def get_scene_data_for_time(output, start, end):
    for scene in output.get("scenes", []):
        same_start = abs(float(scene.get("start", -1)) - float(start)) < 0.01
        same_end = abs(float(scene.get("end", -1)) - float(end)) < 0.01

        if same_start and same_end:
            return scene_data(scene)

    return {}


def segment_search_text(scene):
    data = scene_data(scene)
    parts = [
        data.get("scene_description", ""),
        data.get("visual_fingerprint", ""),
        data.get("visible_text", ""),
        data.get("visual_topic", ""),
    ]
    return " ".join(str(part).strip() for part in parts if str(part).strip())


def compare_suspect_to_protected(suspect_output, similarity_threshold=0.60, top_k=1):
    matches = []

    for suspect_scene in suspect_output.get("scenes", []):
        query_text = segment_search_text(suspect_scene)
        if not query_text:
            continue

        results = protected_video.semantic_search(
            query=query_text,
            index_names=[PROTECTED_INDEX_NAME],
            top_k=top_k,
            return_fields=["scene_description", "visual_fingerprint", "visible_text", "visual_topic"],
        )

        for shot in results.shots:
            score = get_shot_score(shot)
            protected_data = get_scene_data_for_time(protected_output, shot.start, shot.end)

            matches.append(
                {
                    "suspect_start": float(suspect_scene.get("start", 0)),
                    "suspect_end": float(suspect_scene.get("end", 0)),
                    "protected_start": float(shot.start),
                    "protected_end": float(shot.end),
                    "similarity_score": score,
                    "protected_topic": protected_data.get("visual_topic", ""),
                    "protected_description": protected_data.get("scene_description", ""),
                }
            )

    matches_df = pd.DataFrame(matches)
    if matches_df.empty:
        return matches_df, matches_df

    high_confidence_df = matches_df[matches_df["similarity_score"] >= similarity_threshold].copy()
    high_confidence_df = high_confidence_df.sort_values("similarity_score", ascending=False)

    return matches_df, high_confidence_df


matches_df, high_confidence_df = compare_suspect_to_protected(
    suspect_output,
    similarity_threshold=0.60,
    top_k=1,
)

print("Compared suspect segments:", len(suspect_output.get("scenes", [])))
print("Total matches returned:", len(matches_df))
print("High-confidence matches:", len(high_confidence_df))

if not high_confidence_df.empty:
    display(
        high_confidence_df[
            ["similarity_score", "suspect_start", "protected_start", "protected_topic"]
        ].head(10)
    )
# Out:
# Compared suspect segments: 26
# Total matches returned: 26
# High-confidence matches: 26
#     similarity_score  suspect_start  protected_start  \
# 3           0.936333           30.0             30.0
# 4           0.923619           40.0             40.0
# 16          0.893695          160.0            160.0
# 14          0.876127          140.0             40.0
# 22          0.870158          220.0            220.0
# 10          0.859988          100.0            100.0
# 5           0.858246           50.0             40.0
# 11          0.857515          110.0             50.0
# 8           0.855254           80.0             80.0
# 25          0.854915          250.0            250.0
#
#                                       protected_topic
# 3   Illustrated Milky Way infographic with text ov...
# 4   Solar system infographic — labeled eight plane...
# 16  Animated planetary diagram focusing on Uranus ...
# 14  Solar system infographic — labeled eight plane...
# ...

# %% [markdown]
# ## 8. Detect Sequential Matches
#
# Single matching segments can be coincidental. Consecutive matching segments are stronger evidence because the same sequence appears across both videos.

# %%
def detect_sequences(matches, max_gap=12.0, min_segments=2):
    if matches.empty:
        return []

    sorted_matches = matches.sort_values("suspect_start")
    sequences = []
    current = []

    for _, row in sorted_matches.iterrows():
        item = row.to_dict()

        if not current:
            current = [item]
            continue

        suspect_gap = item["suspect_start"] - current[-1]["suspect_end"]
        protected_gap = item["protected_start"] - current[-1]["protected_end"]

        if abs(suspect_gap) <= max_gap and abs(protected_gap) <= max_gap:
            current.append(item)
        else:
            if len(current) >= min_segments:
                sequences.append(current)
            current = [item]

    if len(current) >= min_segments:
        sequences.append(current)

    summaries = []
    for sequence in sequences:
        summaries.append(
            {
                "segments": len(sequence),
                "suspect_start": sequence[0]["suspect_start"],
                "suspect_end": sequence[-1]["suspect_end"],
                "protected_start": sequence[0]["protected_start"],
                "protected_end": sequence[-1]["protected_end"],
                "avg_score": sum(item["similarity_score"] for item in sequence) / len(sequence),
            }
        )

    return sorted(summaries, key=lambda item: item["avg_score"], reverse=True)


sequences = detect_sequences(high_confidence_df)

print("Sequential matching regions:", len(sequences))
for index, sequence in enumerate(sequences[:5], start=1):
    print(f"{index}. {sequence['segments']} matching segments, avg score {sequence['avg_score']:.3f}")
    print(f"   Suspect: {sequence['suspect_start']:.1f}s - {sequence['suspect_end']:.1f}s")
    print(f"   Protected: {sequence['protected_start']:.1f}s - {sequence['protected_end']:.1f}s")
# Out:
# Sequential matching regions: 4
# 1. 6 matching segments, avg score 0.843
#    Suspect: 0.0s - 60.0s
#    Protected: 10.0s - 50.0s
# 2. 4 matching segments, avg score 0.821
#    Suspect: 70.0s - 110.0s
#    Protected: 70.0s - 110.0s
# 3. 5 matching segments, avg score 0.812
#    Suspect: 190.0s - 240.0s
#    Protected: 190.0s - 240.0s
# 4. 2 matching segments, avg score 0.796
#    Suspect: 150.0s - 170.0s
#    Protected: 150.0s - 170.0s

# %% [markdown]
# ## 9. Generate a Copyright Review Report

# %%
plagiarism_detected = not high_confidence_df.empty
confidence = "HIGH" if sequences else "MEDIUM" if plagiarism_detected else "LOW"

print("COPYRIGHT DETECTION REPORT")
print("=" * 70)
print("Protected video:", protected_video.name)
print("Suspect video:", suspect_video.name)
print("Verdict:", "POTENTIAL MATCH FOUND" if plagiarism_detected else "NO MATCH FOUND")
print("Confidence:", confidence)
print("High-confidence matches:", len(high_confidence_df))
print("Sequential regions:", len(sequences))

if plagiarism_detected:
    top_match = high_confidence_df.iloc[0]
    print("Top match score:", f"{top_match['similarity_score']:.3f}")
    print("Top suspect timestamp:", f"{top_match['suspect_start']:.1f}s - {top_match['suspect_end']:.1f}s")
    print("Top protected timestamp:", f"{top_match['protected_start']:.1f}s - {top_match['protected_end']:.1f}s")
    print("Review note: verify rights ownership and context before taking enforcement action.")
# Out:
# COPYRIGHT DETECTION REPORT
# ...
# Protected video: Solar System 101 | National Geographic
# Suspect video: Solar System 101 | National Geographic
# Verdict: POTENTIAL MATCH FOUND
# Confidence: HIGH
# High-confidence matches: 26
# Sequential regions: 4
# Top match score: 0.936
# Top suspect timestamp: 30.0s - 40.0s
# Top protected timestamp: 30.0s - 40.0s
# Review note: verify rights ownership and context before taking enforcement action.

# %% [markdown]
# ## 10. Create and Play a Side-by-Side Evidence Clip
#
# The evidence clip places the protected segment and suspect segment side by side for human review.

# %%
from videodb.editor import Clip, Fit, Position, Timeline, Track, VideoAsset

if high_confidence_df.empty:
    print("No high-confidence match is available for evidence generation.")
else:
    evidence_match = high_confidence_df.iloc[0]
    evidence_duration = min(
        8.0,
        evidence_match["protected_end"] - evidence_match["protected_start"],
        evidence_match["suspect_end"] - evidence_match["suspect_start"],
    )
    evidence_duration = max(2.0, float(evidence_duration))

    timeline = Timeline(conn)
    comparison_track = Track()

    protected_clip = Clip(
        asset=VideoAsset(
            id=protected_video.id,
            start=max(0.0, evidence_match["protected_start"]),
            volume=0,
        ),
        duration=evidence_duration,
        position=Position.left,
        fit=Fit.crop,
        scale=0.5,
    )

    suspect_clip = Clip(
        asset=VideoAsset(
            id=suspect_video.id,
            start=max(0.0, evidence_match["suspect_start"]),
            volume=0,
        ),
        duration=evidence_duration,
        position=Position.right,
        fit=Fit.crop,
        scale=0.5,
    )

    comparison_track.add_clip(0, protected_clip)
    comparison_track.add_clip(0, suspect_clip)
    timeline.add_track(comparison_track)

    evidence_stream = timeline.generate_stream()
    print("Evidence clip score:", f"{evidence_match['similarity_score']:.3f}")
    display(play_stream(evidence_stream))
# Out:
# Evidence clip score: 0.936
#         <iframe
#             width="800"
#             height="400"
#             src="https://console.videodb.io/player?url=https://d1zudc7ewmc6ey.cloudfront.net/v1/75ca8d4e-411f-43ab-b567-c834ea884895.m3u8"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## What We Built
#
# You built an automated visual copyright-review workflow with the new VideoDB indexing pipeline.
#
# Key techniques:
#
# - `understand(vlm)` creates structured visual fingerprints.
# - `video.index()` makes protected content searchable.
# - `semantic_search()` compares suspect visual fingerprints against protected content.
# - Sequential-match analysis helps separate strong evidence from isolated similar shots.
# - The editor timeline creates a side-by-side evidence clip for human review.
#
# Further resources:
#
# - Understanding Artifacts: https://docs.videodb.io/pages/understand/
# - Create an Index: https://docs.videodb.io/pages/understand/indexing-pipelines/create-an-index
# - Search and Retrieval: https://docs.videodb.io/pages/understand/search-and-retrieval/natural-language-query
# - Timeline Editing: https://docs.videodb.io/
